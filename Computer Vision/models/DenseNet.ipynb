# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/DenseNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %% [markdown]
# # DenseNet

# %% [markdown]
# ## The stem component

# %%
def stem(inputs, n_filters):
  """ Build the stem component of the DenseNet
      inputs   : represents the input tensor
      n_filters: number of filters for the dense blocks (k)
  """
  # pad the input from 224x224 to 230x230
  x = keras.layers.ZeroPadding2D(padding=((3, 3), (3, 3)))(inputs)

  # first large convolution for abstract features for input 224 x 224 and output 112 x 112
  # the stem convolution uses 2 * k (growth rate) number of filters
  x = keras.layers.Conv2D(filters=2 * n_filters, kernel_size=7, strides=2, use_bias=False, kernel_initializer='he_normal')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # add padding so when downsampling we fit shape 56 x 56
  x = keras.layers.ZeroPadding2D(padding=((1, 1), (1, 1)))(x)
  x = keras.layers.MaxPooling2D((3, 3), strides=2)(x)

  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### The Transition Block

# %%
def trans_block(x, reduction):
  """ Build a transition block
      x        : input layer
      reduction: percentage of reduction of feature maps
  """

  # calculate the number of filters
  # we reduce (compress) the number of feature maps (DenseNet-C)
  # 'shape[n]' returns a class object. We use int() to cast it into the dimension size
  n_filters = int( int(x.shape[3]) * reduction)

  # a 1x1 linear projection convolution
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=1, strides=1, use_bias=False, kernel_initializer='he_normal')(x)

  # we use mean value (average) instead of max value sampling when pooling reduce by 75%
  x = keras.layers.AveragePooling2D(pool_size=2, strides=2)(x)

  return x

# %% [markdown]
# ### The Dense Block

# %%
def dense_block(x, n_filters):
  """ Build a densely connected residual block
      x        : input to the block
      n_filters: number of filters in convolution layer in residual block
  """
  # save the input tensor into residual block
  shortcut = x

  # a 1x1 conv layer for dimensionality expansion, expand filters by 4 (DenseNet-B)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  x = keras.layers.Conv2D(filters=4 * n_filters, kernel_size=1, strides=1, use_bias=False, kernel_initializer='he_normal')(x)

  # our bottleneck convolution
  # a 3x3 convolution with padding=same to preserve same shape of feature maps
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=3, strides=1, padding='same', use_bias=False, kernel_initializer='he_normal')(x)

  # concatenate the input (identity) with the output of the residual block
  # concatenation (vs. merging) provides Feature Reuse between layers
  x = keras.layers.Concatenate()([shortcut, x])


  return x

# %% [markdown]
# ### The DenseNet Group

# %%
def group(x, n_blocks, n_filters, reduction=None):
  """ Build a dense group.
      x         : input to the group
      n_blocks  : number of residual blocks in dense block
      n_filters : number of filters in convolution layer in residual block
      reduction : amount to reduce feature maps by
  """
  # we construct a group of densely connected residual blocks
  for _ in range(n_blocks):
    x = dense_block(x, n_filters)

  # we construct interceding transition block
  if reduction is not None:
    x = trans_block(x, reduction)

  return x

# %% [markdown]
# ### Putting it all together

# %%
def learner(x, groups, n_filters, reduction):
  """ Build the learner component of the DenseNet
      x         : input to the learner
      groups    : set of number of blocks per group
      n_filters : number of filters (growth rate)
      reduction : the amount to reduce (compress) feature maps by
  """
  # pop off the list the last dense block
  last = groups.pop()

  # we create the dense groups and interceding transition blocks
  for n_blocks in groups:
    x = group(x, n_blocks, n_filters, reduction)

  # we add the last dense group w/o a following transition block
  x = group(x, last, n_filters)

  return x

# %% [markdown]
# ## The task component

# %%
def task(x, n_classes):
  """ Build the task component of DenseNet.
      x         : input to the classifier
      n_classes : number of output classes
  """

  # Global Average Pooling will flatten the 7x7 feature maps into 1D feature maps
  x = keras.layers.GlobalAveragePooling2D()(x)
  # Fully connected output layer (classification)
  x = keras.layers.Dense(units=n_classes, activation='softmax', kernel_initializer='he_normal')(x)

  return x

# %% [markdown]
# ## DenseNet model

# %%
# Meta-parameter: amount to reduce feature maps by (compression factor) during transition blocks
reduction = 0.5

# Meta-parameter: number of filters in a convolution block within a residual block (growth rate)
n_filters = 32

# Meta-parameter: number of residual blocks in each dense group
groups = { 121 : [6, 12, 24, 16],	# DenseNet 121
           169 : [6, 12, 32, 32],	# DenseNet 169
           201 : [6, 12, 48, 32] }	# DenseNet 201

# %%
def build_densenet(groups, shape=(224, 224, 3), reduction = 0.5, n_filters = 32, classes=1000):
  # the input vector
  inputs = keras.Input(shape=shape)
  # stem component
  x = stem(inputs, n_filters)
  # the learner component
  x = learner(x, groups[121], n_filters, reduction)
  # the task component
  outputs = task(x, classes)

  # return the modle
  return keras.Model(inputs=inputs, outputs=outputs, name="DenseNet")

# %%
# create the DenseNet model
densenet_model = build_densenet(groups)

# print a summary of our DenseNet model
densenet_model.summary()
# Out:
# Model: "DenseNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_2 (ZeroPadd  (None, 230, 230, 3)          0         ['input_3[0][0]']
#  ing2D)
#
#  conv2d_120 (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d_2[0][0]']
#
#  batch_normalization_120 (B  (None, 112, 112, 64)         256       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  re_lu_117 (ReLU)            (None, 112, 112, 64)         0         ['batch_normalization_120[0][0
#                                                                     ]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 114, 114, 64)         0         ['re_lu_117[0][0]']
#  ing2D)
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 64)           0         ['zero_padding2d_3[0][0]']
#  g2D)
#
#  batch_normalization_121 (B  (None, 56, 56, 64)           256       ['max_pooling2d_1[0][0]']
#  atchNormalization)
#
#  re_lu_118 (ReLU)            (None, 56, 56, 64)           0         ['batch_normalization_121[0][0
#                                                                     ]']
#
#  conv2d_121 (Conv2D)         (None, 56, 56, 128)          8192      ['re_lu_118[0][0]']
#
#  batch_normalization_122 (B  (None, 56, 56, 128)          512       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  re_lu_119 (ReLU)            (None, 56, 56, 128)          0         ['batch_normalization_122[0][0
#                                                                     ]']
#
#  conv2d_122 (Conv2D)         (None, 56, 56, 32)           36864     ['re_lu_119[0][0]']
#
#  concatenate_58 (Concatenat  (None, 56, 56, 96)           0         ['max_pooling2d_1[0][0]',
#  e)                                                                  'conv2d_122[0][0]']
#
#  batch_normalization_123 (B  (None, 56, 56, 96)           384       ['concatenate_58[0][0]']
#  atchNormalization)
#
#  re_lu_120 (ReLU)            (None, 56, 56, 96)           0         ['batch_normalization_123[0][0
#                                                                     ]']
#
#  conv2d_123 (Conv2D)         (None, 56, 56, 128)          12288     ['re_lu_120[0][0]']
#
#  batch_normalization_124 (B  (None, 56, 56, 128)          512       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  re_lu_121 (ReLU)            (None, 56, 56, 128)          0         ['batch_normalization_124[0][0
#                                                                     ]']
#
#  conv2d_124 (Conv2D)         (None, 56, 56, 32)           36864     ['re_lu_121[0][0]']
#
#  concatenate_59 (Concatenat  (None, 56, 56, 128)          0         ['concatenate_58[0][0]',
#  e)                                                                  'conv2d_124[0][0]']
#
#  batch_normalization_125 (B  (None, 56, 56, 128)          512       ['concatenate_59[0][0]']
#  atchNormalization)
#
#  re_lu_122 (ReLU)            (None, 56, 56, 128)          0         ['batch_normalization_125[0][0
#                                                                     ]']
#
#  conv2d_125 (Conv2D)         (None, 56, 56, 128)          16384     ['re_lu_122[0][0]']
#
#  batch_normalization_126 (B  (None, 56, 56, 128)          512       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  re_lu_123 (ReLU)            (None, 56, 56, 128)          0         ['batch_normalization_126[0][0
#                                                                     ]']
#
#  conv2d_126 (Conv2D)         (None, 56, 56, 32)           36864     ['re_lu_123[0][0]']
#
#  concatenate_60 (Concatenat  (None, 56, 56, 160)          0         ['concatenate_59[0][0]',
#  e)                                                                  'conv2d_126[0][0]']
#
#  batch_normalization_127 (B  (None, 56, 56, 160)          640       ['concatenate_60[0][0]']
#  atchNormalization)
#
#  re_lu_124 (ReLU)            (None, 56, 56, 160)          0         ['batch_normalization_127[0][0
#                                                                     ]']
#
#  conv2d_127 (Conv2D)         (None, 56, 56, 128)          20480     ['re_lu_124[0][0]']
#
#  batch_normalization_128 (B  (None, 56, 56, 128)          512       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  re_lu_125 (ReLU)            (None, 56, 56, 128)          0         ['batch_normalization_128[0][0
#                                                                     ]']
#
#  conv2d_128 (Conv2D)         (None, 56, 56, 32)           36864     ['re_lu_125[0][0]']
#
#  concatenate_61 (Concatenat  (None, 56, 56, 192)          0         ['concatenate_60[0][0]',
#  e)                                                                  'conv2d_128[0][0]']
#
#  batch_normalization_129 (B  (None, 56, 56, 192)          768       ['concatenate_61[0][0]']
#  atchNormalization)
#
#  re_lu_126 (ReLU)            (None, 56, 56, 192)          0         ['batch_normalization_129[0][0
#                                                                     ]']
#
#  conv2d_129 (Conv2D)         (None, 56, 56, 128)          24576     ['re_lu_126[0][0]']
#
#  batch_normalization_130 (B  (None, 56, 56, 128)          512       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  re_lu_127 (ReLU)            (None, 56, 56, 128)          0         ['batch_normalization_130[0][0
#                                                                     ]']
#
#  conv2d_130 (Conv2D)         (None, 56, 56, 32)           36864     ['re_lu_127[0][0]']
#
#  concatenate_62 (Concatenat  (None, 56, 56, 224)          0         ['concatenate_61[0][0]',
#  e)                                                                  'conv2d_130[0][0]']
#
#  batch_normalization_131 (B  (None, 56, 56, 224)          896       ['concatenate_62[0][0]']
#  atchNormalization)
#
#  re_lu_128 (ReLU)            (None, 56, 56, 224)          0         ['batch_normalization_131[0][0
#                                                                     ]']
#
#  conv2d_131 (Conv2D)         (None, 56, 56, 128)          28672     ['re_lu_128[0][0]']
#
#  batch_normalization_132 (B  (None, 56, 56, 128)          512       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  re_lu_129 (ReLU)            (None, 56, 56, 128)          0         ['batch_normalization_132[0][0
#                                                                     ]']
#
#  conv2d_132 (Conv2D)         (None, 56, 56, 32)           36864     ['re_lu_129[0][0]']
#
#  concatenate_63 (Concatenat  (None, 56, 56, 256)          0         ['concatenate_62[0][0]',
#  e)                                                                  'conv2d_132[0][0]']
#
#  batch_normalization_133 (B  (None, 56, 56, 256)          1024      ['concatenate_63[0][0]']
#  atchNormalization)
#
#  conv2d_133 (Conv2D)         (None, 56, 56, 128)          32768     ['batch_normalization_133[0][0
#                                                                     ]']
#
#  average_pooling2d_3 (Avera  (None, 28, 28, 128)          0         ['conv2d_133[0][0]']
#  gePooling2D)
#
#  batch_normalization_134 (B  (None, 28, 28, 128)          512       ['average_pooling2d_3[0][0]']
#  atchNormalization)
#
#  re_lu_130 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_134[0][0
#                                                                     ]']
#
#  conv2d_134 (Conv2D)         (None, 28, 28, 128)          16384     ['re_lu_130[0][0]']
#
#  batch_normalization_135 (B  (None, 28, 28, 128)          512       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  re_lu_131 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_135[0][0
#                                                                     ]']
#
#  conv2d_135 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_131[0][0]']
#
#  concatenate_64 (Concatenat  (None, 28, 28, 160)          0         ['average_pooling2d_3[0][0]',
#  e)                                                                  'conv2d_135[0][0]']
#
#  batch_normalization_136 (B  (None, 28, 28, 160)          640       ['concatenate_64[0][0]']
#  atchNormalization)
#
#  re_lu_132 (ReLU)            (None, 28, 28, 160)          0         ['batch_normalization_136[0][0
#                                                                     ]']
#
#  conv2d_136 (Conv2D)         (None, 28, 28, 128)          20480     ['re_lu_132[0][0]']
#
#  batch_normalization_137 (B  (None, 28, 28, 128)          512       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  re_lu_133 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_137[0][0
#                                                                     ]']
#
#  conv2d_137 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_133[0][0]']
#
#  concatenate_65 (Concatenat  (None, 28, 28, 192)          0         ['concatenate_64[0][0]',
#  e)                                                                  'conv2d_137[0][0]']
#
#  batch_normalization_138 (B  (None, 28, 28, 192)          768       ['concatenate_65[0][0]']
#  atchNormalization)
#
#  re_lu_134 (ReLU)            (None, 28, 28, 192)          0         ['batch_normalization_138[0][0
#                                                                     ]']
#
#  conv2d_138 (Conv2D)         (None, 28, 28, 128)          24576     ['re_lu_134[0][0]']
#
#  batch_normalization_139 (B  (None, 28, 28, 128)          512       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  re_lu_135 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_139[0][0
#                                                                     ]']
#
#  conv2d_139 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_135[0][0]']
#
#  concatenate_66 (Concatenat  (None, 28, 28, 224)          0         ['concatenate_65[0][0]',
#  e)                                                                  'conv2d_139[0][0]']
#
#  batch_normalization_140 (B  (None, 28, 28, 224)          896       ['concatenate_66[0][0]']
#  atchNormalization)
#
#  re_lu_136 (ReLU)            (None, 28, 28, 224)          0         ['batch_normalization_140[0][0
#                                                                     ]']
#
#  conv2d_140 (Conv2D)         (None, 28, 28, 128)          28672     ['re_lu_136[0][0]']
#
#  batch_normalization_141 (B  (None, 28, 28, 128)          512       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  re_lu_137 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_141[0][0
#                                                                     ]']
#
#  conv2d_141 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_137[0][0]']
#
#  concatenate_67 (Concatenat  (None, 28, 28, 256)          0         ['concatenate_66[0][0]',
#  e)                                                                  'conv2d_141[0][0]']
#
#  batch_normalization_142 (B  (None, 28, 28, 256)          1024      ['concatenate_67[0][0]']
#  atchNormalization)
#
#  re_lu_138 (ReLU)            (None, 28, 28, 256)          0         ['batch_normalization_142[0][0
#                                                                     ]']
#
#  conv2d_142 (Conv2D)         (None, 28, 28, 128)          32768     ['re_lu_138[0][0]']
#
#  batch_normalization_143 (B  (None, 28, 28, 128)          512       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  re_lu_139 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_143[0][0
#                                                                     ]']
#
#  conv2d_143 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_139[0][0]']
#
#  concatenate_68 (Concatenat  (None, 28, 28, 288)          0         ['concatenate_67[0][0]',
#  e)                                                                  'conv2d_143[0][0]']
#
#  batch_normalization_144 (B  (None, 28, 28, 288)          1152      ['concatenate_68[0][0]']
#  atchNormalization)
#
#  re_lu_140 (ReLU)            (None, 28, 28, 288)          0         ['batch_normalization_144[0][0
#                                                                     ]']
#
#  conv2d_144 (Conv2D)         (None, 28, 28, 128)          36864     ['re_lu_140[0][0]']
#
#  batch_normalization_145 (B  (None, 28, 28, 128)          512       ['conv2d_144[0][0]']
#  atchNormalization)
#
#  re_lu_141 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_145[0][0
#                                                                     ]']
#
#  conv2d_145 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_141[0][0]']
#
#  concatenate_69 (Concatenat  (None, 28, 28, 320)          0         ['concatenate_68[0][0]',
#  e)                                                                  'conv2d_145[0][0]']
#
#  batch_normalization_146 (B  (None, 28, 28, 320)          1280      ['concatenate_69[0][0]']
#  atchNormalization)
#
#  re_lu_142 (ReLU)            (None, 28, 28, 320)          0         ['batch_normalization_146[0][0
#                                                                     ]']
#
#  conv2d_146 (Conv2D)         (None, 28, 28, 128)          40960     ['re_lu_142[0][0]']
#
#  batch_normalization_147 (B  (None, 28, 28, 128)          512       ['conv2d_146[0][0]']
#  atchNormalization)
#
#  re_lu_143 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_147[0][0
#                                                                     ]']
#
#  conv2d_147 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_143[0][0]']
#
#  concatenate_70 (Concatenat  (None, 28, 28, 352)          0         ['concatenate_69[0][0]',
#  e)                                                                  'conv2d_147[0][0]']
#
#  batch_normalization_148 (B  (None, 28, 28, 352)          1408      ['concatenate_70[0][0]']
#  atchNormalization)
#
#  re_lu_144 (ReLU)            (None, 28, 28, 352)          0         ['batch_normalization_148[0][0
#                                                                     ]']
#
#  conv2d_148 (Conv2D)         (None, 28, 28, 128)          45056     ['re_lu_144[0][0]']
#
#  batch_normalization_149 (B  (None, 28, 28, 128)          512       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  re_lu_145 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_149[0][0
#                                                                     ]']
#
#  conv2d_149 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_145[0][0]']
#
#  concatenate_71 (Concatenat  (None, 28, 28, 384)          0         ['concatenate_70[0][0]',
#  e)                                                                  'conv2d_149[0][0]']
#
#  batch_normalization_150 (B  (None, 28, 28, 384)          1536      ['concatenate_71[0][0]']
#  atchNormalization)
#
#  re_lu_146 (ReLU)            (None, 28, 28, 384)          0         ['batch_normalization_150[0][0
#                                                                     ]']
#
#  conv2d_150 (Conv2D)         (None, 28, 28, 128)          49152     ['re_lu_146[0][0]']
#
#  batch_normalization_151 (B  (None, 28, 28, 128)          512       ['conv2d_150[0][0]']
#  atchNormalization)
#
#  re_lu_147 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_151[0][0
#                                                                     ]']
#
#  conv2d_151 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_147[0][0]']
#
#  concatenate_72 (Concatenat  (None, 28, 28, 416)          0         ['concatenate_71[0][0]',
#  e)                                                                  'conv2d_151[0][0]']
#
#  batch_normalization_152 (B  (None, 28, 28, 416)          1664      ['concatenate_72[0][0]']
#  atchNormalization)
#
#  re_lu_148 (ReLU)            (None, 28, 28, 416)          0         ['batch_normalization_152[0][0
#                                                                     ]']
#
#  conv2d_152 (Conv2D)         (None, 28, 28, 128)          53248     ['re_lu_148[0][0]']
#
#  batch_normalization_153 (B  (None, 28, 28, 128)          512       ['conv2d_152[0][0]']
#  atchNormalization)
#
#  re_lu_149 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_153[0][0
#                                                                     ]']
#
#  conv2d_153 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_149[0][0]']
#
#  concatenate_73 (Concatenat  (None, 28, 28, 448)          0         ['concatenate_72[0][0]',
#  e)                                                                  'conv2d_153[0][0]']
#
#  batch_normalization_154 (B  (None, 28, 28, 448)          1792      ['concatenate_73[0][0]']
#  atchNormalization)
#
#  re_lu_150 (ReLU)            (None, 28, 28, 448)          0         ['batch_normalization_154[0][0
#                                                                     ]']
#
#  conv2d_154 (Conv2D)         (None, 28, 28, 128)          57344     ['re_lu_150[0][0]']
#
#  batch_normalization_155 (B  (None, 28, 28, 128)          512       ['conv2d_154[0][0]']
#  atchNormalization)
#
#  re_lu_151 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_155[0][0
#                                                                     ]']
#
#  conv2d_155 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_151[0][0]']
#
#  concatenate_74 (Concatenat  (None, 28, 28, 480)          0         ['concatenate_73[0][0]',
#  e)                                                                  'conv2d_155[0][0]']
#
#  batch_normalization_156 (B  (None, 28, 28, 480)          1920      ['concatenate_74[0][0]']
#  atchNormalization)
#
#  re_lu_152 (ReLU)            (None, 28, 28, 480)          0         ['batch_normalization_156[0][0
#                                                                     ]']
#
#  conv2d_156 (Conv2D)         (None, 28, 28, 128)          61440     ['re_lu_152[0][0]']
#
#  batch_normalization_157 (B  (None, 28, 28, 128)          512       ['conv2d_156[0][0]']
#  atchNormalization)
#
#  re_lu_153 (ReLU)            (None, 28, 28, 128)          0         ['batch_normalization_157[0][0
#                                                                     ]']
#
#  conv2d_157 (Conv2D)         (None, 28, 28, 32)           36864     ['re_lu_153[0][0]']
#
#  concatenate_75 (Concatenat  (None, 28, 28, 512)          0         ['concatenate_74[0][0]',
#  e)                                                                  'conv2d_157[0][0]']
#
#  batch_normalization_158 (B  (None, 28, 28, 512)          2048      ['concatenate_75[0][0]']
#  atchNormalization)
#
#  conv2d_158 (Conv2D)         (None, 28, 28, 256)          131072    ['batch_normalization_158[0][0
#                                                                     ]']
#
#  average_pooling2d_4 (Avera  (None, 14, 14, 256)          0         ['conv2d_158[0][0]']
#  gePooling2D)
#
#  batch_normalization_159 (B  (None, 14, 14, 256)          1024      ['average_pooling2d_4[0][0]']
#  atchNormalization)
#
#  re_lu_154 (ReLU)            (None, 14, 14, 256)          0         ['batch_normalization_159[0][0
#                                                                     ]']
#
#  conv2d_159 (Conv2D)         (None, 14, 14, 128)          32768     ['re_lu_154[0][0]']
#
#  batch_normalization_160 (B  (None, 14, 14, 128)          512       ['conv2d_159[0][0]']
#  atchNormalization)
#
#  re_lu_155 (ReLU)            (None, 14, 14, 128)          0         ['batch_normalization_160[0][0
#                                                                     ]']
#
#  conv2d_160 (Conv2D)         (None, 14, 14, 32)           36864     ['re_lu_155[0][0]']
#
#  concatenate_76 (Concatenat  (None, 14, 14, 288)          0         ['average_pooling2d_4[0][0]',
#  e)                                                                  'conv2d_160[0][0]']
#
#  batch_normalization_161 (B  (None, 14, 14, 288)          1152      ['concatenate_76[0][0]']
#  atchNormalization)
#
#  re_lu_156 (ReLU)            (None, 14, 14, 288)          0         ['batch_normalization_161[0][0
#                                                                     ]']
#
#  conv2d_161 (Conv2D)         (None, 14, 14, 128)          36864     ['re_lu_156[0][0]']
#
#  batch_normalization_162 (B  (None, 14, 14, 128)          512       ['conv2d_161[0][0]']
#  atchNormalization)
#
#  re_lu_157 (ReLU)            (None, 14, 14, 128)          0         ['batch_normalization_162[0][0
#                                                                     ]']
#
#  conv2d_162 (Conv2D)         (None, 14, 14, 32)           36864     ['re_lu_157[0][0]']
#
#  concatenate_77 (Concatenat  (None, 14, 14, 320)          0         ['concatenate_76[0][0]',
#  e)                                                                  'conv2d_162[0][0]']
#
#  batch_normalization_163 (B  (None, 14, 14, 320)          1280      ['concatenate_77[0][0]']
#  atchNormalization)
#
#  re_lu_158 (ReLU)            (None, 14, 14, 320)          0         ['batch_normalization_163[0][0
#                                                                     ]']
#
#  conv2d_163 (Conv2D)         (None, 14, 14, 128)          40960     ['re_lu_158[0][0]']
#
#  batch_normalization_164 (B  (None, 14, 14, 128)          512       ['conv2d_163[0][0]']
#  atchNormalization)
#
#  re_lu_159 (ReLU)            (None, 14, 14, 128)          0         ['batch_normalization_164[0][0
#                                                                     ]']
#
#  conv2d_164 (Conv2D)         (None, 14, 14, 32)           36864     ['re_lu_159[0][0]']
#
#  concatenate_78 (Concatenat  (None, 14, 14, 352)          0         ['concatenate_77[0][0]',
#  e)                                                                  'conv2d_164[0][0]']
#
#  batch_normalization_165 (B  (None, 14, 14, 352)          1408      ['concatenate_78[0][0]']
#  atchNormalization)
#
#  re_lu_160 (ReLU)            (None, 14, 14, 352)          0         ['batch_normalization_165[0][0
#                                                                     ]']
#
#  conv2d_165 (Conv2D)         (None, 14, 14, 128)          45056     ['re_lu_160[0][0]']
#
#  batch_normalization_166 (B  (None, 14, 14, 128)          512       ['conv2d_165[0][0]']
#  atchNormalization)
#
#  re_lu_161 (ReLU)            (None, 14, 14, 128)          0         ['batch_normalization_166[0][0
#                                                                     ]']
#
#  conv2d_166 (Conv2D)         (None, 14, 14, 32)           36864     ['re_lu_161[0][0]']
#
#  concatenate_79 (Concatenat  (None, 14, 14, 384)          0         ['concatenate_78[0][0]',
#  e)                                                                  'conv2d_166[0][0]']
#
#  batch_normalization_167 (B  (None, 14, 14, 384)          1536      ['concatenate_79[0][0]']
#  atchNormalization)
#
#  re_lu_162 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_167[0][0
#                                                                     ]']
#
#  conv2d_167 (Conv2D)         (None, 14, 14, 128)          49152     ['re_lu_162[0][0]']
#
#  batch_normalization_168 (B  (None, 14, 14, 128)          512       ['conv2d_167[0][0]']
#  atchNormalization)
#
#  re_lu_163 (ReLU)            (None, 14, 14, 128)          0         ['batch_normalization_168[0][0
#                                                                     ]']
#
#  conv2d_168 (Conv2D)         (None, 14, 14, 32)           36864     ['re_lu_163[0][0]']
#
#  concatenate_80 (Concatenat  (None, 14, 14, 416)          0         ['concatenate_79[0][0]',
#  e)                                                                  'conv2d_168[0][0]']
#
#  batch_normalization_169 (B  (None, 14, 14, 416)          1664      ['concatenate_80[0][0]']
#  atchNormalization)
#
#  re_lu_164 (ReLU)            (None, 14, 14, 416)          0         ['batch_normalization_169[0][0
#                                                                     ]']
#
#  conv2d_169 (Conv2D)         (None, 14, 14, 128)          53248     ['re_lu_164[0][0]']
# ...
#  batch_normalization_224 (B  (None, 7, 7, 768)            3072      ['concatenate_107[0][0]']
#  atchNormalization)
#
#  re_lu_218 (ReLU)            (None, 7, 7, 768)            0         ['batch_normalization_224[0][0
#                                                                     ]']
#
#  conv2d_224 (Conv2D)         (None, 7, 7, 128)            98304     ['re_lu_218[0][0]']
#
#  batch_normalization_225 (B  (None, 7, 7, 128)            512       ['conv2d_224[0][0]']
#  atchNormalization)
#
#  re_lu_219 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_225[0][0
#                                                                     ]']
#
#  conv2d_225 (Conv2D)         (None, 7, 7, 32)             36864     ['re_lu_219[0][0]']
#
#  concatenate_108 (Concatena  (None, 7, 7, 800)            0         ['concatenate_107[0][0]',
#  te)                                                                 'conv2d_225[0][0]']
#
#  batch_normalization_226 (B  (None, 7, 7, 800)            3200      ['concatenate_108[0][0]']
#  atchNormalization)
#
#  re_lu_220 (ReLU)            (None, 7, 7, 800)            0         ['batch_normalization_226[0][0
#                                                                     ]']
#
#  conv2d_226 (Conv2D)         (None, 7, 7, 128)            102400    ['re_lu_220[0][0]']
#
#  batch_normalization_227 (B  (None, 7, 7, 128)            512       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  re_lu_221 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_227[0][0
#                                                                     ]']
#
#  conv2d_227 (Conv2D)         (None, 7, 7, 32)             36864     ['re_lu_221[0][0]']
#
#  concatenate_109 (Concatena  (None, 7, 7, 832)            0         ['concatenate_108[0][0]',
#  te)                                                                 'conv2d_227[0][0]']
#
#  batch_normalization_228 (B  (None, 7, 7, 832)            3328      ['concatenate_109[0][0]']
#  atchNormalization)
#
#  re_lu_222 (ReLU)            (None, 7, 7, 832)            0         ['batch_normalization_228[0][0
#                                                                     ]']
#
#  conv2d_228 (Conv2D)         (None, 7, 7, 128)            106496    ['re_lu_222[0][0]']
#
#  batch_normalization_229 (B  (None, 7, 7, 128)            512       ['conv2d_228[0][0]']
#  atchNormalization)
#
#  re_lu_223 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_229[0][0
#                                                                     ]']
#
#  conv2d_229 (Conv2D)         (None, 7, 7, 32)             36864     ['re_lu_223[0][0]']
#
#  concatenate_110 (Concatena  (None, 7, 7, 864)            0         ['concatenate_109[0][0]',
#  te)                                                                 'conv2d_229[0][0]']
#
#  batch_normalization_230 (B  (None, 7, 7, 864)            3456      ['concatenate_110[0][0]']
#  atchNormalization)
#
#  re_lu_224 (ReLU)            (None, 7, 7, 864)            0         ['batch_normalization_230[0][0
#                                                                     ]']
#
#  conv2d_230 (Conv2D)         (None, 7, 7, 128)            110592    ['re_lu_224[0][0]']
#
#  batch_normalization_231 (B  (None, 7, 7, 128)            512       ['conv2d_230[0][0]']
#  atchNormalization)
#
#  re_lu_225 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_231[0][0
#                                                                     ]']
#
#  conv2d_231 (Conv2D)         (None, 7, 7, 32)             36864     ['re_lu_225[0][0]']
#
#  concatenate_111 (Concatena  (None, 7, 7, 896)            0         ['concatenate_110[0][0]',
#  te)                                                                 'conv2d_231[0][0]']
#
#  batch_normalization_232 (B  (None, 7, 7, 896)            3584      ['concatenate_111[0][0]']
#  atchNormalization)
#
#  re_lu_226 (ReLU)            (None, 7, 7, 896)            0         ['batch_normalization_232[0][0
#                                                                     ]']
#
#  conv2d_232 (Conv2D)         (None, 7, 7, 128)            114688    ['re_lu_226[0][0]']
#
#  batch_normalization_233 (B  (None, 7, 7, 128)            512       ['conv2d_232[0][0]']
#  atchNormalization)
#
#  re_lu_227 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_233[0][0
#                                                                     ]']
#
#  conv2d_233 (Conv2D)         (None, 7, 7, 32)             36864     ['re_lu_227[0][0]']
#
#  concatenate_112 (Concatena  (None, 7, 7, 928)            0         ['concatenate_111[0][0]',
#  te)                                                                 'conv2d_233[0][0]']
#
#  batch_normalization_234 (B  (None, 7, 7, 928)            3712      ['concatenate_112[0][0]']
#  atchNormalization)
#
#  re_lu_228 (ReLU)            (None, 7, 7, 928)            0         ['batch_normalization_234[0][0
#                                                                     ]']
#
#  conv2d_234 (Conv2D)         (None, 7, 7, 128)            118784    ['re_lu_228[0][0]']
#
#  batch_normalization_235 (B  (None, 7, 7, 128)            512       ['conv2d_234[0][0]']
#  atchNormalization)
#
#  re_lu_229 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_235[0][0
#                                                                     ]']
#
#  conv2d_235 (Conv2D)         (None, 7, 7, 32)             36864     ['re_lu_229[0][0]']
#
#  concatenate_113 (Concatena  (None, 7, 7, 960)            0         ['concatenate_112[0][0]',
#  te)                                                                 'conv2d_235[0][0]']
#
#  batch_normalization_236 (B  (None, 7, 7, 960)            3840      ['concatenate_113[0][0]']
#  atchNormalization)
#
#  re_lu_230 (ReLU)            (None, 7, 7, 960)            0         ['batch_normalization_236[0][0
#                                                                     ]']
#
#  conv2d_236 (Conv2D)         (None, 7, 7, 128)            122880    ['re_lu_230[0][0]']
#
#  batch_normalization_237 (B  (None, 7, 7, 128)            512       ['conv2d_236[0][0]']
#  atchNormalization)
#
#  re_lu_231 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_237[0][0
#                                                                     ]']
#
#  conv2d_237 (Conv2D)         (None, 7, 7, 32)             36864     ['re_lu_231[0][0]']
#
#  concatenate_114 (Concatena  (None, 7, 7, 992)            0         ['concatenate_113[0][0]',
#  te)                                                                 'conv2d_237[0][0]']
#
#  batch_normalization_238 (B  (None, 7, 7, 992)            3968      ['concatenate_114[0][0]']
#  atchNormalization)
#
#  re_lu_232 (ReLU)            (None, 7, 7, 992)            0         ['batch_normalization_238[0][0
#                                                                     ]']
#
#  conv2d_238 (Conv2D)         (None, 7, 7, 128)            126976    ['re_lu_232[0][0]']
#
#  batch_normalization_239 (B  (None, 7, 7, 128)            512       ['conv2d_238[0][0]']
#  atchNormalization)
#
#  re_lu_233 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_239[0][0
#                                                                     ]']
#
#  conv2d_239 (Conv2D)         (None, 7, 7, 32)             36864     ['re_lu_233[0][0]']
#
#  concatenate_115 (Concatena  (None, 7, 7, 1024)           0         ['concatenate_114[0][0]',
#  te)                                                                 'conv2d_239[0][0]']
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['concatenate_115[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1000)                 1025000   ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 8058408 (30.74 MB)
# Trainable params: 7976808 (30.43 MB)
# Non-trainable params: 81600 (318.75 KB)
# __________________________________________________________________________________________________
