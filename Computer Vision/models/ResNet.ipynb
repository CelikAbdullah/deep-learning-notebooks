# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import

# %%
from tensorflow import keras

# %% [markdown]
# # ResNet

# %% [markdown]
# ## ResNet34

# %% [markdown]
# ### The stem component

# %%
def stem(inputs):
  '''
  Build the stem component of ResNet34.
  Perform the initial coarse-level feature extraction.

  inputs: the input vector
  '''
  # a conv layer that outputs 64 feature maps
  x = keras.layers.Conv2D(filters=64,
                          kernel_size=7,
                          strides=2,
                          padding="same",
                          activation="relu",
                          kernel_initializer="he_normal",
                          )(inputs)

  # a max pooling layer that pools the 64 feature maps
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2, padding="same")(x)

  # following line would have the same effect as the previous max pooling layer
  #x = keras.layers.MaxPooling2D(pool_size=2)(x)


  return x

# %% [markdown]
# ### The learner component

# %% [markdown]
# #### Residual block

# %% [markdown]
# A block that consists of two convolutional layers with the same number of filters for feature extraction. The input to the residual block will be added to the output of the last conv layer via an identity link.

# %%
def residual_block(x, filters):
  '''
  A residual block with an identity link and
  two convolutional layers. All convolutional
  layers have the same number of filters.

  x       :  input into to the residual block
  filters :  nr. of filters of each conv layer
  '''

  # identity link, also referred to as "shortcut"
  shortcut = x

  # apply non-strided 3x3 convolutions for feature extraction
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=3,
                          strides=1,
                          padding="same",
                          activation="relu",
                          kernel_initializer="he_normal"
                          )(x)

  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=3,
                          strides=1,
                          padding="same",
                          activation="relu",
                          kernel_initializer="he_normal"
                          )(x)

  # add the output feature maps to the input
  # note: padding="same" preserved the size of the width & height
  #       so that adding input and output feature maps can work
  x = keras.layers.Add()([shortcut,x])

  # return the addition of the input & output feature maps
  return x

# %% [markdown]
# #### Conv block

# %% [markdown]
# A block that also consists of two convolutional layers. It will be placed after the last residual block of a residual block. It is responsible for doubling the number of output feature maps for the subsequent residual group.

# %%
def conv_block(x, filters):
  '''
  A conv block with two strided convolutional layers that extract
  features, doubles the number of feature maps for the
  next residual group and reduces the size of the feature
  maps.

  x       : input to the conv block
  filters : number of filters
  '''
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=3,
                          strides=2 ,
                          padding="same",
                          activation="relu",
                          kernel_initializer="he_normal")(x)
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=3,
                          strides=2,
                          padding="same",
                          activation="relu",
                          kernel_initializer="he_normal")(x)

  # return the output feature maps
  return x

# %% [markdown]
# #### Residual group

# %% [markdown]
# Now, we can create the residual group. The learner component of ResNet34 has 4 residual groups.

# %%
def residual_group(x, filters, blocks, conv=True):
  '''
  Create a residual group.

  x       : input to the residual group
  filters : number of filters for the conv layers within the residual blocks
  blocks  : number of residual blocks in the residual group
  conv    : flag that decides whether we need a conv block or not
            (note: all residual groups have one, except the last one.)
  '''

  # create the residual blocks of the residual group
  for _ in range(blocks):
    x = residual_block(x, filters)


  # create the conv block to double the number of feature maps for the
  # upcoming residual group and also reduce the size of the feature maps
  # via a stride of 2
  # (Note: Doubling of the number of feature maps has to be done since each residual
  # group doubles the number of filters in their residual blocks. If we don't
  # do this then the addition of feature maps at the end of a residual block
  # wouldn't work.
  if conv:
    x = conv_block(x, filters * 2)


  # return the output feature maps
  return x

# %% [markdown]
# Finally, we can put all pieces together to build the learner component of ResNet34:

# %%
def learner(x):
  '''
  Build the learner component of ResNet34.
  Perform the detailed feature extraction and representational learning
  from the extracted coarse features.

  x: input to the learner
  '''

  # create the 1st residual group with 3 residual blocks.
  # Each residual block consists of 2 convolutional layers with 64 filters.
  x = residual_group(x, 64, 3)

  # create the 1st residual group with 3 residual blocks.
  # Each residual block consists of 2 convolutional layers with 128 filters.
  x = residual_group(x, 128, 3)

  # create the 1st residual group with 5 residual blocks.
  # Each residual block consists of 2 convolutional layers with 256 filters.
  x = residual_group(x, 256, 5)

  # create the 1st residual group with 2 residual blocks.
  # Each residual block consists of 2 convolutional layers with 512 filters.
  x = residual_group(x, 512, 2, False)

  # return the final output feature maps (latent space)
  return x

# %% [markdown]
# ### The task component

# %%
def task(x, classes):
  '''
  Build the task component that perform classification.

  x       : input to the task component
  classes : number of classes
  '''

  # global average pooling to reduce and flatten the
  # feature maps into a 1D vector
  x = keras.layers.GlobalAveragePooling2D()(x)

  # softmax layer
  outputs = keras.layers.Dense(units=classes,
                               activation="softmax",
                               kernel_initializer="he_normal")(x)


  # return the probability of each class
  return outputs

# %%
inputs = keras.Input(shape=(224,224, 3))

# %%
# perform the coarse-level feature extraction
coarse_features = stem(inputs)

# perform the detailed feature extraction & representational learning from the coarse features
detailed_features = learner(coarse_features)

# the task component performing classification
outputs = task(detailed_features, 1000)


model = keras.Model(inputs=inputs, outputs=outputs, name="resnet_34")
model.summary()
# Out:
# Model: "resnet_34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_34 (Conv2D)             (None, 112, 112, 64  9472        ['input_3[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)  0           ['conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 56, 56, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 56, 56, 64)   36928       ['conv2d_35[0][0]']
#
#  add_13 (Add)                   (None, 56, 56, 64)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 56, 56, 64)   36928       ['add_13[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 56, 56, 64)   36928       ['conv2d_37[0][0]']
#
#  add_14 (Add)                   (None, 56, 56, 64)   0           ['add_13[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 56, 56, 64)   36928       ['add_14[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 56, 56, 64)   36928       ['conv2d_39[0][0]']
#
#  add_15 (Add)                   (None, 56, 56, 64)   0           ['add_14[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 28, 28, 128)  73856       ['add_15[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_42[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_43[0][0]']
#
#  add_16 (Add)                   (None, 14, 14, 128)  0           ['conv2d_42[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 128)  147584      ['add_16[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_45[0][0]']
#
#  add_17 (Add)                   (None, 14, 14, 128)  0           ['add_16[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 128)  147584      ['add_17[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_47[0][0]']
#
#  add_18 (Add)                   (None, 14, 14, 128)  0           ['add_17[0][0]',
#                                                                   'conv2d_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 256)    295168      ['add_18[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_51[0][0]']
#
#  add_19 (Add)                   (None, 4, 4, 256)    0           ['conv2d_50[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 4, 4, 256)    590080      ['add_19[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_53[0][0]']
#
#  add_20 (Add)                   (None, 4, 4, 256)    0           ['add_19[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 4, 4, 256)    590080      ['add_20[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_55[0][0]']
#
#  add_21 (Add)                   (None, 4, 4, 256)    0           ['add_20[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 4, 4, 256)    590080      ['add_21[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_57[0][0]']
#
#  add_22 (Add)                   (None, 4, 4, 256)    0           ['add_21[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 4, 4, 256)    590080      ['add_22[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_59[0][0]']
#
#  add_23 (Add)                   (None, 4, 4, 256)    0           ['add_22[0][0]',
#                                                                   'conv2d_60[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 2, 2, 512)    1180160     ['add_23[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 1, 1, 512)    2359808     ['conv2d_61[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 1, 1, 512)    2359808     ['conv2d_62[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 1, 1, 512)    2359808     ['conv2d_63[0][0]']
#
#  add_24 (Add)                   (None, 1, 1, 512)    0           ['conv2d_62[0][0]',
#                                                                   'conv2d_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 1, 1, 512)    2359808     ['add_24[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 1, 1, 512)    2359808     ['conv2d_65[0][0]']
#
#  add_25 (Add)                   (None, 1, 1, 512)    0           ['add_24[0][0]',
#                                                                   'conv2d_66[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 512)         0           ['add_25[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 1000)         513000      ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 21,616,232
# Trainable params: 21,616,232
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet v1

# %% [markdown]
# ### The stem component

# %%
def stem(inputs):
  '''
  Build the stem component of ResNet v1

  inputs: input to the stem
  '''

  # apply zero-padding to preserve the size of the inputs
  # note: instead of a ZeroPadding2D layer, we could also
  #       use the padding="same" argument in conv layer below
  x = keras.layers.ZeroPadding2D(padding=(3,3))(inputs)

  # a conv layer to extract the coarse-level features from inputs
  x = keras.layers.Conv2D(filters=64,
                          kernel_size=7,
                          strides=2,
                          padding="valid",
                          use_bias=False,
                          kernel_initializer="he_normal"
                          )(x)

  # apply batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU activation fct
  x = keras.layers.ReLU()(x)

  # again, apply zero-padding
  x = keras.layers.ZeroPadding2D(padding=(1,1))(x)

  # perform strided max-pooling with a 3x3 pooling window
  x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)

  # return the output feature maps
  return x

# %% [markdown]
# ### The learner component

# %% [markdown]
# #### The identity block

# %%
def identity_block(input, filters):
  '''
  Build a bottleneck residual block with an identity link.

  input   : input to the identity block
  filters : nr. of filters to use in the conv layer of the block
  '''

  # create the identity link, also referred to as "shortcut"
  shortcut = input

  # a 1x1 bottleneck convolution for dimensionality reduction
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal",
                          )(input)
  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)
  # perform ReLU
  x = keras.layers.ReLU()(x)


  # now, create the conv layers used for the residual path

  # a 3x3 conv layer
  x = keras.layers.Conv2D(filters = filters,
                          kernel_size=3,
                          strides=1,
                          padding="same",
                          use_bias=False,
                          kernel_initializer="he_normal")(x)
  # perform batch-normalization
  x = keras.layers.BatchNormalization()(x)
  # perform ReLU
  x = keras.layers.ReLU()(x)


  # a 1x1 linear projection conv layer for expanding the dimensionality
  x = keras.layers.Conv2D(filters=filters*4,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal")(x)

  # perform batch-normalization
  x = keras.layers.BatchNormalization()(x)

  # add the identity link (input) to the output of the residual path
  x = keras.layers.Add()([shortcut, x])

  # perform ReLU
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# #### The projection block

# %%
def projection_block(input, filters, strides=2):
  '''
  Build the bottleneck residual block with an identity link that uses
  a linear projection.

  Expand the number of filters.

  input : input to the block
  filters: nr. of filters in the conv layers of the block
  strides : stride value
  '''

  # create the identity link with linear projection
  shortcut = keras.layers.Conv2D(filters = filters * 4,
                                 kernel_size=1,
                                 strides=strides,
                                 use_bias=False,
                                 kernel_initializer="he_normal")(input)

  # apply batch normalization
  shortcut = keras.layers.BatchNormalization()(shortcut)


  # now, create the conv layers used for the residual path

  # 1.)
  # a 1x1 bottleneck conv layer for reducing the dimensionality
  # and applies feature pooling if strides=2
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=1,
                          strides=strides,
                          use_bias=False,
                          kernel_initializer="he_normal")(input)
  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # 2.)
  # a 3x3 conv layer acting as a bottleneck layer
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=3,
                          strides=1,
                          padding="same",
                          use_bias=False,
                          kernel_initializer="he_normal")(x)

  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # 3.)
  # a 1x1 linear projection conv layer for dimensionality restoration
  # recall that the nr. of input feature maps were increased on the identity link
  # so, we have to account for that when we want to add them to the output of
  # the residual path
  x = keras.layers.Conv2D(filters=filters*4,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal")(x)

  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)

  # finally, we can add the identity link with linear projection to
  # the output of the residual path
  x = keras.layers.Add()([shortcut, x])

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # return the output feature maps
  return x

# %% [markdown]
# #### The residual group

# %%
def residual_group(input, filters, blocks, strides=2):
  '''
  Build a residual group.

  input   : input to the residual group
  filters : nr. of filters for the conv layers in the residual blocks
  blocks  : nr. of residual blocks in the residual group
  strides : stride value
  '''

  # each residual group starts with a projection block
  x = projection_block(input, filters, strides=strides)

  # followed by a couple of identity blocks
  for _ in range(blocks):
    x = identity_block(x, filters)

  # return the output feature maps
  return x

# %% [markdown]
# #### The learner

# %%
def learner(input, groups_spec):
  '''
  Build the learner component of ResNet v1.

  input   : input to the learner component
  groups  : a list of specifications (nr. of filters & blocks) for each group
  '''

  # the first group is not strided; so, we will use strides=1
  filters, blocks = groups_spec.pop(0)
  x = residual_group(input, filters, blocks, strides=1)

  # all other residual groups are strided
  for filters, blocks in groups_spec:
    x = residual_group(x, filters, blocks)


  # return the output feature maps
  return x

# %% [markdown]
# ### The task component

# %%
def task(input, classes):
  '''
  Build the task component of ResNet v1.

  input   : input to the task component
  classes : nr. of classes
  '''

  # global average pooling to reduce and flatten the
  # feature maps into a 1D vector
  x = keras.layers.GlobalAveragePooling2D()(input)

  # create the softmax layer to output a probability for each class
  outputs = keras.layers.Dense(units=classes,
                               activation="softmax",
                               kernel_initializer="he_normal")(x)

  # return the output feature maps
  return outputs

# %% [markdown]
# ### Build the ResNet v1 model

# %%
# create the specifications (nr. filters and blocks) for each group
groups = { 50 : [ (64, 3), (128, 4), (256, 6),  (512, 3) ],		# ResNet50
           101: [ (64, 3), (128, 4), (256, 23), (512, 3) ],		# ResNet101
           152: [ (64, 3), (128, 8), (256, 36), (512, 3) ]		# ResNet152
         }

# create the input tensor with a shape of 224x224x3
inputs = keras.Input(shape=(224,224,3))

# perform the coarse-level feature extraction
coarse_features = stem(inputs)

# perform the detailed feature extraction & representational learning from the coarse features
detailed_features = learner(coarse_features, groups[50])

# the task component performing classification
outputs = task(detailed_features, 1000)

# now, instantiate the ResNet50 model
model = keras.Model(inputs=inputs, outputs=outputs, name="ResNet50")
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_11 (ZeroPadding  (None, 230, 230, 3)  0          ['input_7[0][0]']
#  2D)
#
#  conv2d_137 (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d_11[0][0]']
#                                 )
#
#  batch_normalization_135 (Batch  (None, 112, 112, 64  256        ['conv2d_137[0][0]']
#  Normalization)                 )
#
#  re_lu_125 (ReLU)               (None, 112, 112, 64  0           ['batch_normalization_135[0][0]']
#                                 )
#
#  zero_padding2d_12 (ZeroPadding  (None, 114, 114, 64  0          ['re_lu_125[0][0]']
#  2D)                            )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 64)  0           ['zero_padding2d_12[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 56, 56, 64)   4096        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_137 (Batch  (None, 56, 56, 64)  256         ['conv2d_139[0][0]']
#  Normalization)
#
#  re_lu_126 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_137[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_126[0][0]']
#
#  batch_normalization_138 (Batch  (None, 56, 56, 64)  256         ['conv2d_140[0][0]']
#  Normalization)
#
#  re_lu_127 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_138[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 56, 56, 256)  16384       ['max_pooling2d_4[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_127[0][0]']
#
#  batch_normalization_136 (Batch  (None, 56, 56, 256)  1024       ['conv2d_138[0][0]']
#  Normalization)
#
#  batch_normalization_139 (Batch  (None, 56, 56, 256)  1024       ['conv2d_141[0][0]']
#  Normalization)
#
#  add_40 (Add)                   (None, 56, 56, 256)  0           ['batch_normalization_136[0][0]',
#                                                                   'batch_normalization_139[0][0]']
#
#  re_lu_128 (ReLU)               (None, 56, 56, 256)  0           ['add_40[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_128[0][0]']
#
#  batch_normalization_140 (Batch  (None, 56, 56, 64)  256         ['conv2d_142[0][0]']
#  Normalization)
#
#  re_lu_129 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_140[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_129[0][0]']
#
#  batch_normalization_141 (Batch  (None, 56, 56, 64)  256         ['conv2d_143[0][0]']
#  Normalization)
#
#  re_lu_130 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_141[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_130[0][0]']
#
#  batch_normalization_142 (Batch  (None, 56, 56, 256)  1024       ['conv2d_144[0][0]']
#  Normalization)
#
#  add_41 (Add)                   (None, 56, 56, 256)  0           ['re_lu_128[0][0]',
#                                                                   'batch_normalization_142[0][0]']
#
#  re_lu_131 (ReLU)               (None, 56, 56, 256)  0           ['add_41[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_131[0][0]']
#
#  batch_normalization_143 (Batch  (None, 56, 56, 64)  256         ['conv2d_145[0][0]']
#  Normalization)
#
#  re_lu_132 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_143[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_132[0][0]']
#
#  batch_normalization_144 (Batch  (None, 56, 56, 64)  256         ['conv2d_146[0][0]']
#  Normalization)
#
#  re_lu_133 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_144[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_133[0][0]']
#
#  batch_normalization_145 (Batch  (None, 56, 56, 256)  1024       ['conv2d_147[0][0]']
#  Normalization)
#
#  add_42 (Add)                   (None, 56, 56, 256)  0           ['re_lu_131[0][0]',
#                                                                   'batch_normalization_145[0][0]']
#
#  re_lu_134 (ReLU)               (None, 56, 56, 256)  0           ['add_42[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_134[0][0]']
#
#  batch_normalization_146 (Batch  (None, 56, 56, 64)  256         ['conv2d_148[0][0]']
#  Normalization)
#
#  re_lu_135 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_146[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_135[0][0]']
#
#  batch_normalization_147 (Batch  (None, 56, 56, 64)  256         ['conv2d_149[0][0]']
#  Normalization)
#
#  re_lu_136 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_147[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_136[0][0]']
#
#  batch_normalization_148 (Batch  (None, 56, 56, 256)  1024       ['conv2d_150[0][0]']
#  Normalization)
#
#  add_43 (Add)                   (None, 56, 56, 256)  0           ['re_lu_134[0][0]',
#                                                                   'batch_normalization_148[0][0]']
#
#  re_lu_137 (ReLU)               (None, 56, 56, 256)  0           ['add_43[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 28, 28, 128)  32768       ['re_lu_137[0][0]']
#
#  batch_normalization_150 (Batch  (None, 28, 28, 128)  512        ['conv2d_152[0][0]']
#  Normalization)
#
#  re_lu_138 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_138[0][0]']
#
#  batch_normalization_151 (Batch  (None, 28, 28, 128)  512        ['conv2d_153[0][0]']
#  Normalization)
#
#  re_lu_139 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_151[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 28, 28, 512)  131072      ['re_lu_137[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_139[0][0]']
#
#  batch_normalization_149 (Batch  (None, 28, 28, 512)  2048       ['conv2d_151[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 28, 28, 512)  2048       ['conv2d_154[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_149[0][0]',
#                                                                   'batch_normalization_152[0][0]']
#
#  re_lu_140 (ReLU)               (None, 28, 28, 512)  0           ['add_44[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_140[0][0]']
#
#  batch_normalization_153 (Batch  (None, 28, 28, 128)  512        ['conv2d_155[0][0]']
#  Normalization)
#
#  re_lu_141 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_153[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_141[0][0]']
#
#  batch_normalization_154 (Batch  (None, 28, 28, 128)  512        ['conv2d_156[0][0]']
#  Normalization)
#
#  re_lu_142 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_154[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_142[0][0]']
#
#  batch_normalization_155 (Batch  (None, 28, 28, 512)  2048       ['conv2d_157[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 28, 28, 512)  0           ['re_lu_140[0][0]',
#                                                                   'batch_normalization_155[0][0]']
#
#  re_lu_143 (ReLU)               (None, 28, 28, 512)  0           ['add_45[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_143[0][0]']
#
#  batch_normalization_156 (Batch  (None, 28, 28, 128)  512        ['conv2d_158[0][0]']
#  Normalization)
#
#  re_lu_144 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_156[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_144[0][0]']
#
#  batch_normalization_157 (Batch  (None, 28, 28, 128)  512        ['conv2d_159[0][0]']
#  Normalization)
#
#  re_lu_145 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_157[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_145[0][0]']
#
#  batch_normalization_158 (Batch  (None, 28, 28, 512)  2048       ['conv2d_160[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 28, 28, 512)  0           ['re_lu_143[0][0]',
#                                                                   'batch_normalization_158[0][0]']
#
#  re_lu_146 (ReLU)               (None, 28, 28, 512)  0           ['add_46[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_146[0][0]']
#
#  batch_normalization_159 (Batch  (None, 28, 28, 128)  512        ['conv2d_161[0][0]']
#  Normalization)
#
#  re_lu_147 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_159[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_147[0][0]']
#
#  batch_normalization_160 (Batch  (None, 28, 28, 128)  512        ['conv2d_162[0][0]']
#  Normalization)
#
#  re_lu_148 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_160[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_148[0][0]']
#
#  batch_normalization_161 (Batch  (None, 28, 28, 512)  2048       ['conv2d_163[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 28, 28, 512)  0           ['re_lu_146[0][0]',
#                                                                   'batch_normalization_161[0][0]']
#
#  re_lu_149 (ReLU)               (None, 28, 28, 512)  0           ['add_47[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_149[0][0]']
#
#  batch_normalization_162 (Batch  (None, 28, 28, 128)  512        ['conv2d_164[0][0]']
#  Normalization)
#
#  re_lu_150 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_162[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_150[0][0]']
#
#  batch_normalization_163 (Batch  (None, 28, 28, 128)  512        ['conv2d_165[0][0]']
#  Normalization)
#
#  re_lu_151 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_163[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_151[0][0]']
#
#  batch_normalization_164 (Batch  (None, 28, 28, 512)  2048       ['conv2d_166[0][0]']
#  Normalization)
#
#  add_48 (Add)                   (None, 28, 28, 512)  0           ['re_lu_149[0][0]',
#                                                                   'batch_normalization_164[0][0]']
#
#  re_lu_152 (ReLU)               (None, 28, 28, 512)  0           ['add_48[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 14, 14, 256)  131072      ['re_lu_152[0][0]']
#
#  batch_normalization_166 (Batch  (None, 14, 14, 256)  1024       ['conv2d_168[0][0]']
#  Normalization)
#
#  re_lu_153 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_166[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_153[0][0]']
#
#  batch_normalization_167 (Batch  (None, 14, 14, 256)  1024       ['conv2d_169[0][0]']
#  Normalization)
#
#  re_lu_154 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_167[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 14, 14, 1024  524288      ['re_lu_152[0][0]']
#                                 )
#
#  conv2d_170 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_154[0][0]']
#                                 )
#
#  batch_normalization_165 (Batch  (None, 14, 14, 1024  4096       ['conv2d_167[0][0]']
#  Normalization)                 )
#
#  batch_normalization_168 (Batch  (None, 14, 14, 1024  4096       ['conv2d_170[0][0]']
#  Normalization)                 )
#
#  add_49 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_165[0][0]',
#                                 )                                 'batch_normalization_168[0][0]']
#
#  re_lu_155 (ReLU)               (None, 14, 14, 1024  0           ['add_49[0][0]']
#                                 )
#
#  conv2d_171 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_155[0][0]']
#
#  batch_normalization_169 (Batch  (None, 14, 14, 256)  1024       ['conv2d_171[0][0]']
#  Normalization)
#
#  re_lu_156 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_169[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_156[0][0]']
#
#  batch_normalization_170 (Batch  (None, 14, 14, 256)  1024       ['conv2d_172[0][0]']
#  Normalization)
#
#  re_lu_157 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_170[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_157[0][0]']
#                                 )
#
#  batch_normalization_171 (Batch  (None, 14, 14, 1024  4096       ['conv2d_173[0][0]']
#  Normalization)                 )
#
#  add_50 (Add)                   (None, 14, 14, 1024  0           ['re_lu_155[0][0]',
#                                 )                                 'batch_normalization_171[0][0]']
#
#  re_lu_158 (ReLU)               (None, 14, 14, 1024  0           ['add_50[0][0]']
#                                 )
#
#  conv2d_174 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_158[0][0]']
#
#  batch_normalization_172 (Batch  (None, 14, 14, 256)  1024       ['conv2d_174[0][0]']
#  Normalization)
#
#  re_lu_159 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_172[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_159[0][0]']
#
#  batch_normalization_173 (Batch  (None, 14, 14, 256)  1024       ['conv2d_175[0][0]']
#  Normalization)
#
#  re_lu_160 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_173[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_160[0][0]']
#                                 )
#
#  batch_normalization_174 (Batch  (None, 14, 14, 1024  4096       ['conv2d_176[0][0]']
#  Normalization)                 )
#
#  add_51 (Add)                   (None, 14, 14, 1024  0           ['re_lu_158[0][0]',
#                                 )                                 'batch_normalization_174[0][0]']
#
#  re_lu_161 (ReLU)               (None, 14, 14, 1024  0           ['add_51[0][0]']
#                                 )
#
#  conv2d_177 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_161[0][0]']
#
#  batch_normalization_175 (Batch  (None, 14, 14, 256)  1024       ['conv2d_177[0][0]']
#  Normalization)
#
#  re_lu_162 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_175[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_162[0][0]']
#
#  batch_normalization_176 (Batch  (None, 14, 14, 256)  1024       ['conv2d_178[0][0]']
#  Normalization)
#
#  re_lu_163 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_176[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_163[0][0]']
#                                 )
#
#  batch_normalization_177 (Batch  (None, 14, 14, 1024  4096       ['conv2d_179[0][0]']
#  Normalization)                 )
#
#  add_52 (Add)                   (None, 14, 14, 1024  0           ['re_lu_161[0][0]',
#                                 )                                 'batch_normalization_177[0][0]']
#
#  re_lu_164 (ReLU)               (None, 14, 14, 1024  0           ['add_52[0][0]']
#                                 )
#
#  conv2d_180 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_164[0][0]']
#
#  batch_normalization_178 (Batch  (None, 14, 14, 256)  1024       ['conv2d_180[0][0]']
#  Normalization)
#
#  re_lu_165 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_178[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_165[0][0]']
#
#  batch_normalization_179 (Batch  (None, 14, 14, 256)  1024       ['conv2d_181[0][0]']
#  Normalization)
#
#  re_lu_166 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_179[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_166[0][0]']
#                                 )
#
#  batch_normalization_180 (Batch  (None, 14, 14, 1024  4096       ['conv2d_182[0][0]']
#  Normalization)                 )
#
#  add_53 (Add)                   (None, 14, 14, 1024  0           ['re_lu_164[0][0]',
#                                 )                                 'batch_normalization_180[0][0]']
#
#  re_lu_167 (ReLU)               (None, 14, 14, 1024  0           ['add_53[0][0]']
#                                 )
#
#  conv2d_183 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_167[0][0]']
#
#  batch_normalization_181 (Batch  (None, 14, 14, 256)  1024       ['conv2d_183[0][0]']
#  Normalization)
#
#  re_lu_168 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_181[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_168[0][0]']
#
#  batch_normalization_182 (Batch  (None, 14, 14, 256)  1024       ['conv2d_184[0][0]']
#  Normalization)
#
#  re_lu_169 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_182[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_169[0][0]']
#                                 )
#
#  batch_normalization_183 (Batch  (None, 14, 14, 1024  4096       ['conv2d_185[0][0]']
#  Normalization)                 )
#
#  add_54 (Add)                   (None, 14, 14, 1024  0           ['re_lu_167[0][0]',
#                                 )                                 'batch_normalization_183[0][0]']
#
#  re_lu_170 (ReLU)               (None, 14, 14, 1024  0           ['add_54[0][0]']
#                                 )
#
#  conv2d_186 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_170[0][0]']
#
#  batch_normalization_184 (Batch  (None, 14, 14, 256)  1024       ['conv2d_186[0][0]']
#  Normalization)
#
#  re_lu_171 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_184[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_171[0][0]']
#
#  batch_normalization_185 (Batch  (None, 14, 14, 256)  1024       ['conv2d_187[0][0]']
#  Normalization)
#
#  re_lu_172 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_185[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_172[0][0]']
#                                 )
#
#  batch_normalization_186 (Batch  (None, 14, 14, 1024  4096       ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  add_55 (Add)                   (None, 14, 14, 1024  0           ['re_lu_170[0][0]',
#                                 )                                 'batch_normalization_186[0][0]']
#
#  re_lu_173 (ReLU)               (None, 14, 14, 1024  0           ['add_55[0][0]']
#                                 )
#
#  conv2d_190 (Conv2D)            (None, 7, 7, 512)    524288      ['re_lu_173[0][0]']
#
#  batch_normalization_188 (Batch  (None, 7, 7, 512)   2048        ['conv2d_190[0][0]']
#  Normalization)
#
#  re_lu_174 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_174[0][0]']
#
#  batch_normalization_189 (Batch  (None, 7, 7, 512)   2048        ['conv2d_191[0][0]']
#  Normalization)
#
#  re_lu_175 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_189[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 7, 7, 2048)   2097152     ['re_lu_173[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_175[0][0]']
#
#  batch_normalization_187 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_189[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_192[0][0]']
#  Normalization)
#
#  add_56 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_187[0][0]',
#                                                                   'batch_normalization_190[0][0]']
#
#  re_lu_176 (ReLU)               (None, 7, 7, 2048)   0           ['add_56[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_176[0][0]']
#
#  batch_normalization_191 (Batch  (None, 7, 7, 512)   2048        ['conv2d_193[0][0]']
#  Normalization)
#
#  re_lu_177 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_191[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_177[0][0]']
#
#  batch_normalization_192 (Batch  (None, 7, 7, 512)   2048        ['conv2d_194[0][0]']
#  Normalization)
#
#  re_lu_178 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_178[0][0]']
#
#  batch_normalization_193 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_195[0][0]']
#  Normalization)
#
#  add_57 (Add)                   (None, 7, 7, 2048)   0           ['re_lu_176[0][0]',
#                                                                   'batch_normalization_193[0][0]']
#
#  re_lu_179 (ReLU)               (None, 7, 7, 2048)   0           ['add_57[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_179[0][0]']
#
#  batch_normalization_194 (Batch  (None, 7, 7, 512)   2048        ['conv2d_196[0][0]']
#  Normalization)
#
#  re_lu_180 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_194[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_180[0][0]']
#
#  batch_normalization_195 (Batch  (None, 7, 7, 512)   2048        ['conv2d_197[0][0]']
#  Normalization)
#
#  re_lu_181 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_195[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_181[0][0]']
#
#  batch_normalization_196 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_198[0][0]']
#  Normalization)
#
#  add_58 (Add)                   (None, 7, 7, 2048)   0           ['re_lu_179[0][0]',
#                                                                   'batch_normalization_196[0][0]']
#
#  re_lu_182 (ReLU)               (None, 7, 7, 2048)   0           ['add_58[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_182[0][0]']
#
#  batch_normalization_197 (Batch  (None, 7, 7, 512)   2048        ['conv2d_199[0][0]']
#  Normalization)
#
#  re_lu_183 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_183[0][0]']
#
#  batch_normalization_198 (Batch  (None, 7, 7, 512)   2048        ['conv2d_200[0][0]']
#  Normalization)
#
#  re_lu_184 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_198[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_184[0][0]']
#
#  batch_normalization_199 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_201[0][0]']
#  Normalization)
#
#  add_59 (Add)                   (None, 7, 7, 2048)   0           ['re_lu_182[0][0]',
#                                                                   'batch_normalization_199[0][0]']
#
#  re_lu_185 (ReLU)               (None, 7, 7, 2048)   0           ['add_59[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 2048)        0           ['re_lu_185[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 1000)         2049000     ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 31,551,912
# Trainable params: 31,487,272
# Non-trainable params: 64,640
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet v1.5

# %% [markdown]
# ### The stem component

# %%
def stem(inputs):
  '''
  Build the stem component of ResNet v1.5

  inputs: input to the stem
  '''

  # apply zero-padding to preserve the size of the inputs
  # note: instead of a ZeroPadding2D layer, we could also
  #       use the padding="same" argument in conv layer below
  x = keras.layers.ZeroPadding2D(padding=(3,3))(inputs)

  # a conv layer to extract the coarse-level features from inputs
  x = keras.layers.Conv2D(filters=64,
                          kernel_size=7,
                          strides=2,
                          padding="valid",
                          use_bias=False,
                          kernel_initializer="he_normal"
                          )(x)

  # apply batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU activation fct
  x = keras.layers.ReLU()(x)

  # again, apply zero-padding
  x = keras.layers.ZeroPadding2D(padding=(1,1))(x)

  # perform strided max-pooling with a 3x3 pooling window
  x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)

  # return the output feature maps
  return x

# %% [markdown]
# ### The learner component

# %% [markdown]
# #### The identity block

# %%
def identity_block(input, filters):
  '''
  Build a bottleneck residual block with an identity link.

  input   : input to the identity block
  filters : nr. of filters to use in the conv layer of the block
  '''

  # create the identity link, also referred to as "shortcut"
  shortcut = input

  # a 1x1 bottleneck convolution for dimensionality reduction
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal",
                          )(input)
  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)
  # perform ReLU
  x = keras.layers.ReLU()(x)


  # now, create the conv layers used for the residual path

  # a 3x3 conv layer
  x = keras.layers.Conv2D(filters = filters,
                          kernel_size=3,
                          strides=1,
                          padding="same",
                          use_bias=False,
                          kernel_initializer="he_normal")(x)
  # perform batch-normalization
  x = keras.layers.BatchNormalization()(x)
  # perform ReLU
  x = keras.layers.ReLU()(x)


  # a 1x1 linear projection conv layer for expanding the dimensionality
  x = keras.layers.Conv2D(filters=filters*4,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal")(x)

  # perform batch-normalization
  x = keras.layers.BatchNormalization()(x)

  # add the identity link (input) to the output of the residual path
  x = keras.layers.Add()([shortcut, x])

  # perform ReLU
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# #### The projection block

# %%
def projection_block(input, filters, strides=2):
  '''
  Build the bottleneck residual block with an identity link that uses
  a linear projection.

  Expand the number of filters.

  input : input to the block
  filters: nr. of filters in the conv layers of the block
  strides : stride value
  '''

  # create the identity link with linear projection
  shortcut = keras.layers.Conv2D(filters = filters * 4,
                                 kernel_size=1,
                                 strides=strides,
                                 use_bias=False,
                                 kernel_initializer="he_normal")(input)

  # apply batch normalization
  shortcut = keras.layers.BatchNormalization()(shortcut)


  # now, create the conv layers used for the residual path

  # 1.)
  # a 1x1 bottleneck conv layer for reducing the dimensionality
  # and applies feature pooling if strides=2
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal")(input)
  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # 2.)
  # a 3x3 conv layer acting as a bottleneck layer
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=3,
                          strides=strides,
                          padding="same",
                          use_bias=False,
                          kernel_initializer="he_normal")(x)

  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # 3.)
  # a 1x1 linear projection conv layer for dimensionality restoration
  # recall that the nr. of input feature maps were increased on the identity link
  # so, we have to account for that when we want to add them to the output of
  # the residual path
  x = keras.layers.Conv2D(filters=filters*4,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal")(x)

  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)

  # finally, we can add the identity link with linear projection to
  # the output of the residual path
  x = keras.layers.Add()([shortcut, x])

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # return the output feature maps
  return x

# %% [markdown]
# #### The residual group

# %%
def residual_group(input, filters, blocks, strides=2):
  '''
  Build a residual group.

  input   : input to the residual group
  filters : nr. of filters for the conv layers in the residual blocks
  blocks  : nr. of residual blocks in the residual group
  strides : stride value
  '''

  # each residual group starts with a projection block
  x = projection_block(input, filters, strides=strides)

  # followed by a couple of identity blocks
  for _ in range(blocks):
    x = identity_block(x, filters)

  # return the output feature maps
  return x

# %% [markdown]
# #### The learner

# %%
def learner(input, groups_spec):
  '''
  Build the learner component of ResNet v1.5.

  input   : input to the learner component
  groups  : a list of specifications (nr. of filters & blocks) for each group
  '''

  # the first group is not strided; so, we will use strides=1
  filters, blocks = groups_spec.pop(0)
  x = residual_group(input, filters, blocks, strides=1)

  # all other residual groups are strided
  for filters, blocks in groups_spec:
    x = residual_group(x, filters, blocks)


  # return the output feature maps
  return x

# %% [markdown]
# ### The task component

# %%
def task(input, classes):
  '''
  Build the task component of ResNet v1.5.

  input   : input to the task component
  classes : nr. of classes
  '''

  # global average pooling to reduce and flatten the
  # feature maps into a 1D vector
  x = keras.layers.GlobalAveragePooling2D()(input)

  # create the softmax layer to output a probability for each class
  outputs = keras.layers.Dense(units=classes,
                               activation="softmax",
                               kernel_initializer="he_normal")(x)

  # return the output feature maps
  return outputs

# %% [markdown]
# ### Build the ResNet v1.5 model

# %%
# create the specifications (nr. filters and blocks) for each group
groups = { 50 : [ (64, 3), (128, 4), (256, 6),  (512, 3) ],		# ResNet50
           101: [ (64, 3), (128, 4), (256, 23), (512, 3) ],		# ResNet101
           152: [ (64, 3), (128, 8), (256, 36), (512, 3) ]		# ResNet152
         }

# create the input tensor with a shape of 224x224x3
inputs = keras.Input(shape=(224,224,3))

# perform the coarse-level feature extraction
coarse_features = stem(inputs)

# perform the detailed feature extraction & representational learning from the coarse features
detailed_features = learner(coarse_features, groups[50])

# the task component performing classification
outputs = task(detailed_features, 1000)

# now, instantiate the ResNet50 model
model = keras.Model(inputs=inputs, outputs=outputs, name="ResNet50")
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_15 (ZeroPadding  (None, 230, 230, 3)  0          ['input_9[0][0]']
#  2D)
#
#  conv2d_267 (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d_15[0][0]']
#                                 )
#
#  batch_normalization_265 (Batch  (None, 112, 112, 64  256        ['conv2d_267[0][0]']
#  Normalization)                 )
#
#  re_lu_247 (ReLU)               (None, 112, 112, 64  0           ['batch_normalization_265[0][0]']
#                                 )
#
#  zero_padding2d_16 (ZeroPadding  (None, 114, 114, 64  0          ['re_lu_247[0][0]']
#  2D)                            )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 56, 56, 64)  0           ['zero_padding2d_16[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 56, 56, 64)   4096        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_267 (Batch  (None, 56, 56, 64)  256         ['conv2d_269[0][0]']
#  Normalization)
#
#  re_lu_248 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_267[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_248[0][0]']
#
#  batch_normalization_268 (Batch  (None, 56, 56, 64)  256         ['conv2d_270[0][0]']
#  Normalization)
#
#  re_lu_249 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_268[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 56, 56, 256)  16384       ['max_pooling2d_6[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_249[0][0]']
#
#  batch_normalization_266 (Batch  (None, 56, 56, 256)  1024       ['conv2d_268[0][0]']
#  Normalization)
#
#  batch_normalization_269 (Batch  (None, 56, 56, 256)  1024       ['conv2d_271[0][0]']
#  Normalization)
#
#  add_80 (Add)                   (None, 56, 56, 256)  0           ['batch_normalization_266[0][0]',
#                                                                   'batch_normalization_269[0][0]']
#
#  re_lu_250 (ReLU)               (None, 56, 56, 256)  0           ['add_80[0][0]']
#
#  conv2d_272 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_250[0][0]']
#
#  batch_normalization_270 (Batch  (None, 56, 56, 64)  256         ['conv2d_272[0][0]']
#  Normalization)
#
#  re_lu_251 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_270[0][0]']
#
#  conv2d_273 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_251[0][0]']
#
#  batch_normalization_271 (Batch  (None, 56, 56, 64)  256         ['conv2d_273[0][0]']
#  Normalization)
#
#  re_lu_252 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_271[0][0]']
#
#  conv2d_274 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_252[0][0]']
#
#  batch_normalization_272 (Batch  (None, 56, 56, 256)  1024       ['conv2d_274[0][0]']
#  Normalization)
#
#  add_81 (Add)                   (None, 56, 56, 256)  0           ['re_lu_250[0][0]',
#                                                                   'batch_normalization_272[0][0]']
#
#  re_lu_253 (ReLU)               (None, 56, 56, 256)  0           ['add_81[0][0]']
#
#  conv2d_275 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_253[0][0]']
#
#  batch_normalization_273 (Batch  (None, 56, 56, 64)  256         ['conv2d_275[0][0]']
#  Normalization)
#
#  re_lu_254 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_273[0][0]']
#
#  conv2d_276 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_254[0][0]']
#
#  batch_normalization_274 (Batch  (None, 56, 56, 64)  256         ['conv2d_276[0][0]']
#  Normalization)
#
#  re_lu_255 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_274[0][0]']
#
#  conv2d_277 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_255[0][0]']
#
#  batch_normalization_275 (Batch  (None, 56, 56, 256)  1024       ['conv2d_277[0][0]']
#  Normalization)
#
#  add_82 (Add)                   (None, 56, 56, 256)  0           ['re_lu_253[0][0]',
#                                                                   'batch_normalization_275[0][0]']
#
#  re_lu_256 (ReLU)               (None, 56, 56, 256)  0           ['add_82[0][0]']
#
#  conv2d_278 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_256[0][0]']
#
#  batch_normalization_276 (Batch  (None, 56, 56, 64)  256         ['conv2d_278[0][0]']
#  Normalization)
#
#  re_lu_257 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_276[0][0]']
#
#  conv2d_279 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_257[0][0]']
#
#  batch_normalization_277 (Batch  (None, 56, 56, 64)  256         ['conv2d_279[0][0]']
#  Normalization)
#
#  re_lu_258 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_277[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_258[0][0]']
#
#  batch_normalization_278 (Batch  (None, 56, 56, 256)  1024       ['conv2d_280[0][0]']
#  Normalization)
#
#  add_83 (Add)                   (None, 56, 56, 256)  0           ['re_lu_256[0][0]',
#                                                                   'batch_normalization_278[0][0]']
#
#  re_lu_259 (ReLU)               (None, 56, 56, 256)  0           ['add_83[0][0]']
#
#  conv2d_282 (Conv2D)            (None, 56, 56, 128)  32768       ['re_lu_259[0][0]']
#
#  batch_normalization_280 (Batch  (None, 56, 56, 128)  512        ['conv2d_282[0][0]']
#  Normalization)
#
#  re_lu_260 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_280[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_260[0][0]']
#
#  batch_normalization_281 (Batch  (None, 28, 28, 128)  512        ['conv2d_283[0][0]']
#  Normalization)
#
#  re_lu_261 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_281[0][0]']
#
#  conv2d_281 (Conv2D)            (None, 28, 28, 512)  131072      ['re_lu_259[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_261[0][0]']
#
#  batch_normalization_279 (Batch  (None, 28, 28, 512)  2048       ['conv2d_281[0][0]']
#  Normalization)
#
#  batch_normalization_282 (Batch  (None, 28, 28, 512)  2048       ['conv2d_284[0][0]']
#  Normalization)
#
#  add_84 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_279[0][0]',
#                                                                   'batch_normalization_282[0][0]']
#
#  re_lu_262 (ReLU)               (None, 28, 28, 512)  0           ['add_84[0][0]']
#
#  conv2d_285 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_262[0][0]']
#
#  batch_normalization_283 (Batch  (None, 28, 28, 128)  512        ['conv2d_285[0][0]']
#  Normalization)
#
#  re_lu_263 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_283[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_263[0][0]']
#
#  batch_normalization_284 (Batch  (None, 28, 28, 128)  512        ['conv2d_286[0][0]']
#  Normalization)
#
#  re_lu_264 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_284[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_264[0][0]']
#
#  batch_normalization_285 (Batch  (None, 28, 28, 512)  2048       ['conv2d_287[0][0]']
#  Normalization)
#
#  add_85 (Add)                   (None, 28, 28, 512)  0           ['re_lu_262[0][0]',
#                                                                   'batch_normalization_285[0][0]']
#
#  re_lu_265 (ReLU)               (None, 28, 28, 512)  0           ['add_85[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_265[0][0]']
#
#  batch_normalization_286 (Batch  (None, 28, 28, 128)  512        ['conv2d_288[0][0]']
#  Normalization)
#
#  re_lu_266 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_286[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_266[0][0]']
#
#  batch_normalization_287 (Batch  (None, 28, 28, 128)  512        ['conv2d_289[0][0]']
#  Normalization)
#
#  re_lu_267 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_287[0][0]']
#
#  conv2d_290 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_267[0][0]']
#
#  batch_normalization_288 (Batch  (None, 28, 28, 512)  2048       ['conv2d_290[0][0]']
#  Normalization)
#
#  add_86 (Add)                   (None, 28, 28, 512)  0           ['re_lu_265[0][0]',
#                                                                   'batch_normalization_288[0][0]']
#
#  re_lu_268 (ReLU)               (None, 28, 28, 512)  0           ['add_86[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_268[0][0]']
#
#  batch_normalization_289 (Batch  (None, 28, 28, 128)  512        ['conv2d_291[0][0]']
#  Normalization)
#
#  re_lu_269 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_289[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_269[0][0]']
#
#  batch_normalization_290 (Batch  (None, 28, 28, 128)  512        ['conv2d_292[0][0]']
#  Normalization)
#
#  re_lu_270 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_290[0][0]']
#
#  conv2d_293 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_270[0][0]']
#
#  batch_normalization_291 (Batch  (None, 28, 28, 512)  2048       ['conv2d_293[0][0]']
#  Normalization)
#
#  add_87 (Add)                   (None, 28, 28, 512)  0           ['re_lu_268[0][0]',
#                                                                   'batch_normalization_291[0][0]']
#
#  re_lu_271 (ReLU)               (None, 28, 28, 512)  0           ['add_87[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_271[0][0]']
#
#  batch_normalization_292 (Batch  (None, 28, 28, 128)  512        ['conv2d_294[0][0]']
#  Normalization)
#
#  re_lu_272 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_292[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_272[0][0]']
#
#  batch_normalization_293 (Batch  (None, 28, 28, 128)  512        ['conv2d_295[0][0]']
#  Normalization)
#
#  re_lu_273 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_293[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_273[0][0]']
#
#  batch_normalization_294 (Batch  (None, 28, 28, 512)  2048       ['conv2d_296[0][0]']
#  Normalization)
#
#  add_88 (Add)                   (None, 28, 28, 512)  0           ['re_lu_271[0][0]',
#                                                                   'batch_normalization_294[0][0]']
#
#  re_lu_274 (ReLU)               (None, 28, 28, 512)  0           ['add_88[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 28, 28, 256)  131072      ['re_lu_274[0][0]']
#
#  batch_normalization_296 (Batch  (None, 28, 28, 256)  1024       ['conv2d_298[0][0]']
#  Normalization)
#
#  re_lu_275 (ReLU)               (None, 28, 28, 256)  0           ['batch_normalization_296[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_275[0][0]']
#
#  batch_normalization_297 (Batch  (None, 14, 14, 256)  1024       ['conv2d_299[0][0]']
#  Normalization)
#
#  re_lu_276 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_297[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 14, 14, 1024  524288      ['re_lu_274[0][0]']
#                                 )
#
#  conv2d_300 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_276[0][0]']
#                                 )
#
#  batch_normalization_295 (Batch  (None, 14, 14, 1024  4096       ['conv2d_297[0][0]']
#  Normalization)                 )
#
#  batch_normalization_298 (Batch  (None, 14, 14, 1024  4096       ['conv2d_300[0][0]']
#  Normalization)                 )
#
#  add_89 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_295[0][0]',
#                                 )                                 'batch_normalization_298[0][0]']
#
#  re_lu_277 (ReLU)               (None, 14, 14, 1024  0           ['add_89[0][0]']
#                                 )
#
#  conv2d_301 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_277[0][0]']
#
#  batch_normalization_299 (Batch  (None, 14, 14, 256)  1024       ['conv2d_301[0][0]']
#  Normalization)
#
#  re_lu_278 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_299[0][0]']
#
#  conv2d_302 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_278[0][0]']
#
#  batch_normalization_300 (Batch  (None, 14, 14, 256)  1024       ['conv2d_302[0][0]']
#  Normalization)
#
#  re_lu_279 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_300[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_279[0][0]']
#                                 )
#
#  batch_normalization_301 (Batch  (None, 14, 14, 1024  4096       ['conv2d_303[0][0]']
#  Normalization)                 )
#
#  add_90 (Add)                   (None, 14, 14, 1024  0           ['re_lu_277[0][0]',
#                                 )                                 'batch_normalization_301[0][0]']
#
#  re_lu_280 (ReLU)               (None, 14, 14, 1024  0           ['add_90[0][0]']
#                                 )
#
#  conv2d_304 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_280[0][0]']
#
#  batch_normalization_302 (Batch  (None, 14, 14, 256)  1024       ['conv2d_304[0][0]']
#  Normalization)
#
#  re_lu_281 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_302[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_281[0][0]']
#
#  batch_normalization_303 (Batch  (None, 14, 14, 256)  1024       ['conv2d_305[0][0]']
#  Normalization)
#
#  re_lu_282 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_303[0][0]']
#
#  conv2d_306 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_282[0][0]']
#                                 )
#
#  batch_normalization_304 (Batch  (None, 14, 14, 1024  4096       ['conv2d_306[0][0]']
#  Normalization)                 )
#
#  add_91 (Add)                   (None, 14, 14, 1024  0           ['re_lu_280[0][0]',
#                                 )                                 'batch_normalization_304[0][0]']
#
#  re_lu_283 (ReLU)               (None, 14, 14, 1024  0           ['add_91[0][0]']
#                                 )
#
#  conv2d_307 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_283[0][0]']
#
#  batch_normalization_305 (Batch  (None, 14, 14, 256)  1024       ['conv2d_307[0][0]']
#  Normalization)
#
#  re_lu_284 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_305[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_284[0][0]']
#
#  batch_normalization_306 (Batch  (None, 14, 14, 256)  1024       ['conv2d_308[0][0]']
#  Normalization)
#
#  re_lu_285 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_306[0][0]']
#
#  conv2d_309 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_285[0][0]']
#                                 )
#
#  batch_normalization_307 (Batch  (None, 14, 14, 1024  4096       ['conv2d_309[0][0]']
#  Normalization)                 )
#
#  add_92 (Add)                   (None, 14, 14, 1024  0           ['re_lu_283[0][0]',
#                                 )                                 'batch_normalization_307[0][0]']
#
#  re_lu_286 (ReLU)               (None, 14, 14, 1024  0           ['add_92[0][0]']
#                                 )
#
#  conv2d_310 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_286[0][0]']
#
#  batch_normalization_308 (Batch  (None, 14, 14, 256)  1024       ['conv2d_310[0][0]']
#  Normalization)
#
#  re_lu_287 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_308[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_287[0][0]']
#
#  batch_normalization_309 (Batch  (None, 14, 14, 256)  1024       ['conv2d_311[0][0]']
#  Normalization)
#
#  re_lu_288 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_309[0][0]']
#
#  conv2d_312 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_288[0][0]']
#                                 )
#
#  batch_normalization_310 (Batch  (None, 14, 14, 1024  4096       ['conv2d_312[0][0]']
#  Normalization)                 )
#
#  add_93 (Add)                   (None, 14, 14, 1024  0           ['re_lu_286[0][0]',
#                                 )                                 'batch_normalization_310[0][0]']
#
#  re_lu_289 (ReLU)               (None, 14, 14, 1024  0           ['add_93[0][0]']
#                                 )
#
#  conv2d_313 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_289[0][0]']
#
#  batch_normalization_311 (Batch  (None, 14, 14, 256)  1024       ['conv2d_313[0][0]']
#  Normalization)
#
#  re_lu_290 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_311[0][0]']
#
#  conv2d_314 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_290[0][0]']
#
#  batch_normalization_312 (Batch  (None, 14, 14, 256)  1024       ['conv2d_314[0][0]']
#  Normalization)
#
#  re_lu_291 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_312[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_291[0][0]']
#                                 )
#
#  batch_normalization_313 (Batch  (None, 14, 14, 1024  4096       ['conv2d_315[0][0]']
#  Normalization)                 )
#
#  add_94 (Add)                   (None, 14, 14, 1024  0           ['re_lu_289[0][0]',
#                                 )                                 'batch_normalization_313[0][0]']
#
#  re_lu_292 (ReLU)               (None, 14, 14, 1024  0           ['add_94[0][0]']
#                                 )
#
#  conv2d_316 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_292[0][0]']
#
#  batch_normalization_314 (Batch  (None, 14, 14, 256)  1024       ['conv2d_316[0][0]']
#  Normalization)
#
#  re_lu_293 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_314[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_293[0][0]']
#
#  batch_normalization_315 (Batch  (None, 14, 14, 256)  1024       ['conv2d_317[0][0]']
#  Normalization)
#
#  re_lu_294 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_315[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_294[0][0]']
#                                 )
#
#  batch_normalization_316 (Batch  (None, 14, 14, 1024  4096       ['conv2d_318[0][0]']
#  Normalization)                 )
#
#  add_95 (Add)                   (None, 14, 14, 1024  0           ['re_lu_292[0][0]',
#                                 )                                 'batch_normalization_316[0][0]']
#
#  re_lu_295 (ReLU)               (None, 14, 14, 1024  0           ['add_95[0][0]']
#                                 )
#
#  conv2d_320 (Conv2D)            (None, 14, 14, 512)  524288      ['re_lu_295[0][0]']
#
#  batch_normalization_318 (Batch  (None, 14, 14, 512)  2048       ['conv2d_320[0][0]']
#  Normalization)
#
#  re_lu_296 (ReLU)               (None, 14, 14, 512)  0           ['batch_normalization_318[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_296[0][0]']
#
#  batch_normalization_319 (Batch  (None, 7, 7, 512)   2048        ['conv2d_321[0][0]']
#  Normalization)
#
#  re_lu_297 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_319[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 7, 7, 2048)   2097152     ['re_lu_295[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_297[0][0]']
#
#  batch_normalization_317 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_319[0][0]']
#  Normalization)
#
#  batch_normalization_320 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_322[0][0]']
#  Normalization)
#
#  add_96 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_317[0][0]',
#                                                                   'batch_normalization_320[0][0]']
#
#  re_lu_298 (ReLU)               (None, 7, 7, 2048)   0           ['add_96[0][0]']
#
#  conv2d_323 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_298[0][0]']
#
#  batch_normalization_321 (Batch  (None, 7, 7, 512)   2048        ['conv2d_323[0][0]']
#  Normalization)
#
#  re_lu_299 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_321[0][0]']
#
#  conv2d_324 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_299[0][0]']
#
#  batch_normalization_322 (Batch  (None, 7, 7, 512)   2048        ['conv2d_324[0][0]']
#  Normalization)
#
#  re_lu_300 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_322[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_300[0][0]']
#
#  batch_normalization_323 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_325[0][0]']
#  Normalization)
#
#  add_97 (Add)                   (None, 7, 7, 2048)   0           ['re_lu_298[0][0]',
#                                                                   'batch_normalization_323[0][0]']
#
#  re_lu_301 (ReLU)               (None, 7, 7, 2048)   0           ['add_97[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_301[0][0]']
#
#  batch_normalization_324 (Batch  (None, 7, 7, 512)   2048        ['conv2d_326[0][0]']
#  Normalization)
#
#  re_lu_302 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_324[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_302[0][0]']
#
#  batch_normalization_325 (Batch  (None, 7, 7, 512)   2048        ['conv2d_327[0][0]']
#  Normalization)
#
#  re_lu_303 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_325[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_303[0][0]']
#
#  batch_normalization_326 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_328[0][0]']
#  Normalization)
#
#  add_98 (Add)                   (None, 7, 7, 2048)   0           ['re_lu_301[0][0]',
#                                                                   'batch_normalization_326[0][0]']
#
#  re_lu_304 (ReLU)               (None, 7, 7, 2048)   0           ['add_98[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_304[0][0]']
#
#  batch_normalization_327 (Batch  (None, 7, 7, 512)   2048        ['conv2d_329[0][0]']
#  Normalization)
#
#  re_lu_305 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_327[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_305[0][0]']
#
#  batch_normalization_328 (Batch  (None, 7, 7, 512)   2048        ['conv2d_330[0][0]']
#  Normalization)
#
#  re_lu_306 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_328[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_306[0][0]']
#
#  batch_normalization_329 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_331[0][0]']
#  Normalization)
#
#  add_99 (Add)                   (None, 7, 7, 2048)   0           ['re_lu_304[0][0]',
#                                                                   'batch_normalization_329[0][0]']
#
#  re_lu_307 (ReLU)               (None, 7, 7, 2048)   0           ['add_99[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 2048)        0           ['re_lu_307[0][0]']
#  obalAveragePooling2D)
#
#  dense_3 (Dense)                (None, 1000)         2049000     ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 31,551,912
# Trainable params: 31,487,272
# Non-trainable params: 64,640
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet v2

# %% [markdown]
# ### The stem component

# %%
def stem(inputs):
  '''
  Build the stem component of ResNet v1.5

  inputs: input to the stem
  '''

  # apply zero-padding to preserve the size of the inputs
  # note: instead of a ZeroPadding2D layer, we could also
  #       use the padding="same" argument in conv layer below
  x = keras.layers.ZeroPadding2D(padding=(3,3))(inputs)

  # a conv layer to extract the coarse-level features from inputs
  x = keras.layers.Conv2D(filters=64,
                          kernel_size=7,
                          strides=2,
                          padding="valid",
                          use_bias=False,
                          kernel_initializer="he_normal"
                          )(x)

  # apply batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU activation fct
  x = keras.layers.ReLU()(x)

  # again, apply zero-padding
  x = keras.layers.ZeroPadding2D(padding=(1,1))(x)

  # perform strided max-pooling with a 3x3 pooling window
  x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)

  # return the output feature maps
  return x

# %% [markdown]
# ### The learner component

# %% [markdown]
# #### The identity block

# %%
def identity_block(input, filters):
  '''
  Build a bottleneck residual block with an identity link.

  input   : input to the identity block
  filters : nr. of filters to use in the conv layer of the block
  '''

  # create the identity link, also referred to as "shortcut"
  shortcut = input

  # perform batch normalization
  x = keras.layers.BatchNormalization()(input)

  # perform ReLU
  x = keras.layers.ReLU()(x)

  # a 1x1 bottleneck convolution for dimensionality reduction
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal",
                          )(x)



  # now, create the conv layers used for the residual path

  # perform batch-normalization
  x = keras.layers.BatchNormalization()(x)

  # perform ReLU
  x = keras.layers.ReLU()(x)

  # a 3x3 conv layer
  x = keras.layers.Conv2D(filters = filters,
                          kernel_size=3,
                          strides=1,
                          padding="same",
                          use_bias=False,
                          kernel_initializer="he_normal")(x)

  # perform batch-normalization
  x = keras.layers.BatchNormalization()(x)

  # perform ReLU
  x = keras.layers.ReLU()(x)

  # a 1x1 linear projection conv layer for expanding the dimensionality
  x = keras.layers.Conv2D(filters=filters*4,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal")(x)



  # add the identity link (input) to the output of the residual path
  x = keras.layers.Add()([shortcut, x])


  return x

# %% [markdown]
# #### The projection block

# %%
def projection_block(input, filters, strides=2):
  '''
  Build the bottleneck residual block with an identity link that uses
  a linear projection.

  Expand the number of filters.

  input : input to the block
  filters: nr. of filters in the conv layers of the block
  strides : stride value
  '''

  # apply batch normalization
  shortcut = keras.layers.BatchNormalization()(input)

  # create the identity link with linear projection
  shortcut = keras.layers.Conv2D(filters = filters * 4,
                                 kernel_size=1,
                                 strides=strides,
                                 use_bias=False,
                                 kernel_initializer="he_normal")(shortcut)




  # now, create the conv layers used for the residual path

  # perform batch normalization
  x = keras.layers.BatchNormalization()(input)

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # 1.)
  # a 1x1 bottleneck conv layer for reducing the dimensionality
  # and applies feature pooling if strides=2
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal")(x)

  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # 2.)
  # a 3x3 conv layer acting as a bottleneck layer
  x = keras.layers.Conv2D(filters=filters,
                          kernel_size=3,
                          strides=strides,
                          padding="same",
                          use_bias=False,
                          kernel_initializer="he_normal")(x)


  # perform batch normalization
  x = keras.layers.BatchNormalization()(x)

  # apply ReLU
  x = keras.layers.ReLU()(x)

  # 3.)
  # a 1x1 linear projection conv layer for dimensionality restoration
  # recall that the nr. of input feature maps were increased on the identity link
  # so, we have to account for that when we want to add them to the output of
  # the residual path
  x = keras.layers.Conv2D(filters=filters*4,
                          kernel_size=1,
                          strides=1,
                          use_bias=False,
                          kernel_initializer="he_normal")(x)



  # finally, we can add the identity link with linear projection to
  # the output of the residual path
  x = keras.layers.Add()([shortcut, x])

  # return the output feature maps
  return x

# %% [markdown]
# #### The residual group

# %%
def residual_group(input, filters, blocks, strides=2):
  '''
  Build a residual group.

  input   : input to the residual group
  filters : nr. of filters for the conv layers in the residual blocks
  blocks  : nr. of residual blocks in the residual group
  strides : stride value
  '''

  # each residual group starts with a projection block
  x = projection_block(input, filters, strides=strides)

  # followed by a couple of identity blocks
  for _ in range(blocks):
    x = identity_block(x, filters)

  # return the output feature maps
  return x

# %% [markdown]
# #### The learner

# %%
def learner(input, groups_spec):
  '''
  Build the learner component of ResNet v2.

  input   : input to the learner component
  groups  : a list of specifications (nr. of filters & blocks) for each group
  '''

  # the first group is not strided; so, we will use strides=1
  filters, blocks = groups_spec.pop(0)
  x = residual_group(input, filters, blocks, strides=1)

  # all other residual groups are strided
  for filters, blocks in groups_spec:
    x = residual_group(x, filters, blocks)


  # return the output feature maps
  return x

# %% [markdown]
# ### The task component

# %%
def task(input, classes):
  '''
  Build the task component of ResNet v2.

  input   : input to the task component
  classes : nr. of classes
  '''

  # global average pooling to reduce and flatten the
  # feature maps into a 1D vector
  x = keras.layers.GlobalAveragePooling2D()(input)

  # create the softmax layer to output a probability for each class
  outputs = keras.layers.Dense(units=classes,
                               activation="softmax",
                               kernel_initializer="he_normal")(x)

  # return the output feature maps
  return outputs

# %% [markdown]
# ### Build the ResNet v2 model

# %%
# create the specifications (nr. filters and blocks) for each group
groups = { 50 : [ (64, 3), (128, 4), (256, 6),  (512, 3) ],		# ResNet50
           101: [ (64, 3), (128, 4), (256, 23), (512, 3) ],		# ResNet101
           152: [ (64, 3), (128, 8), (256, 36), (512, 3) ]		# ResNet152
         }

# create the input tensor with a shape of 224x224x3
inputs = keras.Input(shape=(224,224,3))

# perform the coarse-level feature extraction
coarse_features = stem(inputs)

# perform the detailed feature extraction & representational learning from the coarse features
detailed_features = learner(coarse_features, groups[50])

# the task component performing classification
outputs = task(detailed_features, 1000)

# now, instantiate the ResNet50 model
model = keras.Model(inputs=inputs, outputs=outputs, name="ResNet50")
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_17 (ZeroPadding  (None, 230, 230, 3)  0          ['input_10[0][0]']
#  2D)
#
#  conv2d_332 (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d_17[0][0]']
#                                 )
#
#  batch_normalization_330 (Batch  (None, 112, 112, 64  256        ['conv2d_332[0][0]']
#  Normalization)                 )
#
#  re_lu_308 (ReLU)               (None, 112, 112, 64  0           ['batch_normalization_330[0][0]']
#                                 )
#
#  zero_padding2d_18 (ZeroPadding  (None, 114, 114, 64  0          ['re_lu_308[0][0]']
#  2D)                            )
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 56, 56, 64)  0           ['zero_padding2d_18[0][0]']
#
#  batch_normalization_332 (Batch  (None, 56, 56, 64)  256         ['max_pooling2d_7[0][0]']
#  Normalization)
#
#  re_lu_309 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_332[0][0]']
#
#  conv2d_334 (Conv2D)            (None, 56, 56, 64)   4096        ['re_lu_309[0][0]']
#
#  batch_normalization_333 (Batch  (None, 56, 56, 64)  256         ['conv2d_334[0][0]']
#  Normalization)
#
#  re_lu_310 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_333[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_310[0][0]']
#
#  batch_normalization_334 (Batch  (None, 56, 56, 64)  256         ['conv2d_335[0][0]']
#  Normalization)
#
#  batch_normalization_331 (Batch  (None, 56, 56, 64)  256         ['max_pooling2d_7[0][0]']
#  Normalization)
#
#  re_lu_311 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_334[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 56, 56, 256)  16384       ['batch_normalization_331[0][0]']
#
#  conv2d_336 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_311[0][0]']
#
#  add_100 (Add)                  (None, 56, 56, 256)  0           ['conv2d_333[0][0]',
#                                                                   'conv2d_336[0][0]']
#
#  batch_normalization_335 (Batch  (None, 56, 56, 256)  1024       ['add_100[0][0]']
#  Normalization)
#
#  re_lu_312 (ReLU)               (None, 56, 56, 256)  0           ['batch_normalization_335[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_312[0][0]']
#
#  batch_normalization_336 (Batch  (None, 56, 56, 64)  256         ['conv2d_337[0][0]']
#  Normalization)
#
#  re_lu_313 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_336[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_313[0][0]']
#
#  batch_normalization_337 (Batch  (None, 56, 56, 64)  256         ['conv2d_338[0][0]']
#  Normalization)
#
#  re_lu_314 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_337[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_314[0][0]']
#
#  add_101 (Add)                  (None, 56, 56, 256)  0           ['add_100[0][0]',
#                                                                   'conv2d_339[0][0]']
#
#  batch_normalization_338 (Batch  (None, 56, 56, 256)  1024       ['add_101[0][0]']
#  Normalization)
#
#  re_lu_315 (ReLU)               (None, 56, 56, 256)  0           ['batch_normalization_338[0][0]']
#
#  conv2d_340 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_315[0][0]']
#
#  batch_normalization_339 (Batch  (None, 56, 56, 64)  256         ['conv2d_340[0][0]']
#  Normalization)
#
#  re_lu_316 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_339[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_316[0][0]']
#
#  batch_normalization_340 (Batch  (None, 56, 56, 64)  256         ['conv2d_341[0][0]']
#  Normalization)
#
#  re_lu_317 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_340[0][0]']
#
#  conv2d_342 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_317[0][0]']
#
#  add_102 (Add)                  (None, 56, 56, 256)  0           ['add_101[0][0]',
#                                                                   'conv2d_342[0][0]']
#
#  batch_normalization_341 (Batch  (None, 56, 56, 256)  1024       ['add_102[0][0]']
#  Normalization)
#
#  re_lu_318 (ReLU)               (None, 56, 56, 256)  0           ['batch_normalization_341[0][0]']
#
#  conv2d_343 (Conv2D)            (None, 56, 56, 64)   16384       ['re_lu_318[0][0]']
#
#  batch_normalization_342 (Batch  (None, 56, 56, 64)  256         ['conv2d_343[0][0]']
#  Normalization)
#
#  re_lu_319 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_342[0][0]']
#
#  conv2d_344 (Conv2D)            (None, 56, 56, 64)   36864       ['re_lu_319[0][0]']
#
#  batch_normalization_343 (Batch  (None, 56, 56, 64)  256         ['conv2d_344[0][0]']
#  Normalization)
#
#  re_lu_320 (ReLU)               (None, 56, 56, 64)   0           ['batch_normalization_343[0][0]']
#
#  conv2d_345 (Conv2D)            (None, 56, 56, 256)  16384       ['re_lu_320[0][0]']
#
#  add_103 (Add)                  (None, 56, 56, 256)  0           ['add_102[0][0]',
#                                                                   'conv2d_345[0][0]']
#
#  batch_normalization_345 (Batch  (None, 56, 56, 256)  1024       ['add_103[0][0]']
#  Normalization)
#
#  re_lu_321 (ReLU)               (None, 56, 56, 256)  0           ['batch_normalization_345[0][0]']
#
#  conv2d_347 (Conv2D)            (None, 56, 56, 128)  32768       ['re_lu_321[0][0]']
#
#  batch_normalization_346 (Batch  (None, 56, 56, 128)  512        ['conv2d_347[0][0]']
#  Normalization)
#
#  re_lu_322 (ReLU)               (None, 56, 56, 128)  0           ['batch_normalization_346[0][0]']
#
#  conv2d_348 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_322[0][0]']
#
#  batch_normalization_347 (Batch  (None, 28, 28, 128)  512        ['conv2d_348[0][0]']
#  Normalization)
#
#  batch_normalization_344 (Batch  (None, 56, 56, 256)  1024       ['add_103[0][0]']
#  Normalization)
#
#  re_lu_323 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_347[0][0]']
#
#  conv2d_346 (Conv2D)            (None, 28, 28, 512)  131072      ['batch_normalization_344[0][0]']
#
#  conv2d_349 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_323[0][0]']
#
#  add_104 (Add)                  (None, 28, 28, 512)  0           ['conv2d_346[0][0]',
#                                                                   'conv2d_349[0][0]']
#
#  batch_normalization_348 (Batch  (None, 28, 28, 512)  2048       ['add_104[0][0]']
#  Normalization)
#
#  re_lu_324 (ReLU)               (None, 28, 28, 512)  0           ['batch_normalization_348[0][0]']
#
#  conv2d_350 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_324[0][0]']
#
#  batch_normalization_349 (Batch  (None, 28, 28, 128)  512        ['conv2d_350[0][0]']
#  Normalization)
#
#  re_lu_325 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_349[0][0]']
#
#  conv2d_351 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_325[0][0]']
#
#  batch_normalization_350 (Batch  (None, 28, 28, 128)  512        ['conv2d_351[0][0]']
#  Normalization)
#
#  re_lu_326 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_350[0][0]']
#
#  conv2d_352 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_326[0][0]']
#
#  add_105 (Add)                  (None, 28, 28, 512)  0           ['add_104[0][0]',
#                                                                   'conv2d_352[0][0]']
#
#  batch_normalization_351 (Batch  (None, 28, 28, 512)  2048       ['add_105[0][0]']
#  Normalization)
#
#  re_lu_327 (ReLU)               (None, 28, 28, 512)  0           ['batch_normalization_351[0][0]']
#
#  conv2d_353 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_327[0][0]']
#
#  batch_normalization_352 (Batch  (None, 28, 28, 128)  512        ['conv2d_353[0][0]']
#  Normalization)
#
#  re_lu_328 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_352[0][0]']
#
#  conv2d_354 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_328[0][0]']
#
#  batch_normalization_353 (Batch  (None, 28, 28, 128)  512        ['conv2d_354[0][0]']
#  Normalization)
#
#  re_lu_329 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_353[0][0]']
#
#  conv2d_355 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_329[0][0]']
#
#  add_106 (Add)                  (None, 28, 28, 512)  0           ['add_105[0][0]',
#                                                                   'conv2d_355[0][0]']
#
#  batch_normalization_354 (Batch  (None, 28, 28, 512)  2048       ['add_106[0][0]']
#  Normalization)
#
#  re_lu_330 (ReLU)               (None, 28, 28, 512)  0           ['batch_normalization_354[0][0]']
#
#  conv2d_356 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_330[0][0]']
#
#  batch_normalization_355 (Batch  (None, 28, 28, 128)  512        ['conv2d_356[0][0]']
#  Normalization)
#
#  re_lu_331 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_355[0][0]']
#
#  conv2d_357 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_331[0][0]']
#
#  batch_normalization_356 (Batch  (None, 28, 28, 128)  512        ['conv2d_357[0][0]']
#  Normalization)
#
#  re_lu_332 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_356[0][0]']
#
#  conv2d_358 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_332[0][0]']
#
#  add_107 (Add)                  (None, 28, 28, 512)  0           ['add_106[0][0]',
#                                                                   'conv2d_358[0][0]']
#
#  batch_normalization_357 (Batch  (None, 28, 28, 512)  2048       ['add_107[0][0]']
#  Normalization)
#
#  re_lu_333 (ReLU)               (None, 28, 28, 512)  0           ['batch_normalization_357[0][0]']
#
#  conv2d_359 (Conv2D)            (None, 28, 28, 128)  65536       ['re_lu_333[0][0]']
#
#  batch_normalization_358 (Batch  (None, 28, 28, 128)  512        ['conv2d_359[0][0]']
#  Normalization)
#
#  re_lu_334 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_358[0][0]']
#
#  conv2d_360 (Conv2D)            (None, 28, 28, 128)  147456      ['re_lu_334[0][0]']
#
#  batch_normalization_359 (Batch  (None, 28, 28, 128)  512        ['conv2d_360[0][0]']
#  Normalization)
#
#  re_lu_335 (ReLU)               (None, 28, 28, 128)  0           ['batch_normalization_359[0][0]']
#
#  conv2d_361 (Conv2D)            (None, 28, 28, 512)  65536       ['re_lu_335[0][0]']
#
#  add_108 (Add)                  (None, 28, 28, 512)  0           ['add_107[0][0]',
#                                                                   'conv2d_361[0][0]']
#
#  batch_normalization_361 (Batch  (None, 28, 28, 512)  2048       ['add_108[0][0]']
#  Normalization)
#
#  re_lu_336 (ReLU)               (None, 28, 28, 512)  0           ['batch_normalization_361[0][0]']
#
#  conv2d_363 (Conv2D)            (None, 28, 28, 256)  131072      ['re_lu_336[0][0]']
#
#  batch_normalization_362 (Batch  (None, 28, 28, 256)  1024       ['conv2d_363[0][0]']
#  Normalization)
#
#  re_lu_337 (ReLU)               (None, 28, 28, 256)  0           ['batch_normalization_362[0][0]']
#
#  conv2d_364 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_337[0][0]']
#
#  batch_normalization_363 (Batch  (None, 14, 14, 256)  1024       ['conv2d_364[0][0]']
#  Normalization)
#
#  batch_normalization_360 (Batch  (None, 28, 28, 512)  2048       ['add_108[0][0]']
#  Normalization)
#
#  re_lu_338 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_363[0][0]']
#
#  conv2d_362 (Conv2D)            (None, 14, 14, 1024  524288      ['batch_normalization_360[0][0]']
#                                 )
#
#  conv2d_365 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_338[0][0]']
#                                 )
#
#  add_109 (Add)                  (None, 14, 14, 1024  0           ['conv2d_362[0][0]',
#                                 )                                 'conv2d_365[0][0]']
#
#  batch_normalization_364 (Batch  (None, 14, 14, 1024  4096       ['add_109[0][0]']
#  Normalization)                 )
#
#  re_lu_339 (ReLU)               (None, 14, 14, 1024  0           ['batch_normalization_364[0][0]']
#                                 )
#
#  conv2d_366 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_339[0][0]']
#
#  batch_normalization_365 (Batch  (None, 14, 14, 256)  1024       ['conv2d_366[0][0]']
#  Normalization)
#
#  re_lu_340 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_365[0][0]']
#
#  conv2d_367 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_340[0][0]']
#
#  batch_normalization_366 (Batch  (None, 14, 14, 256)  1024       ['conv2d_367[0][0]']
#  Normalization)
#
#  re_lu_341 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_366[0][0]']
#
#  conv2d_368 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_341[0][0]']
#                                 )
#
#  add_110 (Add)                  (None, 14, 14, 1024  0           ['add_109[0][0]',
#                                 )                                 'conv2d_368[0][0]']
#
#  batch_normalization_367 (Batch  (None, 14, 14, 1024  4096       ['add_110[0][0]']
#  Normalization)                 )
#
#  re_lu_342 (ReLU)               (None, 14, 14, 1024  0           ['batch_normalization_367[0][0]']
#                                 )
#
#  conv2d_369 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_342[0][0]']
#
#  batch_normalization_368 (Batch  (None, 14, 14, 256)  1024       ['conv2d_369[0][0]']
#  Normalization)
#
#  re_lu_343 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_368[0][0]']
#
#  conv2d_370 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_343[0][0]']
#
#  batch_normalization_369 (Batch  (None, 14, 14, 256)  1024       ['conv2d_370[0][0]']
#  Normalization)
#
#  re_lu_344 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_369[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_344[0][0]']
#                                 )
#
#  add_111 (Add)                  (None, 14, 14, 1024  0           ['add_110[0][0]',
#                                 )                                 'conv2d_371[0][0]']
#
#  batch_normalization_370 (Batch  (None, 14, 14, 1024  4096       ['add_111[0][0]']
#  Normalization)                 )
#
#  re_lu_345 (ReLU)               (None, 14, 14, 1024  0           ['batch_normalization_370[0][0]']
#                                 )
#
#  conv2d_372 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_345[0][0]']
#
#  batch_normalization_371 (Batch  (None, 14, 14, 256)  1024       ['conv2d_372[0][0]']
#  Normalization)
#
#  re_lu_346 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_371[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_346[0][0]']
#
#  batch_normalization_372 (Batch  (None, 14, 14, 256)  1024       ['conv2d_373[0][0]']
#  Normalization)
#
#  re_lu_347 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_372[0][0]']
#
#  conv2d_374 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_347[0][0]']
#                                 )
#
#  add_112 (Add)                  (None, 14, 14, 1024  0           ['add_111[0][0]',
#                                 )                                 'conv2d_374[0][0]']
#
#  batch_normalization_373 (Batch  (None, 14, 14, 1024  4096       ['add_112[0][0]']
#  Normalization)                 )
#
#  re_lu_348 (ReLU)               (None, 14, 14, 1024  0           ['batch_normalization_373[0][0]']
#                                 )
#
#  conv2d_375 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_348[0][0]']
#
#  batch_normalization_374 (Batch  (None, 14, 14, 256)  1024       ['conv2d_375[0][0]']
#  Normalization)
#
#  re_lu_349 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_374[0][0]']
#
#  conv2d_376 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_349[0][0]']
#
#  batch_normalization_375 (Batch  (None, 14, 14, 256)  1024       ['conv2d_376[0][0]']
#  Normalization)
#
#  re_lu_350 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_375[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_350[0][0]']
#                                 )
#
#  add_113 (Add)                  (None, 14, 14, 1024  0           ['add_112[0][0]',
#                                 )                                 'conv2d_377[0][0]']
#
#  batch_normalization_376 (Batch  (None, 14, 14, 1024  4096       ['add_113[0][0]']
#  Normalization)                 )
#
#  re_lu_351 (ReLU)               (None, 14, 14, 1024  0           ['batch_normalization_376[0][0]']
#                                 )
#
#  conv2d_378 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_351[0][0]']
#
#  batch_normalization_377 (Batch  (None, 14, 14, 256)  1024       ['conv2d_378[0][0]']
#  Normalization)
#
#  re_lu_352 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_377[0][0]']
#
#  conv2d_379 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_352[0][0]']
#
#  batch_normalization_378 (Batch  (None, 14, 14, 256)  1024       ['conv2d_379[0][0]']
#  Normalization)
#
#  re_lu_353 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_378[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_353[0][0]']
#                                 )
#
#  add_114 (Add)                  (None, 14, 14, 1024  0           ['add_113[0][0]',
#                                 )                                 'conv2d_380[0][0]']
#
#  batch_normalization_379 (Batch  (None, 14, 14, 1024  4096       ['add_114[0][0]']
#  Normalization)                 )
#
#  re_lu_354 (ReLU)               (None, 14, 14, 1024  0           ['batch_normalization_379[0][0]']
#                                 )
#
#  conv2d_381 (Conv2D)            (None, 14, 14, 256)  262144      ['re_lu_354[0][0]']
#
#  batch_normalization_380 (Batch  (None, 14, 14, 256)  1024       ['conv2d_381[0][0]']
#  Normalization)
#
#  re_lu_355 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_380[0][0]']
#
#  conv2d_382 (Conv2D)            (None, 14, 14, 256)  589824      ['re_lu_355[0][0]']
#
#  batch_normalization_381 (Batch  (None, 14, 14, 256)  1024       ['conv2d_382[0][0]']
#  Normalization)
#
#  re_lu_356 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_381[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 14, 14, 1024  262144      ['re_lu_356[0][0]']
#                                 )
#
#  add_115 (Add)                  (None, 14, 14, 1024  0           ['add_114[0][0]',
#                                 )                                 'conv2d_383[0][0]']
#
#  batch_normalization_383 (Batch  (None, 14, 14, 1024  4096       ['add_115[0][0]']
#  Normalization)                 )
#
#  re_lu_357 (ReLU)               (None, 14, 14, 1024  0           ['batch_normalization_383[0][0]']
#                                 )
#
#  conv2d_385 (Conv2D)            (None, 14, 14, 512)  524288      ['re_lu_357[0][0]']
#
#  batch_normalization_384 (Batch  (None, 14, 14, 512)  2048       ['conv2d_385[0][0]']
#  Normalization)
#
#  re_lu_358 (ReLU)               (None, 14, 14, 512)  0           ['batch_normalization_384[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_358[0][0]']
#
#  batch_normalization_385 (Batch  (None, 7, 7, 512)   2048        ['conv2d_386[0][0]']
#  Normalization)
#
#  batch_normalization_382 (Batch  (None, 14, 14, 1024  4096       ['add_115[0][0]']
#  Normalization)                 )
#
#  re_lu_359 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_385[0][0]']
#
#  conv2d_384 (Conv2D)            (None, 7, 7, 2048)   2097152     ['batch_normalization_382[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_359[0][0]']
#
#  add_116 (Add)                  (None, 7, 7, 2048)   0           ['conv2d_384[0][0]',
#                                                                   'conv2d_387[0][0]']
#
#  batch_normalization_386 (Batch  (None, 7, 7, 2048)  8192        ['add_116[0][0]']
#  Normalization)
#
#  re_lu_360 (ReLU)               (None, 7, 7, 2048)   0           ['batch_normalization_386[0][0]']
#
#  conv2d_388 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_360[0][0]']
#
#  batch_normalization_387 (Batch  (None, 7, 7, 512)   2048        ['conv2d_388[0][0]']
#  Normalization)
#
#  re_lu_361 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_387[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_361[0][0]']
#
#  batch_normalization_388 (Batch  (None, 7, 7, 512)   2048        ['conv2d_389[0][0]']
#  Normalization)
#
#  re_lu_362 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_388[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_362[0][0]']
#
#  add_117 (Add)                  (None, 7, 7, 2048)   0           ['add_116[0][0]',
#                                                                   'conv2d_390[0][0]']
#
#  batch_normalization_389 (Batch  (None, 7, 7, 2048)  8192        ['add_117[0][0]']
#  Normalization)
#
#  re_lu_363 (ReLU)               (None, 7, 7, 2048)   0           ['batch_normalization_389[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_363[0][0]']
#
#  batch_normalization_390 (Batch  (None, 7, 7, 512)   2048        ['conv2d_391[0][0]']
#  Normalization)
#
#  re_lu_364 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_390[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_364[0][0]']
#
#  batch_normalization_391 (Batch  (None, 7, 7, 512)   2048        ['conv2d_392[0][0]']
#  Normalization)
#
#  re_lu_365 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_391[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_365[0][0]']
#
#  add_118 (Add)                  (None, 7, 7, 2048)   0           ['add_117[0][0]',
#                                                                   'conv2d_393[0][0]']
#
#  batch_normalization_392 (Batch  (None, 7, 7, 2048)  8192        ['add_118[0][0]']
#  Normalization)
#
#  re_lu_366 (ReLU)               (None, 7, 7, 2048)   0           ['batch_normalization_392[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 7, 7, 512)    1048576     ['re_lu_366[0][0]']
#
#  batch_normalization_393 (Batch  (None, 7, 7, 512)   2048        ['conv2d_394[0][0]']
#  Normalization)
#
#  re_lu_367 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_393[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 7, 7, 512)    2359296     ['re_lu_367[0][0]']
#
#  batch_normalization_394 (Batch  (None, 7, 7, 512)   2048        ['conv2d_395[0][0]']
#  Normalization)
#
#  re_lu_368 (ReLU)               (None, 7, 7, 512)    0           ['batch_normalization_394[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 7, 7, 2048)   1048576     ['re_lu_368[0][0]']
#
#  add_119 (Add)                  (None, 7, 7, 2048)   0           ['add_118[0][0]',
#                                                                   'conv2d_396[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 2048)        0           ['add_119[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 1000)         2049000     ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 31,536,040
# Trainable params: 31,479,336
# Non-trainable params: 56,704
# __________________________________________________________________________________________________
