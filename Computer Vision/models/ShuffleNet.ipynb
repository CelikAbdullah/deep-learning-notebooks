# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/ShuffleNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from tensorflow.keras import backend as K

# %% [markdown]
# # ShuffleNet

# %% [markdown]
# ## The stem component

# %%
def stem(inputs):
  ''' Build the stem component of ShuffleNet
      inputs : input image (tensor)
  '''
  # a strided 3x3 conv layer followed by batch normalization and max pooling
  x = keras.layers.Conv2D(filters=24, kernel_size=3, strides=2, padding='same', use_bias=False)(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### Channel Shuffle Layer

# %%
def channel_shuffle(x, n_partitions):
  ''' Build the channel shuffle layer
      x            : input tensor
      n_partitions : number of groups to partition feature maps (channels) into.
  '''
  # extract dimensions of the input tensor
  batch, height, width, n_filters = x.shape

  # calculate the number of input filters (channels) per group
  grp_in_filters  = n_filters // n_partitions

  # separate out the channel groups
  x = keras.layers.Lambda(lambda z: K.reshape(z, [-1, height, width, n_partitions, grp_in_filters]))(x)
  # transpose the order of the channel groups (i.e., 3, 4 => 4, 3)
  x = keras.layers.Lambda(lambda z: K.permute_dimensions(z, (0, 1, 2, 4, 3)))(x)
  # restore shape
  x = keras.layers.Lambda(lambda z: K.reshape(z, [-1, height, width, n_filters]))(x)

  return x

# %% [markdown]
# ### Pointwise Group Convolution

# %%
def pw_group_conv(x, n_partitions, n_filters):
  ''' Build a pointwise group convolution
      x        : input tensor
      n_groups : number of groups to partition feature maps (channels) into.
      n_filers : number of filters
  '''

  # calculate the number of input filters (channels)
  in_filters = x.shape[3]
  # calculate the number of input filters (channels) per group
  grp_in_filters  = in_filters // n_partitions
  # calculate the number of output filters per group (Note the rounding up)
  grp_out_filters = int(n_filters / n_partitions + 0.5)
  # perform convolution across each channel group
  groups = []

  for i in range(n_partitions):
    # slice the input across channel group
    group = keras.layers.Lambda(lambda x: x[:, :, :, grp_in_filters * i: grp_in_filters * (i + 1)])(x)

    # perform convolution on channel group
    conv = keras.layers.Conv2D(filters=grp_out_filters, kernel_size=1, padding='same', strides=1, use_bias=False)(group)
    # maintain the point-wise group convolutions in a list
    groups.append(conv)

  if len(groups) > 1:
    # Concatenate the outputs of the group pointwise convolutions together
    x = keras.layers.Concatenate()(groups)
  else:
    x = groups[0]

  # Do batch normalization of the concatenated filters (feature maps)
  x = keras.layers.BatchNormalization()(x)

  return x

# %% [markdown]
# ### Shuffle Block

# %%
def shuffle_block(x, n_partitions, n_filters, reduction):
  ''' Build a shuffle block
      x           : input to the block
      n_partitions: number of groups to partition feature maps (channels) into.
      n_filters   : number of filters
      reduction   : dimensionality reduction factor (e.g, 0.25)
  '''

  # identity shortcut
  shortcut = x

  # pointwise group convolution, with dimensionality reduction
  x = pw_group_conv(x, n_partitions, int(reduction * n_filters))
  x = keras.layers.ReLU()(x)

  # channel shuffle layer
  x = channel_shuffle(x, n_partitions)

  # create a depthwise 3x3 convolution followed by batch normalization
  x = keras.layers.DepthwiseConv2D((3, 3), strides=1, padding='same', use_bias=False)(x)
  x = keras.layers.BatchNormalization()(x)

  # pointwise group convolution, with dimensionality restoration
  x = pw_group_conv(x, n_partitions, n_filters)

  # add the identity shortcut (input added to output)
  x = keras.layers.Add()([shortcut, x])
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# ### Strided Shuffle Block

# %%
def strided_shuffle_block(x, n_partitions, n_filters, reduction):
  ''' Build a strided shuffle block
      x           : input to the block
      n_partitions: number of groups to partition feature maps (channels) into.
      n_filters   : number of filters
      reduction   : dimensionality reduction factor (e.g, 0.25)
  '''

  # create a projection shortcut
  shortcut = x
  shortcut = keras.layers.AveragePooling2D(pool_size=3, strides=2, padding='same')(shortcut)

  # On entry block, we need to adjust the number of output filters
  # of the entry pointwise group convolution to match the exit
  # pointwise group convolution, by subtracting the number of input filters
  n_filters -= int(x.shape[3])

  # pointwise group convolution, with dimensionality reduction
  x = pw_group_conv(x, n_partitions, int(reduction * n_filters))
  x = keras.layers.ReLU()(x)

  # create a channel shuffle layer
  x = channel_shuffle(x, n_partitions)

  # create a depthwise 3x3 strided convolution
  x = keras.layers.DepthwiseConv2D(kernel_size=3, strides=2, padding='same', use_bias=False)(x)
  x = keras.layers.BatchNormalization()(x)

  # pointwise group convolution, with dimensionality restoration
  x = pw_group_conv(x, n_partitions, n_filters)

  # concatenate the projection shortcut to the output
  x = keras.layers.Concatenate()([shortcut, x])
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# ### Shuffle Group

# %%
def group(x, n_partitions, n_blocks, n_filters, reduction):
  ''' Build a shuffle group
      x            : input to the group
      n_partitions : number of groups to partition feature maps (channels) into.
      n_blocks     : number of shuffle blocks for this group
      n_filters    : number of output filters
      reduction    : dimensionality reduction
  '''

  # create a first block which is a strided shuffle block
  x = strided_shuffle_block(x, n_partitions, n_filters, reduction)

  # create the remaining shuffle blocks in the group
  for _ in range(n_blocks-1):
    x = shuffle_block(x, n_partitions, n_filters, reduction)

  return x

# %% [markdown]
# ### Learner component

# %%
def learner(x, groups, n_partitions, filters, reduction):
  ''' Build the learner component of ShuffleNet
	    x            : input to the learner
      groups       : number of shuffle blocks per shuffle group
      n_partitions : number of groups to partition feature maps (channels) into.
      filters      : number of filters per shuffle group
      reduction    : dimensionality reduction on entry to a shuffle block
  '''

  assert len(groups) == len(filters)-1

  # create the shuffle groups
  for i in range(len(groups)):
    x = group(x, n_partitions, groups[i], filters[i+1], reduction)

  return x

# %% [markdown]
# ## The task component

# %%
def task(x, n_classes):
  ''' Build the task component
      x         : input to the classifier
      n_classes : number of output classes
  '''
  # Use global average pooling to flatten feature maps to 1D vector, where
  # each feature map is a single averaged value (pixel) in flatten vector
  x = keras.layers.GlobalAveragePooling2D()(x)
  # softmax layer
  x = keras.layers.Dense(units=n_classes, activation='softmax')(x)

  return x

# %% [markdown]
# ## The ShuffleNet model

# %%
# number of groups to partition the filters (channels)
n_partitions=2

# number of groups to partition feature maps (key), and
# corresponding number of output filters (value)
filters = {
        1: [24, 144, 288, 576],
        2: [24, 200, 400, 800],
        3: [24, 240, 480, 960],
        4: [24, 272, 544, 1088],
        8: [24, 384, 768, 1536]
}

# the dimensionality reduction on entry to a shuffle block
reduction = 0.25

# number of shuffle blocks per shuffle group
groups = [4, 8, 4 ]

# %%
def build_shufflenet(groups, filters, reduction=0.25, n_partitions = 2, shape=(224, 224, 3), classes=1000):
  # input tensor
  inputs = keras.Input(shape=shape)
  # stem component
  x = stem(inputs)
  # learner component
  x = learner(x, groups, n_partitions, filters[n_partitions], reduction)
  # task component
  outputs = task(x, classes)

  return keras.Model(inputs=inputs, outputs=outputs, name="ShuffleNet")

# %%
# create a ShuffleNet model
shufflenet_model = build_shufflenet(groups, filters)
# print a summary
shufflenet_model.summary()
# Out:
# Model: "ShuffleNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_71 (Conv2D)          (None, 112, 112, 24)         648       ['input_4[0][0]']
#
#  batch_normalization_53 (Ba  (None, 112, 112, 24)         96        ['conv2d_71[0][0]']
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 112, 112, 24)         0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  max_pooling2d_3 (MaxPoolin  (None, 56, 56, 24)           0         ['re_lu_37[0][0]']
#  g2D)
#
#  lambda_120 (Lambda)         (None, 56, 56, 12)           0         ['max_pooling2d_3[0][0]']
#
#  lambda_121 (Lambda)         (None, 56, 56, 12)           0         ['max_pooling2d_3[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 56, 56, 22)           264       ['lambda_120[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 56, 56, 22)           264       ['lambda_121[0][0]']
#
#  concatenate_37 (Concatenat  (None, 56, 56, 44)           0         ['conv2d_72[0][0]',
#  e)                                                                  'conv2d_73[0][0]']
#
#  batch_normalization_54 (Ba  (None, 56, 56, 44)           176       ['concatenate_37[0][0]']
#  tchNormalization)
#
#  re_lu_38 (ReLU)             (None, 56, 56, 44)           0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  lambda_122 (Lambda)         (None, 56, 56, 2, 22)        0         ['re_lu_38[0][0]']
#
#  lambda_123 (Lambda)         (None, 56, 56, 22, 2)        0         ['lambda_122[0][0]']
#
#  lambda_124 (Lambda)         (None, 56, 56, 44)           0         ['lambda_123[0][0]']
#
#  depthwise_conv2d_16 (Depth  (None, 28, 28, 44)           396       ['lambda_124[0][0]']
#  wiseConv2D)
#
#  batch_normalization_55 (Ba  (None, 28, 28, 44)           176       ['depthwise_conv2d_16[0][0]']
#  tchNormalization)
#
#  lambda_125 (Lambda)         (None, 28, 28, 22)           0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  lambda_126 (Lambda)         (None, 28, 28, 22)           0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_74 (Conv2D)          (None, 28, 28, 88)           1936      ['lambda_125[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 28, 28, 88)           1936      ['lambda_126[0][0]']
#
#  concatenate_38 (Concatenat  (None, 28, 28, 176)          0         ['conv2d_74[0][0]',
#  e)                                                                  'conv2d_75[0][0]']
#
#  average_pooling2d_5 (Avera  (None, 28, 28, 24)           0         ['max_pooling2d_3[0][0]']
#  gePooling2D)
#
#  batch_normalization_56 (Ba  (None, 28, 28, 176)          704       ['concatenate_38[0][0]']
#  tchNormalization)
#
#  concatenate_39 (Concatenat  (None, 28, 28, 200)          0         ['average_pooling2d_5[0][0]',
#  e)                                                                  'batch_normalization_56[0][0]
#                                                                     ']
#
#  re_lu_39 (ReLU)             (None, 28, 28, 200)          0         ['concatenate_39[0][0]']
#
#  lambda_127 (Lambda)         (None, 28, 28, 100)          0         ['re_lu_39[0][0]']
#
#  lambda_128 (Lambda)         (None, 28, 28, 100)          0         ['re_lu_39[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 28, 28, 25)           2500      ['lambda_127[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 28, 28, 25)           2500      ['lambda_128[0][0]']
#
#  concatenate_40 (Concatenat  (None, 28, 28, 50)           0         ['conv2d_76[0][0]',
#  e)                                                                  'conv2d_77[0][0]']
#
#  batch_normalization_57 (Ba  (None, 28, 28, 50)           200       ['concatenate_40[0][0]']
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 28, 28, 50)           0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  lambda_129 (Lambda)         (None, 28, 28, 2, 25)        0         ['re_lu_40[0][0]']
#
#  lambda_130 (Lambda)         (None, 28, 28, 25, 2)        0         ['lambda_129[0][0]']
#
#  lambda_131 (Lambda)         (None, 28, 28, 50)           0         ['lambda_130[0][0]']
#
#  depthwise_conv2d_17 (Depth  (None, 28, 28, 50)           450       ['lambda_131[0][0]']
#  wiseConv2D)
#
#  batch_normalization_58 (Ba  (None, 28, 28, 50)           200       ['depthwise_conv2d_17[0][0]']
#  tchNormalization)
#
#  lambda_132 (Lambda)         (None, 28, 28, 25)           0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  lambda_133 (Lambda)         (None, 28, 28, 25)           0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_78 (Conv2D)          (None, 28, 28, 100)          2500      ['lambda_132[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 28, 28, 100)          2500      ['lambda_133[0][0]']
#
#  concatenate_41 (Concatenat  (None, 28, 28, 200)          0         ['conv2d_78[0][0]',
#  e)                                                                  'conv2d_79[0][0]']
#
#  batch_normalization_59 (Ba  (None, 28, 28, 200)          800       ['concatenate_41[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 28, 28, 200)          0         ['re_lu_39[0][0]',
#                                                                      'batch_normalization_59[0][0]
#                                                                     ']
#
#  re_lu_41 (ReLU)             (None, 28, 28, 200)          0         ['add_13[0][0]']
#
#  lambda_134 (Lambda)         (None, 28, 28, 100)          0         ['re_lu_41[0][0]']
#
#  lambda_135 (Lambda)         (None, 28, 28, 100)          0         ['re_lu_41[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 28, 28, 25)           2500      ['lambda_134[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 28, 28, 25)           2500      ['lambda_135[0][0]']
#
#  concatenate_42 (Concatenat  (None, 28, 28, 50)           0         ['conv2d_80[0][0]',
#  e)                                                                  'conv2d_81[0][0]']
#
#  batch_normalization_60 (Ba  (None, 28, 28, 50)           200       ['concatenate_42[0][0]']
#  tchNormalization)
#
#  re_lu_42 (ReLU)             (None, 28, 28, 50)           0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  lambda_136 (Lambda)         (None, 28, 28, 2, 25)        0         ['re_lu_42[0][0]']
#
#  lambda_137 (Lambda)         (None, 28, 28, 25, 2)        0         ['lambda_136[0][0]']
#
#  lambda_138 (Lambda)         (None, 28, 28, 50)           0         ['lambda_137[0][0]']
#
#  depthwise_conv2d_18 (Depth  (None, 28, 28, 50)           450       ['lambda_138[0][0]']
#  wiseConv2D)
#
#  batch_normalization_61 (Ba  (None, 28, 28, 50)           200       ['depthwise_conv2d_18[0][0]']
#  tchNormalization)
#
#  lambda_139 (Lambda)         (None, 28, 28, 25)           0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  lambda_140 (Lambda)         (None, 28, 28, 25)           0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 28, 28, 100)          2500      ['lambda_139[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 28, 28, 100)          2500      ['lambda_140[0][0]']
#
#  concatenate_43 (Concatenat  (None, 28, 28, 200)          0         ['conv2d_82[0][0]',
#  e)                                                                  'conv2d_83[0][0]']
#
#  batch_normalization_62 (Ba  (None, 28, 28, 200)          800       ['concatenate_43[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 28, 28, 200)          0         ['re_lu_41[0][0]',
#                                                                      'batch_normalization_62[0][0]
#                                                                     ']
#
#  re_lu_43 (ReLU)             (None, 28, 28, 200)          0         ['add_14[0][0]']
#
#  lambda_141 (Lambda)         (None, 28, 28, 100)          0         ['re_lu_43[0][0]']
#
#  lambda_142 (Lambda)         (None, 28, 28, 100)          0         ['re_lu_43[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 28, 28, 25)           2500      ['lambda_141[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 28, 28, 25)           2500      ['lambda_142[0][0]']
#
#  concatenate_44 (Concatenat  (None, 28, 28, 50)           0         ['conv2d_84[0][0]',
#  e)                                                                  'conv2d_85[0][0]']
#
#  batch_normalization_63 (Ba  (None, 28, 28, 50)           200       ['concatenate_44[0][0]']
#  tchNormalization)
#
#  re_lu_44 (ReLU)             (None, 28, 28, 50)           0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  lambda_143 (Lambda)         (None, 28, 28, 2, 25)        0         ['re_lu_44[0][0]']
#
#  lambda_144 (Lambda)         (None, 28, 28, 25, 2)        0         ['lambda_143[0][0]']
#
#  lambda_145 (Lambda)         (None, 28, 28, 50)           0         ['lambda_144[0][0]']
#
#  depthwise_conv2d_19 (Depth  (None, 28, 28, 50)           450       ['lambda_145[0][0]']
#  wiseConv2D)
#
#  batch_normalization_64 (Ba  (None, 28, 28, 50)           200       ['depthwise_conv2d_19[0][0]']
#  tchNormalization)
#
#  lambda_146 (Lambda)         (None, 28, 28, 25)           0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  lambda_147 (Lambda)         (None, 28, 28, 25)           0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 28, 28, 100)          2500      ['lambda_146[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 28, 28, 100)          2500      ['lambda_147[0][0]']
#
#  concatenate_45 (Concatenat  (None, 28, 28, 200)          0         ['conv2d_86[0][0]',
#  e)                                                                  'conv2d_87[0][0]']
#
#  batch_normalization_65 (Ba  (None, 28, 28, 200)          800       ['concatenate_45[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 28, 28, 200)          0         ['re_lu_43[0][0]',
#                                                                      'batch_normalization_65[0][0]
#                                                                     ']
#
#  re_lu_45 (ReLU)             (None, 28, 28, 200)          0         ['add_15[0][0]']
#
#  lambda_148 (Lambda)         (None, 28, 28, 100)          0         ['re_lu_45[0][0]']
#
#  lambda_149 (Lambda)         (None, 28, 28, 100)          0         ['re_lu_45[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 28, 28, 25)           2500      ['lambda_148[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 28, 28, 25)           2500      ['lambda_149[0][0]']
#
#  concatenate_46 (Concatenat  (None, 28, 28, 50)           0         ['conv2d_88[0][0]',
#  e)                                                                  'conv2d_89[0][0]']
#
#  batch_normalization_66 (Ba  (None, 28, 28, 50)           200       ['concatenate_46[0][0]']
#  tchNormalization)
#
#  re_lu_46 (ReLU)             (None, 28, 28, 50)           0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  lambda_150 (Lambda)         (None, 28, 28, 2, 25)        0         ['re_lu_46[0][0]']
#
#  lambda_151 (Lambda)         (None, 28, 28, 25, 2)        0         ['lambda_150[0][0]']
#
#  lambda_152 (Lambda)         (None, 28, 28, 50)           0         ['lambda_151[0][0]']
#
#  depthwise_conv2d_20 (Depth  (None, 14, 14, 50)           450       ['lambda_152[0][0]']
#  wiseConv2D)
#
#  batch_normalization_67 (Ba  (None, 14, 14, 50)           200       ['depthwise_conv2d_20[0][0]']
#  tchNormalization)
#
#  lambda_153 (Lambda)         (None, 14, 14, 25)           0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  lambda_154 (Lambda)         (None, 14, 14, 25)           0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  conv2d_90 (Conv2D)          (None, 14, 14, 100)          2500      ['lambda_153[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 14, 14, 100)          2500      ['lambda_154[0][0]']
#
#  concatenate_47 (Concatenat  (None, 14, 14, 200)          0         ['conv2d_90[0][0]',
#  e)                                                                  'conv2d_91[0][0]']
#
#  average_pooling2d_6 (Avera  (None, 14, 14, 200)          0         ['re_lu_45[0][0]']
#  gePooling2D)
#
#  batch_normalization_68 (Ba  (None, 14, 14, 200)          800       ['concatenate_47[0][0]']
#  tchNormalization)
#
#  concatenate_48 (Concatenat  (None, 14, 14, 400)          0         ['average_pooling2d_6[0][0]',
#  e)                                                                  'batch_normalization_68[0][0]
#                                                                     ']
#
#  re_lu_47 (ReLU)             (None, 14, 14, 400)          0         ['concatenate_48[0][0]']
#
#  lambda_155 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_47[0][0]']
#
#  lambda_156 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_47[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 14, 14, 50)           10000     ['lambda_155[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 14, 14, 50)           10000     ['lambda_156[0][0]']
#
#  concatenate_49 (Concatenat  (None, 14, 14, 100)          0         ['conv2d_92[0][0]',
#  e)                                                                  'conv2d_93[0][0]']
#
#  batch_normalization_69 (Ba  (None, 14, 14, 100)          400       ['concatenate_49[0][0]']
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 14, 14, 100)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  lambda_157 (Lambda)         (None, 14, 14, 2, 50)        0         ['re_lu_48[0][0]']
#
#  lambda_158 (Lambda)         (None, 14, 14, 50, 2)        0         ['lambda_157[0][0]']
#
#  lambda_159 (Lambda)         (None, 14, 14, 100)          0         ['lambda_158[0][0]']
#
#  depthwise_conv2d_21 (Depth  (None, 14, 14, 100)          900       ['lambda_159[0][0]']
#  wiseConv2D)
#
#  batch_normalization_70 (Ba  (None, 14, 14, 100)          400       ['depthwise_conv2d_21[0][0]']
#  tchNormalization)
#
#  lambda_160 (Lambda)         (None, 14, 14, 50)           0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  lambda_161 (Lambda)         (None, 14, 14, 50)           0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  conv2d_94 (Conv2D)          (None, 14, 14, 200)          10000     ['lambda_160[0][0]']
#
#  conv2d_95 (Conv2D)          (None, 14, 14, 200)          10000     ['lambda_161[0][0]']
#
#  concatenate_50 (Concatenat  (None, 14, 14, 400)          0         ['conv2d_94[0][0]',
#  e)                                                                  'conv2d_95[0][0]']
#
#  batch_normalization_71 (Ba  (None, 14, 14, 400)          1600      ['concatenate_50[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 14, 14, 400)          0         ['re_lu_47[0][0]',
#                                                                      'batch_normalization_71[0][0]
#                                                                     ']
#
#  re_lu_49 (ReLU)             (None, 14, 14, 400)          0         ['add_16[0][0]']
#
#  lambda_162 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_49[0][0]']
#
#  lambda_163 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_49[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 14, 14, 50)           10000     ['lambda_162[0][0]']
#
#  conv2d_97 (Conv2D)          (None, 14, 14, 50)           10000     ['lambda_163[0][0]']
#
#  concatenate_51 (Concatenat  (None, 14, 14, 100)          0         ['conv2d_96[0][0]',
#  e)                                                                  'conv2d_97[0][0]']
#
#  batch_normalization_72 (Ba  (None, 14, 14, 100)          400       ['concatenate_51[0][0]']
#  tchNormalization)
#
#  re_lu_50 (ReLU)             (None, 14, 14, 100)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  lambda_164 (Lambda)         (None, 14, 14, 2, 50)        0         ['re_lu_50[0][0]']
#
#  lambda_165 (Lambda)         (None, 14, 14, 50, 2)        0         ['lambda_164[0][0]']
#
#  lambda_166 (Lambda)         (None, 14, 14, 100)          0         ['lambda_165[0][0]']
#
#  depthwise_conv2d_22 (Depth  (None, 14, 14, 100)          900       ['lambda_166[0][0]']
#  wiseConv2D)
#
#  batch_normalization_73 (Ba  (None, 14, 14, 100)          400       ['depthwise_conv2d_22[0][0]']
#  tchNormalization)
#
#  lambda_167 (Lambda)         (None, 14, 14, 50)           0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  lambda_168 (Lambda)         (None, 14, 14, 50)           0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 14, 14, 200)          10000     ['lambda_167[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 14, 14, 200)          10000     ['lambda_168[0][0]']
#
#  concatenate_52 (Concatenat  (None, 14, 14, 400)          0         ['conv2d_98[0][0]',
#  e)                                                                  'conv2d_99[0][0]']
#
#  batch_normalization_74 (Ba  (None, 14, 14, 400)          1600      ['concatenate_52[0][0]']
#  tchNormalization)
#
#  add_17 (Add)                (None, 14, 14, 400)          0         ['re_lu_49[0][0]',
#                                                                      'batch_normalization_74[0][0]
#                                                                     ']
#
#  re_lu_51 (ReLU)             (None, 14, 14, 400)          0         ['add_17[0][0]']
#
#  lambda_169 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_51[0][0]']
#
#  lambda_170 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_51[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 14, 14, 50)           10000     ['lambda_169[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 14, 14, 50)           10000     ['lambda_170[0][0]']
#
#  concatenate_53 (Concatenat  (None, 14, 14, 100)          0         ['conv2d_100[0][0]',
#  e)                                                                  'conv2d_101[0][0]']
#
#  batch_normalization_75 (Ba  (None, 14, 14, 100)          400       ['concatenate_53[0][0]']
#  tchNormalization)
#
#  re_lu_52 (ReLU)             (None, 14, 14, 100)          0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  lambda_171 (Lambda)         (None, 14, 14, 2, 50)        0         ['re_lu_52[0][0]']
#
#  lambda_172 (Lambda)         (None, 14, 14, 50, 2)        0         ['lambda_171[0][0]']
#
#  lambda_173 (Lambda)         (None, 14, 14, 100)          0         ['lambda_172[0][0]']
#
#  depthwise_conv2d_23 (Depth  (None, 14, 14, 100)          900       ['lambda_173[0][0]']
#  wiseConv2D)
#
#  batch_normalization_76 (Ba  (None, 14, 14, 100)          400       ['depthwise_conv2d_23[0][0]']
#  tchNormalization)
#
#  lambda_174 (Lambda)         (None, 14, 14, 50)           0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  lambda_175 (Lambda)         (None, 14, 14, 50)           0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  conv2d_102 (Conv2D)         (None, 14, 14, 200)          10000     ['lambda_174[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 14, 14, 200)          10000     ['lambda_175[0][0]']
#
#  concatenate_54 (Concatenat  (None, 14, 14, 400)          0         ['conv2d_102[0][0]',
#  e)                                                                  'conv2d_103[0][0]']
#
#  batch_normalization_77 (Ba  (None, 14, 14, 400)          1600      ['concatenate_54[0][0]']
#  tchNormalization)
#
#  add_18 (Add)                (None, 14, 14, 400)          0         ['re_lu_51[0][0]',
#                                                                      'batch_normalization_77[0][0]
#                                                                     ']
#
#  re_lu_53 (ReLU)             (None, 14, 14, 400)          0         ['add_18[0][0]']
#
#  lambda_176 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_53[0][0]']
#
#  lambda_177 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_53[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 14, 14, 50)           10000     ['lambda_176[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 14, 14, 50)           10000     ['lambda_177[0][0]']
#
#  concatenate_55 (Concatenat  (None, 14, 14, 100)          0         ['conv2d_104[0][0]',
#  e)                                                                  'conv2d_105[0][0]']
#
#  batch_normalization_78 (Ba  (None, 14, 14, 100)          400       ['concatenate_55[0][0]']
#  tchNormalization)
#
#  re_lu_54 (ReLU)             (None, 14, 14, 100)          0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  lambda_178 (Lambda)         (None, 14, 14, 2, 50)        0         ['re_lu_54[0][0]']
#
#  lambda_179 (Lambda)         (None, 14, 14, 50, 2)        0         ['lambda_178[0][0]']
#
#  lambda_180 (Lambda)         (None, 14, 14, 100)          0         ['lambda_179[0][0]']
#
#  depthwise_conv2d_24 (Depth  (None, 14, 14, 100)          900       ['lambda_180[0][0]']
#  wiseConv2D)
#
#  batch_normalization_79 (Ba  (None, 14, 14, 100)          400       ['depthwise_conv2d_24[0][0]']
#  tchNormalization)
#
#  lambda_181 (Lambda)         (None, 14, 14, 50)           0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  lambda_182 (Lambda)         (None, 14, 14, 50)           0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_106 (Conv2D)         (None, 14, 14, 200)          10000     ['lambda_181[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 14, 14, 200)          10000     ['lambda_182[0][0]']
#
#  concatenate_56 (Concatenat  (None, 14, 14, 400)          0         ['conv2d_106[0][0]',
#  e)                                                                  'conv2d_107[0][0]']
#
#  batch_normalization_80 (Ba  (None, 14, 14, 400)          1600      ['concatenate_56[0][0]']
#  tchNormalization)
#
#  add_19 (Add)                (None, 14, 14, 400)          0         ['re_lu_53[0][0]',
#                                                                      'batch_normalization_80[0][0]
#                                                                     ']
#
#  re_lu_55 (ReLU)             (None, 14, 14, 400)          0         ['add_19[0][0]']
#
#  lambda_183 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_55[0][0]']
#
#  lambda_184 (Lambda)         (None, 14, 14, 200)          0         ['re_lu_55[0][0]']
# ...
#
#  lambda_212 (Lambda)         (None, 7, 7, 400)            0         ['re_lu_63[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 7, 7, 100)            40000     ['lambda_211[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 7, 7, 100)            40000     ['lambda_212[0][0]']
#
#  concatenate_66 (Concatenat  (None, 7, 7, 200)            0         ['conv2d_124[0][0]',
#  e)                                                                  'conv2d_125[0][0]']
#
#  batch_normalization_93 (Ba  (None, 7, 7, 200)            800       ['concatenate_66[0][0]']
#  tchNormalization)
#
#  re_lu_64 (ReLU)             (None, 7, 7, 200)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  lambda_213 (Lambda)         (None, 7, 7, 2, 100)         0         ['re_lu_64[0][0]']
#
#  lambda_214 (Lambda)         (None, 7, 7, 100, 2)         0         ['lambda_213[0][0]']
#
#  lambda_215 (Lambda)         (None, 7, 7, 200)            0         ['lambda_214[0][0]']
#
#  depthwise_conv2d_29 (Depth  (None, 7, 7, 200)            1800      ['lambda_215[0][0]']
#  wiseConv2D)
#
#  batch_normalization_94 (Ba  (None, 7, 7, 200)            800       ['depthwise_conv2d_29[0][0]']
#  tchNormalization)
#
#  lambda_216 (Lambda)         (None, 7, 7, 100)            0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  lambda_217 (Lambda)         (None, 7, 7, 100)            0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_126 (Conv2D)         (None, 7, 7, 400)            40000     ['lambda_216[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 7, 7, 400)            40000     ['lambda_217[0][0]']
#
#  concatenate_67 (Concatenat  (None, 7, 7, 800)            0         ['conv2d_126[0][0]',
#  e)                                                                  'conv2d_127[0][0]']
#
#  batch_normalization_95 (Ba  (None, 7, 7, 800)            3200      ['concatenate_67[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 7, 7, 800)            0         ['re_lu_63[0][0]',
#                                                                      'batch_normalization_95[0][0]
#                                                                     ']
#
#  re_lu_65 (ReLU)             (None, 7, 7, 800)            0         ['add_23[0][0]']
#
#  lambda_218 (Lambda)         (None, 7, 7, 400)            0         ['re_lu_65[0][0]']
#
#  lambda_219 (Lambda)         (None, 7, 7, 400)            0         ['re_lu_65[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 7, 7, 100)            40000     ['lambda_218[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 7, 7, 100)            40000     ['lambda_219[0][0]']
#
#  concatenate_68 (Concatenat  (None, 7, 7, 200)            0         ['conv2d_128[0][0]',
#  e)                                                                  'conv2d_129[0][0]']
#
#  batch_normalization_96 (Ba  (None, 7, 7, 200)            800       ['concatenate_68[0][0]']
#  tchNormalization)
#
#  re_lu_66 (ReLU)             (None, 7, 7, 200)            0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  lambda_220 (Lambda)         (None, 7, 7, 2, 100)         0         ['re_lu_66[0][0]']
#
#  lambda_221 (Lambda)         (None, 7, 7, 100, 2)         0         ['lambda_220[0][0]']
#
#  lambda_222 (Lambda)         (None, 7, 7, 200)            0         ['lambda_221[0][0]']
#
#  depthwise_conv2d_30 (Depth  (None, 7, 7, 200)            1800      ['lambda_222[0][0]']
#  wiseConv2D)
#
#  batch_normalization_97 (Ba  (None, 7, 7, 200)            800       ['depthwise_conv2d_30[0][0]']
#  tchNormalization)
#
#  lambda_223 (Lambda)         (None, 7, 7, 100)            0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  lambda_224 (Lambda)         (None, 7, 7, 100)            0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_130 (Conv2D)         (None, 7, 7, 400)            40000     ['lambda_223[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 7, 7, 400)            40000     ['lambda_224[0][0]']
#
#  concatenate_69 (Concatenat  (None, 7, 7, 800)            0         ['conv2d_130[0][0]',
#  e)                                                                  'conv2d_131[0][0]']
#
#  batch_normalization_98 (Ba  (None, 7, 7, 800)            3200      ['concatenate_69[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 7, 7, 800)            0         ['re_lu_65[0][0]',
#                                                                      'batch_normalization_98[0][0]
#                                                                     ']
#
#  re_lu_67 (ReLU)             (None, 7, 7, 800)            0         ['add_24[0][0]']
#
#  lambda_225 (Lambda)         (None, 7, 7, 400)            0         ['re_lu_67[0][0]']
#
#  lambda_226 (Lambda)         (None, 7, 7, 400)            0         ['re_lu_67[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 7, 7, 100)            40000     ['lambda_225[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 7, 7, 100)            40000     ['lambda_226[0][0]']
#
#  concatenate_70 (Concatenat  (None, 7, 7, 200)            0         ['conv2d_132[0][0]',
#  e)                                                                  'conv2d_133[0][0]']
#
#  batch_normalization_99 (Ba  (None, 7, 7, 200)            800       ['concatenate_70[0][0]']
#  tchNormalization)
#
#  re_lu_68 (ReLU)             (None, 7, 7, 200)            0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  lambda_227 (Lambda)         (None, 7, 7, 2, 100)         0         ['re_lu_68[0][0]']
#
#  lambda_228 (Lambda)         (None, 7, 7, 100, 2)         0         ['lambda_227[0][0]']
#
#  lambda_229 (Lambda)         (None, 7, 7, 200)            0         ['lambda_228[0][0]']
#
#  depthwise_conv2d_31 (Depth  (None, 7, 7, 200)            1800      ['lambda_229[0][0]']
#  wiseConv2D)
#
#  batch_normalization_100 (B  (None, 7, 7, 200)            800       ['depthwise_conv2d_31[0][0]']
#  atchNormalization)
#
#  lambda_230 (Lambda)         (None, 7, 7, 100)            0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  lambda_231 (Lambda)         (None, 7, 7, 100)            0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  conv2d_134 (Conv2D)         (None, 7, 7, 400)            40000     ['lambda_230[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 7, 7, 400)            40000     ['lambda_231[0][0]']
#
#  concatenate_71 (Concatenat  (None, 7, 7, 800)            0         ['conv2d_134[0][0]',
#  e)                                                                  'conv2d_135[0][0]']
#
#  batch_normalization_101 (B  (None, 7, 7, 800)            3200      ['concatenate_71[0][0]']
#  atchNormalization)
#
#  add_25 (Add)                (None, 7, 7, 800)            0         ['re_lu_67[0][0]',
#                                                                      'batch_normalization_101[0][0
#                                                                     ]']
#
#  re_lu_69 (ReLU)             (None, 7, 7, 800)            0         ['add_25[0][0]']
#
#  global_average_pooling2d_1  (None, 800)                  0         ['re_lu_69[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1000)                 801000    ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 1700396 (6.49 MB)
# Trainable params: 1680620 (6.41 MB)
# Non-trainable params: 19776 (77.25 KB)
# __________________________________________________________________________________________________
