# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/MobileNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %% [markdown]
# # MobileNet v1

# %% [markdown]
# ## The stem component

# %% [markdown]
# ### The depthwise separable conv block

# %%
def depthwise_block(x, n_filters, alpha, strides):
  """ Build a depthwise separable convolution block
      x         : input to the block
      n_filters : number of filters
      alpha     : width multiplier
      strides   : strides
  """
  # apply the width filter to the number of feature maps
  filters = int(n_filters * alpha)

  # strided convolution to match number of filters
  if strides == (2, 2):
    x = keras.layers.ZeroPadding2D(padding=((0, 1), (0, 1)))(x)
    padding = 'valid'
  else:
    padding = 'same'

  # apply depthwise convolution
  x = keras.layers.DepthwiseConv2D(kernel_size=3, strides=strides, padding=padding, use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(6.0)(x)

  # apply pointwise convolution
  x = keras.layers.Conv2D(filters=filters, kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(6.0)(x)

  return x

# %% [markdown]
# ### Stem Component

# %%
def stem(inputs, alpha):
  """ Build the stem component.
      inputs : input tensor
      alpha  : width multiplier
  """
  # apply zero-padding
  x = keras.layers.ZeroPadding2D(padding=((0, 1), (0, 1)))(inputs)
  x = keras.layers.Conv2D(filters=32 * alpha, kernel_size=3, strides=2, padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(6.0)(x)

  # Depthwise Separable Convolution Block
  x = depthwise_block(x, 64, alpha, (1, 1))

  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### Depthwise Separable Convolution Group

# %%
def group(x, n_filters, n_blocks, alpha):
  """ Build a Depthwise Separable Convolution Group
      x         : input to the group
      n_filters : number of filters
      n_blocks  : number of blocks in the group
      alpha     : width multiplier
  """
  # in the first block, the depthwise convolution is strided; feature map size reduction
  x = depthwise_block(x, n_filters, alpha, strides=(2, 2))

  # create the remaining blocks
  for _ in range(n_blocks - 1):
    x = depthwise_block(x, n_filters, alpha, strides=(1, 1))

  return x

# %% [markdown]
# ### Learner component

# %%
def learner(x, alpha):
  """ Build the learner component
      x      : input to the learner
      alpha  : width multiplier
  """
  # create the first depthwise separable convolution group
  x = group(x, 128, 2, alpha)
  # create the second depthwise separable convolution group
  x = group(x, 256, 2, alpha)
  # create the third depthwise separable convolution group
  x = group(x, 512, 6, alpha)
  # create the fourth depthwise separable convolution group
  x = group(x, 1024, 2, alpha)

  return x

# %% [markdown]
# ## The task component

# %%
def task(x, alpha, dropout, n_classes):
  """ Build the task component
      x         : input to the classifier
      alpha     : width multiplier
      dropout   : dropout percentage
      n_classes : number of output classes
  """
  # flatten the feature maps into 1D feature maps (?, N)
  x = keras.layers.GlobalAveragePooling2D()(x)

  # reshape the feature maps to (?, 1, 1, 1024)
  shape = (1, 1, int(1024 * alpha))
  x = keras.layers.Reshape(shape)(x)
  # apply dropout for preventing overfitting
  x = keras.layers.Dropout(dropout)(x)

  # use convolution for classifying (emulates a fully connected layer)
  x = keras.layers.Conv2D(filters=n_classes, kernel_size=1, padding='same', activation='softmax', kernel_initializer='glorot_uniform')(x)
  # Reshape the resulting output to 1D vector of number of classes
  x = keras.layers.Reshape((n_classes, ))(x)

  return x

# %% [markdown]
# ## The MobileNet v1 model

# %%
# width multiplier (0 .. 1) for reducing number of filters.
alpha      = 1
# resolution multiplier (0 .. 1) for reducing input size
pho        = 1
# dropout rate
dropout    = 0.5
# classes
classes = 1000

# %%
def build_mobilenet_v1(alpha=1, pho=1, dropout=0.5, classes=1000):

  # define the input tensor
  inputs = keras.Input(shape=(int(224 * pho), int(224 * pho), 3))
  # stem component
  x = stem(inputs, alpha)
  # learner component
  x = learner(x, alpha)
  # task component
  outputs = task(x, alpha, dropout, classes)

  # Instantiate the Model
  return keras.Model(inputs=inputs, outputs=outputs, name="MobileNet-v1")

# %%
# create the MobileNet v1 model
mobilenet_v1_model = build_mobilenet_v1()
# print a summary of the MobileNet v1 model
mobilenet_v1_model.summary()
# Out:
# Model: "MobileNet-v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  zero_padding2d_16 (ZeroPad  (None, 225, 225, 3)       0
#  ding2D)
#
#  conv2d_66 (Conv2D)          (None, 112, 112, 32)      864
#
#  batch_normalization_107 (B  (None, 112, 112, 32)      128
#  atchNormalization)
#
#  re_lu_90 (ReLU)             (None, 112, 112, 32)      0
#
#  depthwise_conv2d_43 (Depth  (None, 112, 112, 32)      288
#  wiseConv2D)
#
#  batch_normalization_108 (B  (None, 112, 112, 32)      128
#  atchNormalization)
#
#  re_lu_91 (ReLU)             (None, 112, 112, 32)      0
#
#  conv2d_67 (Conv2D)          (None, 112, 112, 64)      2048
#
#  batch_normalization_109 (B  (None, 112, 112, 64)      256
#  atchNormalization)
#
#  re_lu_92 (ReLU)             (None, 112, 112, 64)      0
#
#  zero_padding2d_17 (ZeroPad  (None, 113, 113, 64)      0
#  ding2D)
#
#  depthwise_conv2d_44 (Depth  (None, 56, 56, 64)        576
#  wiseConv2D)
#
#  batch_normalization_110 (B  (None, 56, 56, 64)        256
#  atchNormalization)
#
#  re_lu_93 (ReLU)             (None, 56, 56, 64)        0
#
#  conv2d_68 (Conv2D)          (None, 56, 56, 128)       8192
#
#  batch_normalization_111 (B  (None, 56, 56, 128)       512
#  atchNormalization)
#
#  re_lu_94 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_45 (Depth  (None, 56, 56, 128)       1152
#  wiseConv2D)
#
#  batch_normalization_112 (B  (None, 56, 56, 128)       512
#  atchNormalization)
#
#  re_lu_95 (ReLU)             (None, 56, 56, 128)       0
#
#  conv2d_69 (Conv2D)          (None, 56, 56, 128)       16384
#
#  batch_normalization_113 (B  (None, 56, 56, 128)       512
#  atchNormalization)
#
#  re_lu_96 (ReLU)             (None, 56, 56, 128)       0
#
#  zero_padding2d_18 (ZeroPad  (None, 57, 57, 128)       0
#  ding2D)
#
#  depthwise_conv2d_46 (Depth  (None, 28, 28, 128)       1152
#  wiseConv2D)
#
#  batch_normalization_114 (B  (None, 28, 28, 128)       512
#  atchNormalization)
#
#  re_lu_97 (ReLU)             (None, 28, 28, 128)       0
#
#  conv2d_70 (Conv2D)          (None, 28, 28, 256)       32768
#
#  batch_normalization_115 (B  (None, 28, 28, 256)       1024
#  atchNormalization)
#
#  re_lu_98 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_47 (Depth  (None, 28, 28, 256)       2304
#  wiseConv2D)
#
#  batch_normalization_116 (B  (None, 28, 28, 256)       1024
#  atchNormalization)
#
#  re_lu_99 (ReLU)             (None, 28, 28, 256)       0
#
#  conv2d_71 (Conv2D)          (None, 28, 28, 256)       65536
#
#  batch_normalization_117 (B  (None, 28, 28, 256)       1024
#  atchNormalization)
#
#  re_lu_100 (ReLU)            (None, 28, 28, 256)       0
#
#  zero_padding2d_19 (ZeroPad  (None, 29, 29, 256)       0
#  ding2D)
#
#  depthwise_conv2d_48 (Depth  (None, 14, 14, 256)       2304
#  wiseConv2D)
#
#  batch_normalization_118 (B  (None, 14, 14, 256)       1024
#  atchNormalization)
#
#  re_lu_101 (ReLU)            (None, 14, 14, 256)       0
#
#  conv2d_72 (Conv2D)          (None, 14, 14, 512)       131072
#
#  batch_normalization_119 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_102 (ReLU)            (None, 14, 14, 512)       0
#
#  depthwise_conv2d_49 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_120 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_103 (ReLU)            (None, 14, 14, 512)       0
#
#  conv2d_73 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_121 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_104 (ReLU)            (None, 14, 14, 512)       0
#
#  depthwise_conv2d_50 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_122 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_105 (ReLU)            (None, 14, 14, 512)       0
#
#  conv2d_74 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_123 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_106 (ReLU)            (None, 14, 14, 512)       0
#
#  depthwise_conv2d_51 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_124 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_107 (ReLU)            (None, 14, 14, 512)       0
#
#  conv2d_75 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_125 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_108 (ReLU)            (None, 14, 14, 512)       0
#
#  depthwise_conv2d_52 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_126 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_109 (ReLU)            (None, 14, 14, 512)       0
#
#  conv2d_76 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_127 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_110 (ReLU)            (None, 14, 14, 512)       0
#
#  depthwise_conv2d_53 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_128 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_111 (ReLU)            (None, 14, 14, 512)       0
#
#  conv2d_77 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_129 (B  (None, 14, 14, 512)       2048
#  atchNormalization)
#
#  re_lu_112 (ReLU)            (None, 14, 14, 512)       0
#
#  zero_padding2d_20 (ZeroPad  (None, 15, 15, 512)       0
#  ding2D)
#
#  depthwise_conv2d_54 (Depth  (None, 7, 7, 512)         4608
#  wiseConv2D)
#
#  batch_normalization_130 (B  (None, 7, 7, 512)         2048
#  atchNormalization)
#
#  re_lu_113 (ReLU)            (None, 7, 7, 512)         0
#
#  conv2d_78 (Conv2D)          (None, 7, 7, 1024)        524288
#
#  batch_normalization_131 (B  (None, 7, 7, 1024)        4096
#  atchNormalization)
#
#  re_lu_114 (ReLU)            (None, 7, 7, 1024)        0
#
#  depthwise_conv2d_55 (Depth  (None, 7, 7, 1024)        9216
#  wiseConv2D)
#
#  batch_normalization_132 (B  (None, 7, 7, 1024)        4096
#  atchNormalization)
#
#  re_lu_115 (ReLU)            (None, 7, 7, 1024)        0
#
#  conv2d_79 (Conv2D)          (None, 7, 7, 1024)        1048576
#
#  batch_normalization_133 (B  (None, 7, 7, 1024)        4096
#  atchNormalization)
#
#  re_lu_116 (ReLU)            (None, 7, 7, 1024)        0
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  reshape_4 (Reshape)         (None, 1, 1, 1024)        0
#
#  dropout_2 (Dropout)         (None, 1, 1, 1024)        0
#
#  conv2d_80 (Conv2D)          (None, 1, 1, 1000)        1025000
#
#  reshape_5 (Reshape)         (None, 1000)              0
#
# =================================================================
# Total params: 4253864 (16.23 MB)
# Trainable params: 4231976 (16.14 MB)
# Non-trainable params: 21888 (85.50 KB)
# _________________________________________________________________

# %% [markdown]
# # MobileNet v2

# %% [markdown]
# ## The stem component

# %%
def stem(inputs, alpha):
  """ Construct the Stem Group
      inputs : input tensor
      alpha  : width multiplier
  """
  # calculate the number of filters for the stem convolution (it must be divisible by 8)
  n_filters = max(8, (int(32 * alpha) + 4) // 8 * 8)

  # apply zero-padding
  x = keras.layers.ZeroPadding2D(padding=((0, 1), (0, 1)))(inputs)
  # a strided 3x3 conv layer followed by batch normalization
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=3, strides=2, padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(6.)(x)

  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### Inverted Residual Block

# %%
def inverted_block(x, n_filters, alpha, expansion=6, strides=(1, 1)):
  """ Build an inverted residual block
      x         : input to the block
      n_filters : number of filters
      alpha     : width multiplier
      strides   : strides
      expansion : multiplier for expanding number of filters
  """
  # save input
  shortcut = x

  # apply the width filter to the number of feature maps for the pointwise convolution
  filters = int(n_filters * alpha)

  # extract the number of channels
  n_channels = int(x.shape[3])

  # dimensionality expansion (non-first block)
  if expansion > 1:
    # a 1x1 linear convolution followed by batch normalization
    x = keras.layers.Conv2D(filters=expansion * n_channels, kernel_size=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.ReLU(6.)(x)

  # strided convolution to match number of filters
  if strides == (2, 2):
    x = keras.layers.ZeroPadding2D(padding=((0, 1), (0, 1)))(x)
    padding = 'valid'
  else:
    padding = 'same'

  # apply depthwise convolution
  x = keras.layers.DepthwiseConv2D(kernel_size=3, strides=strides, padding=padding, use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(6.)(x)

  # apply linear pointwise convolution
  x = keras.layers.Conv2D(filters=filters, kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)

  # number of input filters matches the number of output filters
  if n_channels == filters and strides == (1, 1):
    x = keras.layers.Add()([shortcut, x])

  return x

# %% [markdown]
# ### Residual Group

# %%
def group(x, n_filters, n_blocks, alpha, expansion=6, strides=(2, 2)):
  """ Build an inverted residual group
      x         : input to the group
      n_filters : number of filters
      n_blocks  : number of blocks in the group
      alpha     : width multiplier
      expansion : multiplier for expanding the number of filters
      strides   : whether first inverted residual block is strided.
  """
  # in the first block, the inverted residual block may be strided; feature map size reduction
  x = inverted_block(x, n_filters, alpha, expansion, strides=strides)

  # create the remaining blocks
  for _ in range(n_blocks - 1):
    x = inverted_block(x, n_filters, alpha, expansion, strides=(1, 1))

  return x

# %% [markdown]
# ### Learner component

# %%
def learner(x, alpha, expansion=6):
  """ Build the learner component.
      x        : input to the learner
      alpha    : width multiplier
      expansion: multipler to expand number of filters
  """

  # create the first inverted residual convolution group
  x = group(x, 16, 1, alpha, expansion=1, strides=(1, 1))
  # create the second inverted residual convolution group
  x = group(x, 24, 2, alpha, expansion)
  # create the third inverted residual convolution group
  x = group(x, 32, 3, alpha, expansion)
  # create the fourth inverted residual convolution group
  x = group(x, 64, 4, alpha, expansion)
  # create the fifth inverted residual convolution group
  x = group(x, 96, 3, alpha, expansion, strides=(1, 1))
  # create the sixth inverted residual convolution group
  x = group(x, 160, 3, alpha, expansion)
  # create the seventh inverted residual convolution group
  x = group(x, 320, 1, alpha, expansion, strides=(1, 1))
  # the last block is a 1x1 linear convolutional layer expanding the number of filters to 1280.
  x = keras.layers.Conv2D(filters=1280, kernel_size=1, use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU(6.)(x)

  return x

# %% [markdown]
# ## The task component

# %%
def task(x, n_classes):
  """ Build the task component
      x         : input to the classifier
      n_classes : number of output classes
  """
  # flatten the feature maps into 1D feature maps (?, N)
  x = keras.layers.GlobalAveragePooling2D()(x)

  # softmax layer
  x = keras.layers.Dense(units=n_classes, activation='softmax', kernel_initializer='glorot_uniform')(x)

  return x

# %% [markdown]
# ## The MobileNet v2 model

# %%
# width multiplier (0 .. 1) for reducing number of filters.
alpha = 1
# multiplier to expand number of filters
expansion = 6
# classes
classes=1000

# %%
def build_mobilenet_v2(alpha=1, expansion=6, shape=(224,224,3), classes=1000):
  # input tensor
  inputs = keras.Input(shape=shape)
  # stem component
  x = stem(inputs, alpha)
  # learner component
  x = learner(x, alpha, expansion)
  # task component
  outputs = task(x, classes)
  # return the model
  return keras.Model(inputs=inputs, outputs=outputs, name="MobileNet-v2")

# %%
# create the MobileNet v2 model
mobilenet_v2_model = build_mobilenet_v2()
# print a summary
mobilenet_v2_model.summary()
# Out:
# Model: "MobileNet-v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_21 (ZeroPad  (None, 225, 225, 3)          0         ['input_6[0][0]']
#  ding2D)
#
#  conv2d_81 (Conv2D)          (None, 112, 112, 32)         864       ['zero_padding2d_21[0][0]']
#
#  batch_normalization_134 (B  (None, 112, 112, 32)         128       ['conv2d_81[0][0]']
#  atchNormalization)
#
#  re_lu_117 (ReLU)            (None, 112, 112, 32)         0         ['batch_normalization_134[0][0
#                                                                     ]']
#
#  depthwise_conv2d_56 (Depth  (None, 112, 112, 32)         288       ['re_lu_117[0][0]']
#  wiseConv2D)
#
#  batch_normalization_135 (B  (None, 112, 112, 32)         128       ['depthwise_conv2d_56[0][0]']
#  atchNormalization)
#
#  re_lu_118 (ReLU)            (None, 112, 112, 32)         0         ['batch_normalization_135[0][0
#                                                                     ]']
#
#  conv2d_82 (Conv2D)          (None, 112, 112, 16)         512       ['re_lu_118[0][0]']
#
#  batch_normalization_136 (B  (None, 112, 112, 16)         64        ['conv2d_82[0][0]']
#  atchNormalization)
#
#  conv2d_83 (Conv2D)          (None, 112, 112, 96)         1536      ['batch_normalization_136[0][0
#                                                                     ]']
#
#  batch_normalization_137 (B  (None, 112, 112, 96)         384       ['conv2d_83[0][0]']
#  atchNormalization)
#
#  re_lu_119 (ReLU)            (None, 112, 112, 96)         0         ['batch_normalization_137[0][0
#                                                                     ]']
#
#  zero_padding2d_22 (ZeroPad  (None, 113, 113, 96)         0         ['re_lu_119[0][0]']
#  ding2D)
#
#  depthwise_conv2d_57 (Depth  (None, 56, 56, 96)           864       ['zero_padding2d_22[0][0]']
#  wiseConv2D)
#
#  batch_normalization_138 (B  (None, 56, 56, 96)           384       ['depthwise_conv2d_57[0][0]']
#  atchNormalization)
#
#  re_lu_120 (ReLU)            (None, 56, 56, 96)           0         ['batch_normalization_138[0][0
#                                                                     ]']
#
#  conv2d_84 (Conv2D)          (None, 56, 56, 24)           2304      ['re_lu_120[0][0]']
#
#  batch_normalization_139 (B  (None, 56, 56, 24)           96        ['conv2d_84[0][0]']
#  atchNormalization)
#
#  conv2d_85 (Conv2D)          (None, 56, 56, 144)          3456      ['batch_normalization_139[0][0
#                                                                     ]']
#
#  batch_normalization_140 (B  (None, 56, 56, 144)          576       ['conv2d_85[0][0]']
#  atchNormalization)
#
#  re_lu_121 (ReLU)            (None, 56, 56, 144)          0         ['batch_normalization_140[0][0
#                                                                     ]']
#
#  depthwise_conv2d_58 (Depth  (None, 56, 56, 144)          1296      ['re_lu_121[0][0]']
#  wiseConv2D)
#
#  batch_normalization_141 (B  (None, 56, 56, 144)          576       ['depthwise_conv2d_58[0][0]']
#  atchNormalization)
#
#  re_lu_122 (ReLU)            (None, 56, 56, 144)          0         ['batch_normalization_141[0][0
#                                                                     ]']
#
#  conv2d_86 (Conv2D)          (None, 56, 56, 24)           3456      ['re_lu_122[0][0]']
#
#  batch_normalization_142 (B  (None, 56, 56, 24)           96        ['conv2d_86[0][0]']
#  atchNormalization)
#
#  add_10 (Add)                (None, 56, 56, 24)           0         ['batch_normalization_139[0][0
#                                                                     ]',
#                                                                      'batch_normalization_142[0][0
#                                                                     ]']
#
#  conv2d_87 (Conv2D)          (None, 56, 56, 144)          3456      ['add_10[0][0]']
#
#  batch_normalization_143 (B  (None, 56, 56, 144)          576       ['conv2d_87[0][0]']
#  atchNormalization)
#
#  re_lu_123 (ReLU)            (None, 56, 56, 144)          0         ['batch_normalization_143[0][0
#                                                                     ]']
#
#  zero_padding2d_23 (ZeroPad  (None, 57, 57, 144)          0         ['re_lu_123[0][0]']
#  ding2D)
#
#  depthwise_conv2d_59 (Depth  (None, 28, 28, 144)          1296      ['zero_padding2d_23[0][0]']
#  wiseConv2D)
#
#  batch_normalization_144 (B  (None, 28, 28, 144)          576       ['depthwise_conv2d_59[0][0]']
#  atchNormalization)
#
#  re_lu_124 (ReLU)            (None, 28, 28, 144)          0         ['batch_normalization_144[0][0
#                                                                     ]']
#
#  conv2d_88 (Conv2D)          (None, 28, 28, 32)           4608      ['re_lu_124[0][0]']
#
#  batch_normalization_145 (B  (None, 28, 28, 32)           128       ['conv2d_88[0][0]']
#  atchNormalization)
#
#  conv2d_89 (Conv2D)          (None, 28, 28, 192)          6144      ['batch_normalization_145[0][0
#                                                                     ]']
#
#  batch_normalization_146 (B  (None, 28, 28, 192)          768       ['conv2d_89[0][0]']
#  atchNormalization)
#
#  re_lu_125 (ReLU)            (None, 28, 28, 192)          0         ['batch_normalization_146[0][0
#                                                                     ]']
#
#  depthwise_conv2d_60 (Depth  (None, 28, 28, 192)          1728      ['re_lu_125[0][0]']
#  wiseConv2D)
#
#  batch_normalization_147 (B  (None, 28, 28, 192)          768       ['depthwise_conv2d_60[0][0]']
#  atchNormalization)
#
#  re_lu_126 (ReLU)            (None, 28, 28, 192)          0         ['batch_normalization_147[0][0
#                                                                     ]']
#
#  conv2d_90 (Conv2D)          (None, 28, 28, 32)           6144      ['re_lu_126[0][0]']
#
#  batch_normalization_148 (B  (None, 28, 28, 32)           128       ['conv2d_90[0][0]']
#  atchNormalization)
#
#  add_11 (Add)                (None, 28, 28, 32)           0         ['batch_normalization_145[0][0
#                                                                     ]',
#                                                                      'batch_normalization_148[0][0
#                                                                     ]']
#
#  conv2d_91 (Conv2D)          (None, 28, 28, 192)          6144      ['add_11[0][0]']
#
#  batch_normalization_149 (B  (None, 28, 28, 192)          768       ['conv2d_91[0][0]']
#  atchNormalization)
#
#  re_lu_127 (ReLU)            (None, 28, 28, 192)          0         ['batch_normalization_149[0][0
#                                                                     ]']
#
#  depthwise_conv2d_61 (Depth  (None, 28, 28, 192)          1728      ['re_lu_127[0][0]']
#  wiseConv2D)
#
#  batch_normalization_150 (B  (None, 28, 28, 192)          768       ['depthwise_conv2d_61[0][0]']
#  atchNormalization)
#
#  re_lu_128 (ReLU)            (None, 28, 28, 192)          0         ['batch_normalization_150[0][0
#                                                                     ]']
#
#  conv2d_92 (Conv2D)          (None, 28, 28, 32)           6144      ['re_lu_128[0][0]']
#
#  batch_normalization_151 (B  (None, 28, 28, 32)           128       ['conv2d_92[0][0]']
#  atchNormalization)
#
#  add_12 (Add)                (None, 28, 28, 32)           0         ['add_11[0][0]',
#                                                                      'batch_normalization_151[0][0
#                                                                     ]']
#
#  conv2d_93 (Conv2D)          (None, 28, 28, 192)          6144      ['add_12[0][0]']
#
#  batch_normalization_152 (B  (None, 28, 28, 192)          768       ['conv2d_93[0][0]']
#  atchNormalization)
#
#  re_lu_129 (ReLU)            (None, 28, 28, 192)          0         ['batch_normalization_152[0][0
#                                                                     ]']
#
#  zero_padding2d_24 (ZeroPad  (None, 29, 29, 192)          0         ['re_lu_129[0][0]']
#  ding2D)
#
#  depthwise_conv2d_62 (Depth  (None, 14, 14, 192)          1728      ['zero_padding2d_24[0][0]']
#  wiseConv2D)
#
#  batch_normalization_153 (B  (None, 14, 14, 192)          768       ['depthwise_conv2d_62[0][0]']
#  atchNormalization)
#
#  re_lu_130 (ReLU)            (None, 14, 14, 192)          0         ['batch_normalization_153[0][0
#                                                                     ]']
#
#  conv2d_94 (Conv2D)          (None, 14, 14, 64)           12288     ['re_lu_130[0][0]']
#
#  batch_normalization_154 (B  (None, 14, 14, 64)           256       ['conv2d_94[0][0]']
#  atchNormalization)
#
#  conv2d_95 (Conv2D)          (None, 14, 14, 384)          24576     ['batch_normalization_154[0][0
#                                                                     ]']
#
#  batch_normalization_155 (B  (None, 14, 14, 384)          1536      ['conv2d_95[0][0]']
#  atchNormalization)
#
#  re_lu_131 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_155[0][0
#                                                                     ]']
#
#  depthwise_conv2d_63 (Depth  (None, 14, 14, 384)          3456      ['re_lu_131[0][0]']
#  wiseConv2D)
#
#  batch_normalization_156 (B  (None, 14, 14, 384)          1536      ['depthwise_conv2d_63[0][0]']
#  atchNormalization)
#
#  re_lu_132 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_156[0][0
#                                                                     ]']
#
#  conv2d_96 (Conv2D)          (None, 14, 14, 64)           24576     ['re_lu_132[0][0]']
#
#  batch_normalization_157 (B  (None, 14, 14, 64)           256       ['conv2d_96[0][0]']
#  atchNormalization)
#
#  add_13 (Add)                (None, 14, 14, 64)           0         ['batch_normalization_154[0][0
#                                                                     ]',
#                                                                      'batch_normalization_157[0][0
#                                                                     ]']
#
#  conv2d_97 (Conv2D)          (None, 14, 14, 384)          24576     ['add_13[0][0]']
#
#  batch_normalization_158 (B  (None, 14, 14, 384)          1536      ['conv2d_97[0][0]']
#  atchNormalization)
#
#  re_lu_133 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_158[0][0
#                                                                     ]']
#
#  depthwise_conv2d_64 (Depth  (None, 14, 14, 384)          3456      ['re_lu_133[0][0]']
#  wiseConv2D)
#
#  batch_normalization_159 (B  (None, 14, 14, 384)          1536      ['depthwise_conv2d_64[0][0]']
#  atchNormalization)
#
#  re_lu_134 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_159[0][0
#                                                                     ]']
#
#  conv2d_98 (Conv2D)          (None, 14, 14, 64)           24576     ['re_lu_134[0][0]']
#
#  batch_normalization_160 (B  (None, 14, 14, 64)           256       ['conv2d_98[0][0]']
#  atchNormalization)
#
#  add_14 (Add)                (None, 14, 14, 64)           0         ['add_13[0][0]',
#                                                                      'batch_normalization_160[0][0
#                                                                     ]']
#
#  conv2d_99 (Conv2D)          (None, 14, 14, 384)          24576     ['add_14[0][0]']
#
#  batch_normalization_161 (B  (None, 14, 14, 384)          1536      ['conv2d_99[0][0]']
#  atchNormalization)
#
#  re_lu_135 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_161[0][0
#                                                                     ]']
#
#  depthwise_conv2d_65 (Depth  (None, 14, 14, 384)          3456      ['re_lu_135[0][0]']
#  wiseConv2D)
#
#  batch_normalization_162 (B  (None, 14, 14, 384)          1536      ['depthwise_conv2d_65[0][0]']
#  atchNormalization)
#
#  re_lu_136 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_162[0][0
#                                                                     ]']
#
#  conv2d_100 (Conv2D)         (None, 14, 14, 64)           24576     ['re_lu_136[0][0]']
#
#  batch_normalization_163 (B  (None, 14, 14, 64)           256       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  add_15 (Add)                (None, 14, 14, 64)           0         ['add_14[0][0]',
#                                                                      'batch_normalization_163[0][0
#                                                                     ]']
#
#  conv2d_101 (Conv2D)         (None, 14, 14, 384)          24576     ['add_15[0][0]']
#
#  batch_normalization_164 (B  (None, 14, 14, 384)          1536      ['conv2d_101[0][0]']
#  atchNormalization)
#
#  re_lu_137 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_164[0][0
#                                                                     ]']
#
#  depthwise_conv2d_66 (Depth  (None, 14, 14, 384)          3456      ['re_lu_137[0][0]']
#  wiseConv2D)
#
#  batch_normalization_165 (B  (None, 14, 14, 384)          1536      ['depthwise_conv2d_66[0][0]']
#  atchNormalization)
#
#  re_lu_138 (ReLU)            (None, 14, 14, 384)          0         ['batch_normalization_165[0][0
#                                                                     ]']
#
#  conv2d_102 (Conv2D)         (None, 14, 14, 96)           36864     ['re_lu_138[0][0]']
#
#  batch_normalization_166 (B  (None, 14, 14, 96)           384       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  conv2d_103 (Conv2D)         (None, 14, 14, 576)          55296     ['batch_normalization_166[0][0
#                                                                     ]']
#
#  batch_normalization_167 (B  (None, 14, 14, 576)          2304      ['conv2d_103[0][0]']
#  atchNormalization)
#
#  re_lu_139 (ReLU)            (None, 14, 14, 576)          0         ['batch_normalization_167[0][0
#                                                                     ]']
#
#  depthwise_conv2d_67 (Depth  (None, 14, 14, 576)          5184      ['re_lu_139[0][0]']
#  wiseConv2D)
#
#  batch_normalization_168 (B  (None, 14, 14, 576)          2304      ['depthwise_conv2d_67[0][0]']
#  atchNormalization)
#
#  re_lu_140 (ReLU)            (None, 14, 14, 576)          0         ['batch_normalization_168[0][0
#                                                                     ]']
#
#  conv2d_104 (Conv2D)         (None, 14, 14, 96)           55296     ['re_lu_140[0][0]']
#
#  batch_normalization_169 (B  (None, 14, 14, 96)           384       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  add_16 (Add)                (None, 14, 14, 96)           0         ['batch_normalization_166[0][0
#                                                                     ]',
#                                                                      'batch_normalization_169[0][0
#                                                                     ]']
#
#  conv2d_105 (Conv2D)         (None, 14, 14, 576)          55296     ['add_16[0][0]']
#
#  batch_normalization_170 (B  (None, 14, 14, 576)          2304      ['conv2d_105[0][0]']
#  atchNormalization)
#
#  re_lu_141 (ReLU)            (None, 14, 14, 576)          0         ['batch_normalization_170[0][0
#                                                                     ]']
#
#  depthwise_conv2d_68 (Depth  (None, 14, 14, 576)          5184      ['re_lu_141[0][0]']
#  wiseConv2D)
#
#  batch_normalization_171 (B  (None, 14, 14, 576)          2304      ['depthwise_conv2d_68[0][0]']
#  atchNormalization)
#
#  re_lu_142 (ReLU)            (None, 14, 14, 576)          0         ['batch_normalization_171[0][0
#                                                                     ]']
#
#  conv2d_106 (Conv2D)         (None, 14, 14, 96)           55296     ['re_lu_142[0][0]']
#
#  batch_normalization_172 (B  (None, 14, 14, 96)           384       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  add_17 (Add)                (None, 14, 14, 96)           0         ['add_16[0][0]',
#                                                                      'batch_normalization_172[0][0
#                                                                     ]']
#
#  conv2d_107 (Conv2D)         (None, 14, 14, 576)          55296     ['add_17[0][0]']
#
#  batch_normalization_173 (B  (None, 14, 14, 576)          2304      ['conv2d_107[0][0]']
#  atchNormalization)
#
#  re_lu_143 (ReLU)            (None, 14, 14, 576)          0         ['batch_normalization_173[0][0
#                                                                     ]']
#
#  zero_padding2d_25 (ZeroPad  (None, 15, 15, 576)          0         ['re_lu_143[0][0]']
#  ding2D)
#
#  depthwise_conv2d_69 (Depth  (None, 7, 7, 576)            5184      ['zero_padding2d_25[0][0]']
#  wiseConv2D)
#
#  batch_normalization_174 (B  (None, 7, 7, 576)            2304      ['depthwise_conv2d_69[0][0]']
#  atchNormalization)
#
#  re_lu_144 (ReLU)            (None, 7, 7, 576)            0         ['batch_normalization_174[0][0
#                                                                     ]']
#
#  conv2d_108 (Conv2D)         (None, 7, 7, 160)            92160     ['re_lu_144[0][0]']
#
#  batch_normalization_175 (B  (None, 7, 7, 160)            640       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  conv2d_109 (Conv2D)         (None, 7, 7, 960)            153600    ['batch_normalization_175[0][0
#                                                                     ]']
#
#  batch_normalization_176 (B  (None, 7, 7, 960)            3840      ['conv2d_109[0][0]']
#  atchNormalization)
#
#  re_lu_145 (ReLU)            (None, 7, 7, 960)            0         ['batch_normalization_176[0][0
#                                                                     ]']
#
#  depthwise_conv2d_70 (Depth  (None, 7, 7, 960)            8640      ['re_lu_145[0][0]']
#  wiseConv2D)
#
#  batch_normalization_177 (B  (None, 7, 7, 960)            3840      ['depthwise_conv2d_70[0][0]']
#  atchNormalization)
#
#  re_lu_146 (ReLU)            (None, 7, 7, 960)            0         ['batch_normalization_177[0][0
#                                                                     ]']
#
#  conv2d_110 (Conv2D)         (None, 7, 7, 160)            153600    ['re_lu_146[0][0]']
#
#  batch_normalization_178 (B  (None, 7, 7, 160)            640       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  add_18 (Add)                (None, 7, 7, 160)            0         ['batch_normalization_175[0][0
#                                                                     ]',
#                                                                      'batch_normalization_178[0][0
#                                                                     ]']
#
#  conv2d_111 (Conv2D)         (None, 7, 7, 960)            153600    ['add_18[0][0]']
#
#  batch_normalization_179 (B  (None, 7, 7, 960)            3840      ['conv2d_111[0][0]']
#  atchNormalization)
#
#  re_lu_147 (ReLU)            (None, 7, 7, 960)            0         ['batch_normalization_179[0][0
#                                                                     ]']
#
#  depthwise_conv2d_71 (Depth  (None, 7, 7, 960)            8640      ['re_lu_147[0][0]']
#  wiseConv2D)
#
#  batch_normalization_180 (B  (None, 7, 7, 960)            3840      ['depthwise_conv2d_71[0][0]']
#  atchNormalization)
#
#  re_lu_148 (ReLU)            (None, 7, 7, 960)            0         ['batch_normalization_180[0][0
#                                                                     ]']
#
#  conv2d_112 (Conv2D)         (None, 7, 7, 160)            153600    ['re_lu_148[0][0]']
#
#  batch_normalization_181 (B  (None, 7, 7, 160)            640       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  add_19 (Add)                (None, 7, 7, 160)            0         ['add_18[0][0]',
#                                                                      'batch_normalization_181[0][0
#                                                                     ]']
#
#  conv2d_113 (Conv2D)         (None, 7, 7, 960)            153600    ['add_19[0][0]']
#
#  batch_normalization_182 (B  (None, 7, 7, 960)            3840      ['conv2d_113[0][0]']
#  atchNormalization)
#
#  re_lu_149 (ReLU)            (None, 7, 7, 960)            0         ['batch_normalization_182[0][0
#                                                                     ]']
#
#  depthwise_conv2d_72 (Depth  (None, 7, 7, 960)            8640      ['re_lu_149[0][0]']
#  wiseConv2D)
#
#  batch_normalization_183 (B  (None, 7, 7, 960)            3840      ['depthwise_conv2d_72[0][0]']
#  atchNormalization)
#
#  re_lu_150 (ReLU)            (None, 7, 7, 960)            0         ['batch_normalization_183[0][0
#                                                                     ]']
#
#  conv2d_114 (Conv2D)         (None, 7, 7, 320)            307200    ['re_lu_150[0][0]']
#
#  batch_normalization_184 (B  (None, 7, 7, 320)            1280      ['conv2d_114[0][0]']
#  atchNormalization)
#
#  conv2d_115 (Conv2D)         (None, 7, 7, 1280)           409600    ['batch_normalization_184[0][0
#                                                                     ]']
#
#  batch_normalization_185 (B  (None, 7, 7, 1280)           5120      ['conv2d_115[0][0]']
#  atchNormalization)
#
#  re_lu_151 (ReLU)            (None, 7, 7, 1280)           0         ['batch_normalization_185[0][0
#                                                                     ]']
#
#  global_average_pooling2d_4  (None, 1280)                 0         ['re_lu_151[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1000)                 1281000   ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 3538984 (13.50 MB)
# Trainable params: 3504872 (13.37 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________
