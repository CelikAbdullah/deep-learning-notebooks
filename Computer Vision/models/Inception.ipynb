# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/Inception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %% [markdown]
# # Inception v1

# %% [markdown]
# ## The stem component

# %%
def stem(inputs):
  '''
  Build the stem component of Inception v1.
  It extracts the coarse-level features of the input.

  input: the input image
  '''

  # apply ZeroPadding so that the size of the input is preserved
  x = keras.layers.ZeroPadding2D(padding=3)(inputs)

  # apply a strided 7x7 convolution to extract features
  # it will generate 64 output feature maps
  x = keras.layers.Conv2D(filters=64,
                          kernel_size=7,
                          strides=2,
                          padding="valid",
                          activation="relu",
                          kernel_initializer="glorot_uniform"
                          )(x)

  # again, apply ZeroPadding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # apply strided max pooling with a 3x3 window
  # the size of each feature map will be reduced by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)

  # apply a 1x1 convolution
  x = keras.layers.Conv2D(filters = 64,
                          kernel_size=1,
                          padding="same",
                          activation="relu",
                          kernel_initializer="glorot_uniform")(x)

  # zero-padding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # a 3x3 convolution; it will output 192 feature maps
  x = keras.layers.Conv2D(filters=192,
                          kernel_size=3,
                          strides=1,
                          padding="valid",
                          activation="relu",
                          kernel_initializer="glorot_uniform"
                          )(x)

  # zero-padding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # apply strided max pooling with a 3x3 window
  # the size of each feature map will be reduced by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)


  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### Auxiliary Classifier

# %%
def auxiliary(x, classes):
  '''
  Build the auxiliary classifier.

  x       : input to the auxiliary classifier
  classes : number of output classes
  '''

  # strided average pooling operation with a 5x5 window
  x = keras.layers.AveragePooling2D(pool_size=5, strides=3)(x)

  # a 1x1 convolution which will output 128 feature maps
  x = keras.layers.Conv2D(filters=128,
                          kernel_size=1,
                          padding="same",
                          activation="relu",
                          kernel_initializer="glorot_uniform"
                          )(x)

  # flatten the feature maps before passing them to the Dense layer
  x = keras.layers.Flatten()(x)

  # a fully connected layer with 1024 neurons
  x = keras.layers.Dense(units=1024,
                         activation="relu",
                         kernel_initializer="glorot_uniform")(x)

  # dropout layer for regularization
  x = keras.layers.Dropout(rate=0.7)(x)

  # softmax layer to output probabilities for each class
  output = keras.layers.Dense(units=classes,
                              activation="softmax",
                              kernel_initializer="glorot_uniform")(x)


  return output

# %% [markdown]
# ### Inception Block

# %%
def inception_block(input, filters_1x1, filters_3x3, filters_5x5, filter_pool):
  '''
  Build the inception block/module.

  input : input to the inception block/module
  filters_1x1 : nr. of filters for the 1x1 conv branch of the inception module
  filters_3x3 : nr. of filters for the 3x3 conv branch of the inception model
  filters_5x5 : nr. of filters for the 5x5 conv branch of the inception module
  filters_pool: nr. of filters for the max pooling branch of the inception module
  '''

  # create the 1x1 conv branch
  branch_1x1 = keras.layers.Conv2D(filters=filters_1x1[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(input)

  # create the 3x3 conv branch with the 1x1 bottleneck convolution that performs dimensionality reduction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(input)

  branch_3x3 = keras.layers.ZeroPadding2D(padding=1)(branch_3x3)
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[1],
                                   kernel_size=3,
                                   strides=1,
                                   padding="valid",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(branch_3x3)

  # create the 5x5 conv branch with the 1x1 bottleneck convolution that performs dimensionality reduction
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(input)

  branch_5x5 = keras.layers.ZeroPadding2D(padding=1)(branch_5x5)
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[1],
                                   kernel_size=3,
                                   strides=1,
                                   padding="valid",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(branch_5x5)

  # create the max pooling branch with 1x1 linear projection for dimensionality expansion
  branch_pool = keras.layers.MaxPooling2D(pool_size=3,
                                          strides=1,
                                          padding="same")(input)

  branch_pool = keras.layers.Conv2D(filters=filter_pool[0],
                                    kernel_size=1,
                                    strides=1,
                                    padding='same',
                                    activation='relu',
                                    kernel_initializer='glorot_uniform')(branch_pool)


  # Concatenate the output feature maps of the branches
  x = keras.layers.Concatenate()([branch_1x1, branch_3x3, branch_5x5, branch_pool])

  return x

# %% [markdown]
# ### Inception Group

# %%
def group(x, blocks, pooling=True, classes=1000):
  '''
  Build an Inception group.

  x       : input to the inception group
  blocks  : list of tuples containing nr. of filters for each block in the group
  pooling : flag indicating whether to end the group with max pooling
  classes : nr. of classes for auxiliary classifier
  '''

  # list to save the auxiliary outputs
  aux = []

  # build the inception blocks
  for block in blocks:

    # adding the auxiliary classifier
    if block is None:
      # save the auxiliary output
      aux.append(auxiliary(x,classes))

    else:
       # create inception block
       x = inception_block(x,
                           block[0],
                           block[1],
                           block[2],
                           block[3])


  # if pooling is True
  if pooling:
    # zero-padding
    x = keras.layers.ZeroPadding2D(padding=(1,1))(x)

    # max pooling
    x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)


  return x, aux

# %% [markdown]
# Now, we can finally build the learner component of Inception v1:

# %%
def learner(x, classes):
  '''
  Build the learner component.

  x       : input to the learner
  classes : nr. of classes
  '''

  # a list to store outputs from the auxiliary classifiers
  aux = []

  # set the block specs for group 3
  blocks = [((64,),  (96,128),   (16, 32), (32,)),
            ((128,), (128, 192), (32, 96), (64,))]

  # build group 3
  x, o = group(x, blocks)
  aux += o

  # set block spec for group 4
  blocks = [((192,),  (96, 208), (16, 48), (64,)),
            None,
            ((160,), (112, 224), (24, 64), (64,)),
            ((128,), (128, 256), (24, 64), (64,)),
            ((112,), (144, 288), (32, 64), (64,)),
            None,
            ((256,), (160, 320), (32, 128), (128,))]

  # build group 4
  x, o = group(x, blocks, classes=classes)
  aux += o

  # set block specs for group 5
  blocks = [((256,), (160, 320), (32, 128), (128,)),
            ((384,), (192, 384), (48, 128), (128,))]
  # build group 5
  x, o = group(x, blocks, pooling=False)
  aux += o


  return x, aux

# %% [markdown]
# ## The task component

# %%
def task(x, classes, dropout=0.4):
  '''
  Build the task component.

  x       : input to the task component
  classes : nr. of output classes
  dropout : dropout rate
  '''

  # a 7x7 average pooling
  x = keras.layers.AveragePooling2D(pool_size=7)(x)

  # flatten the output from the avg pooling
  x = keras.layers.Flatten()(x)

  # dropout for regularization
  x = keras.layers.Dropout(rate=dropout)(x)

  # softmax layer
  outputs = keras.layers.Dense(units=classes,
                               activation="softmax",
                               kernel_initializer="glorot_uniform")(x)

  return outputs

# %% [markdown]
# ## Inception model v1

# %%
def build_model(shape=(224, 224, 3), dropout=0.4):

  # define inputs
  inputs = keras.layers.Input(shape=shape)

  # the stem component
  x = stem(inputs)

  # the learner component
  x, aux = learner(x, 1000)

  # the task component
  outputs = task(x, 1000, dropout)

  # build the model
  model = keras.Model(inputs=inputs,
                      outputs=[outputs] + aux,
                      name="inception_v1")

  return model

# %%
# create the inception model (v1)
inception_model_v1 = build_model()

# print a summary
inception_model_v1.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['zero_padding2d[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 114, 114, 64)         0         ['conv2d[0][0]']
#  ing2D)
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['zero_padding2d_1[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 64)           4160      ['max_pooling2d[0][0]']
#
#  zero_padding2d_2 (ZeroPadd  (None, 58, 58, 64)           0         ['conv2d_1[0][0]']
#  ing2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 192)          110784    ['zero_padding2d_2[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 58, 58, 192)          0         ['conv2d_2[0][0]']
#  ing2D)
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 192)          0         ['zero_padding2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 96)           18528     ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 16)           3088      ['max_pooling2d_1[0][0]']
#
#  zero_padding2d_4 (ZeroPadd  (None, 30, 30, 96)           0         ['conv2d_4[0][0]']
#  ing2D)
#
#  zero_padding2d_5 (ZeroPadd  (None, 30, 30, 16)           0         ['conv2d_6[0][0]']
#  ing2D)
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 192)          0         ['max_pooling2d_1[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)           12352     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 128)          110720    ['zero_padding2d_4[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 32)           4640      ['zero_padding2d_5[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)           6176      ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)   (None, 28, 28, 256)          0         ['conv2d_3[0][0]',
#                                                                      'conv2d_5[0][0]',
#                                                                      'conv2d_7[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 32)           8224      ['concatenate[0][0]']
#
#  zero_padding2d_6 (ZeroPadd  (None, 30, 30, 128)          0         ['conv2d_10[0][0]']
#  ing2D)
#
#  zero_padding2d_7 (ZeroPadd  (None, 30, 30, 32)           0         ['conv2d_12[0][0]']
#  ing2D)
#
#  max_pooling2d_3 (MaxPoolin  (None, 28, 28, 256)          0         ['concatenate[0][0]']
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 192)          221376    ['zero_padding2d_6[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 96)           27744     ['zero_padding2d_7[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 64)           16448     ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 28, 28, 480)          0         ['conv2d_9[0][0]',
#  )                                                                   'conv2d_11[0][0]',
#                                                                      'conv2d_13[0][0]',
#                                                                      'conv2d_14[0][0]']
#
#  zero_padding2d_8 (ZeroPadd  (None, 30, 30, 480)          0         ['concatenate_1[0][0]']
#  ing2D)
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 480)          0         ['zero_padding2d_8[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 96)           46176     ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 16)           7696      ['max_pooling2d_4[0][0]']
#
#  zero_padding2d_9 (ZeroPadd  (None, 16, 16, 96)           0         ['conv2d_16[0][0]']
#  ing2D)
#
#  zero_padding2d_10 (ZeroPad  (None, 16, 16, 16)           0         ['conv2d_18[0][0]']
#  ding2D)
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 480)          0         ['max_pooling2d_4[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 192)          92352     ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 208)          179920    ['zero_padding2d_9[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 48)           6960      ['zero_padding2d_10[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 64)           30784     ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_15[0][0]',
#  )                                                                   'conv2d_17[0][0]',
#                                                                      'conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 112)          57456     ['concatenate_2[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 24)           12312     ['concatenate_2[0][0]']
#
#  zero_padding2d_11 (ZeroPad  (None, 16, 16, 112)          0         ['conv2d_23[0][0]']
#  ding2D)
#
#  zero_padding2d_12 (ZeroPad  (None, 16, 16, 24)           0         ['conv2d_25[0][0]']
#  ding2D)
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_2[0][0]']
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 160)          82080     ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 224)          226016    ['zero_padding2d_11[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 64)           13888     ['zero_padding2d_12[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_22[0][0]',
#  )                                                                   'conv2d_24[0][0]',
#                                                                      'conv2d_26[0][0]',
#                                                                      'conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 24)           12312     ['concatenate_3[0][0]']
#
#  zero_padding2d_13 (ZeroPad  (None, 16, 16, 128)          0         ['conv2d_29[0][0]']
#  ding2D)
#
#  zero_padding2d_14 (ZeroPad  (None, 16, 16, 24)           0         ['conv2d_31[0][0]']
#  ding2D)
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_3[0][0]']
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 14, 14, 256)          295168    ['zero_padding2d_13[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 64)           13888     ['zero_padding2d_14[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_28[0][0]',
#  )                                                                   'conv2d_30[0][0]',
#                                                                      'conv2d_32[0][0]',
#                                                                      'conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 144)          73872     ['concatenate_4[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 14, 14, 32)           16416     ['concatenate_4[0][0]']
#
#  zero_padding2d_15 (ZeroPad  (None, 16, 16, 144)          0         ['conv2d_35[0][0]']
#  ding2D)
#
#  zero_padding2d_16 (ZeroPad  (None, 16, 16, 32)           0         ['conv2d_37[0][0]']
#  ding2D)
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_4[0][0]']
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 112)          57456     ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 288)          373536    ['zero_padding2d_15[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 14, 14, 64)           18496     ['zero_padding2d_16[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate  (None, 14, 14, 528)          0         ['conv2d_34[0][0]',
#  )                                                                   'conv2d_36[0][0]',
#                                                                      'conv2d_38[0][0]',
#                                                                      'conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 160)          84640     ['concatenate_5[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 14, 14, 32)           16928     ['concatenate_5[0][0]']
#
#  zero_padding2d_17 (ZeroPad  (None, 16, 16, 160)          0         ['conv2d_42[0][0]']
#  ding2D)
#
#  zero_padding2d_18 (ZeroPad  (None, 16, 16, 32)           0         ['conv2d_44[0][0]']
#  ding2D)
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 528)          0         ['concatenate_5[0][0]']
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 256)          135424    ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 320)          461120    ['zero_padding2d_17[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 14, 14, 128)          36992     ['zero_padding2d_18[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 14, 14, 128)          67712     ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate  (None, 14, 14, 832)          0         ['conv2d_41[0][0]',
#  )                                                                   'conv2d_43[0][0]',
#                                                                      'conv2d_45[0][0]',
#                                                                      'conv2d_46[0][0]']
#
#  zero_padding2d_19 (ZeroPad  (None, 16, 16, 832)          0         ['concatenate_6[0][0]']
#  ding2D)
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 832)            0         ['zero_padding2d_19[0][0]']
#  ng2D)
#
#  conv2d_48 (Conv2D)          (None, 7, 7, 160)            133280    ['max_pooling2d_10[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 7, 7, 32)             26656     ['max_pooling2d_10[0][0]']
#
#  zero_padding2d_20 (ZeroPad  (None, 9, 9, 160)            0         ['conv2d_48[0][0]']
#  ding2D)
#
#  zero_padding2d_21 (ZeroPad  (None, 9, 9, 32)             0         ['conv2d_50[0][0]']
#  ding2D)
#
#  max_pooling2d_11 (MaxPooli  (None, 7, 7, 832)            0         ['max_pooling2d_10[0][0]']
#  ng2D)
#
#  conv2d_47 (Conv2D)          (None, 7, 7, 256)            213248    ['max_pooling2d_10[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 7, 7, 320)            461120    ['zero_padding2d_20[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 7, 7, 128)            36992     ['zero_padding2d_21[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate  (None, 7, 7, 832)            0         ['conv2d_47[0][0]',
#  )                                                                   'conv2d_49[0][0]',
#                                                                      'conv2d_51[0][0]',
#                                                                      'conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 7, 7, 192)            159936    ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 7, 7, 48)             39984     ['concatenate_7[0][0]']
#
#  zero_padding2d_22 (ZeroPad  (None, 9, 9, 192)            0         ['conv2d_54[0][0]']
#  ding2D)
#
#  zero_padding2d_23 (ZeroPad  (None, 9, 9, 48)             0         ['conv2d_56[0][0]']
#  ding2D)
#
#  max_pooling2d_12 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_7[0][0]']
#  ng2D)
#
#  conv2d_53 (Conv2D)          (None, 7, 7, 384)            319872    ['concatenate_7[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 7, 7, 384)            663936    ['zero_padding2d_22[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 7, 7, 128)            55424     ['zero_padding2d_23[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_12[0][0]']
#
#  average_pooling2d (Average  (None, 4, 4, 512)            0         ['concatenate_2[0][0]']
#  Pooling2D)
#
#  average_pooling2d_1 (Avera  (None, 4, 4, 528)            0         ['concatenate_5[0][0]']
#  gePooling2D)
#
#  concatenate_8 (Concatenate  (None, 7, 7, 1024)           0         ['conv2d_53[0][0]',
#  )                                                                   'conv2d_55[0][0]',
#                                                                      'conv2d_57[0][0]',
#                                                                      'conv2d_58[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 4, 4, 128)            65664     ['average_pooling2d[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 4, 4, 128)            67712     ['average_pooling2d_1[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 1, 1, 1024)           0         ['concatenate_8[0][0]']
#  gePooling2D)
#
#  flatten (Flatten)           (None, 2048)                 0         ['conv2d_21[0][0]']
#
#  flatten_1 (Flatten)         (None, 2048)                 0         ['conv2d_40[0][0]']
#
#  flatten_2 (Flatten)         (None, 1024)                 0         ['average_pooling2d_2[0][0]']
#
#  dense (Dense)               (None, 1024)                 2098176   ['flatten[0][0]']
#
#  dense_2 (Dense)             (None, 1024)                 2098176   ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 1024)                 0         ['flatten_2[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['dense[0][0]']
#
#  dropout_1 (Dropout)         (None, 1024)                 0         ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 1000)                 1025000   ['dropout_2[0][0]']
#
#  dense_1 (Dense)             (None, 1000)                 1025000   ['dropout[0][0]']
#
#  dense_3 (Dense)             (None, 1000)                 1025000   ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 12997352 (49.58 MB)
# Trainable params: 12997352 (49.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Inception v2

# %% [markdown]
# ## The stem component

# %%
def stem(inputs):
  '''
  Build the stem component of Inception v1.
  It extracts the coarse-level features of the input.

  input: the input image
  '''

  # apply ZeroPadding so that the size of the input is preserved
  x = keras.layers.ZeroPadding2D(padding=3)(inputs)

  # apply a strided 7x7 convolution to extract features
  # it will generate 64 output feature maps
  x = keras.layers.Conv2D(filters=64,
                          kernel_size=7,
                          strides=2,
                          padding="valid",
                          use_bias=False,
                          kernel_initializer="glorot_uniform"
                          )(x)

  # a BatchNormalization layer followed by a ReLu activation layer
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # again, apply ZeroPadding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # apply strided max pooling with a 3x3 window
  # the size of each feature map will be reduced by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)

  # apply a 1x1 convolution
  x = keras.layers.Conv2D(filters = 64,
                          kernel_size=1,
                          padding="same",
                          use_bias = False,
                          kernel_initializer="glorot_uniform")(x)

  # a BatchNormalization layer followed by a ReLu activation layer
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # zero-padding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # a 3x3 convolution; it will output 192 feature maps
  x = keras.layers.Conv2D(filters=192,
                          kernel_size=3,
                          strides=1,
                          padding="valid",
                          use_bias=False,
                          kernel_initializer="glorot_uniform"
                          )(x)

  # a BatchNormalization layer followed by a ReLu activation layer
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # zero-padding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # apply strided max pooling with a 3x3 window
  # the size of each feature map will be reduced by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)


  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### Auxiliary Classifier

# %%
def auxiliary(x, classes):
  '''
  Build the auxiliary classifier.

  x       : input to the auxiliary classifier
  classes : number of output classes
  '''

  # strided average pooling operation with a 5x5 window
  x = keras.layers.AveragePooling2D(pool_size=5, strides=3)(x)

  # a 1x1 convolution which will output 128 feature maps
  x = keras.layers.Conv2D(filters=128,
                          kernel_size=1,
                          padding="same",
                          use_bias=False,
                          kernel_initializer="glorot_uniform"
                          )(x)

  # a BatchNormalization layer followed by a ReLU action layer
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # flatten the feature maps before passing them to the Dense layer
  x = keras.layers.Flatten()(x)

  # a fully connected layer with 1024 neurons
  x = keras.layers.Dense(units=1024,
                         activation="relu",
                         kernel_initializer="glorot_uniform")(x)

  # dropout layer for regularization
  x = keras.layers.Dropout(rate=0.7)(x)

  # softmax layer to output probabilities for each class
  output = keras.layers.Dense(units=classes,
                              activation="softmax",
                              kernel_initializer="glorot_uniform")(x)


  return output

# %% [markdown]
# ### Inception Block

# %%
def inception_block(input, filters_1x1, filters_3x3, filters_5x5, filter_pool):
  '''
  Build the inception block/module.

  input : input to the inception block/module
  filters_1x1 : nr. of filters for the 1x1 conv branch of the inception module
  filters_3x3 : nr. of filters for the 3x3 conv branch of the inception model
  filters_5x5 : nr. of filters for the 5x5 conv branch of the inception module
  filters_pool: nr. of filters for the max pooling branch of the inception module
  '''

  # create the 1x1 conv branch with a BatchNormalization followed by a ReLU activation
  branch_1x1 = keras.layers.Conv2D(filters=filters_1x1[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(input)

  branch_1x1 = keras.layers.BatchNormalization()(branch_1x1)
  branch_1x1 = keras.layers.ReLU()(branch_1x1)

  # create the 3x3 conv branch with the 1x1 bottleneck convolution that performs dimensionality reduction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(input)

  # a BatchNormalization layer followed by a ReLU action layer
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)

  # zero-padding
  branch_3x3 = keras.layers.ZeroPadding2D(padding=1)(branch_3x3)

  # a 3x3 conv layer for feature extraction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[1],
                                   kernel_size=3,
                                   strides=1,
                                   padding="valid",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(branch_3x3)

  # a BatchNormalization layer followed by a ReLU activation layer
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)


  # create the 5x5 conv branch with the 1x1 bottleneck convolution that performs dimensionality reduction
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(input)

  # a BatchNormalization layer followed by a ReLU activation layer
  branch_5x5 = keras.layers.BatchNormalization()(branch_5x5)
  branch_5x5 = keras.layers.ReLU()(branch_5x5)

  # zero-padding
  branch_5x5 = keras.layers.ZeroPadding2D(padding=1)(branch_5x5)

  # a 3x3 convolution layer
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[1],
                                   kernel_size=3,
                                   strides=1,
                                   padding="valid",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(branch_5x5)

  # a BatchNormalization layer followed by a ReLU activation layer
  branch_5x5 = keras.layers.BatchNormalization()(branch_5x5)
  branch_5x5 = keras.layers.ReLU()(branch_5x5)


  # create the max pooling branch with 1x1 linear projection for dimensionality expansion
  branch_pool = keras.layers.MaxPooling2D(pool_size=3,
                                          strides=1,
                                          padding="same")(input)

  # a 1x1 convolution layer
  branch_pool = keras.layers.Conv2D(filters=filter_pool[0],
                                    kernel_size=1,
                                    strides=1,
                                    padding='same',
                                    use_bias=False,
                                    kernel_initializer='glorot_uniform')(branch_pool)
  # a BatchNormalization layer followed by a ReLU activation layer
  branch_pool = keras.layers.BatchNormalization()(branch_pool)
  branch_pool = keras.layers.ReLU()(branch_pool)

  # Concatenate the output feature maps of the branches
  x = keras.layers.Concatenate()([branch_1x1, branch_3x3, branch_5x5, branch_pool])

  return x

# %% [markdown]
# ### Inception Group

# %%
def group(x, blocks, pooling=True, classes=1000):
  '''
  Build an Inception group.

  x       : input to the inception group
  blocks  : list of tuples containing nr. of filters for each block in the group
  pooling : flag indicating whether to end the group with max pooling
  classes : nr. of classes for auxiliary classifier
  '''

  # list to save the auxiliary outputs
  aux = []

  # build the inception blocks
  for block in blocks:

    # adding the auxiliary classifier
    if block is None:
      # save the auxiliary output
      aux.append(auxiliary(x,classes))

    else:
       # create inception block
       x = inception_block(x,
                           block[0],
                           block[1],
                           block[2],
                           block[3])


  # if pooling is True
  if pooling:
    # zero-padding
    x = keras.layers.ZeroPadding2D(padding=(1,1))(x)

    # max pooling
    x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)


  return x, aux

# %% [markdown]
# ### Putting it all together

# %% [markdown]
# Finally, we can build the learner component as follows:

# %%
def learner(x, classes):
  """ Build the learner component.

      x        : input to the learner
      classes: number of output classes
  """

  # a list to keep track of the auxiliary classifiers
  aux = []

  # the block specs for group 3
  blocks = [((64,),  (96,128),   (16, 32), (32,)),
              ((128,), (128, 192), (32, 96), (64,))]
  # build group 3
  x, o = group(x, blocks)
  aux += o

  # the block specs for group 4
  blocks = [((192,),  (96, 208), (16, 48), (64,)),
            None,
            ((160,), (112, 224), (24, 64), (64,)),
            ((128,), (128, 256), (24, 64), (64,)),
            ((112,), (144, 288), (32, 64), (64,)),
            None,
            ((256,), (160, 320), (32, 128), (128,))]
  # build group 4
  x, o = group(x, blocks, classes=classes)
  aux += o

  # the block specs for group 5
  blocks = [((256,), (160, 320), (32, 128), (128,)),
            ((384,), (192, 384), (48, 128), (128,))]
  # build group 5
  x, o = group(x, blocks, pooling=False)
  aux += o


  return x, aux

# %% [markdown]
# ## The task component

# %%
def task(x, classes, dropout=0.4):
  '''
  Build the task component.

  x       : input to the task component
  classes : nr. of output classes
  dropout : dropout rate
  '''

  # a 7x7 average pooling
  x = keras.layers.AveragePooling2D(pool_size=7)(x)

  # flatten the output from the avg pooling
  x = keras.layers.Flatten()(x)

  # dropout for regularization
  x = keras.layers.Dropout(rate=dropout)(x)

  # softmax layer
  outputs = keras.layers.Dense(units=classes,
                               activation="softmax",
                               kernel_initializer="glorot_uniform")(x)

  return outputs

# %% [markdown]
# ## Inception model v2

# %%
def build_model(shape=(224, 224, 3), dropout=0.4):

  # define inputs
  inputs = keras.layers.Input(shape=shape)

  # the stem component
  x = stem(inputs)

  # the learner component
  x, aux = learner(x, 1000)

  # the task component
  outputs = task(x, 1000, dropout)

  # build the model
  model = keras.Model(inputs=inputs,
                      outputs=[outputs] + aux,
                      name="inception_v2")

  return model

# %%
# create the inception model (v2)
inception_model_v2 = build_model()

# print a summary
inception_model_v2.summary()
# Out:
# Model: "inception_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_24 (ZeroPad  (None, 230, 230, 3)          0         ['input_2[0][0]']
#  ding2D)
#
#  conv2d_59 (Conv2D)          (None, 112, 112, 64)         9408      ['zero_padding2d_24[0][0]']
#
#  batch_normalization (Batch  (None, 112, 112, 64)         256       ['conv2d_59[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 112, 112, 64)         0         ['batch_normalization[0][0]']
#
#  zero_padding2d_25 (ZeroPad  (None, 114, 114, 64)         0         ['re_lu[0][0]']
#  ding2D)
#
#  max_pooling2d_13 (MaxPooli  (None, 56, 56, 64)           0         ['zero_padding2d_25[0][0]']
#  ng2D)
#
#  conv2d_60 (Conv2D)          (None, 56, 56, 64)           4096      ['max_pooling2d_13[0][0]']
#
#  batch_normalization_1 (Bat  (None, 56, 56, 64)           256       ['conv2d_60[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 56, 56, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  zero_padding2d_26 (ZeroPad  (None, 58, 58, 64)           0         ['re_lu_1[0][0]']
#  ding2D)
#
#  conv2d_61 (Conv2D)          (None, 56, 56, 192)          110592    ['zero_padding2d_26[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 192)          768       ['conv2d_61[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 56, 56, 192)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  zero_padding2d_27 (ZeroPad  (None, 58, 58, 192)          0         ['re_lu_2[0][0]']
#  ding2D)
#
#  max_pooling2d_14 (MaxPooli  (None, 28, 28, 192)          0         ['zero_padding2d_27[0][0]']
#  ng2D)
#
#  conv2d_63 (Conv2D)          (None, 28, 28, 96)           18432     ['max_pooling2d_14[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 28, 28, 16)           3072      ['max_pooling2d_14[0][0]']
#
#  batch_normalization_4 (Bat  (None, 28, 28, 96)           384       ['conv2d_63[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 28, 28, 16)           64        ['conv2d_65[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 28, 28, 96)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  re_lu_6 (ReLU)              (None, 28, 28, 16)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  zero_padding2d_28 (ZeroPad  (None, 30, 30, 96)           0         ['re_lu_4[0][0]']
#  ding2D)
#
#  zero_padding2d_29 (ZeroPad  (None, 30, 30, 16)           0         ['re_lu_6[0][0]']
#  ding2D)
#
#  max_pooling2d_15 (MaxPooli  (None, 28, 28, 192)          0         ['max_pooling2d_14[0][0]']
#  ng2D)
#
#  conv2d_62 (Conv2D)          (None, 28, 28, 64)           12288     ['max_pooling2d_14[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 28, 28, 128)          110592    ['zero_padding2d_28[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 28, 28, 32)           4608      ['zero_padding2d_29[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 28, 28, 32)           6144      ['max_pooling2d_15[0][0]']
#
#  batch_normalization_3 (Bat  (None, 28, 28, 64)           256       ['conv2d_62[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 28, 28, 128)          512       ['conv2d_64[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 28, 28, 32)           128       ['conv2d_66[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 28, 28, 32)           128       ['conv2d_67[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 28, 28, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  re_lu_5 (ReLU)              (None, 28, 28, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  re_lu_7 (ReLU)              (None, 28, 28, 32)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  re_lu_8 (ReLU)              (None, 28, 28, 32)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  concatenate_9 (Concatenate  (None, 28, 28, 256)          0         ['re_lu_3[0][0]',
#  )                                                                   're_lu_5[0][0]',
#                                                                      're_lu_7[0][0]',
#                                                                      're_lu_8[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 28, 28, 128)          32768     ['concatenate_9[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 28, 28, 32)           8192      ['concatenate_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 28, 28, 128)          512       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 28, 28, 32)           128       ['conv2d_71[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  re_lu_12 (ReLU)             (None, 28, 28, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  zero_padding2d_30 (ZeroPad  (None, 30, 30, 128)          0         ['re_lu_10[0][0]']
#  ding2D)
#
#  zero_padding2d_31 (ZeroPad  (None, 30, 30, 32)           0         ['re_lu_12[0][0]']
#  ding2D)
#
#  max_pooling2d_16 (MaxPooli  (None, 28, 28, 256)          0         ['concatenate_9[0][0]']
#  ng2D)
#
#  conv2d_68 (Conv2D)          (None, 28, 28, 128)          32768     ['concatenate_9[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 28, 28, 192)          221184    ['zero_padding2d_30[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 28, 28, 96)           27648     ['zero_padding2d_31[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 28, 28, 64)           16384     ['max_pooling2d_16[0][0]']
#
#  batch_normalization_9 (Bat  (None, 28, 28, 128)          512       ['conv2d_68[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 28, 28, 192)          768       ['conv2d_70[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (None, 28, 28, 96)           384       ['conv2d_72[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 28, 28, 64)           256       ['conv2d_73[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 28, 28, 128)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  re_lu_11 (ReLU)             (None, 28, 28, 192)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  re_lu_13 (ReLU)             (None, 28, 28, 96)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  re_lu_14 (ReLU)             (None, 28, 28, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  concatenate_10 (Concatenat  (None, 28, 28, 480)          0         ['re_lu_9[0][0]',
#  e)                                                                  're_lu_11[0][0]',
#                                                                      're_lu_13[0][0]',
#                                                                      're_lu_14[0][0]']
#
#  zero_padding2d_32 (ZeroPad  (None, 30, 30, 480)          0         ['concatenate_10[0][0]']
#  ding2D)
#
#  max_pooling2d_17 (MaxPooli  (None, 14, 14, 480)          0         ['zero_padding2d_32[0][0]']
#  ng2D)
#
#  conv2d_75 (Conv2D)          (None, 14, 14, 96)           46080     ['max_pooling2d_17[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 14, 14, 16)           7680      ['max_pooling2d_17[0][0]']
#
#  batch_normalization_16 (Ba  (None, 14, 14, 96)           384       ['conv2d_75[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 14, 14, 16)           64        ['conv2d_77[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 14, 14, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  re_lu_18 (ReLU)             (None, 14, 14, 16)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  zero_padding2d_33 (ZeroPad  (None, 16, 16, 96)           0         ['re_lu_16[0][0]']
#  ding2D)
#
#  zero_padding2d_34 (ZeroPad  (None, 16, 16, 16)           0         ['re_lu_18[0][0]']
#  ding2D)
#
#  max_pooling2d_18 (MaxPooli  (None, 14, 14, 480)          0         ['max_pooling2d_17[0][0]']
#  ng2D)
#
#  conv2d_74 (Conv2D)          (None, 14, 14, 192)          92160     ['max_pooling2d_17[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 14, 14, 208)          179712    ['zero_padding2d_33[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 14, 14, 48)           6912      ['zero_padding2d_34[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 14, 14, 64)           30720     ['max_pooling2d_18[0][0]']
#
#  batch_normalization_15 (Ba  (None, 14, 14, 192)          768       ['conv2d_74[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 14, 14, 208)          832       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 14, 14, 48)           192       ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 14, 14, 64)           256       ['conv2d_79[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 14, 14, 192)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  re_lu_17 (ReLU)             (None, 14, 14, 208)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 48)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  re_lu_20 (ReLU)             (None, 14, 14, 64)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  concatenate_11 (Concatenat  (None, 14, 14, 512)          0         ['re_lu_15[0][0]',
#  e)                                                                  're_lu_17[0][0]',
#                                                                      're_lu_19[0][0]',
#                                                                      're_lu_20[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 14, 14, 112)          57344     ['concatenate_11[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 14, 14, 24)           12288     ['concatenate_11[0][0]']
#
#  batch_normalization_23 (Ba  (None, 14, 14, 112)          448       ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 14, 14, 24)           96        ['conv2d_84[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 14, 14, 112)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  re_lu_25 (ReLU)             (None, 14, 14, 24)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  zero_padding2d_35 (ZeroPad  (None, 16, 16, 112)          0         ['re_lu_23[0][0]']
#  ding2D)
#
#  zero_padding2d_36 (ZeroPad  (None, 16, 16, 24)           0         ['re_lu_25[0][0]']
#  ding2D)
#
#  max_pooling2d_19 (MaxPooli  (None, 14, 14, 512)          0         ['concatenate_11[0][0]']
#  ng2D)
#
#  conv2d_81 (Conv2D)          (None, 14, 14, 160)          81920     ['concatenate_11[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 14, 14, 224)          225792    ['zero_padding2d_35[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 14, 14, 64)           13824     ['zero_padding2d_36[0][0]']
#
#  conv2d_86 (Conv2D)          (None, 14, 14, 64)           32768     ['max_pooling2d_19[0][0]']
#
#  batch_normalization_22 (Ba  (None, 14, 14, 160)          640       ['conv2d_81[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 14, 14, 224)          896       ['conv2d_83[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 14, 14, 64)           256       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 14, 14, 64)           256       ['conv2d_86[0][0]']
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 14, 14, 160)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  re_lu_24 (ReLU)             (None, 14, 14, 224)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  re_lu_26 (ReLU)             (None, 14, 14, 64)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  re_lu_27 (ReLU)             (None, 14, 14, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  concatenate_12 (Concatenat  (None, 14, 14, 512)          0         ['re_lu_22[0][0]',
#  e)                                                                  're_lu_24[0][0]',
#                                                                      're_lu_26[0][0]',
#                                                                      're_lu_27[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 14, 14, 128)          65536     ['concatenate_12[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 14, 14, 24)           12288     ['concatenate_12[0][0]']
#
#  batch_normalization_29 (Ba  (None, 14, 14, 128)          512       ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 14, 14, 24)           96        ['conv2d_90[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  re_lu_31 (ReLU)             (None, 14, 14, 24)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  zero_padding2d_37 (ZeroPad  (None, 16, 16, 128)          0         ['re_lu_29[0][0]']
#  ding2D)
#
#  zero_padding2d_38 (ZeroPad  (None, 16, 16, 24)           0         ['re_lu_31[0][0]']
#  ding2D)
#
#  max_pooling2d_20 (MaxPooli  (None, 14, 14, 512)          0         ['concatenate_12[0][0]']
#  ng2D)
#
#  conv2d_87 (Conv2D)          (None, 14, 14, 128)          65536     ['concatenate_12[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 14, 14, 256)          294912    ['zero_padding2d_37[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 14, 14, 64)           13824     ['zero_padding2d_38[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 14, 14, 64)           32768     ['max_pooling2d_20[0][0]']
#
#  batch_normalization_28 (Ba  (None, 14, 14, 128)          512       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 14, 14, 256)          1024      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 14, 14, 64)           256       ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 14, 14, 64)           256       ['conv2d_92[0][0]']
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  re_lu_30 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  re_lu_32 (ReLU)             (None, 14, 14, 64)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  re_lu_33 (ReLU)             (None, 14, 14, 64)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  concatenate_13 (Concatenat  (None, 14, 14, 512)          0         ['re_lu_28[0][0]',
#  e)                                                                  're_lu_30[0][0]',
#                                                                      're_lu_32[0][0]',
#                                                                      're_lu_33[0][0]']
#
#  conv2d_94 (Conv2D)          (None, 14, 14, 144)          73728     ['concatenate_13[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 14, 14, 32)           16384     ['concatenate_13[0][0]']
#
#  batch_normalization_35 (Ba  (None, 14, 14, 144)          576       ['conv2d_94[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 14, 14, 32)           128       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  re_lu_35 (ReLU)             (None, 14, 14, 144)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  re_lu_37 (ReLU)             (None, 14, 14, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  zero_padding2d_39 (ZeroPad  (None, 16, 16, 144)          0         ['re_lu_35[0][0]']
#  ding2D)
#
#  zero_padding2d_40 (ZeroPad  (None, 16, 16, 32)           0         ['re_lu_37[0][0]']
#  ding2D)
#
#  max_pooling2d_21 (MaxPooli  (None, 14, 14, 512)          0         ['concatenate_13[0][0]']
#  ng2D)
#
#  conv2d_93 (Conv2D)          (None, 14, 14, 112)          57344     ['concatenate_13[0][0]']
#
#  conv2d_95 (Conv2D)          (None, 14, 14, 288)          373248    ['zero_padding2d_39[0][0]']
#
#  conv2d_97 (Conv2D)          (None, 14, 14, 64)           18432     ['zero_padding2d_40[0][0]']
#
#  conv2d_98 (Conv2D)          (None, 14, 14, 64)           32768     ['max_pooling2d_21[0][0]']
#
#  batch_normalization_34 (Ba  (None, 14, 14, 112)          448       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 14, 14, 288)          1152      ['conv2d_95[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 14, 14, 64)           256       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 14, 14, 64)           256       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 14, 14, 112)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  re_lu_36 (ReLU)             (None, 14, 14, 288)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  re_lu_38 (ReLU)             (None, 14, 14, 64)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  re_lu_39 (ReLU)             (None, 14, 14, 64)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  concatenate_14 (Concatenat  (None, 14, 14, 528)          0         ['re_lu_34[0][0]',
#  e)                                                                  're_lu_36[0][0]',
#                                                                      're_lu_38[0][0]',
#                                                                      're_lu_39[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 14, 14, 160)          84480     ['concatenate_14[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 14, 14, 32)           16896     ['concatenate_14[0][0]']
#
#  batch_normalization_42 (Ba  (None, 14, 14, 160)          640       ['conv2d_101[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 14, 14, 32)           128       ['conv2d_103[0][0]']
#  tchNormalization)
#
#  re_lu_42 (ReLU)             (None, 14, 14, 160)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  re_lu_44 (ReLU)             (None, 14, 14, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  zero_padding2d_41 (ZeroPad  (None, 16, 16, 160)          0         ['re_lu_42[0][0]']
#  ding2D)
#
#  zero_padding2d_42 (ZeroPad  (None, 16, 16, 32)           0         ['re_lu_44[0][0]']
#  ding2D)
#
#  max_pooling2d_22 (MaxPooli  (None, 14, 14, 528)          0         ['concatenate_14[0][0]']
#  ng2D)
#
#  conv2d_100 (Conv2D)         (None, 14, 14, 256)          135168    ['concatenate_14[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 14, 14, 320)          460800    ['zero_padding2d_41[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 14, 14, 128)          36864     ['zero_padding2d_42[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 14, 14, 128)          67584     ['max_pooling2d_22[0][0]']
#
#  batch_normalization_41 (Ba  (None, 14, 14, 256)          1024      ['conv2d_100[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 14, 14, 320)          1280      ['conv2d_102[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 14, 14, 128)          512       ['conv2d_104[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 14, 14, 128)          512       ['conv2d_105[0][0]']
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  re_lu_43 (ReLU)             (None, 14, 14, 320)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  re_lu_45 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  re_lu_46 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  concatenate_15 (Concatenat  (None, 14, 14, 832)          0         ['re_lu_41[0][0]',
#  e)                                                                  're_lu_43[0][0]',
#                                                                      're_lu_45[0][0]',
# ...
#  re_lu_50 (ReLU)             (None, 7, 7, 32)             0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  zero_padding2d_44 (ZeroPad  (None, 9, 9, 160)            0         ['re_lu_48[0][0]']
#  ding2D)
#
#  zero_padding2d_45 (ZeroPad  (None, 9, 9, 32)             0         ['re_lu_50[0][0]']
#  ding2D)
#
#  max_pooling2d_24 (MaxPooli  (None, 7, 7, 832)            0         ['max_pooling2d_23[0][0]']
#  ng2D)
#
#  conv2d_106 (Conv2D)         (None, 7, 7, 256)            212992    ['max_pooling2d_23[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 7, 7, 320)            460800    ['zero_padding2d_44[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 7, 7, 128)            36864     ['zero_padding2d_45[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 7, 7, 128)            106496    ['max_pooling2d_24[0][0]']
#
#  batch_normalization_47 (Ba  (None, 7, 7, 256)            1024      ['conv2d_106[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 7, 7, 320)            1280      ['conv2d_108[0][0]']
#  tchNormalization)
#
#  batch_normalization_51 (Ba  (None, 7, 7, 128)            512       ['conv2d_110[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 7, 7, 128)            512       ['conv2d_111[0][0]']
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 7, 7, 256)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  re_lu_49 (ReLU)             (None, 7, 7, 320)            0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  re_lu_51 (ReLU)             (None, 7, 7, 128)            0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  re_lu_52 (ReLU)             (None, 7, 7, 128)            0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  concatenate_16 (Concatenat  (None, 7, 7, 832)            0         ['re_lu_47[0][0]',
#  e)                                                                  're_lu_49[0][0]',
#                                                                      're_lu_51[0][0]',
#                                                                      're_lu_52[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 7, 7, 192)            159744    ['concatenate_16[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 7, 7, 48)             39936     ['concatenate_16[0][0]']
#
#  batch_normalization_54 (Ba  (None, 7, 7, 192)            768       ['conv2d_113[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 7, 7, 48)             192       ['conv2d_115[0][0]']
#  tchNormalization)
#
#  re_lu_54 (ReLU)             (None, 7, 7, 192)            0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  re_lu_56 (ReLU)             (None, 7, 7, 48)             0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  zero_padding2d_46 (ZeroPad  (None, 9, 9, 192)            0         ['re_lu_54[0][0]']
#  ding2D)
#
#  zero_padding2d_47 (ZeroPad  (None, 9, 9, 48)             0         ['re_lu_56[0][0]']
#  ding2D)
#
#  max_pooling2d_25 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_16[0][0]']
#  ng2D)
#
#  conv2d_112 (Conv2D)         (None, 7, 7, 384)            319488    ['concatenate_16[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 7, 7, 384)            663552    ['zero_padding2d_46[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 7, 7, 128)            55296     ['zero_padding2d_47[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 7, 7, 128)            106496    ['max_pooling2d_25[0][0]']
#
#  average_pooling2d_3 (Avera  (None, 4, 4, 512)            0         ['concatenate_11[0][0]']
#  gePooling2D)
#
#  average_pooling2d_4 (Avera  (None, 4, 4, 528)            0         ['concatenate_14[0][0]']
#  gePooling2D)
#
#  batch_normalization_53 (Ba  (None, 7, 7, 384)            1536      ['conv2d_112[0][0]']
#  tchNormalization)
#
#  batch_normalization_55 (Ba  (None, 7, 7, 384)            1536      ['conv2d_114[0][0]']
#  tchNormalization)
#
#  batch_normalization_57 (Ba  (None, 7, 7, 128)            512       ['conv2d_116[0][0]']
#  tchNormalization)
#
#  batch_normalization_58 (Ba  (None, 7, 7, 128)            512       ['conv2d_117[0][0]']
#  tchNormalization)
#
#  conv2d_80 (Conv2D)          (None, 4, 4, 128)            65536     ['average_pooling2d_3[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 4, 4, 128)            67584     ['average_pooling2d_4[0][0]']
#
#  re_lu_53 (ReLU)             (None, 7, 7, 384)            0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  re_lu_55 (ReLU)             (None, 7, 7, 384)            0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  re_lu_57 (ReLU)             (None, 7, 7, 128)            0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  re_lu_58 (ReLU)             (None, 7, 7, 128)            0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  batch_normalization_21 (Ba  (None, 4, 4, 128)            512       ['conv2d_80[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 4, 4, 128)            512       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  concatenate_17 (Concatenat  (None, 7, 7, 1024)           0         ['re_lu_53[0][0]',
#  e)                                                                  're_lu_55[0][0]',
#                                                                      're_lu_57[0][0]',
#                                                                      're_lu_58[0][0]']
#
#  re_lu_21 (ReLU)             (None, 4, 4, 128)            0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  re_lu_40 (ReLU)             (None, 4, 4, 128)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  average_pooling2d_5 (Avera  (None, 1, 1, 1024)           0         ['concatenate_17[0][0]']
#  gePooling2D)
#
#  flatten_3 (Flatten)         (None, 2048)                 0         ['re_lu_21[0][0]']
#
#  flatten_4 (Flatten)         (None, 2048)                 0         ['re_lu_40[0][0]']
#
#  flatten_5 (Flatten)         (None, 1024)                 0         ['average_pooling2d_5[0][0]']
#
#  dense_5 (Dense)             (None, 1024)                 2098176   ['flatten_3[0][0]']
#
#  dense_7 (Dense)             (None, 1024)                 2098176   ['flatten_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 1024)                 0         ['flatten_5[0][0]']
#
#  dropout_3 (Dropout)         (None, 1024)                 0         ['dense_5[0][0]']
#
#  dropout_4 (Dropout)         (None, 1024)                 0         ['dense_7[0][0]']
#
#  dense_9 (Dense)             (None, 1000)                 1025000   ['dropout_5[0][0]']
#
#  dense_6 (Dense)             (None, 1000)                 1025000   ['dropout_3[0][0]']
#
#  dense_8 (Dense)             (None, 1000)                 1025000   ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 13019960 (49.67 MB)
# Trainable params: 13004888 (49.61 MB)
# Non-trainable params: 15072 (58.88 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Inception v3

# %% [markdown]
# ## The stem component

# %%
def stem(inputs):
  '''
  Construct the stem.
  The 7x7 coarse filter of v1 will be factorized into three 3x3 conv layers.
  The first conv layer is strided.
  '''
  # strided 3x3 conv layer
  x = keras.layers.Conv2D(filters=32, kernel_size=3, strides=2, padding="valid", use_bias=False, kernel_initializer="glorot_uniform")(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  # 2nd 3x3 conv layer
  x = keras.layers.Conv2D(32, (3, 3), strides=(1, 1), padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  # 3rd 3x3 conv layer
  x = keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  # reduce pooled feature maps by 75%
  x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)
  # a 1x1 conv layer for dimensionality reduction
  x = keras.layers.Conv2D(80, (1, 1), strides=(1, 1), padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  # a 3x3 conv layer for dimensionality expansion
  x = keras.layers.Conv2D(192, (3, 3), strides=(1, 1), padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  # reduce pooled feature maps by 75%
  x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)

  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### Auxiliary Classifier

# %%
def auxiliary(x, classes):
  """ Build the auxiliary classier
      x         : input to the auxiliary classifier
      classes   : number of output classes
  """
  x = keras.layers.AveragePooling2D(pool_size=5, strides=(3, 3))(x)
  x = keras.layers.Conv2D(filters=128, kernel_size=1, strides=(1, 1), use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)
  x = keras.layers.Conv2D(filters=768, kernel_size=x.shape[1:3].as_list(), strides=(1, 1), use_bias=False, kernel_initializer='glorot_uniform')(x)
  x = keras.layers.Flatten()(x)

  output = keras.layers.Dense(units=classes, activation='softmax', kernel_initializer='glorot_uniform')(x)

  return output

# %% [markdown]
# ### Inception Group

# %%
def group(x, blocks, inception=None, reduction=None, classes=0):
  """
  Build the Inception group.

  x         : input into the group
  blocks    : filters for each block in the group
  inception : type of inception block
  reduction : whether to end the group with grid reduction
  classes   : nr. of classes for auxiliary classifier
  """

  # list of auxiliary outputs
  auxiliary_outputs = []

  # build the inception blocks/modules
  for block in blocks:
    x = inception(x, block[0], block[1], block[2], block[3])

  # add the auxiliary classifier
  if classes:
    auxiliary_outputs.append(auxiliary(x, classes))

  # add grid reduction
  if reduction:
    x = reduction(x)

  return x, auxiliary_outputs

# %% [markdown]
# ### Inception Block A

# %%
def inception_block_A(x, filters_1x1, filters_3x3, filters_5x5, filters_pool):
  """
  Build an Inception block 35x35.

  x             : input to the block
  filters_1x1   : filters for 1x1 branch
  filters_3x3   : filters for 3x3 branch
  filters_5x5   : filters for 5x5 branch
  filters_pool  : filters for pooling branch
  """

  # building the 1x1 branch
  branch_1x1 = keras.layers.Conv2D(filters=filters_1x1[0], kernel_size=1, strides=1, padding="same", use_bias=False, kernel_initializer="glorot_uniform")(x)
  branch_1x1 = keras.layers.BatchNormalization()(branch_1x1)
  branch_1x1 = keras.layers.ReLU()(branch_1x1)

  # build a double 3x3 branch with a 1x1 conv layer for dimensionality reduction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)

  # a 3x3 conv layer
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[1], kernel_size=3, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3)
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)

  # a 3x3 conv layer
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[1], kernel_size=3, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3)
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)

  # a 5x5 branch with a 1x1 conv layer for dimensionality reduction
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_5x5 = keras.layers.BatchNormalization()(branch_5x5)
  branch_5x5 = keras.layers.ReLU()(branch_5x5)
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[1], kernel_size=(3, 3), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_5x5)
  branch_5x5 = keras.layers.BatchNormalization()(branch_5x5)
  branch_5x5 = keras.layers.ReLU()(branch_5x5)

  # a 1x1 pooling branch
  branch_pool = keras.layers.AveragePooling2D(pool_size=3, strides=1, padding='same')(x)
  branch_pool = keras.layers.Conv2D(filters=filters_pool[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_pool)
  branch_pool = keras.layers.BatchNormalization()(branch_pool)
  branch_pool = keras.layers.ReLU()(branch_pool)

  # Concatenate the outputs (filters) of the branches
  x = keras.layers.Concatenate()([branch_1x1, branch_3x3, branch_5x5, branch_pool])

  return x

# %% [markdown]
# ### Inception Block B

# %%
def inception_block_B(x, filters_1x1, filters_7x7, filters_7x7_double, filters_pool):
  """ Build an Inception block 17x17.

      x                 : input to the block
      filters_1x1       : filters for 1x1 branch
      filters_7x7       : filters for 7x7 factorized asn 1x7, 7x1 branch
      filters_7x7_double: filters for double 7x7 factorized as 1x7, 7x1 branch
      filters_pool      : filters for pooling branch
  """
  # build the 1x1 branch
  branch_1x1 = keras.layers.Conv2D(filters=filters_1x1[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_1x1 = keras.layers.BatchNormalization()(branch_1x1)
  branch_1x1 = keras.layers.ReLU()(branch_1x1)

  # build the 7x7 branch with a 1x1 conv layer for dimensionality reduction
  branch_7x7 = keras.layers.Conv2D(filters=filters_7x7[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_7x7 = keras.layers.BatchNormalization()(branch_7x7)
  branch_7x7 = keras.layers.ReLU()(branch_7x7)
  # a 1x7 conv layer
  branch_7x7 = keras.layers.Conv2D(filters=filters_7x7[1], kernel_size=(1, 7), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7)
  branch_7x7 = keras.layers.BatchNormalization()(branch_7x7)
  branch_7x7 = keras.layers.ReLU()(branch_7x7)
  # a 7x1 conv layer
  branch_7x7 = keras.layers.Conv2D(filters=filters_7x7[2], kernel_size=(7, 1), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7)
  branch_7x7 = keras.layers.BatchNormalization()(branch_7x7)
  branch_7x7 = keras.layers.ReLU()(branch_7x7)

  # build the double 7x7 branch with a 1x1 conv layer for dimensionality reduction
  branch_7x7_double = keras.layers.Conv2D(filters=filters_7x7_double[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_7x7_double = keras.layers.BatchNormalization()(branch_7x7_double)
  branch_7x7_double = keras.layers.ReLU()(branch_7x7_double)
  # a 1x7 conv layer
  branch_7x7_double = keras.layers.Conv2D(filters=filters_7x7_double[1], kernel_size=(1, 7), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7_double)
  branch_7x7_double = keras.layers.BatchNormalization()(branch_7x7_double)
  branch_7x7_double = keras.layers.ReLU()(branch_7x7_double)
  # a 7x1 conv layer
  branch_7x7_double = keras.layers.Conv2D(filters=filters_7x7_double[2], kernel_size=(7, 1), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7_double)
  branch_7x7_double = keras.layers.BatchNormalization()(branch_7x7_double)
  branch_7x7_double = keras.layers.ReLU()(branch_7x7_double)
  # a 1x7 conv layer
  branch_7x7_double = keras.layers.Conv2D(filters=filters_7x7_double[3], kernel_size=(1, 7), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7_double)
  branch_7x7_double = keras.layers.BatchNormalization()(branch_7x7_double)
  branch_7x7_double = keras.layers.ReLU()(branch_7x7_double)
  # a 7x1 conv layer
  branch_7x7_double = keras.layers.Conv2D(filters=filters_7x7_double[4], kernel_size=(7, 1), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7_double)
  branch_7x7_double = keras.layers.BatchNormalization()(branch_7x7_double)
  branch_7x7_double = keras.layers.ReLU()(branch_7x7_double)

  # build the pooling branch with average pooling and a 1x1 conv layer
  branch_pool = keras.layers.AveragePooling2D(pool_size=3, strides=1, padding='same')(x)
  branch_pool = keras.layers.Conv2D(filters=filters_pool[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_pool)
  branch_pool = keras.layers.BatchNormalization()(branch_pool)
  branch_pool = keras.layers.ReLU()(branch_pool)

  # Concatenate the outputs (filters) of the branches
  x = keras.layers.Concatenate()([branch_1x1, branch_7x7, branch_7x7_double, branch_pool])

  return x

# %% [markdown]
# ### Inception Block C

# %%
def inception_block_C(x, filters_1x1, filters_3x3, filters_3x3_double, filters_pool):
  """ Build an Inception block 8x8.
      x                 : input to the block
      filters_1x1       : filters for 1x1 branch
      filters_3x3       : filters for 3x3 factorized asn 1x3, 3x1 branch
      filters_3x3_double: filters for double 3x3 factorized as 1x3, 3x1 branch
      filters_pool      : filters for pooling branch
  """
  # build the 1x1 branch
  branch_1x1 = keras.layers.Conv2D(filters=filters_1x1[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_1x1 = keras.layers.BatchNormalization()(branch_1x1)
  branch_1x1 = keras.layers.ReLU()(branch_1x1)

  # build the 3x3 branch with a 1x1 conv layer
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)
  # split the branch into a 1x3 conv layer and a 3x1 conv layer
  branch_3x3_1 = keras.layers.Conv2D(filters=filters_3x3[0], kernel_size=(1, 3), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3)
  branch_3x3_1 = keras.layers.BatchNormalization()(branch_3x3_1)
  branch_3x3_1 = keras.layers.ReLU()(branch_3x3_1)
  branch_3x3_2 = keras.layers.Conv2D(filters=filters_3x3[1], kernel_size=(3, 1), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3)
  branch_3x3_2 = keras.layers.BatchNormalization()(branch_3x3_2)
  branch_3x3_2 = keras.layers.ReLU()(branch_3x3_2)
  # merge the two sub-branches
  branch_3x3   = keras.layers.Concatenate()([branch_3x3_1, branch_3x3_2])

  # build a double 3x3 branch with a 1x1 conv layer
  branch_3x3_double = keras.layers.Conv2D(filters=filters_3x3_double[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_3x3_double = keras.layers.BatchNormalization()(branch_3x3_double)
  branch_3x3_double = keras.layers.ReLU()(branch_3x3_double)
  branch_3x3_double = keras.layers.Conv2D(filters=filters_3x3_double[1], kernel_size=3, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3_double)
  branch_3x3_double = keras.layers.BatchNormalization()(branch_3x3_double)
  branch_3x3_double = keras.layers.ReLU()(branch_3x3_double)
  # split the branch into a 1x3 conv layer and 3x1 conv layer
  branch_3x3_double_1 = keras.layers.Conv2D(filters_3x3_double[2], (1, 3), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3_double)
  branch_3x3_double_1 = keras.layers.BatchNormalization()(branch_3x3_double_1)
  branch_3x3_double_1 = keras.layers.ReLU()(branch_3x3_double_1)
  branch_3x3_double_2 = keras.layers.Conv2D(filters_3x3_double[3], (3, 1), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3_double)
  branch_3x3_double_2 = keras.layers.BatchNormalization()(branch_3x3_double_2)
  branch_3x3_double_2 = keras.layers.ReLU()(branch_3x3_double_2)
  # merge the two sub-branches
  b3x3dbl   = keras.layers.Concatenate()([branch_3x3_double_1, branch_3x3_double_2])

  # build the pooling branch with average pooling and a 1x1 conv layer
  branch_pool = keras.layers.AveragePooling2D(pool_size=3, strides=1, padding='same')(x)
  branch_pool = keras.layers.Conv2D(filters=filters_pool[0], kernel_size=(1, 1), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_pool)
  branch_pool = keras.layers.BatchNormalization()(branch_pool)
  branch_pool = keras.layers.ReLU()(branch_pool)

  # concatenate the outputs (filters) of the branches
  x = keras.layers.Concatenate()([branch_1x1, branch_3x3, branch_3x3_double, branch_pool])

  return x

# %% [markdown]
# ### Grid Reduction A

# %%
def grid_reduction_A(x, filters_3x3=384, filters_3x3_double=(64, 96, 96)):
  """ Build the Grid Reduction block
      x                   : input to the block
      filters_3x3         : filter size for 3x3 branch
      filters_3x3_double  : filter sizes for double 3x3 branch
  """
  # build the 3x3 branch for grid reduction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3, kernel_size=3, strides=2, padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)

  # build the double 3x3 branch with a 1x1 conv layer for dimensionality reduction
  branch_3x3_double = keras.layers.Conv2D(filters=filters_3x3_double[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_3x3_double = keras.layers.BatchNormalization()(branch_3x3_double)
  branch_3x3_double = keras.layers.ReLU()(branch_3x3_double)
  branch_3x3_double = keras.layers.Conv2D(filters=filters_3x3_double[1], kernel_size=(3, 3), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3_double)
  branch_3x3_double = keras.layers.BatchNormalization()(branch_3x3_double)
  branch_3x3_double = keras.layers.ReLU()(branch_3x3_double)
  # a 3x3 conv layer for grid reduction
  branch_3x3_double = keras.layers.Conv2D(filters=filters_3x3_double[1], kernel_size=3, strides=2, padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3_double)
  branch_3x3_double = keras.layers.BatchNormalization()(branch_3x3_double)
  branch_3x3_double = keras.layers.ReLU()(branch_3x3_double)

  # pool branch
  branch_pool = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)

  # Concatenate the outputs (filters) of the branches
  x = keras.layers.Concatenate()([branch_3x3, branch_3x3_double, branch_pool])

  return x

# %% [markdown]
# ### Grid Reduction B

# %%
def grid_reduction_B(x, filters_3x3=(192, 320), filters_7x7=(192, 192, 192, 192)):
  """ Build the Grid Reduction block
      x               : input to the block
      filters_3x3     : filter size for 3x3 branch
      filters_7x7     : filter sizes for 7x7 + 3x3 branch
  """
  # build the 3x3 branch with a 1x1 conv layer
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)
  # build the grid reduction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[1], kernel_size=3, strides=2, padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(branch_3x3)
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)

  # build the 7x7 conv layer (factorized as 1x7, 7x1) with the 1x1 conv layer for dimensionality reduction
  branch_7x7 = keras.layers.Conv2D(filters=filters_7x7[0], kernel_size=1, strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(x)
  branch_7x7 = keras.layers.BatchNormalization()(branch_7x7)
  branch_7x7 = keras.layers.ReLU()(branch_7x7)
  # build the 1x7 conv layer
  branch_7x7 = keras.layers.Conv2D(filters=filters_7x7[1], kernel_size=(1, 7), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7)
  branch_7x7 = keras.layers.BatchNormalization()(branch_7x7)
  branch_7x7 = keras.layers.ReLU()(branch_7x7)
  branch_7x7 = keras.layers.Conv2D(filters=filters_7x7[2], kernel_size=(7, 1), strides=1, padding='same', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7)
  branch_7x7 = keras.layers.BatchNormalization()(branch_7x7)
  branch_7x7 = keras.layers.ReLU()(branch_7x7)
  # grid reduction
  branch_7x7 = keras.layers.Conv2D(filters=filters_7x7[3], kernel_size= 3, strides=2, padding='valid', use_bias=False, kernel_initializer='glorot_uniform')(branch_7x7)
  branch_7x7 = keras.layers.BatchNormalization()(branch_7x7)
  branch_7x7 = keras.layers.ReLU()(branch_7x7)

  # build a pool branch
  branch_pool = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)

  # concatenate the outputs (filters) of the branches
  x = keras.layers.Concatenate()([branch_3x3, branch_7x7, branch_pool])

  return x

# %% [markdown]
# ### Putting it all together

# %%
def learner(x, classes):
  """ Build the Learner
      x         : input to the learner
      classes   : number of output classes
  """
  aux_outputs = [] # Auxiliary Outputs

  # Group A (35x35)
  x, o = group(x, [((64,), (64, 96), (48, 64), (32,)),
                   ((64,), (64, 96), (48, 64), (64,)),
                   ((64,), (64, 96), (48, 64), (64,))
                  ], inception=inception_block_A, reduction=grid_reduction_A)
  aux_outputs += o

  # Group B (17x17)
  x, o = group(x, [((192,), (128, 128, 192), (128, 128, 128, 128, 192), (192,)),
                   ((192,), (160, 160, 192), (160, 160, 160, 160, 192), (192,)),
                   ((192,), (160, 160, 192), (160, 160, 160, 160, 192), (192,)),
                   ((192,), (192, 192, 192), (192, 192, 192, 192, 192), (192,))
                   ], inception=inception_block_B, reduction=grid_reduction_B, classes=classes)
  aux_outputs += o

  # Group C (8x8)
  x, o = group(x, [((320,), (384, 384, 384), (448, 384, 384, 384), (192,)),
                   ((320,), (384, 384, 384), (448, 384, 384, 384), (192,))
                  ], inception=inception_block_C)
  aux_outputs += o
  return x, aux_outputs

# %% [markdown]
# ## The task component

# %%
def task(x, classes, dropout=0.4):
  """ Build the task.
      x         : input to the classifier
      classes   : number of output classes
      dropout   : percentage for dropout rate
  """
  # pool at the end of all the convolutional residual blocks will be 8x8 in V3
  x = keras.layers.AveragePooling2D(pool_size=x.shape[1:3].as_list())(x)
  x = keras.layers.Dropout(dropout)(x)
  x = keras.layers.Flatten()(x)

  # outputs
  outputs = keras.layers.Dense(units=classes, activation='softmax', kernel_initializer='glorot_uniform')(x)


  return outputs

# %% [markdown]
# ## Inception model v3

# %%
def model():
  # The input tensor (299x299 in V3 vs 224x224 in V1/V2)
  inputs = keras.Input(shape=(299, 299, 3))

  # step
  x = stem(inputs)

  # The learner
  x, aux = learner(x, 1000)

  # The classifier for 1000 classes
  outputs = task(x, 1000)

  # Instantiate and return the Model
  return keras.Model(inputs, [outputs] + aux, name="Inception-v3")

# %%
# create the inception model (v3)
inception_model_v3 = model()

# print a summary
inception_model_v3.summary()
# Out:
# Model: "Inception-v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_118 (Conv2D)         (None, 149, 149, 32)         864       ['input_3[0][0]']
#
#  batch_normalization_59 (Ba  (None, 149, 149, 32)         128       ['conv2d_118[0][0]']
#  tchNormalization)
#
#  re_lu_59 (ReLU)             (None, 149, 149, 32)         0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_119 (Conv2D)         (None, 147, 147, 32)         9216      ['re_lu_59[0][0]']
#
#  batch_normalization_60 (Ba  (None, 147, 147, 32)         128       ['conv2d_119[0][0]']
#  tchNormalization)
#
#  re_lu_60 (ReLU)             (None, 147, 147, 32)         0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_120 (Conv2D)         (None, 147, 147, 64)         18432     ['re_lu_60[0][0]']
#
#  batch_normalization_61 (Ba  (None, 147, 147, 64)         256       ['conv2d_120[0][0]']
#  tchNormalization)
#
#  re_lu_61 (ReLU)             (None, 147, 147, 64)         0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  max_pooling2d_26 (MaxPooli  (None, 73, 73, 64)           0         ['re_lu_61[0][0]']
#  ng2D)
#
#  conv2d_121 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_26[0][0]']
#
#  batch_normalization_62 (Ba  (None, 73, 73, 80)           320       ['conv2d_121[0][0]']
#  tchNormalization)
#
#  re_lu_62 (ReLU)             (None, 73, 73, 80)           0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  conv2d_122 (Conv2D)         (None, 71, 71, 192)          138240    ['re_lu_62[0][0]']
#
#  batch_normalization_63 (Ba  (None, 71, 71, 192)          768       ['conv2d_122[0][0]']
#  tchNormalization)
#
#  re_lu_63 (ReLU)             (None, 71, 71, 192)          0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  max_pooling2d_27 (MaxPooli  (None, 35, 35, 192)          0         ['re_lu_63[0][0]']
#  ng2D)
#
#  conv2d_124 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_27[0][0]']
#
#  batch_normalization_65 (Ba  (None, 35, 35, 64)           256       ['conv2d_124[0][0]']
#  tchNormalization)
#
#  re_lu_65 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_125 (Conv2D)         (None, 35, 35, 96)           55296     ['re_lu_65[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_27[0][0]']
#
#  batch_normalization_66 (Ba  (None, 35, 35, 96)           384       ['conv2d_125[0][0]']
#  tchNormalization)
#
#  batch_normalization_68 (Ba  (None, 35, 35, 48)           192       ['conv2d_127[0][0]']
#  tchNormalization)
#
#  re_lu_66 (ReLU)             (None, 35, 35, 96)           0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  re_lu_68 (ReLU)             (None, 35, 35, 48)           0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  average_pooling2d_6 (Avera  (None, 35, 35, 192)          0         ['max_pooling2d_27[0][0]']
#  gePooling2D)
#
#  conv2d_123 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_27[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 35, 35, 96)           82944     ['re_lu_66[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 35, 35, 64)           27648     ['re_lu_68[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 35, 35, 32)           6144      ['average_pooling2d_6[0][0]']
#
#  batch_normalization_64 (Ba  (None, 35, 35, 64)           256       ['conv2d_123[0][0]']
#  tchNormalization)
#
#  batch_normalization_67 (Ba  (None, 35, 35, 96)           384       ['conv2d_126[0][0]']
#  tchNormalization)
#
#  batch_normalization_69 (Ba  (None, 35, 35, 64)           256       ['conv2d_128[0][0]']
#  tchNormalization)
#
#  batch_normalization_70 (Ba  (None, 35, 35, 32)           128       ['conv2d_129[0][0]']
#  tchNormalization)
#
#  re_lu_64 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  re_lu_67 (ReLU)             (None, 35, 35, 96)           0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  re_lu_69 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  re_lu_70 (ReLU)             (None, 35, 35, 32)           0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  concatenate_18 (Concatenat  (None, 35, 35, 256)          0         ['re_lu_64[0][0]',
#  e)                                                                  're_lu_67[0][0]',
#                                                                      're_lu_69[0][0]',
#                                                                      're_lu_70[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 35, 35, 64)           16384     ['concatenate_18[0][0]']
#
#  batch_normalization_72 (Ba  (None, 35, 35, 64)           256       ['conv2d_131[0][0]']
#  tchNormalization)
#
#  re_lu_72 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  conv2d_132 (Conv2D)         (None, 35, 35, 96)           55296     ['re_lu_72[0][0]']
#
#  conv2d_134 (Conv2D)         (None, 35, 35, 48)           12288     ['concatenate_18[0][0]']
#
#  batch_normalization_73 (Ba  (None, 35, 35, 96)           384       ['conv2d_132[0][0]']
#  tchNormalization)
#
#  batch_normalization_75 (Ba  (None, 35, 35, 48)           192       ['conv2d_134[0][0]']
#  tchNormalization)
#
#  re_lu_73 (ReLU)             (None, 35, 35, 96)           0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  re_lu_75 (ReLU)             (None, 35, 35, 48)           0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  average_pooling2d_7 (Avera  (None, 35, 35, 256)          0         ['concatenate_18[0][0]']
#  gePooling2D)
#
#  conv2d_130 (Conv2D)         (None, 35, 35, 64)           16384     ['concatenate_18[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 35, 35, 96)           82944     ['re_lu_73[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 35, 35, 64)           27648     ['re_lu_75[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 35, 35, 64)           16384     ['average_pooling2d_7[0][0]']
#
#  batch_normalization_71 (Ba  (None, 35, 35, 64)           256       ['conv2d_130[0][0]']
#  tchNormalization)
#
#  batch_normalization_74 (Ba  (None, 35, 35, 96)           384       ['conv2d_133[0][0]']
#  tchNormalization)
#
#  batch_normalization_76 (Ba  (None, 35, 35, 64)           256       ['conv2d_135[0][0]']
#  tchNormalization)
#
#  batch_normalization_77 (Ba  (None, 35, 35, 64)           256       ['conv2d_136[0][0]']
#  tchNormalization)
#
#  re_lu_71 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  re_lu_74 (ReLU)             (None, 35, 35, 96)           0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  re_lu_76 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  re_lu_77 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  concatenate_19 (Concatenat  (None, 35, 35, 288)          0         ['re_lu_71[0][0]',
#  e)                                                                  're_lu_74[0][0]',
#                                                                      're_lu_76[0][0]',
#                                                                      're_lu_77[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 35, 35, 64)           18432     ['concatenate_19[0][0]']
#
#  batch_normalization_79 (Ba  (None, 35, 35, 64)           256       ['conv2d_138[0][0]']
#  tchNormalization)
#
#  re_lu_79 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_139 (Conv2D)         (None, 35, 35, 96)           55296     ['re_lu_79[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 35, 35, 48)           13824     ['concatenate_19[0][0]']
#
#  batch_normalization_80 (Ba  (None, 35, 35, 96)           384       ['conv2d_139[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 35, 35, 48)           192       ['conv2d_141[0][0]']
#  tchNormalization)
#
#  re_lu_80 (ReLU)             (None, 35, 35, 96)           0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  re_lu_82 (ReLU)             (None, 35, 35, 48)           0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  average_pooling2d_8 (Avera  (None, 35, 35, 288)          0         ['concatenate_19[0][0]']
#  gePooling2D)
#
#  conv2d_137 (Conv2D)         (None, 35, 35, 64)           18432     ['concatenate_19[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 35, 35, 96)           82944     ['re_lu_80[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 35, 35, 64)           27648     ['re_lu_82[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 35, 35, 64)           18432     ['average_pooling2d_8[0][0]']
#
#  batch_normalization_78 (Ba  (None, 35, 35, 64)           256       ['conv2d_137[0][0]']
#  tchNormalization)
#
#  batch_normalization_81 (Ba  (None, 35, 35, 96)           384       ['conv2d_140[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 35, 35, 64)           256       ['conv2d_142[0][0]']
#  tchNormalization)
#
#  batch_normalization_84 (Ba  (None, 35, 35, 64)           256       ['conv2d_143[0][0]']
#  tchNormalization)
#
#  re_lu_78 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  re_lu_81 (ReLU)             (None, 35, 35, 96)           0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  re_lu_83 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  re_lu_84 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  concatenate_20 (Concatenat  (None, 35, 35, 288)          0         ['re_lu_78[0][0]',
#  e)                                                                  're_lu_81[0][0]',
#                                                                      're_lu_83[0][0]',
#                                                                      're_lu_84[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 35, 35, 64)           18432     ['concatenate_20[0][0]']
#
#  batch_normalization_86 (Ba  (None, 35, 35, 64)           256       ['conv2d_145[0][0]']
#  tchNormalization)
#
#  re_lu_86 (ReLU)             (None, 35, 35, 64)           0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_146 (Conv2D)         (None, 35, 35, 96)           55296     ['re_lu_86[0][0]']
#
#  batch_normalization_87 (Ba  (None, 35, 35, 96)           384       ['conv2d_146[0][0]']
#  tchNormalization)
#
#  re_lu_87 (ReLU)             (None, 35, 35, 96)           0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv2d_144 (Conv2D)         (None, 17, 17, 384)          995328    ['concatenate_20[0][0]']
#
#  conv2d_147 (Conv2D)         (None, 17, 17, 96)           82944     ['re_lu_87[0][0]']
#
#  batch_normalization_85 (Ba  (None, 17, 17, 384)          1536      ['conv2d_144[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 17, 17, 96)           384       ['conv2d_147[0][0]']
#  tchNormalization)
#
#  re_lu_85 (ReLU)             (None, 17, 17, 384)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  re_lu_88 (ReLU)             (None, 17, 17, 96)           0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  max_pooling2d_28 (MaxPooli  (None, 17, 17, 288)          0         ['concatenate_20[0][0]']
#  ng2D)
#
#  concatenate_21 (Concatenat  (None, 17, 17, 768)          0         ['re_lu_85[0][0]',
#  e)                                                                  're_lu_88[0][0]',
#                                                                      'max_pooling2d_28[0][0]']
#
#  conv2d_152 (Conv2D)         (None, 17, 17, 128)          98304     ['concatenate_21[0][0]']
#
#  batch_normalization_93 (Ba  (None, 17, 17, 128)          512       ['conv2d_152[0][0]']
#  tchNormalization)
#
#  re_lu_93 (ReLU)             (None, 17, 17, 128)          0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  conv2d_153 (Conv2D)         (None, 17, 17, 128)          114688    ['re_lu_93[0][0]']
#
#  batch_normalization_94 (Ba  (None, 17, 17, 128)          512       ['conv2d_153[0][0]']
#  tchNormalization)
#
#  re_lu_94 (ReLU)             (None, 17, 17, 128)          0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_149 (Conv2D)         (None, 17, 17, 128)          98304     ['concatenate_21[0][0]']
#
#  conv2d_154 (Conv2D)         (None, 17, 17, 128)          114688    ['re_lu_94[0][0]']
#
#  batch_normalization_90 (Ba  (None, 17, 17, 128)          512       ['conv2d_149[0][0]']
#  tchNormalization)
#
#  batch_normalization_95 (Ba  (None, 17, 17, 128)          512       ['conv2d_154[0][0]']
#  tchNormalization)
#
#  re_lu_90 (ReLU)             (None, 17, 17, 128)          0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  re_lu_95 (ReLU)             (None, 17, 17, 128)          0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_150 (Conv2D)         (None, 17, 17, 128)          114688    ['re_lu_90[0][0]']
#
#  conv2d_155 (Conv2D)         (None, 17, 17, 128)          114688    ['re_lu_95[0][0]']
#
#  batch_normalization_91 (Ba  (None, 17, 17, 128)          512       ['conv2d_150[0][0]']
#  tchNormalization)
#
#  batch_normalization_96 (Ba  (None, 17, 17, 128)          512       ['conv2d_155[0][0]']
#  tchNormalization)
#
#  re_lu_91 (ReLU)             (None, 17, 17, 128)          0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  re_lu_96 (ReLU)             (None, 17, 17, 128)          0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  average_pooling2d_9 (Avera  (None, 17, 17, 768)          0         ['concatenate_21[0][0]']
#  gePooling2D)
#
#  conv2d_148 (Conv2D)         (None, 17, 17, 192)          147456    ['concatenate_21[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 17, 17, 192)          172032    ['re_lu_91[0][0]']
#
#  conv2d_156 (Conv2D)         (None, 17, 17, 192)          172032    ['re_lu_96[0][0]']
#
#  conv2d_157 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 17, 17, 192)          768       ['conv2d_148[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 17, 17, 192)          768       ['conv2d_151[0][0]']
#  tchNormalization)
#
#  batch_normalization_97 (Ba  (None, 17, 17, 192)          768       ['conv2d_156[0][0]']
#  tchNormalization)
#
#  batch_normalization_98 (Ba  (None, 17, 17, 192)          768       ['conv2d_157[0][0]']
#  tchNormalization)
#
#  re_lu_89 (ReLU)             (None, 17, 17, 192)          0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  re_lu_92 (ReLU)             (None, 17, 17, 192)          0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  re_lu_97 (ReLU)             (None, 17, 17, 192)          0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  re_lu_98 (ReLU)             (None, 17, 17, 192)          0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  concatenate_22 (Concatenat  (None, 17, 17, 768)          0         ['re_lu_89[0][0]',
#  e)                                                                  're_lu_92[0][0]',
#                                                                      're_lu_97[0][0]',
#                                                                      're_lu_98[0][0]']
#
#  conv2d_162 (Conv2D)         (None, 17, 17, 160)          122880    ['concatenate_22[0][0]']
#
#  batch_normalization_103 (B  (None, 17, 17, 160)          640       ['conv2d_162[0][0]']
#  atchNormalization)
#
#  re_lu_103 (ReLU)            (None, 17, 17, 160)          0         ['batch_normalization_103[0][0
#                                                                     ]']
#
#  conv2d_163 (Conv2D)         (None, 17, 17, 160)          179200    ['re_lu_103[0][0]']
#
#  batch_normalization_104 (B  (None, 17, 17, 160)          640       ['conv2d_163[0][0]']
#  atchNormalization)
#
#  re_lu_104 (ReLU)            (None, 17, 17, 160)          0         ['batch_normalization_104[0][0
#                                                                     ]']
#
#  conv2d_159 (Conv2D)         (None, 17, 17, 160)          122880    ['concatenate_22[0][0]']
#
#  conv2d_164 (Conv2D)         (None, 17, 17, 160)          179200    ['re_lu_104[0][0]']
#
#  batch_normalization_100 (B  (None, 17, 17, 160)          640       ['conv2d_159[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 17, 17, 160)          640       ['conv2d_164[0][0]']
#  atchNormalization)
#
#  re_lu_100 (ReLU)            (None, 17, 17, 160)          0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  re_lu_105 (ReLU)            (None, 17, 17, 160)          0         ['batch_normalization_105[0][0
#                                                                     ]']
#
#  conv2d_160 (Conv2D)         (None, 17, 17, 160)          179200    ['re_lu_100[0][0]']
#
#  conv2d_165 (Conv2D)         (None, 17, 17, 160)          179200    ['re_lu_105[0][0]']
#
#  batch_normalization_101 (B  (None, 17, 17, 160)          640       ['conv2d_160[0][0]']
#  atchNormalization)
#
#  batch_normalization_106 (B  (None, 17, 17, 160)          640       ['conv2d_165[0][0]']
#  atchNormalization)
#
#  re_lu_101 (ReLU)            (None, 17, 17, 160)          0         ['batch_normalization_101[0][0
#                                                                     ]']
#
#  re_lu_106 (ReLU)            (None, 17, 17, 160)          0         ['batch_normalization_106[0][0
#                                                                     ]']
#
#  average_pooling2d_10 (Aver  (None, 17, 17, 768)          0         ['concatenate_22[0][0]']
#  agePooling2D)
#
#  conv2d_158 (Conv2D)         (None, 17, 17, 192)          147456    ['concatenate_22[0][0]']
#
#  conv2d_161 (Conv2D)         (None, 17, 17, 192)          215040    ['re_lu_101[0][0]']
#
#  conv2d_166 (Conv2D)         (None, 17, 17, 192)          215040    ['re_lu_106[0][0]']
#
#  conv2d_167 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_10[0][0]']
#
#  batch_normalization_99 (Ba  (None, 17, 17, 192)          768       ['conv2d_158[0][0]']
#  tchNormalization)
#
#  batch_normalization_102 (B  (None, 17, 17, 192)          768       ['conv2d_161[0][0]']
#  atchNormalization)
#
#  batch_normalization_107 (B  (None, 17, 17, 192)          768       ['conv2d_166[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 17, 17, 192)          768       ['conv2d_167[0][0]']
#  atchNormalization)
#
#  re_lu_99 (ReLU)             (None, 17, 17, 192)          0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  re_lu_102 (ReLU)            (None, 17, 17, 192)          0         ['batch_normalization_102[0][0
#                                                                     ]']
#
#  re_lu_107 (ReLU)            (None, 17, 17, 192)          0         ['batch_normalization_107[0][0
#                                                                     ]']
#
#  re_lu_108 (ReLU)            (None, 17, 17, 192)          0         ['batch_normalization_108[0][0
#                                                                     ]']
#
#  concatenate_23 (Concatenat  (None, 17, 17, 768)          0         ['re_lu_99[0][0]',
#  e)                                                                  're_lu_102[0][0]',
#                                                                      're_lu_107[0][0]',
#                                                                      're_lu_108[0][0]']
#
#  conv2d_172 (Conv2D)         (None, 17, 17, 160)          122880    ['concatenate_23[0][0]']
#
#  batch_normalization_113 (B  (None, 17, 17, 160)          640       ['conv2d_172[0][0]']
#  atchNormalization)
#
#  re_lu_113 (ReLU)            (None, 17, 17, 160)          0         ['batch_normalization_113[0][0
#                                                                     ]']
#
#  conv2d_173 (Conv2D)         (None, 17, 17, 160)          179200    ['re_lu_113[0][0]']
#
#  batch_normalization_114 (B  (None, 17, 17, 160)          640       ['conv2d_173[0][0]']
#  atchNormalization)
#
#  re_lu_114 (ReLU)            (None, 17, 17, 160)          0         ['batch_normalization_114[0][0
#                                                                     ]']
#
#  conv2d_169 (Conv2D)         (None, 17, 17, 160)          122880    ['concatenate_23[0][0]']
#
#  conv2d_174 (Conv2D)         (None, 17, 17, 160)          179200    ['re_lu_114[0][0]']
#
#  batch_normalization_110 (B  (None, 17, 17, 160)          640       ['conv2d_169[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 17, 17, 160)          640       ['conv2d_174[0][0]']
#  atchNormalization)
#
# ...
#  batch_normalization_137 (B  (None, 8, 8, 384)            1536      ['conv2d_197[0][0]']
#  atchNormalization)
#
#  conv2d_200 (Conv2D)         (None, 8, 8, 448)            573440    ['concatenate_26[0][0]']
#
#  re_lu_137 (ReLU)            (None, 8, 8, 384)            0         ['batch_normalization_137[0][0
#                                                                     ]']
#
#  batch_normalization_140 (B  (None, 8, 8, 448)            1792      ['conv2d_200[0][0]']
#  atchNormalization)
#
#  conv2d_198 (Conv2D)         (None, 8, 8, 384)            442368    ['re_lu_137[0][0]']
#
#  conv2d_199 (Conv2D)         (None, 8, 8, 384)            442368    ['re_lu_137[0][0]']
#
#  re_lu_140 (ReLU)            (None, 8, 8, 448)            0         ['batch_normalization_140[0][0
#                                                                     ]']
#
#  average_pooling2d_14 (Aver  (None, 8, 8, 1280)           0         ['concatenate_26[0][0]']
#  agePooling2D)
#
#  conv2d_196 (Conv2D)         (None, 8, 8, 320)            409600    ['concatenate_26[0][0]']
#
#  batch_normalization_138 (B  (None, 8, 8, 384)            1536      ['conv2d_198[0][0]']
#  atchNormalization)
#
#  batch_normalization_139 (B  (None, 8, 8, 384)            1536      ['conv2d_199[0][0]']
#  atchNormalization)
#
#  conv2d_201 (Conv2D)         (None, 8, 8, 384)            1548288   ['re_lu_140[0][0]']
#
#  conv2d_204 (Conv2D)         (None, 8, 8, 192)            245760    ['average_pooling2d_14[0][0]']
#
#  batch_normalization_136 (B  (None, 8, 8, 320)            1280      ['conv2d_196[0][0]']
#  atchNormalization)
#
#  re_lu_138 (ReLU)            (None, 8, 8, 384)            0         ['batch_normalization_138[0][0
#                                                                     ]']
#
#  re_lu_139 (ReLU)            (None, 8, 8, 384)            0         ['batch_normalization_139[0][0
#                                                                     ]']
#
#  batch_normalization_141 (B  (None, 8, 8, 384)            1536      ['conv2d_201[0][0]']
#  atchNormalization)
#
#  batch_normalization_144 (B  (None, 8, 8, 192)            768       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  re_lu_136 (ReLU)            (None, 8, 8, 320)            0         ['batch_normalization_136[0][0
#                                                                     ]']
#
#  concatenate_27 (Concatenat  (None, 8, 8, 768)            0         ['re_lu_138[0][0]',
#  e)                                                                  're_lu_139[0][0]']
#
#  re_lu_141 (ReLU)            (None, 8, 8, 384)            0         ['batch_normalization_141[0][0
#                                                                     ]']
#
#  re_lu_144 (ReLU)            (None, 8, 8, 192)            0         ['batch_normalization_144[0][0
#                                                                     ]']
#
#  concatenate_29 (Concatenat  (None, 8, 8, 1664)           0         ['re_lu_136[0][0]',
#  e)                                                                  'concatenate_27[0][0]',
#                                                                      're_lu_141[0][0]',
#                                                                      're_lu_144[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 8, 8, 384)            638976    ['concatenate_29[0][0]']
#
#  batch_normalization_146 (B  (None, 8, 8, 384)            1536      ['conv2d_206[0][0]']
#  atchNormalization)
#
#  conv2d_209 (Conv2D)         (None, 8, 8, 448)            745472    ['concatenate_29[0][0]']
#
#  re_lu_146 (ReLU)            (None, 8, 8, 384)            0         ['batch_normalization_146[0][0
#                                                                     ]']
#
#  batch_normalization_149 (B  (None, 8, 8, 448)            1792      ['conv2d_209[0][0]']
#  atchNormalization)
#
#  conv2d_207 (Conv2D)         (None, 8, 8, 384)            442368    ['re_lu_146[0][0]']
#
#  conv2d_208 (Conv2D)         (None, 8, 8, 384)            442368    ['re_lu_146[0][0]']
#
#  re_lu_149 (ReLU)            (None, 8, 8, 448)            0         ['batch_normalization_149[0][0
#                                                                     ]']
#
#  average_pooling2d_15 (Aver  (None, 8, 8, 1664)           0         ['concatenate_29[0][0]']
#  agePooling2D)
#
#  conv2d_205 (Conv2D)         (None, 8, 8, 320)            532480    ['concatenate_29[0][0]']
#
#  batch_normalization_147 (B  (None, 8, 8, 384)            1536      ['conv2d_207[0][0]']
#  atchNormalization)
#
#  batch_normalization_148 (B  (None, 8, 8, 384)            1536      ['conv2d_208[0][0]']
#  atchNormalization)
#
#  conv2d_210 (Conv2D)         (None, 8, 8, 384)            1548288   ['re_lu_149[0][0]']
#
#  conv2d_213 (Conv2D)         (None, 8, 8, 192)            319488    ['average_pooling2d_15[0][0]']
#
#  batch_normalization_145 (B  (None, 8, 8, 320)            1280      ['conv2d_205[0][0]']
#  atchNormalization)
#
#  re_lu_147 (ReLU)            (None, 8, 8, 384)            0         ['batch_normalization_147[0][0
#                                                                     ]']
#
#  re_lu_148 (ReLU)            (None, 8, 8, 384)            0         ['batch_normalization_148[0][0
#                                                                     ]']
#
#  batch_normalization_150 (B  (None, 8, 8, 384)            1536      ['conv2d_210[0][0]']
#  atchNormalization)
#
#  batch_normalization_153 (B  (None, 8, 8, 192)            768       ['conv2d_213[0][0]']
#  atchNormalization)
#
#  average_pooling2d_13 (Aver  (None, 5, 5, 768)            0         ['concatenate_25[0][0]']
#  agePooling2D)
#
#  re_lu_145 (ReLU)            (None, 8, 8, 320)            0         ['batch_normalization_145[0][0
#                                                                     ]']
#
#  concatenate_30 (Concatenat  (None, 8, 8, 768)            0         ['re_lu_147[0][0]',
#  e)                                                                  're_lu_148[0][0]']
#
#  re_lu_150 (ReLU)            (None, 8, 8, 384)            0         ['batch_normalization_150[0][0
#                                                                     ]']
#
#  re_lu_153 (ReLU)            (None, 8, 8, 192)            0         ['batch_normalization_153[0][0
#                                                                     ]']
#
#  conv2d_188 (Conv2D)         (None, 5, 5, 128)            98304     ['average_pooling2d_13[0][0]']
#
#  concatenate_32 (Concatenat  (None, 8, 8, 1664)           0         ['re_lu_145[0][0]',
#  e)                                                                  'concatenate_30[0][0]',
#                                                                      're_lu_150[0][0]',
#                                                                      're_lu_153[0][0]']
#
#  batch_normalization_129 (B  (None, 5, 5, 128)            512       ['conv2d_188[0][0]']
#  atchNormalization)
#
#  average_pooling2d_16 (Aver  (None, 1, 1, 1664)           0         ['concatenate_32[0][0]']
#  agePooling2D)
#
#  re_lu_129 (ReLU)            (None, 5, 5, 128)            0         ['batch_normalization_129[0][0
#                                                                     ]']
#
#  dropout_6 (Dropout)         (None, 1, 1, 1664)           0         ['average_pooling2d_16[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 1, 1, 768)            2457600   ['re_lu_129[0][0]']
#
#  flatten_7 (Flatten)         (None, 1664)                 0         ['dropout_6[0][0]']
#
#  flatten_6 (Flatten)         (None, 768)                  0         ['conv2d_189[0][0]']
#
#  dense_11 (Dense)            (None, 1000)                 1665000   ['flatten_7[0][0]']
#
#  dense_10 (Dense)            (None, 1000)                 769000    ['flatten_6[0][0]']
#
# ==================================================================================================
# Total params: 24371248 (92.97 MB)
# Trainable params: 24339632 (92.85 MB)
# Non-trainable params: 31616 (123.50 KB)
# __________________________________________________________________________________________________
