# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/Xception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %% [markdown]
# # Xception

# %% [markdown]
# ## The entry flow section with the stem component and projection block

# %% [markdown]
# ### The stem component

# %%
def stem(inputs):
  """ Create the stem component of Xception
      inputs : input tensor to neural network
  """

  # a strided 3x3 convolution for dimensionality reduction to reduce feature maps by 75%
  x = keras.layers.Conv2D(filters=32, kernel_size=3, strides=2)(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 convolution for dimensionality expansion to double the number of filters
  x = keras.layers.Conv2D(filters=64, kernel_size=3, strides=1)(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# ### The Projection Block

# %%
def projection_block(x, n_filters):
  """ Build a residual block using depthwise separable convolutions
      with projection shortcut.
      x        : input into residual block
      n_filters: number of filters
  """
  # save the input
  shortcut = x

  # a strided 1x1 convolution to double number of filters in identity link to
  # match output of residual block for the add operation (projection shortcut)
  shortcut = keras.layers.Conv2D(filters=n_filters, kernel_size=1, strides=2, padding='same')(shortcut)
  shortcut = keras.layers.BatchNormalization()(shortcut)

  # first depthwise separable convolution
  x = keras.layers.SeparableConv2D(filters=n_filters, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # second depthwise separable convolution
  x = keras.layers.SeparableConv2D(filters=n_filters, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # create pooled feature maps, reduce size by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

  # add the projection shortcut to the output of the block
  x = keras.layers.Add()([x, shortcut])

  return x

# %% [markdown]
# ### The Entry Flow

# %%
def entryFlow(inputs):
  """ create the entry flow section
      inputs : input tensor to neural network
  """

  # create the stem to the neural network
  x = stem(inputs)

  # create three residual blocks using linear projection
  for n_filters in [128, 256, 728]:
    x = projection_block(x, n_filters)


  return x

# %% [markdown]
# ## The middle flow section with a residual block

# %% [markdown]
# ### The Residual Block

# %%
def residual_block(x, n_filters):
  """ Create a residual block using depthwise separable convolutions
      x        : input into residual block
      n_filters: number of filters
  """

  # save the input
  shortcut = x

  # a 3x3 depthwise separable convolution
  x = keras.layers.SeparableConv2D(filters=n_filters, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 depthwise separable convolution
  x = keras.layers.SeparableConv2D(filters=n_filters, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 depthwise separable convolution
  x = keras.layers.SeparableConv2D(filters=n_filters, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # we add the identity link to the output of the block
  x = keras.layers.Add()([x, shortcut])
  return x

# %% [markdown]
# ### The Middle Flow

# %%
def middleFlow(x):
  """ Create the middle flow section
      x : input tensor into section
  """
  # we create 8 residual blocks
  for _ in range(8):
    x = residual_block(x, 728)

  return x

# %% [markdown]
# ## The exit flow section with a task component

# %% [markdown]
# ### The task component

# %%
def task(x, n_classes):
  """ The task component of Xception.
      x         : input to the classifier
      n_classes : number of output classes
  """
  # Global Average Pooling will flatten the 10x10 feature maps into 1D
  # feature maps
  x = keras.layers.GlobalAveragePooling2D()(x)

  # Fully connected output layer (classification)
  x = keras.layers.Dense(units=n_classes, activation='softmax')(x)

  return x

# %% [markdown]
# ### The Exit Flow

# %%
def exitFlow(x, n_classes):
  """ Create the exit flow section
      x         : input to the exit flow section
      n_classes : number of output classes
  """

  # 1x1 strided convolution to increase number and reduce size of feature maps
  # in identity link to match output of residual block for the add operation (projection shortcut)
  shortcut = keras.layers.Conv2D(filters=1024, kernel_size=1, strides=2, padding='same')(x)
  shortcut = keras.layers.BatchNormalization()(shortcut)

  # a 3x3 depthwise separable convolution for dimensionality reduction (reduce number of filters)
  x = keras.layers.SeparableConv2D(filters=728, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 depthwise separable convolution for dimensionality restoration
  x = keras.layers.SeparableConv2D(filters=1024, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 max pooling to create pooled feature maps, reduce size by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

  # we add the projection shortcut to the output of the pooling layer
  x = keras.layers.Add()([x, shortcut])

  # a 3x3 depthwise separable convolution
  x = keras.layers.SeparableConv2D(filters=1556, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 depthwise separable convolution
  x = keras.layers.SeparableConv2D(filters=2048, kernel_size=3, padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # pass 'x' to the task component for classification
  x = task(x, n_classes)

  return x

# %% [markdown]
# ## The Xception model

# %%
def build_xception(shape=(299,299,3), classes=1000):
  # create the input vector
  inputs = keras.Input(shape=(299, 299, 3))

  # pass the inputs through the entry flow section
  x = entryFlow(inputs)

  # pass output of entry flow through the middle flow section
  x = middleFlow(x)

  # pass output of middle flow through the exit flow section
  outputs = exitFlow(x, classes)

  # Instantiate the model
  return keras.Model(inputs=inputs, outputs=outputs, name="Xception")

# %%
# create the Xception model
xception_model = build_xception()
# print the xception model
xception_model.summary()
# Out:
# Model: "Xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_6 (Conv2D)           (None, 149, 149, 32)         896       ['input_2[0][0]']
#
#  batch_normalization_40 (Ba  (None, 149, 149, 32)         128       ['conv2d_6[0][0]']
#  tchNormalization)
#
#  re_lu_36 (ReLU)             (None, 149, 149, 32)         0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_7 (Conv2D)           (None, 147, 147, 64)         18496     ['re_lu_36[0][0]']
#
#  batch_normalization_41 (Ba  (None, 147, 147, 64)         256       ['conv2d_7[0][0]']
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 147, 147, 64)         0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  separable_conv2d_34 (Separ  (None, 147, 147, 128)        8896      ['re_lu_37[0][0]']
#  ableConv2D)
#
#  batch_normalization_43 (Ba  (None, 147, 147, 128)        512       ['separable_conv2d_34[0][0]']
#  tchNormalization)
#
#  re_lu_38 (ReLU)             (None, 147, 147, 128)        0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  separable_conv2d_35 (Separ  (None, 147, 147, 128)        17664     ['re_lu_38[0][0]']
#  ableConv2D)
#
#  batch_normalization_44 (Ba  (None, 147, 147, 128)        512       ['separable_conv2d_35[0][0]']
#  tchNormalization)
#
#  re_lu_39 (ReLU)             (None, 147, 147, 128)        0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_8 (Conv2D)           (None, 74, 74, 128)          8320      ['re_lu_37[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 74, 74, 128)          0         ['re_lu_39[0][0]']
#  g2D)
#
#  batch_normalization_42 (Ba  (None, 74, 74, 128)          512       ['conv2d_8[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 74, 74, 128)          0         ['max_pooling2d_4[0][0]',
#                                                                      'batch_normalization_42[0][0]
#                                                                     ']
#
#  separable_conv2d_36 (Separ  (None, 74, 74, 256)          34176     ['add_12[0][0]']
#  ableConv2D)
#
#  batch_normalization_46 (Ba  (None, 74, 74, 256)          1024      ['separable_conv2d_36[0][0]']
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 74, 74, 256)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  separable_conv2d_37 (Separ  (None, 74, 74, 256)          68096     ['re_lu_40[0][0]']
#  ableConv2D)
#
#  batch_normalization_47 (Ba  (None, 74, 74, 256)          1024      ['separable_conv2d_37[0][0]']
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 74, 74, 256)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_9 (Conv2D)           (None, 37, 37, 256)          33024     ['add_12[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 37, 37, 256)          0         ['re_lu_41[0][0]']
#  g2D)
#
#  batch_normalization_45 (Ba  (None, 37, 37, 256)          1024      ['conv2d_9[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 37, 37, 256)          0         ['max_pooling2d_5[0][0]',
#                                                                      'batch_normalization_45[0][0]
#                                                                     ']
#
#  separable_conv2d_38 (Separ  (None, 37, 37, 728)          189400    ['add_13[0][0]']
#  ableConv2D)
#
#  batch_normalization_49 (Ba  (None, 37, 37, 728)          2912      ['separable_conv2d_38[0][0]']
#  tchNormalization)
#
#  re_lu_42 (ReLU)             (None, 37, 37, 728)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  separable_conv2d_39 (Separ  (None, 37, 37, 728)          537264    ['re_lu_42[0][0]']
#  ableConv2D)
#
#  batch_normalization_50 (Ba  (None, 37, 37, 728)          2912      ['separable_conv2d_39[0][0]']
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 37, 37, 728)          0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 19, 19, 728)          187096    ['add_13[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 19, 19, 728)          0         ['re_lu_43[0][0]']
#  g2D)
#
#  batch_normalization_48 (Ba  (None, 19, 19, 728)          2912      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 19, 19, 728)          0         ['max_pooling2d_6[0][0]',
#                                                                      'batch_normalization_48[0][0]
#                                                                     ']
#
#  separable_conv2d_40 (Separ  (None, 19, 19, 728)          537264    ['add_14[0][0]']
#  ableConv2D)
#
#  batch_normalization_51 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_40[0][0]']
#  tchNormalization)
#
#  re_lu_44 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  separable_conv2d_41 (Separ  (None, 19, 19, 728)          537264    ['re_lu_44[0][0]']
#  ableConv2D)
#
#  batch_normalization_52 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_41[0][0]']
#  tchNormalization)
#
#  re_lu_45 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  separable_conv2d_42 (Separ  (None, 19, 19, 728)          537264    ['re_lu_45[0][0]']
#  ableConv2D)
#
#  batch_normalization_53 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_42[0][0]']
#  tchNormalization)
#
#  re_lu_46 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  add_15 (Add)                (None, 19, 19, 728)          0         ['re_lu_46[0][0]',
#                                                                      'add_14[0][0]']
#
#  separable_conv2d_43 (Separ  (None, 19, 19, 728)          537264    ['add_15[0][0]']
#  ableConv2D)
#
#  batch_normalization_54 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_43[0][0]']
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  separable_conv2d_44 (Separ  (None, 19, 19, 728)          537264    ['re_lu_47[0][0]']
#  ableConv2D)
#
#  batch_normalization_55 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_44[0][0]']
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  separable_conv2d_45 (Separ  (None, 19, 19, 728)          537264    ['re_lu_48[0][0]']
#  ableConv2D)
#
#  batch_normalization_56 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_45[0][0]']
#  tchNormalization)
#
#  re_lu_49 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  add_16 (Add)                (None, 19, 19, 728)          0         ['re_lu_49[0][0]',
#                                                                      'add_15[0][0]']
#
#  separable_conv2d_46 (Separ  (None, 19, 19, 728)          537264    ['add_16[0][0]']
#  ableConv2D)
#
#  batch_normalization_57 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_46[0][0]']
#  tchNormalization)
#
#  re_lu_50 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  separable_conv2d_47 (Separ  (None, 19, 19, 728)          537264    ['re_lu_50[0][0]']
#  ableConv2D)
#
#  batch_normalization_58 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_47[0][0]']
#  tchNormalization)
#
#  re_lu_51 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  separable_conv2d_48 (Separ  (None, 19, 19, 728)          537264    ['re_lu_51[0][0]']
#  ableConv2D)
#
#  batch_normalization_59 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_48[0][0]']
#  tchNormalization)
#
#  re_lu_52 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  add_17 (Add)                (None, 19, 19, 728)          0         ['re_lu_52[0][0]',
#                                                                      'add_16[0][0]']
#
#  separable_conv2d_49 (Separ  (None, 19, 19, 728)          537264    ['add_17[0][0]']
#  ableConv2D)
#
#  batch_normalization_60 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_49[0][0]']
#  tchNormalization)
#
#  re_lu_53 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  separable_conv2d_50 (Separ  (None, 19, 19, 728)          537264    ['re_lu_53[0][0]']
#  ableConv2D)
#
#  batch_normalization_61 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_50[0][0]']
#  tchNormalization)
#
#  re_lu_54 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  separable_conv2d_51 (Separ  (None, 19, 19, 728)          537264    ['re_lu_54[0][0]']
#  ableConv2D)
#
#  batch_normalization_62 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_51[0][0]']
#  tchNormalization)
#
#  re_lu_55 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 19, 19, 728)          0         ['re_lu_55[0][0]',
#                                                                      'add_17[0][0]']
#
#  separable_conv2d_52 (Separ  (None, 19, 19, 728)          537264    ['add_18[0][0]']
#  ableConv2D)
#
#  batch_normalization_63 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_52[0][0]']
#  tchNormalization)
#
#  re_lu_56 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  separable_conv2d_53 (Separ  (None, 19, 19, 728)          537264    ['re_lu_56[0][0]']
#  ableConv2D)
#
#  batch_normalization_64 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_53[0][0]']
#  tchNormalization)
#
#  re_lu_57 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  separable_conv2d_54 (Separ  (None, 19, 19, 728)          537264    ['re_lu_57[0][0]']
#  ableConv2D)
#
#  batch_normalization_65 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_54[0][0]']
#  tchNormalization)
#
#  re_lu_58 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  add_19 (Add)                (None, 19, 19, 728)          0         ['re_lu_58[0][0]',
#                                                                      'add_18[0][0]']
#
#  separable_conv2d_55 (Separ  (None, 19, 19, 728)          537264    ['add_19[0][0]']
#  ableConv2D)
#
#  batch_normalization_66 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_55[0][0]']
#  tchNormalization)
#
#  re_lu_59 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  separable_conv2d_56 (Separ  (None, 19, 19, 728)          537264    ['re_lu_59[0][0]']
#  ableConv2D)
#
#  batch_normalization_67 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_56[0][0]']
#  tchNormalization)
#
#  re_lu_60 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  separable_conv2d_57 (Separ  (None, 19, 19, 728)          537264    ['re_lu_60[0][0]']
#  ableConv2D)
#
#  batch_normalization_68 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_57[0][0]']
#  tchNormalization)
#
#  re_lu_61 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  add_20 (Add)                (None, 19, 19, 728)          0         ['re_lu_61[0][0]',
#                                                                      'add_19[0][0]']
#
#  separable_conv2d_58 (Separ  (None, 19, 19, 728)          537264    ['add_20[0][0]']
#  ableConv2D)
#
#  batch_normalization_69 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_58[0][0]']
#  tchNormalization)
#
#  re_lu_62 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  separable_conv2d_59 (Separ  (None, 19, 19, 728)          537264    ['re_lu_62[0][0]']
#  ableConv2D)
#
#  batch_normalization_70 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_59[0][0]']
#  tchNormalization)
#
#  re_lu_63 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  separable_conv2d_60 (Separ  (None, 19, 19, 728)          537264    ['re_lu_63[0][0]']
#  ableConv2D)
#
#  batch_normalization_71 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_60[0][0]']
#  tchNormalization)
#
#  re_lu_64 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  add_21 (Add)                (None, 19, 19, 728)          0         ['re_lu_64[0][0]',
#                                                                      'add_20[0][0]']
#
#  separable_conv2d_61 (Separ  (None, 19, 19, 728)          537264    ['add_21[0][0]']
#  ableConv2D)
#
#  batch_normalization_72 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_61[0][0]']
#  tchNormalization)
#
#  re_lu_65 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  separable_conv2d_62 (Separ  (None, 19, 19, 728)          537264    ['re_lu_65[0][0]']
#  ableConv2D)
#
#  batch_normalization_73 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_62[0][0]']
#  tchNormalization)
#
#  re_lu_66 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  separable_conv2d_63 (Separ  (None, 19, 19, 728)          537264    ['re_lu_66[0][0]']
#  ableConv2D)
#
#  batch_normalization_74 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_63[0][0]']
#  tchNormalization)
#
#  re_lu_67 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  add_22 (Add)                (None, 19, 19, 728)          0         ['re_lu_67[0][0]',
#                                                                      'add_21[0][0]']
#
#  separable_conv2d_64 (Separ  (None, 19, 19, 728)          537264    ['add_22[0][0]']
#  ableConv2D)
#
#  batch_normalization_76 (Ba  (None, 19, 19, 728)          2912      ['separable_conv2d_64[0][0]']
#  tchNormalization)
#
#  re_lu_68 (ReLU)             (None, 19, 19, 728)          0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  separable_conv2d_65 (Separ  (None, 19, 19, 1024)         753048    ['re_lu_68[0][0]']
#  ableConv2D)
#
#  batch_normalization_77 (Ba  (None, 19, 19, 1024)         4096      ['separable_conv2d_65[0][0]']
#  tchNormalization)
#
#  re_lu_69 (ReLU)             (None, 19, 19, 1024)         0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 10, 10, 1024)         746496    ['add_22[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 10, 10, 1024)         0         ['re_lu_69[0][0]']
#  g2D)
#
#  batch_normalization_75 (Ba  (None, 10, 10, 1024)         4096      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 10, 10, 1024)         0         ['max_pooling2d_7[0][0]',
#                                                                      'batch_normalization_75[0][0]
#                                                                     ']
#
#  separable_conv2d_66 (Separ  (None, 10, 10, 1556)         1604116   ['add_23[0][0]']
#  ableConv2D)
#
#  batch_normalization_78 (Ba  (None, 10, 10, 1556)         6224      ['separable_conv2d_66[0][0]']
#  tchNormalization)
#
#  re_lu_70 (ReLU)             (None, 10, 10, 1556)         0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  separable_conv2d_67 (Separ  (None, 10, 10, 2048)         3202740   ['re_lu_70[0][0]']
#  ableConv2D)
#
#  batch_normalization_79 (Ba  (None, 10, 10, 2048)         8192      ['separable_conv2d_67[0][0]']
#  tchNormalization)
#
#  re_lu_71 (ReLU)             (None, 10, 10, 2048)         0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['re_lu_71[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)                 2049000   ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 22999464 (87.74 MB)
# Trainable params: 22944896 (87.53 MB)
# Non-trainable params: 54568 (213.16 KB)
# __________________________________________________________________________________________________
