# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/SE-ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %% [markdown]
# # SE-ResNet

# %% [markdown]
# ## The stem component

# %%
def stem(inputs):
  """ Build the stem component of SE-ResNet
      inputs : the input vector
  """
  # The 224x224 images are zero padded (black - no signal) to be 230x230 images prior to the first convolution
  x = keras.layers.ZeroPadding2D(padding=(3, 3))(inputs)

  # a 7x7 conv layer which uses a large (coarse) filter
  x = keras.layers.Conv2D(filters=64, kernel_size=7, strides=2, padding='valid', use_bias=False, kernel_initializer='he_normal')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 max pooling to create pooled feature maps will be reduced by 75%
  x = keras.layers.ZeroPadding2D(padding=(1, 1))(x)
  x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)

  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### The queeze & excite block

# %%
def squeeze_excite_block(x, ratio=16):
  """ Create a Squeeze and Excite block
      x    : input to the block
      ratio : amount of filter reduction during squeeze
  """
  # save the input
  shortcut = x

  # extract the number of filters on the input
  filters = x.shape[-1]

  # squeeze (dimensionality reduction)
  # apply global average pooling across the filters, which will output a 1D vector
  x = keras.layers.GlobalAveragePooling2D()(x)

  # reshape into 1x1 feature maps (1x1xC)
  x = keras.layers.Reshape((1, 1, filters))(x)

  # reduce the number of filters (1x1xC/r)
  n_filters = filters // ratio
  x = keras.layers.Dense(units=n_filters, activation='relu', kernel_initializer='he_normal', use_bias=False)(x)

  # excitation (dimensionality restoration)
  # restore the number of filters (1x1xC)
  x = keras.layers.Dense(units=filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(x)

  # scale - multiply the squeeze/excitation output with the input (WxHxC)
  x = keras.layers.Multiply()([shortcut, x])

  return x

# %% [markdown]
# ### The Identity Block

# %%
def identity_block(x, n_filters, ratio=16):
  """ Create a Bottleneck Residual Block with Identity Link
      x        : input into the block
      n_filters: number of filters
      ratio    : amount of filter reduction during squeeze
  """
  # Save input vector (feature maps) for the identity link
  shortcut = x

  # a 1x1 conv layer for dimensionality reduction
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=1, strides=1, use_bias=False, kernel_initializer='he_normal')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 conv layer serving as a bottleneck layer
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=3, strides=1, padding="same", use_bias=False, kernel_initializer='he_normal')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 1x1 conv layer for dimensionality restoration - increase the number of output filters by 4X
  x = keras.layers.Conv2D(filters=n_filters * 4, kernel_size=1, strides=1, use_bias=False, kernel_initializer='he_normal')(x)
  x = keras.layers.BatchNormalization()(x)

  # pass the output through the squeeze and excitation block
  x = squeeze_excite_block(x, ratio)

  # add the identity link (input) to the output of the residual block
  x = keras.layers.Add()([shortcut, x])
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# ### The Projection Block

# %%
def projection_block(x, n_filters, strides=(2,2), ratio=16):
  """ Create Bottleneck Residual Block with Projection Shortcut
      Increase the number of filters by 4X
      x        : input into the block
      n_filters: number of filters
      strides  : whether entry convolution is strided (i.e., (2, 2) vs (1, 1))
      ratio    : amount of filter reduction during squeeze
  """

  # Construct the projection shortcut
  # Increase filters by 4X to match shape when added to output of block
  shortcut = keras.layers.Conv2D(filters=4 * n_filters, kernel_size=1, strides=strides, use_bias=False, kernel_initializer='he_normal')(x)
  shortcut = keras.layers.BatchNormalization()(shortcut)

  # a 1x1 conv layer for dimensionality reduction
  # note that a feature pooling is done when strides=(2, 2)
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=1, strides=strides, use_bias=False, kernel_initializer='he_normal')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 3x3 conv layer acting as a bottleneck layer
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=3, strides=1, padding='same', use_bias=False, kernel_initializer='he_normal')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a conv layer for dimensionality restoration - increase the number of filters by 4X
  x = keras.layers.Conv2D(filters=4 * n_filters, kernel_size=1, strides=1, use_bias=False, kernel_initializer='he_normal')(x)
  x = keras.layers.BatchNormalization()(x)

  # pass the output through the squeeze and excitation block
  x = squeeze_excite_block(x, ratio)

  # add the projection shortcut link to the output of the residual block
  x = keras.layers.Add()([x, shortcut])
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# ### The SE-ResNet Group

# %%
def group(x, n_filters, n_blocks, ratio, strides=(2, 2)):
  """ Build the Squeeze-Excite Group
	    x        : input to the group
      n_blocks : number of blocks
	    n_filters: number of filters
      ratio    : amount of filter reduction during squeeze
      strides  : whether projection block is strided
  """
  # the first block uses linear projection to match the doubling of filters between groups
  x = projection_block(x, n_filters, strides=strides, ratio=ratio)

  # the remaining blocks use identity link
  for _ in range(n_blocks-1):
    x = identity_block(x, n_filters, ratio=ratio)

  return x

# %% [markdown]
# ### Putting it all together

# %%
def learner(x, groups, ratio):
  """ Build the learner component of the SE-ResNet.
      x     : input to the learner
	    groups: list of groups: number of filters and blocks
      ratio : amount of filter reduction in squeeze
  """
  # the first residual block group is not strided
  n_filters, n_blocks = groups.pop(0)
  x = group(x, n_filters, n_blocks, ratio, strides=(1, 1))

  # the remaining residual block groups are strided
  for n_filters, n_blocks in groups:
    x = group(x, n_filters, n_blocks, ratio)

  return x

# %% [markdown]
# ## The task component

# %%
def classifier(x, n_classes):
  """ Create the Classifier Group
      x         : input to the classifier
      n_classes : number of output classes
  """
  # global average pooling at the end of all the convolutional residual blocks
  x = keras.layers.GlobalAveragePooling2D()(x)

  # a final softmax layer
  outputs = keras.layers.Dense(units=n_classes, activation='softmax', kernel_initializer='he_normal')(x)

  return outputs

# %% [markdown]
# ## The SE-ResNet model

# %%
def build_se_resnet(groups, shape=(224, 224, 3), ratio=16, classes=1000):

  # The input tensor
  inputs = keras.Input(shape=(224, 224, 3))
  # The stem component
  x = stem(inputs)
  # The learner component
  x = learner(x, groups[50], ratio)
  # The task component
  outputs = classifier(x, classes)

  # return the SE-ResNet model
  return keras.Model(inputs=inputs, outputs=outputs)

# %%
# Meta-parameter: # Meta-parameter: list of groups: filter size and number of blocks
groups = { 50 : [ (64, 3), (128, 4), (256, 6),  (512, 3) ],		# SE-ResNet50
           101: [ (64, 3), (128, 4), (256, 23), (512, 3) ],		# SE-ResNet101
           152: [ (64, 3), (128, 8), (256, 36), (512, 3) ]		# SE-ResNet152
         }

# Meta-parameter: Amount of filter reduction in squeeze operation
ratio = 16

# %%
# create the SE-ResNet model
se_resnet_model = build_se_resnet(groups)

# print a summary
se_resnet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_6 (ZeroPadd  (None, 230, 230, 3)          0         ['input_4[0][0]']
#  ing2D)
#
#  conv2d_13 (Conv2D)          (None, 112, 112, 64)         9408      ['zero_padding2d_6[0][0]']
#
#  batch_normalization_13 (Ba  (None, 112, 112, 64)         256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  re_lu_8 (ReLU)              (None, 112, 112, 64)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  zero_padding2d_7 (ZeroPadd  (None, 114, 114, 64)         0         ['re_lu_8[0][0]']
#  ing2D)
#
#  max_pooling2d_3 (MaxPoolin  (None, 56, 56, 64)           0         ['zero_padding2d_7[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 56, 56, 64)           4096      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_15 (Ba  (None, 56, 56, 64)           256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 56, 56, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 56, 56, 64)           36864     ['re_lu_9[0][0]']
#
#  batch_normalization_16 (Ba  (None, 56, 56, 64)           256       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 56, 56, 256)          16384     ['re_lu_10[0][0]']
#
#  batch_normalization_17 (Ba  (None, 56, 56, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_2  (None, 256)                  0         ['batch_normalization_17[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  reshape_2 (Reshape)         (None, 1, 1, 256)            0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_3 (Dense)             (None, 1, 1, 16)             4096      ['reshape_2[0][0]']
#
#  dense_4 (Dense)             (None, 1, 1, 256)            4096      ['dense_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 56, 56, 256)          16384     ['max_pooling2d_3[0][0]']
#
#  multiply (Multiply)         (None, 56, 56, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'dense_4[0][0]']
#
#  batch_normalization_14 (Ba  (None, 56, 56, 256)          1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add (Add)                   (None, 56, 56, 256)          0         ['multiply[0][0]',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  re_lu_11 (ReLU)             (None, 56, 56, 256)          0         ['add[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 56, 56, 64)           16384     ['re_lu_11[0][0]']
#
#  batch_normalization_18 (Ba  (None, 56, 56, 64)           256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 56, 56, 64)           36864     ['re_lu_12[0][0]']
#
#  batch_normalization_19 (Ba  (None, 56, 56, 64)           256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 56, 56, 256)          16384     ['re_lu_13[0][0]']
#
#  batch_normalization_20 (Ba  (None, 56, 56, 256)          1024      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_3  (None, 256)                  0         ['batch_normalization_20[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  reshape_3 (Reshape)         (None, 1, 1, 256)            0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  dense_5 (Dense)             (None, 1, 1, 16)             4096      ['reshape_3[0][0]']
#
#  dense_6 (Dense)             (None, 1, 1, 256)            4096      ['dense_5[0][0]']
#
#  multiply_1 (Multiply)       (None, 56, 56, 256)          0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      'dense_6[0][0]']
#
#  add_1 (Add)                 (None, 56, 56, 256)          0         ['re_lu_11[0][0]',
#                                                                      'multiply_1[0][0]']
#
#  re_lu_14 (ReLU)             (None, 56, 56, 256)          0         ['add_1[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 56, 56, 64)           16384     ['re_lu_14[0][0]']
#
#  batch_normalization_21 (Ba  (None, 56, 56, 64)           256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 56, 56, 64)           36864     ['re_lu_15[0][0]']
#
#  batch_normalization_22 (Ba  (None, 56, 56, 64)           256       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 56, 56, 256)          16384     ['re_lu_16[0][0]']
#
#  batch_normalization_23 (Ba  (None, 56, 56, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_4  (None, 256)                  0         ['batch_normalization_23[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  reshape_4 (Reshape)         (None, 1, 1, 256)            0         ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  dense_7 (Dense)             (None, 1, 1, 16)             4096      ['reshape_4[0][0]']
#
#  dense_8 (Dense)             (None, 1, 1, 256)            4096      ['dense_7[0][0]']
#
#  multiply_2 (Multiply)       (None, 56, 56, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'dense_8[0][0]']
#
#  add_2 (Add)                 (None, 56, 56, 256)          0         ['re_lu_14[0][0]',
#                                                                      'multiply_2[0][0]']
#
#  re_lu_17 (ReLU)             (None, 56, 56, 256)          0         ['add_2[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 128)          32768     ['re_lu_17[0][0]']
#
#  batch_normalization_25 (Ba  (None, 28, 28, 128)          512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 128)          147456    ['re_lu_18[0][0]']
#
#  batch_normalization_26 (Ba  (None, 28, 28, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  re_lu_19 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 512)          65536     ['re_lu_19[0][0]']
#
#  batch_normalization_27 (Ba  (None, 28, 28, 512)          2048      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_5  (None, 512)                  0         ['batch_normalization_27[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  reshape_5 (Reshape)         (None, 1, 1, 512)            0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  dense_9 (Dense)             (None, 1, 1, 32)             16384     ['reshape_5[0][0]']
#
#  dense_10 (Dense)            (None, 1, 1, 512)            16384     ['dense_9[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 512)          131072    ['re_lu_17[0][0]']
#
#  multiply_3 (Multiply)       (None, 28, 28, 512)          0         ['batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'dense_10[0][0]']
#
#  batch_normalization_24 (Ba  (None, 28, 28, 512)          2048      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 28, 28, 512)          0         ['multiply_3[0][0]',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ']
#
#  re_lu_20 (ReLU)             (None, 28, 28, 512)          0         ['add_3[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 28, 28, 128)          65536     ['re_lu_20[0][0]']
#
#  batch_normalization_28 (Ba  (None, 28, 28, 128)          512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 128)          147456    ['re_lu_21[0][0]']
#
#  batch_normalization_29 (Ba  (None, 28, 28, 128)          512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 512)          65536     ['re_lu_22[0][0]']
#
#  batch_normalization_30 (Ba  (None, 28, 28, 512)          2048      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_6  (None, 512)                  0         ['batch_normalization_30[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  reshape_6 (Reshape)         (None, 1, 1, 512)            0         ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  dense_11 (Dense)            (None, 1, 1, 32)             16384     ['reshape_6[0][0]']
#
#  dense_12 (Dense)            (None, 1, 1, 512)            16384     ['dense_11[0][0]']
#
#  multiply_4 (Multiply)       (None, 28, 28, 512)          0         ['batch_normalization_30[0][0]
#                                                                     ',
#                                                                      'dense_12[0][0]']
#
#  add_4 (Add)                 (None, 28, 28, 512)          0         ['re_lu_20[0][0]',
#                                                                      'multiply_4[0][0]']
#
#  re_lu_23 (ReLU)             (None, 28, 28, 512)          0         ['add_4[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 128)          65536     ['re_lu_23[0][0]']
#
#  batch_normalization_31 (Ba  (None, 28, 28, 128)          512       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 128)          147456    ['re_lu_24[0][0]']
#
#  batch_normalization_32 (Ba  (None, 28, 28, 128)          512       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 512)          65536     ['re_lu_25[0][0]']
#
#  batch_normalization_33 (Ba  (None, 28, 28, 512)          2048      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_7  (None, 512)                  0         ['batch_normalization_33[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  reshape_7 (Reshape)         (None, 1, 1, 512)            0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  dense_13 (Dense)            (None, 1, 1, 32)             16384     ['reshape_7[0][0]']
#
#  dense_14 (Dense)            (None, 1, 1, 512)            16384     ['dense_13[0][0]']
#
#  multiply_5 (Multiply)       (None, 28, 28, 512)          0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'dense_14[0][0]']
#
#  add_5 (Add)                 (None, 28, 28, 512)          0         ['re_lu_23[0][0]',
#                                                                      'multiply_5[0][0]']
#
#  re_lu_26 (ReLU)             (None, 28, 28, 512)          0         ['add_5[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 28, 28, 128)          65536     ['re_lu_26[0][0]']
#
#  batch_normalization_34 (Ba  (None, 28, 28, 128)          512       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 28, 28, 128)          147456    ['re_lu_27[0][0]']
#
#  batch_normalization_35 (Ba  (None, 28, 28, 128)          512       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 28, 28, 512)          65536     ['re_lu_28[0][0]']
#
#  batch_normalization_36 (Ba  (None, 28, 28, 512)          2048      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_8  (None, 512)                  0         ['batch_normalization_36[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  reshape_8 (Reshape)         (None, 1, 1, 512)            0         ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  dense_15 (Dense)            (None, 1, 1, 32)             16384     ['reshape_8[0][0]']
#
#  dense_16 (Dense)            (None, 1, 1, 512)            16384     ['dense_15[0][0]']
#
#  multiply_6 (Multiply)       (None, 28, 28, 512)          0         ['batch_normalization_36[0][0]
#                                                                     ',
#                                                                      'dense_16[0][0]']
#
#  add_6 (Add)                 (None, 28, 28, 512)          0         ['re_lu_26[0][0]',
#                                                                      'multiply_6[0][0]']
#
#  re_lu_29 (ReLU)             (None, 28, 28, 512)          0         ['add_6[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 14, 14, 256)          131072    ['re_lu_29[0][0]']
#
#  batch_normalization_38 (Ba  (None, 14, 14, 256)          1024      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 256)          589824    ['re_lu_30[0][0]']
#
#  batch_normalization_39 (Ba  (None, 14, 14, 256)          1024      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 1024)         262144    ['re_lu_31[0][0]']
#
#  batch_normalization_40 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_9  (None, 1024)                 0         ['batch_normalization_40[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  reshape_9 (Reshape)         (None, 1, 1, 1024)           0         ['global_average_pooling2d_9[0
#                                                                     ][0]']
#
#  dense_17 (Dense)            (None, 1, 1, 64)             65536     ['reshape_9[0][0]']
#
#  dense_18 (Dense)            (None, 1, 1, 1024)           65536     ['dense_17[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 14, 14, 1024)         524288    ['re_lu_29[0][0]']
#
#  multiply_7 (Multiply)       (None, 14, 14, 1024)         0         ['batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'dense_18[0][0]']
#
#  batch_normalization_37 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 14, 14, 1024)         0         ['multiply_7[0][0]',
#                                                                      'batch_normalization_37[0][0]
#                                                                     ']
#
#  re_lu_32 (ReLU)             (None, 14, 14, 1024)         0         ['add_7[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 256)          262144    ['re_lu_32[0][0]']
#
#  batch_normalization_41 (Ba  (None, 14, 14, 256)          1024      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 256)          589824    ['re_lu_33[0][0]']
#
#  batch_normalization_42 (Ba  (None, 14, 14, 256)          1024      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 1024)         262144    ['re_lu_34[0][0]']
#
#  batch_normalization_43 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['batch_normalization_43[0][0]
#  0 (GlobalAveragePooling2D)                                         ']
#
#  reshape_10 (Reshape)        (None, 1, 1, 1024)           0         ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  dense_19 (Dense)            (None, 1, 1, 64)             65536     ['reshape_10[0][0]']
#
#  dense_20 (Dense)            (None, 1, 1, 1024)           65536     ['dense_19[0][0]']
#
#  multiply_8 (Multiply)       (None, 14, 14, 1024)         0         ['batch_normalization_43[0][0]
#                                                                     ',
#                                                                      'dense_20[0][0]']
#
#  add_8 (Add)                 (None, 14, 14, 1024)         0         ['re_lu_32[0][0]',
#                                                                      'multiply_8[0][0]']
#
#  re_lu_35 (ReLU)             (None, 14, 14, 1024)         0         ['add_8[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 14, 14, 256)          262144    ['re_lu_35[0][0]']
#
#  batch_normalization_44 (Ba  (None, 14, 14, 256)          1024      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  re_lu_36 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 14, 14, 256)          589824    ['re_lu_36[0][0]']
#
#  batch_normalization_45 (Ba  (None, 14, 14, 256)          1024      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 14, 14, 1024)         262144    ['re_lu_37[0][0]']
#
#  batch_normalization_46 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['batch_normalization_46[0][0]
#  1 (GlobalAveragePooling2D)                                         ']
#
#  reshape_11 (Reshape)        (None, 1, 1, 1024)           0         ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  dense_21 (Dense)            (None, 1, 1, 64)             65536     ['reshape_11[0][0]']
#
#  dense_22 (Dense)            (None, 1, 1, 1024)           65536     ['dense_21[0][0]']
#
#  multiply_9 (Multiply)       (None, 14, 14, 1024)         0         ['batch_normalization_46[0][0]
#                                                                     ',
#                                                                      'dense_22[0][0]']
#
#  add_9 (Add)                 (None, 14, 14, 1024)         0         ['re_lu_35[0][0]',
#                                                                      'multiply_9[0][0]']
#
#  re_lu_38 (ReLU)             (None, 14, 14, 1024)         0         ['add_9[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 14, 14, 256)          262144    ['re_lu_38[0][0]']
#
#  batch_normalization_47 (Ba  (None, 14, 14, 256)          1024      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  re_lu_39 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 14, 14, 256)          589824    ['re_lu_39[0][0]']
#
#  batch_normalization_48 (Ba  (None, 14, 14, 256)          1024      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 14, 14, 1024)         262144    ['re_lu_40[0][0]']
#
#  batch_normalization_49 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_49[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['batch_normalization_49[0][0]
#  2 (GlobalAveragePooling2D)                                         ']
#
#  reshape_12 (Reshape)        (None, 1, 1, 1024)           0         ['global_average_pooling2d_12[
#                                                                     0][0]']
#
#  dense_23 (Dense)            (None, 1, 1, 64)             65536     ['reshape_12[0][0]']
#
#  dense_24 (Dense)            (None, 1, 1, 1024)           65536     ['dense_23[0][0]']
#
#  multiply_10 (Multiply)      (None, 14, 14, 1024)         0         ['batch_normalization_49[0][0]
#                                                                     ',
#                                                                      'dense_24[0][0]']
#
#  add_10 (Add)                (None, 14, 14, 1024)         0         ['re_lu_38[0][0]',
#                                                                      'multiply_10[0][0]']
#
#  re_lu_41 (ReLU)             (None, 14, 14, 1024)         0         ['add_10[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 14, 14, 256)          262144    ['re_lu_41[0][0]']
#
#  batch_normalization_50 (Ba  (None, 14, 14, 256)          1024      ['conv2d_50[0][0]']
#  tchNormalization)
# ...
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 14, 14, 1024)         262144    ['re_lu_46[0][0]']
#
#  batch_normalization_55 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_55[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['batch_normalization_55[0][0]
#  4 (GlobalAveragePooling2D)                                         ']
#
#  reshape_14 (Reshape)        (None, 1, 1, 1024)           0         ['global_average_pooling2d_14[
#                                                                     0][0]']
#
#  dense_27 (Dense)            (None, 1, 1, 64)             65536     ['reshape_14[0][0]']
#
#  dense_28 (Dense)            (None, 1, 1, 1024)           65536     ['dense_27[0][0]']
#
#  multiply_12 (Multiply)      (None, 14, 14, 1024)         0         ['batch_normalization_55[0][0]
#                                                                     ',
#                                                                      'dense_28[0][0]']
#
#  add_12 (Add)                (None, 14, 14, 1024)         0         ['re_lu_44[0][0]',
#                                                                      'multiply_12[0][0]']
#
#  re_lu_47 (ReLU)             (None, 14, 14, 1024)         0         ['add_12[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 7, 7, 512)            524288    ['re_lu_47[0][0]']
#
#  batch_normalization_57 (Ba  (None, 7, 7, 512)            2048      ['conv2d_57[0][0]']
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 7, 7, 512)            2359296   ['re_lu_48[0][0]']
#
#  batch_normalization_58 (Ba  (None, 7, 7, 512)            2048      ['conv2d_58[0][0]']
#  tchNormalization)
#
#  re_lu_49 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_59 (Conv2D)          (None, 7, 7, 2048)           1048576   ['re_lu_49[0][0]']
#
#  batch_normalization_59 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_59[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['batch_normalization_59[0][0]
#  5 (GlobalAveragePooling2D)                                         ']
#
#  reshape_15 (Reshape)        (None, 1, 1, 2048)           0         ['global_average_pooling2d_15[
#                                                                     0][0]']
#
#  dense_29 (Dense)            (None, 1, 1, 128)            262144    ['reshape_15[0][0]']
#
#  dense_30 (Dense)            (None, 1, 1, 2048)           262144    ['dense_29[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 7, 7, 2048)           2097152   ['re_lu_47[0][0]']
#
#  multiply_13 (Multiply)      (None, 7, 7, 2048)           0         ['batch_normalization_59[0][0]
#                                                                     ',
#                                                                      'dense_30[0][0]']
#
#  batch_normalization_56 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_56[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 7, 7, 2048)           0         ['multiply_13[0][0]',
#                                                                      'batch_normalization_56[0][0]
#                                                                     ']
#
#  re_lu_50 (ReLU)             (None, 7, 7, 2048)           0         ['add_13[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 7, 7, 512)            1048576   ['re_lu_50[0][0]']
#
#  batch_normalization_60 (Ba  (None, 7, 7, 512)            2048      ['conv2d_60[0][0]']
#  tchNormalization)
#
#  re_lu_51 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_61 (Conv2D)          (None, 7, 7, 512)            2359296   ['re_lu_51[0][0]']
#
#  batch_normalization_61 (Ba  (None, 7, 7, 512)            2048      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  re_lu_52 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_62 (Conv2D)          (None, 7, 7, 2048)           1048576   ['re_lu_52[0][0]']
#
#  batch_normalization_62 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_62[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['batch_normalization_62[0][0]
#  6 (GlobalAveragePooling2D)                                         ']
#
#  reshape_16 (Reshape)        (None, 1, 1, 2048)           0         ['global_average_pooling2d_16[
#                                                                     0][0]']
#
#  dense_31 (Dense)            (None, 1, 1, 128)            262144    ['reshape_16[0][0]']
#
#  dense_32 (Dense)            (None, 1, 1, 2048)           262144    ['dense_31[0][0]']
#
#  multiply_14 (Multiply)      (None, 7, 7, 2048)           0         ['batch_normalization_62[0][0]
#                                                                     ',
#                                                                      'dense_32[0][0]']
#
#  add_14 (Add)                (None, 7, 7, 2048)           0         ['re_lu_50[0][0]',
#                                                                      'multiply_14[0][0]']
#
#  re_lu_53 (ReLU)             (None, 7, 7, 2048)           0         ['add_14[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 7, 7, 512)            1048576   ['re_lu_53[0][0]']
#
#  batch_normalization_63 (Ba  (None, 7, 7, 512)            2048      ['conv2d_63[0][0]']
#  tchNormalization)
#
#  re_lu_54 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 7, 7, 512)            2359296   ['re_lu_54[0][0]']
#
#  batch_normalization_64 (Ba  (None, 7, 7, 512)            2048      ['conv2d_64[0][0]']
#  tchNormalization)
#
#  re_lu_55 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 7, 7, 2048)           1048576   ['re_lu_55[0][0]']
#
#  batch_normalization_65 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_65[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['batch_normalization_65[0][0]
#  7 (GlobalAveragePooling2D)                                         ']
#
#  reshape_17 (Reshape)        (None, 1, 1, 2048)           0         ['global_average_pooling2d_17[
#                                                                     0][0]']
#
#  dense_33 (Dense)            (None, 1, 1, 128)            262144    ['reshape_17[0][0]']
#
#  dense_34 (Dense)            (None, 1, 1, 2048)           262144    ['dense_33[0][0]']
#
#  multiply_15 (Multiply)      (None, 7, 7, 2048)           0         ['batch_normalization_65[0][0]
#                                                                     ',
#                                                                      'dense_34[0][0]']
#
#  add_15 (Add)                (None, 7, 7, 2048)           0         ['re_lu_53[0][0]',
#                                                                      'multiply_15[0][0]']
#
#  re_lu_56 (ReLU)             (None, 7, 7, 2048)           0         ['add_15[0][0]']
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['re_lu_56[0][0]']
#  8 (GlobalAveragePooling2D)
#
#  dense_35 (Dense)            (None, 1000)                 2049000   ['global_average_pooling2d_18[
#                                                                     0][0]']
#
# ==================================================================================================
# Total params: 28125096 (107.29 MB)
# Trainable params: 28071976 (107.09 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________
