# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Deep%20Reinforcement%20Learning%20(TF)/Value%20Based/DDQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import tensorflow as tf
import numpy as np
import gym
import time
from itertools import count

# %% [markdown]
# # Q Network

# %% [markdown]
# In this section, we create a fully connected neural network which will approximate the Q function. Given a batch of states as input, it outputs a batch of Q-values. Each Q-value represents the return we can expect when we take a particular action in the given state.

# %%
class QNetwork(tf.keras.Model):

  def __init__(self, input_dim, output_dim):
    super().__init__()
    self.input_dim = input_dim
    self.output_dim = output_dim
    self.model = self.get_model()

  def get_model(self):
    inputs = tf.keras.Input(shape=(None, self.input_dim))
    x = tf.keras.layers.Dense(units=128, activation="relu")(inputs)
    x = tf.keras.layers.Dense(units=512, activation="relu")(x)
    outputs = tf.keras.layers.Dense(units=self.output_dim)(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

  def _format(self, state):
    x = state
    if not isinstance(x, tf.Tensor):
      x = tf.convert_to_tensor(x)
    if tf.rank(x) == 1:
      x = tf.expand_dims(x, 0)

    return x

  def call(self, state):
    x = self._format(state)
    output = self.model(x)

    return output

  def load(self, experiences):
    states, actions, rewards, new_states, is_terminals = experiences
    states = tf.convert_to_tensor(states, dtype="float32")
    actions = tf.convert_to_tensor(actions, dtype="int64")
    new_states = tf.convert_to_tensor(new_states, dtype="float32")
    rewards = tf.convert_to_tensor(rewards, dtype="float32")
    is_terminals = tf.convert_to_tensor(is_terminals, dtype="float32")
    return states, actions, rewards, new_states, is_terminals
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Replay Buffer

# %% [markdown]
# The replay buffer is a data structure that allows us to implement a technique called **experience replay**. It holds experience samples for several timesteps so that we can sample mini-batches of experiences.
#
# The main benefit of using a replay buffer: the samples (experiences) we pass to the network appear independent and identically distributed which in turn stabilize the optimization process.
#
# The idea behind experience replay is very straightforward:
# During training, we collect experiences and store them into the replay buffer. After enough experiences are collected, we then sample a mini-batch of a certain size from the buffer and pass it to the network.

# %%
class ReplayBuffer():
  # our replay buffer has a default max size of 10000 and uses a batch size of 64
  def __init__(self, max_size=50000,batch_size=64):

    # initialize five empty NumPy arrays that will hold states, actions, rewards, next_states and done flags
    self.ss_mem = np.empty(shape=(max_size), dtype=np.ndarray)
    self.as_mem = np.empty(shape=(max_size), dtype=np.ndarray)
    self.rs_mem = np.empty(shape=(max_size), dtype=np.ndarray)
    self.ps_mem = np.empty(shape=(max_size), dtype=np.ndarray)
    self.ds_mem = np.empty(shape=(max_size), dtype=np.ndarray)

    self.max_size = max_size
    self.batch_size = batch_size
    self._idx = 0
    self.size = 0

  def store(self, experience):
    '''
    Store the components of the experience into the corresponding NumPy array.
    '''
    # unwrap the experience which is just a tuple
    s, a, r, p, d = experience

    # store each component to its corresponding NumPy array
    self.ss_mem[self._idx] = s
    self.as_mem[self._idx] = a
    self.rs_mem[self._idx] = r
    self.ps_mem[self._idx] = p
    self.ds_mem[self._idx] = d

    # adjust the index
    self._idx += 1

    # if the replay buffer is full, we wrap around and overwrite older experiences with new ones
    self._idx = self._idx % self.max_size

    # adjust the size
    self.size += 1
    # determine the size
    self.size = min(self.size, self.max_size)

  def sample(self, batch_size=None):
    '''
    Sample a mini-batch of experiences from the replay buffer.
    '''
    if batch_size == None:
      batch_size = self.batch_size

    # Generate a uniform random sample from np.arange(self.size) of size 'batch_size' without replacement:
    idxs = np.random.choice(self.size, batch_size, replace=False)

    # create the mini-batch of experiences
    mini_batch_experiences = np.vstack(self.ss_mem[idxs]), \
                             np.vstack(self.as_mem[idxs]), \
                             np.vstack(self.rs_mem[idxs]), \
                             np.vstack(self.ps_mem[idxs]), \
                             np.vstack(self.ds_mem[idxs])

    return mini_batch_experiences

  def __len__(self):
    return self.size

# %% [markdown]
# # Exploration Strategies

# %% [markdown]
# In DDQN, we use exploration strategies based on Q-values. We get the values of actions in a given state using the learned Q-function and explore based on those values.

# %% [markdown]
# The GreedyStrategy will always select the maximum Q-value.

# %%
class GreedyStrategy():
  def select_action(self, model, state):
    # get the q-value of each action given the state
    q_values = model(state, training = False).numpy().squeeze()
    # return the index of the action with the highest estimate
    return np.argmax(q_values)

# %% [markdown]
# The exponential ϵ -greedy strategy a decaying epsilon value so that the probability of exploration is higher at the beginning and the probability of exploitation is higher at the end of the training phase.

# %%
class EGreedyExpStrategy():
  def __init__(self, init_epsilon=1.0, min_epsilon=0.1, decay_steps=20000):
    self.epsilon = init_epsilon
    self.init_epsilon = init_epsilon
    self.decay_steps = decay_steps
    self.min_epsilon = min_epsilon
    self.epsilons = 0.01 / np.logspace(-2, 0, decay_steps, endpoint=False) - 0.01
    self.epsilons = self.epsilons * (init_epsilon - min_epsilon) + min_epsilon
    self.t = 0

  def _epsilon_update(self):
    self.epsilon = self.min_epsilon if self.t >= self.decay_steps else self.epsilons[self.t]
    self.t += 1

    return self.epsilon

  def select_action(self, model, state):
    q_values = model(state, training=False).numpy().squeeze()
    if np.random.rand() > self.epsilon:
      action = np.argmax(q_values)
    else:
      action = np.random.randint(len(q_values))

    self._epsilon_update()
    return action

# %% [markdown]
# # DDQN

# %% [markdown]
# DDQN stands for "double deep Q-network" and it is an improvement to the DQN algorithm since it mitigates the overestimation of action-value functions.
#
# Recall that the DQN algorithm uses the off-policy TD target with the max operator. The problem is: it takes the max of estimated values. But estimated values can be off-center (meaning that they can be higher/lower than the true values).
#
# The solution DDQN offers to this problem is very simple: we will use the online network to find out the index of the highest-valued action & then ask the target network to tell us the action-value of that action. Basically, the online network is used for action selection and the target network is used for action evaluation. By using the target network for value estimates, we make sure the target values are frozen as needed for stability (like we did in DQN).
#
# All in all, the steps we used in DQN such as interaction step, update step etc. remain the same.
# We only need to change the optimization step as you can see below.

# %% [markdown]
# At the optimization step, we optimize the model using the following formula:
#
# $\nabla_{\theta_{i}} L_{i} (\theta_{i}) = \mathbb{E}_{\underbrace{(s,a,r,s') \sim U(D)}_\text{sampling of experiences}}[\underbrace{(r+\gamma Q(s', argmax_{a'} Q(s', a'; \theta_{i}); \theta^-}_\text{Target}) - \underbrace{Q(s,a; \theta_{i})}_\text{Prediction}) \nabla_{\theta_{i}} Q(s, a; \theta_{i})]$

# %% [markdown]
# An in-depth explanation of the formula:
#
# *   $\mathbb{E}_{(s,a,r,s') \sim U(D)}$
#
#     we use the expectations of the experience tuples; we obtain the experiences we use for training by sampling uniformly at random the replay buffer D
#
# *   $r$
#
#     the experienced reward we get when we take a particular action $a$ in state $s$
#
# *   $\gamma Q(s', argmax_{a'} Q(s', a'; \theta_{i}); \theta^-))$
#
#     This part is different from the DQN formula.
#     Here, we first ask the online network to tell us the index of the highest-valued action in the next state.
#     Then, we use that index to obtain the corresponding Q-value from the target network.
#     So, the index is coming from the online network but the Q-value is coming from the target network.
#     As usual, we discount that Q-value with gamma.
#     Together with $r$, this part forms the target.
#
# *   $Q(s,a; \theta_{i})$
#
#     The current Q-value estimates are our predictions
#     (just like in DQN)

# %%
class DDQN():
  def __init__(self,
               env,
               seed,
               online_model,
               target_model,
               replay_buffer,
               optimizer,
               training_strategy,
               evaluation_strategy,
               loss_function,
               max_gradient_norm,
               gamma=1.0,
               update_steps=10,
               max_episodes=10000,
               goal = 475,
               warmup_batches=5):

    # set the attributes
    self.env = env
    self.seed = seed
    self.online_model = online_model
    self.target_model = target_model
    self.replay_buffer = replay_buffer
    self.optimizer = optimizer
    self.training_strategy = training_strategy
    self.evaluation_strategy = evaluation_strategy
    self.loss_function = loss_function
    self.max_gradient_norm = max_gradient_norm
    self.gamma = gamma
    self.update_steps = update_steps
    self.max_episodes = max_episodes
    self.goal = goal
    self.warmup_batches = warmup_batches
    self.evaluation_scores = []
    self.mean_eval_scores = []

  def __update_target_model(self):
    # update the weights of the target model
    self.target_model.set_weights(self.online_model.get_weights())

  def __interact(self, state):
    # select an action according to the exponentially decaying epsilon-greedy exploration strategy
    action = self.training_strategy.select_action(self.online_model, state)
    # perform the selected action in the environment
    next_state, reward, is_terminal, info = self.env.step(action)
    # determine if CartPole's built-in TimeLimit is reached
    is_truncated = 'TimeLimit.truncated' in info and info['TimeLimit.truncated']
    # calculate the is_failure flag indicating a terminal state
    is_failure = is_terminal and not is_truncated
    # create the experience
    experience = (state, action, reward, next_state, float(is_failure))

    return experience, next_state, is_terminal

  def __optimize(self, experiences):
    # extract the experiences
    states, actions, rewards, next_states, is_terminals = experiences

    with tf.GradientTape() as tape:
      # query the online network to get the index of the highest-valued
      # action of the next state
      online_next_q_values = self.online_model(next_states)
      index_of_highest_valued_q_values = tf.argmax(online_next_q_values, axis=1)
      # query the q values of the next state according to target network
      # Setting training=False when calling self.target_model(next_states) ensures that
      # TensorFlow does not compute gradients for the target network, as it operates in inference mode.
      q_values_of_target_network = self.target_model(next_states, training=False)

      # index the Q values given by the target network
      # with the action indices given be the online network
      masks_1 = tf.one_hot(index_of_highest_valued_q_values, self.env.action_space.n).numpy()
      highest_valued_q_values = tf.reduce_sum(tf.multiply(q_values_of_target_network, masks_1), axis=1)
      highest_valued_q_values = tf.expand_dims(highest_valued_q_values, axis=1)

      # create the target values
      target_q_values = rewards + (self.gamma * highest_valued_q_values * (1-is_terminals))
      masks_2 = tf.one_hot(actions, self.env.action_space.n).numpy().squeeze(1)

      # query the online network to get the Q-value estimates of 'states'
      predicted_Q_values = self.online_model(states)
      # since we are only interested in the Q-values of those actions
      # that were actually taken, we use the mask tensor to extract them
      preds = tf.reduce_sum(tf.multiply(predicted_Q_values, masks_2), axis=1)
      preds = tf.expand_dims(preds, axis=1)
      # compute the value loss
      loss = loss_function(target_q_values, preds)

    # compute gradients
    grads = tape.gradient(loss, self.online_model.trainable_variables)
    # clip gradients by norm
    clipped_gradients, _ = tf.clip_by_global_norm(grads, self.max_gradient_norm)
    # apply gradients to update the weights of the online network
    self.optimizer.apply_gradients(zip(grads, self.online_model.trainable_variables))

  def __sample(self):
    # sample a mini-batch of experiences from the replay buffer
    experiences = self.replay_buffer.sample()
    experiences = self.online_model.load(experiences)
    return experiences

  def __evaluate(self, episodes=1):
    # keep a list of the rewards
    rewards = []
    # for each episode
    for _ in range(episodes):
      # get the initial state
      state = self.env.reset(seed=self.seed)
      # set 'is_terminal' flag to False
      is_terminal = False
      # initialize the rewards list
      rewards.append(0)
      # for each timestep in the current episode
      for _ in count():
        # get the action according to evaluation strategy from the online_model
        action = self.evaluation_strategy.select_action(self.online_model, state)
        # perform the action in the environment
        state, reward, is_terminal, _ = self.env.step(action)
        # save the experienced reward
        rewards[-1] += reward
        # break if we are in a terminal state
        if is_terminal:
          break

    # return the mean of the rewards
    return np.mean(rewards)


  def train(self):
    # make sure that online and target network have the same weights before training starts
    self.__update_target_model()

    # for each episode do the following
    for episode in range(self.max_episodes):
      # get the initial state
      state = self.env.reset(seed=self.seed)
      # flag indicating whether episode is finished or not
      is_terminal = False
      # initialize list to hold the number of timesteps
      episode_timestep = 0

      # for each timestep in the current episode do the following
      for timestep in count():
        # interact with the environment
        experience, new_state, is_terminal = self.__interact(state)
        # adjust the timestep so that we know when to update the target network
        episode_timestep += 1
        # store the experience into the replay buffer
        self.replay_buffer.store(experience)
        # update current state
        state = new_state

        # check if we have enough experiences in the replay buffer
        if len(self.replay_buffer) > self.replay_buffer.batch_size * self.warmup_batches:
          # get a minibatch of experiences from the replay buffer
          experiences = self.__sample()
          # optimize the model
          self.__optimize(experiences)

        # update the weights of the target network periodically
        if episode_timestep % self.update_steps == 0:
          # make sure that online and target network have the same weights
          self.__update_target_model()

        # break if current state was a terminal state
        if is_terminal:
          break

      # compute the evaluation score
      evaluation_score = self.__evaluate()
      # store the evaluation score
      self.evaluation_scores.append(evaluation_score)

      # compute the mean evaluation score
      mean_100_eval_score = np.mean(self.evaluation_scores[-100:])
      # append mean evaluation score (will be used later for visualization)
      self.mean_eval_scores.append(mean_100_eval_score)
      print(f"Episode {episode}: Mean evaluation score {mean_100_eval_score}") # printing for debugging purposes
      # flag indicating whether max episodes is reached
      reached_max_episodes = episode >= self.max_episodes
      # flag indicating whether mean goal reward is reached
      reached_goal_mean_reward = mean_100_eval_score >= self.goal

      # finish if one of the flags is true
      training_is_over = reached_max_episodes or reached_goal_mean_reward
      if training_is_over:
        if reached_max_episodes: print('Max episodes are reached')
        if reached_goal_mean_reward: print('Goal mean reward is reached')
        break

    # get the final evaluation score
    final_evaluation_score = self.__evaluate(episodes=100)
    print(f"Final_evaluation score: {final_evaluation_score}")

    self.env.close()
    del self.env

# %% [markdown]
# # Train

# %%
# set the discount factor
gamma = 1.0
# set the number of step to update the target network periodically
update_steps = 10
# define max episodes
max_episodes = 10000
# define goal reward value
goal = 475
warmup_batches = 5
# learning rate for the optimizer
lr = 0.0005
# define the loss function
loss_function = tf.keras.losses.MeanSquaredError()
# define the seed value
seed = 12
max_gradient_norm = float('inf')

# %%
# create the CartPole environment with a unique seed
env = gym.make("CartPole-v1")
 # create the replay buffer
replay_buffer = ReplayBuffer()
# set the training strategy
training_strategy = EGreedyExpStrategy(init_epsilon=1.0, min_epsilon=0.3, decay_steps=20000)
# set the evaluation strategy
evaluation_strategy = GreedyStrategy()
# define the state space
state_space = env.observation_space.shape[0]
# define the action space
action_space = env.action_space.n
# create the online model
online_model = QNetwork(state_space, action_space)
# create the target model
target_model = QNetwork(state_space, action_space)
# create the optimizer
optimizer = tf.keras.optimizers.RMSprop(learning_rate=lr)

# create the DDQN agent
ddqn_agent = DDQN(env,
                  seed,
                  online_model,
                  target_model,
                  replay_buffer,
                  optimizer,
                  training_strategy,
                  evaluation_strategy,
                  loss_function,
                  max_gradient_norm,
                  gamma,
                  update_steps,
                  max_episodes,
                  goal,
                  warmup_batches)

# let the agent train
ddqn_agent.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# Episode 0: Mean evaluation score 9.0
# Episode 1: Mean evaluation score 9.0
# Episode 2: Mean evaluation score 9.0
# Episode 3: Mean evaluation score 9.0
# Episode 4: Mean evaluation score 9.0
# Episode 5: Mean evaluation score 9.0
# Episode 6: Mean evaluation score 9.0
# Episode 7: Mean evaluation score 9.0
# Episode 8: Mean evaluation score 9.0
# Episode 9: Mean evaluation score 9.0
# Episode 10: Mean evaluation score 9.0
# Episode 11: Mean evaluation score 9.0
# Episode 12: Mean evaluation score 9.0
# Episode 13: Mean evaluation score 9.0
# Episode 14: Mean evaluation score 9.066666666666666
# Episode 15: Mean evaluation score 9.125
# Episode 16: Mean evaluation score 9.117647058823529
# Episode 17: Mean evaluation score 9.11111111111111
# Episode 18: Mean evaluation score 9.157894736842104
# Episode 19: Mean evaluation score 9.2
# Episode 20: Mean evaluation score 9.238095238095237
# Episode 21: Mean evaluation score 9.272727272727273
# Episode 22: Mean evaluation score 9.304347826086957
# Episode 23: Mean evaluation score 9.333333333333334
# Episode 24: Mean evaluation score 9.36
# Episode 25: Mean evaluation score 9.384615384615385
# Episode 26: Mean evaluation score 9.407407407407407
# Episode 27: Mean evaluation score 9.428571428571429
# Episode 28: Mean evaluation score 9.448275862068966
# Episode 29: Mean evaluation score 9.466666666666667
# Episode 30: Mean evaluation score 9.483870967741936
# Episode 31: Mean evaluation score 9.5
# Episode 32: Mean evaluation score 9.515151515151516
# Episode 33: Mean evaluation score 9.529411764705882
# Episode 34: Mean evaluation score 9.542857142857143
# Episode 35: Mean evaluation score 9.555555555555555
# Episode 36: Mean evaluation score 9.567567567567568
# Episode 37: Mean evaluation score 9.578947368421053
# Episode 38: Mean evaluation score 9.58974358974359
# Episode 39: Mean evaluation score 9.6
# Episode 40: Mean evaluation score 9.609756097560975
# Episode 41: Mean evaluation score 9.619047619047619
# Episode 42: Mean evaluation score 9.627906976744185
# Episode 43: Mean evaluation score 9.636363636363637
# Episode 44: Mean evaluation score 9.644444444444444
# Episode 45: Mean evaluation score 9.652173913043478
# Episode 46: Mean evaluation score 9.659574468085106
# Episode 47: Mean evaluation score 9.666666666666666
# Episode 48: Mean evaluation score 9.673469387755102
# Episode 49: Mean evaluation score 9.68
# Episode 50: Mean evaluation score 9.686274509803921
# Episode 584: Mean evaluation score 189.35
# Episode 585: Mean evaluation score 184.44
# Episode 586: Mean evaluation score 182.45
# Episode 587: Mean evaluation score 178.72
# Episode 588: Mean evaluation score 178.54
# Episode 589: Mean evaluation score 178.48
# Episode 590: Mean evaluation score 178.39
# Episode 591: Mean evaluation score 178.35
# Episode 592: Mean evaluation score 178.3
# Episode 593: Mean evaluation score 178.18
# Episode 594: Mean evaluation score 178.11
# Episode 595: Mean evaluation score 178.07
# Episode 596: Mean evaluation score 178.0
# Episode 597: Mean evaluation score 177.97
# Episode 598: Mean evaluation score 177.95
# Episode 599: Mean evaluation score 177.88
# Episode 600: Mean evaluation score 177.74
# Episode 601: Mean evaluation score 177.33
# Episode 602: Mean evaluation score 172.42
# Episode 603: Mean evaluation score 167.66
# Episode 604: Mean evaluation score 162.75
# Episode 605: Mean evaluation score 157.84
# Episode 606: Mean evaluation score 152.93
# Episode 607: Mean evaluation score 148.02
# Episode 608: Mean evaluation score 143.11
# Episode 609: Mean evaluation score 138.2
# Episode 610: Mean evaluation score 133.29
# Episode 611: Mean evaluation score 128.38
# Episode 612: Mean evaluation score 124.0
# Episode 613: Mean evaluation score 119.09
# Episode 614: Mean evaluation score 116.49
# Episode 615: Mean evaluation score 111.58
# Episode 616: Mean evaluation score 106.67
# Episode 617: Mean evaluation score 101.76
# Episode 618: Mean evaluation score 96.85
# Episode 619: Mean evaluation score 92.5
# Episode 620: Mean evaluation score 87.59
# Episode 621: Mean evaluation score 82.68
# Episode 622: Mean evaluation score 77.77
# Episode 623: Mean evaluation score 72.86
# Episode 624: Mean evaluation score 67.95
# Episode 625: Mean evaluation score 63.04
# Episode 626: Mean evaluation score 58.13
# Episode 627: Mean evaluation score 53.22
# Episode 628: Mean evaluation score 48.31
# Episode 629: Mean evaluation score 43.4
# Episode 630: Mean evaluation score 38.49
# Episode 631: Mean evaluation score 33.58
# Episode 632: Mean evaluation score 28.67
# Episode 633: Mean evaluation score 23.76
# Episode 634: Mean evaluation score 18.85
# Episode 635: Mean evaluation score 13.94
# Episode 636: Mean evaluation score 9.03
# Episode 637: Mean evaluation score 9.0
# Episode 638: Mean evaluation score 9.0
# Episode 639: Mean evaluation score 9.0
# Episode 640: Mean evaluation score 9.0
# Episode 641: Mean evaluation score 9.0
# Episode 642: Mean evaluation score 9.0
# Episode 643: Mean evaluation score 9.0
# Episode 644: Mean evaluation score 9.0
# Episode 645: Mean evaluation score 9.0
# Episode 646: Mean evaluation score 9.0
# Episode 647: Mean evaluation score 9.0
# Episode 648: Mean evaluation score 9.0
# Episode 649: Mean evaluation score 9.0
# Episode 650: Mean evaluation score 9.0
# Episode 651: Mean evaluation score 9.0
# Episode 652: Mean evaluation score 9.0
# Episode 653: Mean evaluation score 9.0
# Episode 654: Mean evaluation score 9.0
# Episode 655: Mean evaluation score 9.0
# Episode 656: Mean evaluation score 9.0
# Episode 657: Mean evaluation score 9.0
# Episode 658: Mean evaluation score 9.0
# Episode 659: Mean evaluation score 9.0
# Episode 660: Mean evaluation score 9.0
# Episode 661: Mean evaluation score 9.0
# Episode 972: Mean evaluation score 20.18
# Episode 973: Mean evaluation score 20.19
# Episode 974: Mean evaluation score 20.2
# Episode 975: Mean evaluation score 20.21
# Episode 976: Mean evaluation score 20.22
# Episode 977: Mean evaluation score 20.23
# Episode 978: Mean evaluation score 20.24
# Episode 979: Mean evaluation score 20.25
# Episode 980: Mean evaluation score 20.26
# Episode 981: Mean evaluation score 20.27
# Episode 982: Mean evaluation score 20.28
# Episode 983: Mean evaluation score 20.29
# Episode 984: Mean evaluation score 20.3
# Episode 985: Mean evaluation score 20.31
# Episode 986: Mean evaluation score 20.32
# Episode 987: Mean evaluation score 20.33
# Episode 988: Mean evaluation score 20.34
# Episode 989: Mean evaluation score 20.35
# Episode 990: Mean evaluation score 20.36
# Episode 991: Mean evaluation score 20.37
# Episode 992: Mean evaluation score 20.38
# Episode 993: Mean evaluation score 20.39
# Episode 994: Mean evaluation score 20.4
# Episode 995: Mean evaluation score 20.41
# Episode 996: Mean evaluation score 20.42
# Episode 997: Mean evaluation score 20.43
# Episode 998: Mean evaluation score 20.43
# Episode 999: Mean evaluation score 20.43
# Episode 1000: Mean evaluation score 20.43
# Episode 1001: Mean evaluation score 20.43
# Episode 1002: Mean evaluation score 20.43
# Episode 1003: Mean evaluation score 20.42
# Episode 1004: Mean evaluation score 20.41
# Episode 1005: Mean evaluation score 20.4
# Episode 1006: Mean evaluation score 20.39
# Episode 1007: Mean evaluation score 20.37
# Episode 1008: Mean evaluation score 20.35
# Episode 1009: Mean evaluation score 20.33
# Episode 1010: Mean evaluation score 20.31
# Episode 1011: Mean evaluation score 20.29
# Episode 1012: Mean evaluation score 20.27
# Episode 1013: Mean evaluation score 20.23
# Episode 1014: Mean evaluation score 20.19
# Episode 1015: Mean evaluation score 15.29
# Episode 1016: Mean evaluation score 10.39
# Episode 1017: Mean evaluation score 10.16
# Episode 1018: Mean evaluation score 10.0
# Episode 1019: Mean evaluation score 10.0
# Episode 1020: Mean evaluation score 10.0
# Episode 1021: Mean evaluation score 10.0
# Episode 1022: Mean evaluation score 10.0
# Episode 1023: Mean evaluation score 10.0
# Episode 1024: Mean evaluation score 10.0
# Episode 1025: Mean evaluation score 10.0
# Episode 1026: Mean evaluation score 10.0
# Episode 1027: Mean evaluation score 10.0
# Episode 1028: Mean evaluation score 10.0
# Episode 1029: Mean evaluation score 10.0
# Episode 1030: Mean evaluation score 10.0
# Episode 1031: Mean evaluation score 10.0
# Episode 1032: Mean evaluation score 10.0
# Episode 1033: Mean evaluation score 10.0
# Episode 1034: Mean evaluation score 10.0
# Episode 1035: Mean evaluation score 10.0
# Episode 1036: Mean evaluation score 10.0
# Episode 1037: Mean evaluation score 10.0
# Episode 1038: Mean evaluation score 10.0
# Episode 1039: Mean evaluation score 10.0
# Episode 1040: Mean evaluation score 10.0
# Episode 1041: Mean evaluation score 10.0
# Episode 1042: Mean evaluation score 10.0
# Episode 1043: Mean evaluation score 10.0
# Episode 1044: Mean evaluation score 10.0
# Episode 1045: Mean evaluation score 10.0
# Episode 1046: Mean evaluation score 10.0
# Episode 1047: Mean evaluation score 10.0
# Episode 1048: Mean evaluation score 10.0
# Episode 1049: Mean evaluation score 10.0
# Episode 1050: Mean evaluation score 10.0
# Episode 1051: Mean evaluation score 10.0
# Episode 1052: Mean evaluation score 10.0
# Episode 1053: Mean evaluation score 10.0
# Episode 1054: Mean evaluation score 10.0
# Episode 1055: Mean evaluation score 10.0
# Episode 1056: Mean evaluation score 10.0
# Episode 1057: Mean evaluation score 10.0
# Episode 1058: Mean evaluation score 10.0
# Episode 1059: Mean evaluation score 10.0
# Episode 1060: Mean evaluation score 10.0
# Episode 1061: Mean evaluation score 10.0
# Episode 1062: Mean evaluation score 10.0
# Episode 1063: Mean evaluation score 10.0
# Episode 1064: Mean evaluation score 10.0
# Episode 1065: Mean evaluation score 10.0
# Episode 1066: Mean evaluation score 10.0
# Episode 1067: Mean evaluation score 10.0
# Episode 1068: Mean evaluation score 10.0
# Episode 1069: Mean evaluation score 10.0
# Episode 1070: Mean evaluation score 10.0
# Episode 1071: Mean evaluation score 10.0
# Episode 1072: Mean evaluation score 10.0
# Episode 1073: Mean evaluation score 10.0
# Episode 1074: Mean evaluation score 10.0
# Episode 1075: Mean evaluation score 10.0
# Episode 1076: Mean evaluation score 10.0
# Episode 1077: Mean evaluation score 10.0
# Episode 1078: Mean evaluation score 10.0
# Episode 1079: Mean evaluation score 10.0
# Episode 1080: Mean evaluation score 10.0
# Episode 1081: Mean evaluation score 10.0
# Episode 1082: Mean evaluation score 10.0
# Episode 1083: Mean evaluation score 10.0
# Episode 1084: Mean evaluation score 10.0
# Episode 1085: Mean evaluation score 10.0
# Episode 1086: Mean evaluation score 10.0
# Episode 1087: Mean evaluation score 10.0
# Episode 1088: Mean evaluation score 10.0
# Episode 1089: Mean evaluation score 10.0
# Episode 1090: Mean evaluation score 10.0
# Episode 1091: Mean evaluation score 10.0
# Episode 1092: Mean evaluation score 10.0
# Episode 1093: Mean evaluation score 10.0
# Episode 1094: Mean evaluation score 10.0
# Episode 1095: Mean evaluation score 10.0
# Episode 1096: Mean evaluation score 10.0
# Episode 1097: Mean evaluation score 10.0
# Episode 1098: Mean evaluation score 10.0
# Episode 1099: Mean evaluation score 10.0
# Episode 1100: Mean evaluation score 10.0
# Episode 1101: Mean evaluation score 10.0
# Episode 1102: Mean evaluation score 10.0
# Episode 1103: Mean evaluation score 10.0
# Episode 1104: Mean evaluation score 10.0
# Episode 1105: Mean evaluation score 10.0
# Episode 1106: Mean evaluation score 10.0
# Episode 1107: Mean evaluation score 10.0
# Episode 1108: Mean evaluation score 10.0
# Episode 1109: Mean evaluation score 10.0
# Episode 1110: Mean evaluation score 10.0
# Episode 1111: Mean evaluation score 10.0
# Episode 1112: Mean evaluation score 10.0
# Episode 1113: Mean evaluation score 10.0
# Episode 1114: Mean evaluation score 10.0
# Episode 1115: Mean evaluation score 10.0
# Episode 1116: Mean evaluation score 10.0
# Episode 1117: Mean evaluation score 10.0
# Episode 1118: Mean evaluation score 10.0
# Episode 1119: Mean evaluation score 10.0
# Episode 1120: Mean evaluation score 10.0
# Episode 1467: Mean evaluation score 9.49
# Episode 1468: Mean evaluation score 9.5
# Episode 1469: Mean evaluation score 9.51
# Episode 1470: Mean evaluation score 9.52
# Episode 1471: Mean evaluation score 9.54
# Episode 1472: Mean evaluation score 9.56
# Episode 1473: Mean evaluation score 9.58
# Episode 1474: Mean evaluation score 9.6
# Episode 1475: Mean evaluation score 9.62
# Episode 1476: Mean evaluation score 9.64
# Episode 1477: Mean evaluation score 9.66
# Episode 1478: Mean evaluation score 9.68
# Episode 1479: Mean evaluation score 9.7
# Episode 1480: Mean evaluation score 9.72
# Episode 1481: Mean evaluation score 9.74
# Episode 1482: Mean evaluation score 9.76
# Episode 1483: Mean evaluation score 9.78
# Episode 1484: Mean evaluation score 9.8
# Episode 1485: Mean evaluation score 9.82
# Episode 1486: Mean evaluation score 9.84
# Episode 1487: Mean evaluation score 9.86
# Episode 1488: Mean evaluation score 9.88
# Episode 1489: Mean evaluation score 9.9
# Episode 1490: Mean evaluation score 9.92
# Episode 1491: Mean evaluation score 9.94
# Episode 1492: Mean evaluation score 9.96
# Episode 1493: Mean evaluation score 9.98
# Episode 1494: Mean evaluation score 10.0
# Episode 1495: Mean evaluation score 10.02
# Episode 1496: Mean evaluation score 10.04
# Episode 1497: Mean evaluation score 10.06
# Episode 1498: Mean evaluation score 10.08
# Episode 1499: Mean evaluation score 10.1
# Episode 1500: Mean evaluation score 10.12
# Episode 1501: Mean evaluation score 10.14
# Episode 1502: Mean evaluation score 10.16
# Episode 1503: Mean evaluation score 10.18
# Episode 1504: Mean evaluation score 10.2
# Episode 1505: Mean evaluation score 10.23
# Episode 1506: Mean evaluation score 10.25
# Episode 1507: Mean evaluation score 10.28
# Episode 1508: Mean evaluation score 10.31
# Episode 1509: Mean evaluation score 10.34
# Episode 1510: Mean evaluation score 10.36
# Episode 1511: Mean evaluation score 10.38
# Episode 1512: Mean evaluation score 10.4
# Episode 1513: Mean evaluation score 10.42
# Episode 1514: Mean evaluation score 10.43
# Episode 1515: Mean evaluation score 10.44
# Episode 1516: Mean evaluation score 10.45
# Episode 1517: Mean evaluation score 10.46
# Episode 1518: Mean evaluation score 10.48
# Episode 1519: Mean evaluation score 10.5
# Episode 1520: Mean evaluation score 10.52
# Episode 1521: Mean evaluation score 10.54
# Episode 1522: Mean evaluation score 10.56
# Episode 1523: Mean evaluation score 10.58
# Episode 1524: Mean evaluation score 10.6
# Episode 1525: Mean evaluation score 10.62
# Episode 1526: Mean evaluation score 10.64
# Episode 1527: Mean evaluation score 10.66
# Episode 1528: Mean evaluation score 10.68
# Episode 1529: Mean evaluation score 10.7
# Episode 1530: Mean evaluation score 10.73
# Episode 1531: Mean evaluation score 10.75
# Episode 1532: Mean evaluation score 10.77
# Episode 1533: Mean evaluation score 10.79
# Episode 1534: Mean evaluation score 10.81
# Episode 1535: Mean evaluation score 10.84
# Episode 1536: Mean evaluation score 10.87
# Episode 1537: Mean evaluation score 10.9
# Episode 1538: Mean evaluation score 10.93
# Episode 1539: Mean evaluation score 10.96
# Episode 1540: Mean evaluation score 11.0
# Episode 1762: Mean evaluation score 380.31
# Episode 1763: Mean evaluation score 384.34
# Episode 1764: Mean evaluation score 388.37
# Episode 1765: Mean evaluation score 392.4
# Episode 1766: Mean evaluation score 396.45
# Episode 1767: Mean evaluation score 400.54
# Episode 1768: Mean evaluation score 404.67
# Episode 1769: Mean evaluation score 408.77
# Episode 1770: Mean evaluation score 412.87
# Episode 1771: Mean evaluation score 417.0
# Episode 1772: Mean evaluation score 421.13
# Episode 1773: Mean evaluation score 424.47
# Episode 1774: Mean evaluation score 426.95
# Episode 1775: Mean evaluation score 429.52
# Episode 1776: Mean evaluation score 432.86
# Episode 1777: Mean evaluation score 436.22
# Episode 1778: Mean evaluation score 438.85
# Episode 1779: Mean evaluation score 442.24
# Episode 1780: Mean evaluation score 445.62
# Episode 1781: Mean evaluation score 449.05
# Episode 1782: Mean evaluation score 452.48
# Episode 1783: Mean evaluation score 455.17
# Episode 1784: Mean evaluation score 457.85
# Episode 1785: Mean evaluation score 459.82
# Episode 1786: Mean evaluation score 462.5
# Episode 1787: Mean evaluation score 464.38
# Episode 1788: Mean evaluation score 467.1
# Episode 1789: Mean evaluation score 469.84
# Episode 1790: Mean evaluation score 472.59
# Episode 1791: Mean evaluation score 474.6
# Episode 1792: Mean evaluation score 476.63
# Goal mean reward is reached
# Final_evaluation score: 500.0

# %% [markdown]
# # Save the model

# %%
ddqn_agent.online_model.save_weights("/content/drive/MyDrive/Tensorflow/DDQN/DDQN.ckpt")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Visualize

# %% [markdown]
# Let's plot the mean rewards collected during training:

# %%
import matplotlib.pyplot as plt

plt.plot(ddqn_agent.mean_eval_scores)
plt.xlabel("Epochs")
plt.ylabel("Mean evaluation score")
plt.title("Training Process")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Let our DQN agent play CartPole

# %%
import os
import imageio
from PIL import Image as Im
import PIL.ImageDraw as ImageDraw
from IPython import display

# %%
def create_gif(env, episodes):
  # list to keep track of frames
  frames = []

  for episode in range(1, episodes + 1):
    # get the initial state
    state = env.reset()

    # for each timestep, do the following
    for t in range(500):
      # get the Q-value estimates
      q_values = ddqn_agent.online_model(state, training = False).numpy().squeeze()
      # select the action (greedily)
      action = np.argmax(q_values)

      # get the frame & store it
      frame = env.render(mode='rgb_array')

      # prepare the frame
      im = Im.fromarray(frame)
      drawer = ImageDraw.Draw(im)
      if np.mean(im) < 128:
        text_color = (255,255,255)
      else:
        text_color = (0,0,0)
        drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode+1}', fill=text_color)
        drawer.text((im.size[0]/20,im.size[1]/8), f'Timestep: {t+1}', fill=text_color)

      # store the frame
      frames.append(im)

      # take the action in the environment
      state, _, is_terminal, _ = env.step(action)

      # if we land at a terminal state, break
      if is_terminal:
        break

    # close the environment
    env.close()

    # create the gif
    imageio.mimwrite(os.path.join('/content/drive/MyDrive/Tensorflow/DDQN/Gif/', 'DDQN_agent.gif'), frames, duration=20)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
episodes = 5
env = gym.make('CartPole-v1')
create_gif(env, episodes)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(

# %%
from IPython import display
display.Image(open('/content/drive/MyDrive/Tensorflow/DDQN/Gif/DDQN_agent.gif','rb').read())
