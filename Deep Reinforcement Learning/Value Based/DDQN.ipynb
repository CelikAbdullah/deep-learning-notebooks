# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Deep%20Reinforcement%20Learning/Value%20Based/DDQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import gym
import time
import os
import imageio
import random
from matplotlib import pyplot as plt
from itertools import count
import PIL.ImageDraw as ImageDraw
from PIL import Image as Im
from IPython import display
import matplotlib.pyplot as plt

# %% [markdown]
# # Q Network

# %% [markdown]
# In this section, we create a fully connected neural network which will approximate the Q function. Given a batch of states as input, it outputs a batch of Q-values. Each Q-value represents the return we can expect when we take a particular action in the given state.

# %%
class QNetwork(nn.Module):
  def __init__(self,
               input_dim,
               output_dim,
               hidden_dims=(32,32),
               activation_fc=F.relu):

    super(QNetwork, self).__init__()
    self.activation_fc = activation_fc
    self.input_layer = nn.Linear(input_dim, hidden_dims[0])

    self.hidden_layers = nn.ModuleList()
    for i in range(len(hidden_dims)-1):
      hidden_layer = nn.Linear(hidden_dims[i], hidden_dims[i+1])
      self.hidden_layers.append(hidden_layer)

    self.output_layer = nn.Linear(hidden_dims[-1], output_dim)

    device = "cpu"
    if torch.cuda.is_available():
      device = "cuda:0"
    self.device = torch.device(device)
    self.to(self.device)

  def _format(self, state):
    x = state
    if not isinstance(x, torch.Tensor):
      x = torch.tensor(x, device=self.device, dtype=torch.float32)
      x = x.unsqueeze(0)

    return x

  def forward(self, state):
    x = self._format(state)
    x = self.activation_fc(self.input_layer(x))
    for hidden_layer in self.hidden_layers:
      x = self.activation_fc(hidden_layer(x))

    x = self.output_layer(x)
    return x

  def numpy_float_to_device(self, variable):
    variable = torch.from_numpy(variable).float().to(self.device)
    return variable

  def load(self, experiences):
    states, actions, rewards, new_states, is_terminals = experiences
    states = torch.from_numpy(states).float().to(self.device)
    actions = torch.from_numpy(actions).long().to(self.device)
    new_states = torch.from_numpy(new_states).float().to(self.device)
    rewards = torch.from_numpy(rewards).float().to(self.device)
    is_terminals = torch.from_numpy(is_terminals).float().to(self.device)
    return states, actions, rewards, new_states, is_terminals
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Replay Buffer

# %% [markdown]
# The replay buffer is a data structure that allows us to implement a technique called **experience replay**. It holds experience samples for several timesteps so that we can sample mini-batches of experiences.
#
# The main benefit of using a replay buffer: the samples (experiences) we pass to the network appear independent and identically distributed which in turn stabilize the optimization process.
#
# The idea behind experience replay is very straightforward:
# During training, we collect experiences and store them into the replay buffer. After enough experiences are collected, we then sample a mini-batch of a certain size from the buffer and pass it to the network.

# %%
class ReplayBuffer():

  # our replay buffer has a default max size of 50000 and uses a batch size of 64
  def __init__(self, max_size=10000,
               batch_size=64):

    # initialize five empty NumPy arrays that will hold states, actions, rewards, next_states and done flags
    self.ss_mem = np.empty(shape=(max_size), dtype=np.ndarray)
    self.as_mem = np.empty(shape=(max_size), dtype=np.ndarray)
    self.rs_mem = np.empty(shape=(max_size), dtype=np.ndarray)
    self.ps_mem = np.empty(shape=(max_size), dtype=np.ndarray)
    self.ds_mem = np.empty(shape=(max_size), dtype=np.ndarray)

    self.max_size = max_size
    self.batch_size = batch_size
    self._idx = 0
    self.size = 0

  def store(self, experience):
    '''
    Store the components of the experience into the corresponding NumPy array.
    '''
    # unwrap the experience which is just a tuple
    s, a, r, p, d = experience

    # store each component to its corresponding NumPy array
    self.ss_mem[self._idx] = s
    self.as_mem[self._idx] = a
    self.rs_mem[self._idx] = r
    self.ps_mem[self._idx] = p
    self.ds_mem[self._idx] = d

    # adjust the index
    self._idx += 1

    # if the replay buffer is full, we wrap around and overwrite older experiences with new ones
    self._idx = self._idx % self.max_size

    # adjust the size
    self.size += 1
    # determine the size
    self.size = min(self.size, self.max_size)

  def sample(self, batch_size=None):
    '''
    Sample a mini-batch of experiences from the replay buffer.
    '''
    if batch_size == None:
      batch_size = self.batch_size

    # Generate a uniform random sample from np.arange(self.size) of size 'batch_size' without replacement:
    idxs = np.random.choice(self.size, batch_size, replace=False)

    # create the mini-batch of experiences
    mini_batch_experiences = np.vstack(self.ss_mem[idxs]), \
                             np.vstack(self.as_mem[idxs]), \
                             np.vstack(self.rs_mem[idxs]), \
                             np.vstack(self.ps_mem[idxs]), \
                             np.vstack(self.ds_mem[idxs])

    return mini_batch_experiences

  def __len__(self):
    return self.size

# %% [markdown]
# # Exploration strategies

# %% [markdown]
# The GreedyStrategy will always select the maximum Q-value.

# %%
# the strategy we will use in the evaluation phase
class GreedyStrategy():
  def __init__(self):
    self.exploratory_action_taken = False

  def select_action(self, model, state):
    with torch.no_grad():
      # get the q-value of each action given the state
      q_values = model(state).cpu().detach().data.numpy().squeeze()

      # return the index of the action with the highest estimate
      return np.argmax(q_values)

# %% [markdown]
# The exponential $\epsilon$-greedy strategy a decaying epsilon value so that the probability of exploration is higher at the beginning and the probability of exploitation is higher at the end of the training phase.

# %%
# the strategy we will use in the training phase
class EGreedyExpStrategy():
  '''
  In the exponentially decaying strategy, the epsilon value is decaying in an exponential curve.
  '''

  def __init__(self, init_epsilon=1.0, min_epsilon=0.1, decay_steps=20000):
    self.epsilon = init_epsilon
    self.init_epsilon = init_epsilon
    self.decay_steps = decay_steps
    self.min_epsilon = min_epsilon
    self.epsilons = 0.01 / np.logspace(-2, 0, decay_steps, endpoint=False) - 0.01
    self.epsilons = self.epsilons * (init_epsilon - min_epsilon) + min_epsilon
    self.t = 0

  def _epsilon_update(self):
    self.epsilon = self.min_epsilon if self.t >= self.decay_steps else self.epsilons[self.t]
    self.t += 1

    return self.epsilon

  def select_action(self, model, state):
    self.exploratory_action_taken = False
    with torch.no_grad():
      q_values = model(state).detach().cpu().data.numpy().squeeze()

    # we draw the random number from a uniform distribution and compare it to epsilon
    # if it is higher, we use the argmax of the q-values
    # otherwise, we use a random action
    if np.random.rand() > self.epsilon:
      action = np.argmax(q_values)
    else:
      action = np.random.randint(len(q_values))

    # adjust the epsilon value
    self._epsilon_update()

    return action

# %% [markdown]
# # DDQN

# %% [markdown]
# DDQN stands for "double deep Q-network" and it is an improvement to the DQN algorithm since it mitigates the overestimation of action-value functions.
#
# Recall that the DQN algorithm uses the off-policy TD target with the max operator. The problem is: it takes the max of estimated values. But estimated values can be off-center (meaning that they can be higher/lower than the true values).
#
# The solution DDQN offers to this problem is very simple: we will use the online network to find out the index of the highest-valued action & then ask the target network to tell us the action-value of that action. Basically, the online network is used for action selection and the target network is used for action evaluation. By using the target network for value estimates, we make sure the target values are frozen as needed for stability (like we did in DQN).
#
# All in all, the steps we used in DQN such as interaction step, update step etc. remain the same.
# We only need to change the optimization step as you can see below.

# %% [markdown]
# At the optimization step, we optimize the model using the following formula:
#
# $\nabla_{\theta_{i}} L_{i} (\theta_{i}) = \mathbb{E}_{\underbrace{(s,a,r,s') \sim U(D)}_\text{sampling of experiences}}[\underbrace{(r+\gamma Q(s', argmax_{a'} Q(s', a'; \theta_{i}); \theta^-}_\text{Target}) - \underbrace{Q(s,a; \theta_{i})}_\text{Prediction}) \nabla_{\theta_{i}} Q(s, a; \theta_{i})]$

# %% [markdown]
# An in-depth explanation of the formula:
#
# *   $\mathbb{E}_{(s,a,r,s') \sim U(D)}$
#
#     we use the expectations of the experience tuples; we obtain the experiences we use for training by sampling uniformly at random the replay buffer D
#
# *   $r$
#
#     the experienced reward we get when we take a particular action $a$ in state $s$
#
# *   $\gamma Q(s', argmax_{a'} Q(s', a'; \theta_{i}); \theta^-))$
#
#     This part is different from the DQN formula.
#     Here, we first ask the online network to tell us the index of the highest-valued action in the next state.
#     Then, we use that index to obtain the corresponding Q-value from the target network.
#     So, the index is coming from the online network but the Q-value is coming from the target network.
#     As usual, we discount that Q-value with gamma.
#     Together with $r$, this part forms the target.
#
# *   $Q(s,a; \theta_{i})$
#
#     The current Q-value estimates are our predictions
#     (just like in DQN)

# %%
class DDQN():
  def __init__(self,
               env,
               seed,
               online_model,
               target_model,
               replay_buffer,
               optimizer,
               training_strategy,
               evaluation_strategy,
               max_gradient_norm,
               gamma,
               update_steps,
               max_episodes,
               goal,
               warmup_batches):

    # set the attributes
    self.env = env
    self.seed = seed
    self.online_model = online_model
    self.target_model = target_model
    self.replay_buffer = replay_buffer
    self.optimizer = optimizer
    self.training_strategy = training_strategy
    self.evaluation_strategy = evaluation_strategy
    self.max_gradient_norm = max_gradient_norm
    self.gamma = gamma
    self.update_steps = update_steps
    self.max_episodes = max_episodes
    self.goal = goal
    self.warmup_batches = warmup_batches
    self.evaluation_scores = []
    self.mean_evaluation_scores = []

  def __update(self):
    # copy the online weights to the target network
    for target, online in zip(self.target_model.parameters(), self.online_model.parameters()):
      target.data.copy_(online.data)


  def __interact(self, cur_state):
    # select an action according to the exponentially decaying epsilon-greedy exploration strategy
    action = self.training_strategy.select_action(self.online_model, cur_state)
    # perform the selected action in the environment
    next_state, reward, is_terminal, info = env.step(action)
    # determine if CartPole's built-in TimeLimit is reached
    is_truncated = 'TimeLimit.truncated' in info and info['TimeLimit.truncated']
    # calculate the is_failure flag indicating a terminal state
    is_failure = is_terminal and not is_truncated
    # create the experience
    experience = (cur_state, action, reward, next_state, float(is_failure))

    return experience, next_state, is_terminal


  def __optimize(self, experiences):
    # extract the experience components
    states, actions, rewards, next_states, is_terminals = experiences
    batch_size = len(is_terminals)
    # query the online network to get the index of the highest-valued
    # action of the next state
    index_of_highest_valued_q_values = self.online_model(next_states).max(dim=1)[1]
    # query the q values of the next state according to target network
    q_values_of_target_network = self.target_model(next_states).detach()
    # index the Q values given by the target network
    # with the action indices given be the online network
    highest_valued_q_values = q_values_of_target_network[np.arange(batch_size), index_of_highest_valued_q_values].unsqueeze(1)
    # create the target values
    target_q_values = rewards + (self.gamma * highest_valued_q_values * (1-is_terminals))
    # get the current estimates
    predicted_q_values = self.online_model(states).gather(dim=1, index=actions)
    # determine the loss
    loss = (predicted_q_values - target_q_values).pow(2).mul(0.5).mean()
    # zero-out the gradients
    self.optimizer.zero_grad()
    # compute the gradients
    loss.backward()
    # to implement the Huber loss, we compute the MSE loss (as above) and
    # now we set the all gradients larger than a threshold to a fixed magnitude
    # value; so we clip the magnitude of the gradients
    torch.nn.utils.clip_grad_norm_(self.online_model.parameters(), self.max_gradient_norm)
    # update the weights
    self.optimizer.step()

  def __evaluate(self, episodes=1):
    # keep a list of the rewards
    rewards = []
    # for each episode
    for _ in range(episodes):
      # get the initial state
      state = self.env.reset(seed=self.seed)
      # set 'is_terminal' flag to False
      is_terminal = False
      # initialize the rewards list
      rewards.append(0)
      # for each timestep in the current episode
      for _ in count():
        # get the action according to evaluation strategy from the online_model
        action = self.evaluation_strategy.select_action(self.online_model, state)
        # perform the action in the environment
        state, reward, is_terminal, _ = self.env.step(action)
        # save the experienced reward
        rewards[-1] += reward
        # break if we are in a terminal state
        if is_terminal:
          break

    # return the mean of the rewards
    return np.mean(rewards)

  def __sample(self):
    # sample a mini-batch of experiences from the replay buffer
    experiences = self.replay_buffer.sample()

    # invoke the load() method which extracts the components of each experience
    # transforms them into a PyTorch tensor, and loads them onto the current device (cpu or gpu)
    experiences = self.online_model.load(experiences)

    return experiences


  def train(self):
    # make sure that online and target network have the same weights before training starts
    self.__update()
    # get the starting time of the training
    training_start = time.time()
    # for each episode
    for episode in range(self.max_episodes):
      cur_state = self.env.reset(seed=self.seed)    # get the initial state
      is_terminal = False        # flag indicating whether episode is finished or not
      episode_timestep = 0   # initialize list to hold the number of timesteps
      # for each timestep in the current episode
      for timestep in count():
        # interact with the environment
        experience, new_state, is_terminal = self.__interact(cur_state)
        # adjust the timestep so that we know when to update the target network
        episode_timestep += 1
        # store the experience into the replay buffer
        replay_buffer.store(experience)
        # update current state
        cur_state = new_state
        # check if we have enough experiences in the replay buffer
        if len(replay_buffer) > replay_buffer.batch_size * warmup_batches:
          # get a minibatch of experiences from the replay buffer
          experiences = self.__sample()
          # OPTIMIZATION STEP
          # optimize the model
          self.__optimize(experiences)
        # update the weights of the target network periodically
        if episode_timestep % self.update_steps == 0:
          # UPDATE step
          # make sure that online and target network have the same weights
          self.__update()
        # break if current state was a terminal state
        if is_terminal:
          break


      # EVALUATION step (optional)
      # compute the evaluation score
      evaluation_score = self.__evaluate()
      # store the evaluation score
      self.evaluation_scores.append(evaluation_score)
      # comput the mean evaluation score
      mean_100_eval_score = np.mean(self.evaluation_scores[-100:])
      self.mean_evaluation_scores.append(mean_100_eval_score)
      print(f"Episode: {episode}, Timestep: {episode_timestep}, Evaluation score: {evaluation_score}, Mean evaluation score: {mean_100_eval_score}")
      # flag indicating whether max episodes is reached
      reached_max_episodes = episode >= self.max_episodes
      # flag indicating whether mean goal reward is reached
      reached_goal_mean_reward = mean_100_eval_score >= self.goal

      # finish if one of the flags is true
      training_is_over = reached_max_episodes or reached_goal_mean_reward
      if training_is_over:
        if reached_max_episodes: print('Max episodes are reached')
        if reached_goal_mean_reward: print('Goal mean reward is reached')
        break

    # get the final evaluation score
    final_evaluation_score = self.__evaluate(episodes=100)
    print(f"Final evaluation score: {final_evaluation_score}")

    self.env.close()
    del self.env

# %% [markdown]
# # CartPole environment

# %% [markdown]
# ## Train the DDQN agent

# %%
# define the our discount factor
gamma = 1.0
# number of steps when to update the target network
update_steps = 10
# define nr. of max episodes
max_episodes = 10000
# define mean reward value
goal = 500
# warmup batches
warmup_batches = 5
# define the max gradient norm
max_gradient_norm = float('inf')
# define the learning rate
lr = 5e-04 # 0.0005
# define a seed value
seed = 42

# %%
# create an instance of the environment
env = gym.make("CartPole-v1")
# create an instance of the replay buffer
replay_buffer = ReplayBuffer(max_size=50000, batch_size=64)
# define our action-selection policy for the training phase
training_strategy = EGreedyExpStrategy(init_epsilon=1.0, min_epsilon=0.3, decay_steps=20000)
# define our action-selection policy for the evaluation phase
evaluation_strategy = GreedyStrategy()
# define the state space
state_space = env.observation_space.shape[0]
# define the action space
action_space = env.action_space.n
# build the online network
online_model = QNetwork(state_space, action_space, hidden_dims=(512,128))
# build the target network
target_model = QNetwork(state_space, action_space, hidden_dims=(512,128))
# create an instance of the RMSprop optimizer
optimizer = optim.RMSprop(online_model.parameters(), lr=lr)
# create the DDQN agent
ddqn_agent = DDQN(env,
                  seed,
                  online_model,
                  target_model,
                  replay_buffer,
                  optimizer,
                  training_strategy,
                  evaluation_strategy,
                  max_gradient_norm,
                  gamma,
                  update_steps,
                  max_episodes,
                  goal,
                  warmup_batches
                  )

# let the DDQN agent train
ddqn_agent.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# Episode: 0, Timestep: 25, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 1, Timestep: 25, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 2, Timestep: 10, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 3, Timestep: 20, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 4, Timestep: 49, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 5, Timestep: 11, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 6, Timestep: 17, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 7, Timestep: 17, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 8, Timestep: 36, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 9, Timestep: 53, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 10, Timestep: 29, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 11, Timestep: 16, Evaluation score: 10.0, Mean evaluation score: 10.0
# Episode: 12, Timestep: 14, Evaluation score: 8.0, Mean evaluation score: 9.846153846153847
# Episode: 13, Timestep: 21, Evaluation score: 10.0, Mean evaluation score: 9.857142857142858
# Episode: 14, Timestep: 24, Evaluation score: 34.0, Mean evaluation score: 11.466666666666667
# Episode: 15, Timestep: 8, Evaluation score: 8.0, Mean evaluation score: 11.25
# Episode: 16, Timestep: 40, Evaluation score: 138.0, Mean evaluation score: 18.705882352941178
# Episode: 17, Timestep: 16, Evaluation score: 103.0, Mean evaluation score: 23.38888888888889
# Episode: 18, Timestep: 23, Evaluation score: 24.0, Mean evaluation score: 23.42105263157895
# Episode: 19, Timestep: 105, Evaluation score: 61.0, Mean evaluation score: 25.3
# Episode: 20, Timestep: 68, Evaluation score: 173.0, Mean evaluation score: 32.333333333333336
# Episode: 21, Timestep: 19, Evaluation score: 161.0, Mean evaluation score: 38.18181818181818
# Episode: 22, Timestep: 17, Evaluation score: 121.0, Mean evaluation score: 41.78260869565217
# Episode: 23, Timestep: 26, Evaluation score: 299.0, Mean evaluation score: 52.5
# Episode: 24, Timestep: 19, Evaluation score: 100.0, Mean evaluation score: 54.4
# Episode: 25, Timestep: 15, Evaluation score: 192.0, Mean evaluation score: 59.69230769230769
# Episode: 26, Timestep: 12, Evaluation score: 182.0, Mean evaluation score: 64.22222222222223
# Episode: 27, Timestep: 14, Evaluation score: 68.0, Mean evaluation score: 64.35714285714286
# Episode: 28, Timestep: 18, Evaluation score: 77.0, Mean evaluation score: 64.79310344827586
# Episode: 29, Timestep: 23, Evaluation score: 108.0, Mean evaluation score: 66.23333333333333
# Episode: 30, Timestep: 34, Evaluation score: 197.0, Mean evaluation score: 70.45161290322581
# Episode: 31, Timestep: 10, Evaluation score: 99.0, Mean evaluation score: 71.34375
# Episode: 32, Timestep: 17, Evaluation score: 171.0, Mean evaluation score: 74.36363636363636
# Episode: 33, Timestep: 66, Evaluation score: 141.0, Mean evaluation score: 76.32352941176471
# Episode: 34, Timestep: 39, Evaluation score: 83.0, Mean evaluation score: 76.51428571428572
# Episode: 35, Timestep: 22, Evaluation score: 101.0, Mean evaluation score: 77.19444444444444
# Episode: 36, Timestep: 29, Evaluation score: 191.0, Mean evaluation score: 80.27027027027027
# Episode: 37, Timestep: 13, Evaluation score: 126.0, Mean evaluation score: 81.47368421052632
# Episode: 38, Timestep: 44, Evaluation score: 199.0, Mean evaluation score: 84.48717948717949
# Episode: 39, Timestep: 10, Evaluation score: 167.0, Mean evaluation score: 86.55
# Episode: 40, Timestep: 15, Evaluation score: 207.0, Mean evaluation score: 89.48780487804878
# Episode: 41, Timestep: 111, Evaluation score: 93.0, Mean evaluation score: 89.57142857142857
# Episode: 42, Timestep: 43, Evaluation score: 86.0, Mean evaluation score: 89.48837209302326
# Episode: 43, Timestep: 28, Evaluation score: 116.0, Mean evaluation score: 90.0909090909091
# Episode: 44, Timestep: 48, Evaluation score: 120.0, Mean evaluation score: 90.75555555555556
# Episode: 45, Timestep: 20, Evaluation score: 142.0, Mean evaluation score: 91.8695652173913
# Episode: 46, Timestep: 14, Evaluation score: 135.0, Mean evaluation score: 92.7872340425532
# Episode: 47, Timestep: 15, Evaluation score: 82.0, Mean evaluation score: 92.5625
# Episode: 48, Timestep: 27, Evaluation score: 116.0, Mean evaluation score: 93.04081632653062
# Episode: 49, Timestep: 27, Evaluation score: 112.0, Mean evaluation score: 93.42
# Episode: 50, Timestep: 24, Evaluation score: 134.0, Mean evaluation score: 94.2156862745098
# Episode: 51, Timestep: 81, Evaluation score: 77.0, Mean evaluation score: 93.88461538461539
# Episode: 52, Timestep: 23, Evaluation score: 132.0, Mean evaluation score: 94.60377358490567
# Episode: 53, Timestep: 66, Evaluation score: 124.0, Mean evaluation score: 95.14814814814815
# Episode: 54, Timestep: 38, Evaluation score: 82.0, Mean evaluation score: 94.9090909090909
# Episode: 55, Timestep: 33, Evaluation score: 75.0, Mean evaluation score: 94.55357142857143
# Episode: 56, Timestep: 19, Evaluation score: 87.0, Mean evaluation score: 94.42105263157895
# Episode: 57, Timestep: 29, Evaluation score: 121.0, Mean evaluation score: 94.87931034482759
# Episode: 58, Timestep: 11, Evaluation score: 94.0, Mean evaluation score: 94.86440677966101
# Episode: 59, Timestep: 31, Evaluation score: 127.0, Mean evaluation score: 95.4
# Episode: 60, Timestep: 26, Evaluation score: 135.0, Mean evaluation score: 96.04918032786885
# Episode: 61, Timestep: 60, Evaluation score: 121.0, Mean evaluation score: 96.45161290322581
# Episode: 62, Timestep: 128, Evaluation score: 121.0, Mean evaluation score: 96.84126984126983
# Episode: 63, Timestep: 111, Evaluation score: 121.0, Mean evaluation score: 97.21875
# Episode: 64, Timestep: 74, Evaluation score: 124.0, Mean evaluation score: 97.63076923076923
# Episode: 65, Timestep: 13, Evaluation score: 128.0, Mean evaluation score: 98.0909090909091
# Episode: 66, Timestep: 132, Evaluation score: 146.0, Mean evaluation score: 98.80597014925372
# Episode: 67, Timestep: 28, Evaluation score: 132.0, Mean evaluation score: 99.29411764705883
# Episode: 68, Timestep: 37, Evaluation score: 140.0, Mean evaluation score: 99.8840579710145
# Episode: 69, Timestep: 94, Evaluation score: 139.0, Mean evaluation score: 100.44285714285714
# Episode: 70, Timestep: 45, Evaluation score: 147.0, Mean evaluation score: 101.09859154929578
# Episode: 71, Timestep: 64, Evaluation score: 137.0, Mean evaluation score: 101.59722222222223
# Episode: 72, Timestep: 56, Evaluation score: 151.0, Mean evaluation score: 102.27397260273973
# Episode: 73, Timestep: 29, Evaluation score: 137.0, Mean evaluation score: 102.74324324324324
# Episode: 74, Timestep: 52, Evaluation score: 158.0, Mean evaluation score: 103.48
# Episode: 75, Timestep: 47, Evaluation score: 165.0, Mean evaluation score: 104.28947368421052
# Episode: 76, Timestep: 69, Evaluation score: 172.0, Mean evaluation score: 105.16883116883118
# Episode: 77, Timestep: 23, Evaluation score: 167.0, Mean evaluation score: 105.96153846153847
# Episode: 78, Timestep: 22, Evaluation score: 153.0, Mean evaluation score: 106.55696202531645
# Episode: 79, Timestep: 75, Evaluation score: 158.0, Mean evaluation score: 107.2
# Episode: 80, Timestep: 148, Evaluation score: 145.0, Mean evaluation score: 107.66666666666667
# Episode: 81, Timestep: 63, Evaluation score: 169.0, Mean evaluation score: 108.41463414634147
# Episode: 82, Timestep: 136, Evaluation score: 170.0, Mean evaluation score: 109.1566265060241
# Episode: 83, Timestep: 17, Evaluation score: 186.0, Mean evaluation score: 110.07142857142857
# Episode: 84, Timestep: 19, Evaluation score: 186.0, Mean evaluation score: 110.96470588235294
# Episode: 85, Timestep: 137, Evaluation score: 228.0, Mean evaluation score: 112.32558139534883
# Episode: 86, Timestep: 107, Evaluation score: 304.0, Mean evaluation score: 114.52873563218391
# Episode: 87, Timestep: 24, Evaluation score: 189.0, Mean evaluation score: 115.375
# Episode: 88, Timestep: 117, Evaluation score: 235.0, Mean evaluation score: 116.71910112359551
# Episode: 89, Timestep: 92, Evaluation score: 227.0, Mean evaluation score: 117.94444444444444
# Episode: 90, Timestep: 136, Evaluation score: 188.0, Mean evaluation score: 118.71428571428571
# Episode: 91, Timestep: 181, Evaluation score: 169.0, Mean evaluation score: 119.26086956521739
# Episode: 92, Timestep: 146, Evaluation score: 189.0, Mean evaluation score: 120.01075268817205
# Episode: 93, Timestep: 141, Evaluation score: 261.0, Mean evaluation score: 121.51063829787235
# Episode: 94, Timestep: 70, Evaluation score: 191.0, Mean evaluation score: 122.2421052631579
# Episode: 95, Timestep: 127, Evaluation score: 248.0, Mean evaluation score: 123.55208333333333
# Episode: 96, Timestep: 151, Evaluation score: 181.0, Mean evaluation score: 124.14432989690722
# Episode: 97, Timestep: 127, Evaluation score: 221.0, Mean evaluation score: 125.13265306122449
# Episode: 98, Timestep: 133, Evaluation score: 202.0, Mean evaluation score: 125.9090909090909
# Episode: 99, Timestep: 249, Evaluation score: 208.0, Mean evaluation score: 126.73
# Episode: 100, Timestep: 37, Evaluation score: 216.0, Mean evaluation score: 128.79
# Episode: 101, Timestep: 114, Evaluation score: 207.0, Mean evaluation score: 130.76
# Episode: 102, Timestep: 159, Evaluation score: 319.0, Mean evaluation score: 133.85
# Episode: 103, Timestep: 254, Evaluation score: 216.0, Mean evaluation score: 135.91
# Episode: 104, Timestep: 145, Evaluation score: 204.0, Mean evaluation score: 137.85
# Episode: 105, Timestep: 142, Evaluation score: 212.0, Mean evaluation score: 139.87
# Episode: 106, Timestep: 31, Evaluation score: 214.0, Mean evaluation score: 141.91
# Episode: 107, Timestep: 195, Evaluation score: 292.0, Mean evaluation score: 144.73
# Episode: 108, Timestep: 427, Evaluation score: 210.0, Mean evaluation score: 146.73
# Episode: 109, Timestep: 184, Evaluation score: 234.0, Mean evaluation score: 148.97
# Episode: 110, Timestep: 165, Evaluation score: 208.0, Mean evaluation score: 150.95
# Episode: 111, Timestep: 43, Evaluation score: 217.0, Mean evaluation score: 153.02
# Episode: 112, Timestep: 177, Evaluation score: 213.0, Mean evaluation score: 155.07
# Episode: 113, Timestep: 132, Evaluation score: 224.0, Mean evaluation score: 157.21
# Episode: 114, Timestep: 202, Evaluation score: 231.0, Mean evaluation score: 159.18
# Episode: 115, Timestep: 230, Evaluation score: 303.0, Mean evaluation score: 162.13
# Episode: 116, Timestep: 209, Evaluation score: 367.0, Mean evaluation score: 164.42
# Episode: 117, Timestep: 91, Evaluation score: 213.0, Mean evaluation score: 165.52
# Episode: 118, Timestep: 151, Evaluation score: 363.0, Mean evaluation score: 168.91
# Episode: 119, Timestep: 155, Evaluation score: 221.0, Mean evaluation score: 170.51
# Episode: 120, Timestep: 144, Evaluation score: 199.0, Mean evaluation score: 170.77
# Episode: 121, Timestep: 303, Evaluation score: 209.0, Mean evaluation score: 171.25
# Episode: 122, Timestep: 135, Evaluation score: 204.0, Mean evaluation score: 172.08
# Episode: 123, Timestep: 224, Evaluation score: 376.0, Mean evaluation score: 172.85
# Episode: 124, Timestep: 163, Evaluation score: 210.0, Mean evaluation score: 173.95
# Episode: 125, Timestep: 198, Evaluation score: 474.0, Mean evaluation score: 176.77
# Episode: 126, Timestep: 269, Evaluation score: 369.0, Mean evaluation score: 178.64
# Episode: 127, Timestep: 248, Evaluation score: 479.0, Mean evaluation score: 182.75
# Episode: 128, Timestep: 286, Evaluation score: 198.0, Mean evaluation score: 183.96
# Episode: 129, Timestep: 231, Evaluation score: 199.0, Mean evaluation score: 184.87
# Episode: 130, Timestep: 259, Evaluation score: 219.0, Mean evaluation score: 185.09
# Episode: 131, Timestep: 198, Evaluation score: 375.0, Mean evaluation score: 187.85
# Episode: 132, Timestep: 253, Evaluation score: 294.0, Mean evaluation score: 189.08
# Episode: 133, Timestep: 257, Evaluation score: 326.0, Mean evaluation score: 190.93
# Episode: 134, Timestep: 80, Evaluation score: 430.0, Mean evaluation score: 194.4
# Episode: 135, Timestep: 291, Evaluation score: 323.0, Mean evaluation score: 196.62
# Episode: 136, Timestep: 254, Evaluation score: 390.0, Mean evaluation score: 198.61
# Episode: 137, Timestep: 361, Evaluation score: 400.0, Mean evaluation score: 201.35
# Episode: 138, Timestep: 101, Evaluation score: 457.0, Mean evaluation score: 203.93
# Episode: 139, Timestep: 459, Evaluation score: 425.0, Mean evaluation score: 206.51
# Episode: 140, Timestep: 227, Evaluation score: 255.0, Mean evaluation score: 206.99
# Episode: 141, Timestep: 114, Evaluation score: 298.0, Mean evaluation score: 209.04
# Episode: 142, Timestep: 332, Evaluation score: 256.0, Mean evaluation score: 210.74
# Episode: 143, Timestep: 211, Evaluation score: 249.0, Mean evaluation score: 212.07
# Episode: 144, Timestep: 180, Evaluation score: 269.0, Mean evaluation score: 213.56
# Episode: 145, Timestep: 192, Evaluation score: 248.0, Mean evaluation score: 214.62
# Episode: 146, Timestep: 244, Evaluation score: 257.0, Mean evaluation score: 215.84
# Episode: 147, Timestep: 75, Evaluation score: 444.0, Mean evaluation score: 219.46
# Episode: 148, Timestep: 252, Evaluation score: 405.0, Mean evaluation score: 222.35
# Episode: 149, Timestep: 469, Evaluation score: 362.0, Mean evaluation score: 224.85
# Episode: 150, Timestep: 171, Evaluation score: 392.0, Mean evaluation score: 227.43
# Episode: 151, Timestep: 262, Evaluation score: 367.0, Mean evaluation score: 230.33
# Episode: 152, Timestep: 217, Evaluation score: 343.0, Mean evaluation score: 232.44
# Episode: 153, Timestep: 210, Evaluation score: 500.0, Mean evaluation score: 236.2
# Episode: 154, Timestep: 159, Evaluation score: 276.0, Mean evaluation score: 238.14
# Episode: 155, Timestep: 195, Evaluation score: 395.0, Mean evaluation score: 241.34
# Episode: 156, Timestep: 150, Evaluation score: 500.0, Mean evaluation score: 245.47
# Episode: 157, Timestep: 246, Evaluation score: 500.0, Mean evaluation score: 249.26
# Episode: 158, Timestep: 295, Evaluation score: 500.0, Mean evaluation score: 253.32
# Episode: 159, Timestep: 177, Evaluation score: 431.0, Mean evaluation score: 256.36
# Episode: 160, Timestep: 164, Evaluation score: 500.0, Mean evaluation score: 260.01
# Episode: 161, Timestep: 279, Evaluation score: 296.0, Mean evaluation score: 261.76
# Episode: 162, Timestep: 242, Evaluation score: 500.0, Mean evaluation score: 265.55
# Episode: 163, Timestep: 195, Evaluation score: 392.0, Mean evaluation score: 268.26
# Episode: 164, Timestep: 119, Evaluation score: 500.0, Mean evaluation score: 272.02
# Episode: 165, Timestep: 122, Evaluation score: 320.0, Mean evaluation score: 273.94
# Episode: 166, Timestep: 115, Evaluation score: 500.0, Mean evaluation score: 277.48
# Episode: 167, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 281.16
# Episode: 168, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 284.76
# Episode: 169, Timestep: 239, Evaluation score: 500.0, Mean evaluation score: 288.37
# Episode: 170, Timestep: 499, Evaluation score: 500.0, Mean evaluation score: 291.9
# Episode: 171, Timestep: 462, Evaluation score: 500.0, Mean evaluation score: 295.53
# Episode: 172, Timestep: 327, Evaluation score: 500.0, Mean evaluation score: 299.02
# Episode: 173, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 302.65
# Episode: 174, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 306.07
# Episode: 175, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 309.42
# Episode: 176, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 312.7
# Episode: 177, Timestep: 114, Evaluation score: 500.0, Mean evaluation score: 316.03
# Episode: 178, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 319.5
# Episode: 179, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 322.92
# Episode: 180, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 326.47
# Episode: 181, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 329.78
# Episode: 182, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 333.08
# Episode: 183, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 336.22
# Episode: 184, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 339.36
# Episode: 185, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 342.08
# Episode: 186, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 344.04
# Episode: 187, Timestep: 140, Evaluation score: 500.0, Mean evaluation score: 347.15
# Episode: 188, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 349.8
# Episode: 189, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 352.53
# Episode: 190, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 355.65
# Episode: 191, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 358.96
# Episode: 192, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 362.07
# Episode: 193, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 364.46
# Episode: 194, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 367.55
# Episode: 195, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 370.07
# Episode: 196, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 373.26
# Episode: 197, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 376.05
# Episode: 198, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 379.03
# Episode: 199, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 381.95
# Episode: 200, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 384.79
# Episode: 201, Timestep: 482, Evaluation score: 500.0, Mean evaluation score: 387.72
# Episode: 202, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 389.53
# Episode: 203, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 392.37
# Episode: 204, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 395.33
# Episode: 205, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 398.21
# Episode: 206, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 401.07
# Episode: 207, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 403.15
# Episode: 208, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 406.05
# Episode: 209, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 408.71
# Episode: 210, Timestep: 315, Evaluation score: 500.0, Mean evaluation score: 411.63
# Episode: 211, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 414.46
# Episode: 212, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 417.33
# Episode: 213, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 420.09
# Episode: 214, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 422.78
# Episode: 215, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 424.75
# Episode: 216, Timestep: 180, Evaluation score: 500.0, Mean evaluation score: 426.08
# Episode: 217, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 428.95
# Episode: 218, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 430.32
# Episode: 219, Timestep: 273, Evaluation score: 500.0, Mean evaluation score: 433.11
# Episode: 220, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 436.12
# Episode: 221, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 439.03
# Episode: 222, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 441.99
# Episode: 223, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 443.23
# Episode: 224, Timestep: 227, Evaluation score: 500.0, Mean evaluation score: 446.13
# Episode: 225, Timestep: 442, Evaluation score: 500.0, Mean evaluation score: 446.39
# Episode: 226, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 447.7
# Episode: 227, Timestep: 254, Evaluation score: 500.0, Mean evaluation score: 447.91
# Episode: 228, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 450.93
# Episode: 229, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 453.94
# Episode: 230, Timestep: 487, Evaluation score: 500.0, Mean evaluation score: 456.75
# Episode: 231, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 458.0
# Episode: 232, Timestep: 371, Evaluation score: 500.0, Mean evaluation score: 460.06
# Episode: 233, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 461.8
# Episode: 234, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 462.5
# Episode: 235, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 464.27
# Episode: 236, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 465.37
# Episode: 237, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 466.37
# Episode: 238, Timestep: 239, Evaluation score: 500.0, Mean evaluation score: 466.8
# Episode: 239, Timestep: 458, Evaluation score: 500.0, Mean evaluation score: 467.55
# Episode: 240, Timestep: 195, Evaluation score: 500.0, Mean evaluation score: 470.0
# Episode: 241, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 472.02
# Episode: 242, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 474.46
# Episode: 243, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 476.97
# Episode: 244, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 479.28
# Episode: 245, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 481.8
# Episode: 246, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 484.23
# Episode: 247, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 484.79
# Episode: 248, Timestep: 489, Evaluation score: 500.0, Mean evaluation score: 485.74
# Episode: 249, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 487.12
# Episode: 250, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 488.2
# Episode: 251, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 489.53
# Episode: 252, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 491.1
# Episode: 253, Timestep: 165, Evaluation score: 500.0, Mean evaluation score: 491.1
# Episode: 254, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 493.34
# Episode: 255, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 494.39
# Episode: 256, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 494.39
# Episode: 257, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 494.39
# Episode: 258, Timestep: 25, Evaluation score: 500.0, Mean evaluation score: 494.39
# Episode: 259, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 495.08
# Episode: 260, Timestep: 226, Evaluation score: 500.0, Mean evaluation score: 495.08
# Episode: 261, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 497.12
# Episode: 262, Timestep: 487, Evaluation score: 500.0, Mean evaluation score: 497.12
# Episode: 263, Timestep: 384, Evaluation score: 500.0, Mean evaluation score: 498.2
# Episode: 264, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 498.2
# Episode: 265, Timestep: 500, Evaluation score: 500.0, Mean evaluation score: 500.0
# Goal mean reward is reached
# Final evaluation score: 500.0

# %% [markdown]
# ## Save model

# %%
torch.save(ddqn_agent.online_model.state_dict(), "/content/drive/MyDrive/DDQN/DDQN_agent_cartpole.pt")

# %% [markdown]
# ## Load the model

# %%
env = gym.make("CartPole-v1")
model = QNetwork(env.observation_space.shape[0], env.action_space.n, hidden_dims=(512,128))
model.load_state_dict(torch.load("/content/drive/MyDrive/DDQN/DDQN_agent_cartpole.pt"))
model.eval()
# Out:
# QNetwork(
#   (input_layer): Linear(in_features=4, out_features=512, bias=True)
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#   )
#   (output_layer): Linear(in_features=128, out_features=2, bias=True)
# )

# %% [markdown]
# ## Visualize

# %%
plt.plot(ddqn_agent.mean_evaluation_scores)
plt.xlabel("Epochs")
plt.ylabel("Mean evaluation score")
plt.title("Training Process")
plt.show()

# %%
def create_gif(env, episodes):
  # list to keep track of frames
  frames = []

  for episode in range(1, episodes + 1):
    # select a seed value randomly
    seed = random.randint(0,20)

    # get the initial state
    state = env.reset(seed = seed)

    # for each timestep, do the following
    for t in range(500):
      # get the Q-value estimates
      q_values = model(state)
      # select the action (greedily)
      action = np.argmax(q_values.data.numpy())

      # get the frame & store it
      frame = env.render(mode='rgb_array')

      # prepare the frame
      im = Im.fromarray(frame)
      drawer = ImageDraw.Draw(im)
      if np.mean(im) < 128:
        text_color = (255,255,255)
      else:
        text_color = (0,0,0)
        drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode}', fill=text_color)
        drawer.text((im.size[0]/20,im.size[1]/8), f'Timestep: {t+1}', fill=text_color)

      # store the frame
      frames.append(im)

      # take the action in the environment
      state, _, is_terminal, _ = env.step(action)

      # if we land at a terminal state, break
      if is_terminal:
        break

    # close the environment
    env.close()

    # create the gif
    imageio.mimwrite(os.path.join('/content/drive/MyDrive/Gif/', 'ddqn_agent_cartpole.gif'), frames, duration=20)

# %%
episodes = 5
env = gym.make('CartPole-v1')
create_gif(env, episodes)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(

# %%
from IPython import display
display.Image(open('/content/drive/MyDrive/Gif/ddqn_agent_cartpole.gif','rb').read())
