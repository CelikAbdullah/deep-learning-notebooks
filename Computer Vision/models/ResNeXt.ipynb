# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/ResNeXt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %% [markdown]
# # ResNeXt

# %% [markdown]
# ## The stem component

# %%
def stem(inputs):
  """ Build the stem component of ResNeXt
      inputs : represents the input vector
  """
  # a strided 7x7 conv layer
  x = keras.layers.Conv2D(filters=64, kernel_size=7, strides=2, padding='same', kernel_initializer='he_normal', use_bias=False)(inputs)
  # apply batch normalization
  x = keras.layers.BatchNormalization()(x)
  # the ReLU activation layer
  x = keras.layers.ReLU()(x)
  # apply a strided 3x3 max pooling
  x = keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### The Identity Block

# %%
def identity_block(x, filters_in, filters_out, cardinality=32):
  """ Build a ResNeXT block with an identity link
      x          : input to block
      filters_in : number of filters  (channels) at the input convolution
      filters_out: number of filters (channels) at the output convolution
      cardinality: width of group convolution
  """

  # Save the input
  shortcut = x

  # a 1x1 conv layer for dimensionality reduction followed by a batch normalization and ReLU activation layer
  x = keras.layers.Conv2D(filters=filters_in, kernel_size=1, strides=1, padding='same', kernel_initializer='he_normal', use_bias=False)(shortcut)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # compute the cardinality (wide) layer (split-transform)
  filters_card = filters_in // cardinality
  groups = []
  for i in range(cardinality):
    group = keras.layers.Lambda(lambda z: z[:, :, :, i * filters_card:i * filters_card + filters_card])(x)
    groups.append(keras.layers.Conv2D(filters=filters_card, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', use_bias=False)(group))

  # concatenate the outputs of the cardinality layer together (merge)
  x = keras.layers.Concatenate()(groups)
  # apply BN + ReLU activation
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 1x1 conv layer for dimensionality restoration followed by batch normalization
  x = keras.layers.Conv2D(filters=filters_out, kernel_size=1, strides=1, padding='same', kernel_initializer='he_normal', use_bias=False)(x)
  x = keras.layers.BatchNormalization()(x)

  # Identity Link: Add the shortcut (input) to the output of the block
  x = keras.layers.Add()([shortcut, x])
  # after adding, apply ReLU activation
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# ### The Projection Block

# %%
def projection_block(x, filters_in, filters_out, cardinality=32, strides=(2, 2)):
  """ Build a ResNeXT block with projection shortcut
      x          : input to the block
      filters_in : number of filters  (channels) at the input convolution
      filters_out: number of filters (channels) at the output convolution
      cardinality: width of group convolution
      strides    : whether entry convolution is strided (i.e., (2, 2) vs (1, 1))
  """

  # a 1x1 conv layer to build the projection shortcut
  # we increase filters by 2X to match shape when added to output of block
  shortcut = keras.layers.Conv2D(filters=filters_out, kernel_size=1, strides=strides, padding='same', kernel_initializer='he_normal')(x)
  shortcut = keras.layers.BatchNormalization()(shortcut)

  # a 1x1 conv layer for dimensionality reduction
  x = keras.layers.Conv2D(filters=filters_in, kernel_size=1, strides=1, padding='same', kernel_initializer='he_normal', use_bias=False)(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # compute the cardinality (wide) layer (split-transform)
  filters_card = filters_in // cardinality
  groups = []
  for i in range(cardinality):
    group = keras.layers.Lambda(lambda z: z[:, :, :, i * filters_card:i * filters_card + filters_card])(x)
    groups.append(keras.layers.Conv2D(filters=filters_card, kernel_size=3, strides=strides, padding='same', kernel_initializer='he_normal', use_bias=False)(group))

  # concatenate the outputs of the cardinality layer together (merge)
  x = keras.layers.Concatenate()(groups)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # a 1x1 conv layer for dimensionality restoration
  x = keras.layers.Conv2D(filters_out, (1, 1), strides=(1, 1), padding='same', kernel_initializer='he_normal', use_bias=False)(x)
  x = keras.layers.BatchNormalization()(x)

  # use the iddentity link to add the shortcut (input) to the output of the block
  x = keras.layers.Add()([shortcut, x])
  x = keras.layers.ReLU()(x)

  return x

# %% [markdown]
# ### The ResNeXt Group

# %%
def group(x, filters_in, filters_out, n_blocks, cardinality=32, strides=(2, 2)):
  """ Build a Residual group
      x          : input to the group
      filters_in : number of filters  (channels) at the input convolution
      filters_out: number of filters (channels) at the output convolution
      cardinality: width of group convolution
      strides    : whether its a strided convolution
  """
  # create the projection block
  # we double the size of filters to fit the first residual group
  # we also reduce feature maps by 75% (strides=2, 2) to fit the next Residual Group
  x = projection_block(x, filters_in, filters_out, strides=strides, cardinality=cardinality)

  # create the remaining blocks
  for _ in range(n_blocks):
    x = identity_block(x, filters_in, filters_out, cardinality=cardinality)

  return x

# %% [markdown]
# ### Putting it all together

# %%
def learner(x, groups, cardinality=32):
  """ Build the Learner
      x          : input to the learner
      groups     : list of groups: filters in, filters out, number of blocks
      cardinality: width of group convolution
  """
  # create the first ResNeXt group (not-strided)
  filters_in, filters_out, n_blocks = groups.pop(0)
  x = group(x, filters_in, filters_out, n_blocks, strides=(1, 1), cardinality=cardinality)

  # create the remaining ResNeXt groups
  for filters_in, filters_out, n_blocks in groups:
    x = group(x, filters_in, filters_out, n_blocks, cardinality=cardinality)
  return x

# %% [markdown]
# ## The task component

# %%
def task(x, classes):
  """ Construct the Classifier
      x         : input to the classifier
      classes   : number of output classes
  """
  # Final Dense Outputting Layer
  x = keras.layers.GlobalAveragePooling2D()(x)
  outputs = keras.layers.Dense(units=classes, activation='softmax', kernel_initializer='he_normal')(x)

  return outputs

# %% [markdown]
# ## ResNeXt model

# %%
def build_model(groups, shape=(224,224,3), cardinality=32, classes=1000):
  # the input tensor
  inputs = keras.Input(shape=(224, 224, 3))

  # the stem component
  x = stem(inputs)

  # the learner component
  x = learner(x, groups[50], cardinality)

  # the task component
  outputs = task(x, classes)

  # Instantiate the Model
  return keras.Model(inputs, outputs)

# %%
# Meta-parameter: number of filters in, out and number of blocks
groups = { 50 : [ (128, 256, 3), (256, 512, 4), (512, 1024, 6),  (1024, 2048, 3)], # ResNeXt 50
           101: [ (128, 256, 3), (256, 512, 4), (512, 1024, 23), (1024, 2048, 3)], # ResNeXt 101
           152: [ (128, 256, 3), (256, 512, 8), (512, 1024, 36), (1024, 2048, 3)]  # ResNeXt 152
         }

# %%
# create the ResNeXt model
resnext_model = build_model(groups=groups)

# print a summary
resnext_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_38 (Conv2D)          (None, 112, 112, 64)         9408      ['input_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 112, 112, 64)         256       ['conv2d_38[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 112, 112, 64)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 56, 56, 64)           0         ['re_lu_4[0][0]']
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 56, 56, 128)          8192      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_8 (Bat  (None, 56, 56, 128)          512       ['conv2d_40[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lambda_32 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_33 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_34 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_35 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_36 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_37 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_38 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_39 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_40 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_41 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_42 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_43 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_44 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_45 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_46 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_47 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_48 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_49 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_50 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_51 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_52 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_53 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_54 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_55 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_56 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_57 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_58 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_59 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_60 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_61 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_62 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  lambda_63 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_5[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_32[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_33[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_34[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_35[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_36[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_37[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_38[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_39[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_40[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_41[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_42[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_43[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_44[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_45[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_46[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_47[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_48[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_49[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_50[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_51[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_52[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_53[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_54[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_55[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_56[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_57[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_58[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_59[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_60[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_61[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_62[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_63[0][0]']
#
#  concatenate (Concatenate)   (None, 56, 56, 128)          0         ['conv2d_41[0][0]',
#                                                                      'conv2d_42[0][0]',
#                                                                      'conv2d_43[0][0]',
#                                                                      'conv2d_44[0][0]',
#                                                                      'conv2d_45[0][0]',
#                                                                      'conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]',
#                                                                      'conv2d_48[0][0]',
#                                                                      'conv2d_49[0][0]',
#                                                                      'conv2d_50[0][0]',
#                                                                      'conv2d_51[0][0]',
#                                                                      'conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]',
#                                                                      'conv2d_54[0][0]',
#                                                                      'conv2d_55[0][0]',
#                                                                      'conv2d_56[0][0]',
#                                                                      'conv2d_57[0][0]',
#                                                                      'conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]',
#                                                                      'conv2d_60[0][0]',
#                                                                      'conv2d_61[0][0]',
#                                                                      'conv2d_62[0][0]',
#                                                                      'conv2d_63[0][0]',
#                                                                      'conv2d_64[0][0]',
#                                                                      'conv2d_65[0][0]',
#                                                                      'conv2d_66[0][0]',
#                                                                      'conv2d_67[0][0]',
#                                                                      'conv2d_68[0][0]',
#                                                                      'conv2d_69[0][0]',
#                                                                      'conv2d_70[0][0]',
#                                                                      'conv2d_71[0][0]',
#                                                                      'conv2d_72[0][0]']
#
#  batch_normalization_9 (Bat  (None, 56, 56, 128)          512       ['concatenate[0][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_39 (Conv2D)          (None, 56, 56, 256)          16640     ['max_pooling2d_2[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 56, 56, 256)          32768     ['re_lu_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 56, 56, 256)          1024      ['conv2d_39[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 56, 56, 256)          1024      ['conv2d_73[0][0]']
#  tchNormalization)
#
#  add (Add)                   (None, 56, 56, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 'batch_normalization_10[0][0
#                                                                     ]']
#
#  re_lu_7 (ReLU)              (None, 56, 56, 256)          0         ['add[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 56, 56, 128)          32768     ['re_lu_7[0][0]']
#
#  batch_normalization_11 (Ba  (None, 56, 56, 128)          512       ['conv2d_74[0][0]']
#  tchNormalization)
#
#  re_lu_8 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lambda_64 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_65 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_66 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_67 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_68 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_69 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_70 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_71 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_72 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_73 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_74 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_75 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_76 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_77 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_78 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_79 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_80 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_81 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_82 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_83 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_84 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_85 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_86 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_87 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_88 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_89 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_90 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_91 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_92 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_93 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_94 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  lambda_95 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_8[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_64[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_65[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_66[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_67[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_68[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_69[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_70[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_71[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_72[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_73[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_74[0][0]']
#
#  conv2d_86 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_75[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_76[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_77[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_78[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_79[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_80[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_81[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_82[0][0]']
#
#  conv2d_94 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_83[0][0]']
#
#  conv2d_95 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_84[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_85[0][0]']
#
#  conv2d_97 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_86[0][0]']
#
#  conv2d_98 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_87[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 56, 56, 4)            144       ['lambda_88[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_89[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_90[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_91[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_92[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_93[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_94[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_95[0][0]']
#
#  concatenate_1 (Concatenate  (None, 56, 56, 128)          0         ['conv2d_75[0][0]',
#  )                                                                   'conv2d_76[0][0]',
#                                                                      'conv2d_77[0][0]',
#                                                                      'conv2d_78[0][0]',
#                                                                      'conv2d_79[0][0]',
#                                                                      'conv2d_80[0][0]',
#                                                                      'conv2d_81[0][0]',
#                                                                      'conv2d_82[0][0]',
#                                                                      'conv2d_83[0][0]',
#                                                                      'conv2d_84[0][0]',
#                                                                      'conv2d_85[0][0]',
#                                                                      'conv2d_86[0][0]',
#                                                                      'conv2d_87[0][0]',
#                                                                      'conv2d_88[0][0]',
#                                                                      'conv2d_89[0][0]',
#                                                                      'conv2d_90[0][0]',
#                                                                      'conv2d_91[0][0]',
#                                                                      'conv2d_92[0][0]',
#                                                                      'conv2d_93[0][0]',
#                                                                      'conv2d_94[0][0]',
#                                                                      'conv2d_95[0][0]',
#                                                                      'conv2d_96[0][0]',
#                                                                      'conv2d_97[0][0]',
#                                                                      'conv2d_98[0][0]',
#                                                                      'conv2d_99[0][0]',
#                                                                      'conv2d_100[0][0]',
#                                                                      'conv2d_101[0][0]',
#                                                                      'conv2d_102[0][0]',
#                                                                      'conv2d_103[0][0]',
#                                                                      'conv2d_104[0][0]',
#                                                                      'conv2d_105[0][0]',
#                                                                      'conv2d_106[0][0]']
#
#  batch_normalization_12 (Ba  (None, 56, 56, 128)          512       ['concatenate_1[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_107 (Conv2D)         (None, 56, 56, 256)          32768     ['re_lu_9[0][0]']
#
#  batch_normalization_13 (Ba  (None, 56, 56, 256)          1024      ['conv2d_107[0][0]']
#  tchNormalization)
#
#  add_1 (Add)                 (None, 56, 56, 256)          0         ['re_lu_7[0][0]',
#                                                                      'batch_normalization_13[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 56, 56, 256)          0         ['add_1[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 56, 56, 128)          32768     ['re_lu_10[0][0]']
#
#  batch_normalization_14 (Ba  (None, 56, 56, 128)          512       ['conv2d_108[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 56, 56, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  lambda_96 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_97 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_98 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_99 (Lambda)          (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_100 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_101 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_102 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_103 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_104 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_105 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_106 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_107 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_108 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_109 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_110 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_111 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_112 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_113 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_114 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_115 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_116 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_117 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_118 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_119 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_120 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_121 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_122 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_123 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_124 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_125 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_126 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  lambda_127 (Lambda)         (None, 56, 56, 4)            0         ['re_lu_11[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_96[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_97[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_98[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_99[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_100[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_101[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_102[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_103[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_104[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 56, 56, 4)            144       ['lambda_105[0][0]']
# ...
#  lambda_475 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_44[0][0]']
#
#  lambda_476 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_44[0][0]']
#
#  lambda_477 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_44[0][0]']
#
#  lambda_478 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_44[0][0]']
#
#  lambda_479 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_44[0][0]']
#
#  conv2d_485 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_448[0][0]']
#
#  conv2d_486 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_449[0][0]']
#
#  conv2d_487 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_450[0][0]']
#
#  conv2d_488 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_451[0][0]']
#
#  conv2d_489 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_452[0][0]']
#
#  conv2d_490 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_453[0][0]']
#
#  conv2d_491 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_454[0][0]']
#
#  conv2d_492 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_455[0][0]']
#
#  conv2d_493 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_456[0][0]']
#
#  conv2d_494 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_457[0][0]']
#
#  conv2d_495 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_458[0][0]']
#
#  conv2d_496 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_459[0][0]']
#
#  conv2d_497 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_460[0][0]']
#
#  conv2d_498 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_461[0][0]']
#
#  conv2d_499 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_462[0][0]']
#
#  conv2d_500 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_463[0][0]']
#
#  conv2d_501 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_464[0][0]']
#
#  conv2d_502 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_465[0][0]']
#
#  conv2d_503 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_466[0][0]']
#
#  conv2d_504 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_467[0][0]']
#
#  conv2d_505 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_468[0][0]']
#
#  conv2d_506 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_469[0][0]']
#
#  conv2d_507 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_470[0][0]']
#
#  conv2d_508 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_471[0][0]']
#
#  conv2d_509 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_472[0][0]']
#
#  conv2d_510 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_473[0][0]']
#
#  conv2d_511 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_474[0][0]']
#
#  conv2d_512 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_475[0][0]']
#
#  conv2d_513 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_476[0][0]']
#
#  conv2d_514 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_477[0][0]']
#
#  conv2d_515 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_478[0][0]']
#
#  conv2d_516 (Conv2D)         (None, 14, 14, 16)           2304      ['lambda_479[0][0]']
#
#  concatenate_13 (Concatenat  (None, 14, 14, 512)          0         ['conv2d_485[0][0]',
#  e)                                                                  'conv2d_486[0][0]',
#                                                                      'conv2d_487[0][0]',
#                                                                      'conv2d_488[0][0]',
#                                                                      'conv2d_489[0][0]',
#                                                                      'conv2d_490[0][0]',
#                                                                      'conv2d_491[0][0]',
#                                                                      'conv2d_492[0][0]',
#                                                                      'conv2d_493[0][0]',
#                                                                      'conv2d_494[0][0]',
#                                                                      'conv2d_495[0][0]',
#                                                                      'conv2d_496[0][0]',
#                                                                      'conv2d_497[0][0]',
#                                                                      'conv2d_498[0][0]',
#                                                                      'conv2d_499[0][0]',
#                                                                      'conv2d_500[0][0]',
#                                                                      'conv2d_501[0][0]',
#                                                                      'conv2d_502[0][0]',
#                                                                      'conv2d_503[0][0]',
#                                                                      'conv2d_504[0][0]',
#                                                                      'conv2d_505[0][0]',
#                                                                      'conv2d_506[0][0]',
#                                                                      'conv2d_507[0][0]',
#                                                                      'conv2d_508[0][0]',
#                                                                      'conv2d_509[0][0]',
#                                                                      'conv2d_510[0][0]',
#                                                                      'conv2d_511[0][0]',
#                                                                      'conv2d_512[0][0]',
#                                                                      'conv2d_513[0][0]',
#                                                                      'conv2d_514[0][0]',
#                                                                      'conv2d_515[0][0]',
#                                                                      'conv2d_516[0][0]']
#
#  batch_normalization_50 (Ba  (None, 14, 14, 512)          2048      ['concatenate_13[0][0]']
#  tchNormalization)
#
#  re_lu_45 (ReLU)             (None, 14, 14, 512)          0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_517 (Conv2D)         (None, 14, 14, 1024)         524288    ['re_lu_45[0][0]']
#
#  batch_normalization_51 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_517[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 14, 14, 1024)         0         ['re_lu_43[0][0]',
#                                                                      'batch_normalization_51[0][0]
#                                                                     ']
#
#  re_lu_46 (ReLU)             (None, 14, 14, 1024)         0         ['add_13[0][0]']
#
#  conv2d_518 (Conv2D)         (None, 14, 14, 512)          524288    ['re_lu_46[0][0]']
#
#  batch_normalization_52 (Ba  (None, 14, 14, 512)          2048      ['conv2d_518[0][0]']
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 14, 14, 512)          0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  lambda_480 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_481 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_482 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_483 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_484 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_485 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_486 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_487 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_488 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_489 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_490 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_491 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_492 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
#
#  lambda_493 (Lambda)         (None, 14, 14, 16)           0         ['re_lu_47[0][0]']
# Total params: 31093928 (118.61 MB)
# Trainable params: 31010344 (118.30 MB)
# Non-trainable params: 83584 (326.50 KB)
# __________________________________________________________________________________________________
