# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Computer%20Vision/models/Inception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %% [markdown]
# # Inception v1

# %% [markdown]
# ## The stem component

# %%
def stem(inputs):
  '''
  Build the stem component of Inception v1.
  It extracts the coarse-level features of the input.

  input: the input image
  '''

  # apply ZeroPadding so that the size of the input is preserved
  x = keras.layers.ZeroPadding2D(padding=3)(inputs)

  # apply a strided 7x7 convolution to extract features
  # it will generate 64 output feature maps
  x = keras.layers.Conv2D(filters=64,
                          kernel_size=7,
                          strides=2,
                          padding="valid",
                          activation="relu",
                          kernel_initializer="glorot_uniform"
                          )(x)

  # again, apply ZeroPadding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # apply strided max pooling with a 3x3 window
  # the size of each feature map will be reduced by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)

  # apply a 1x1 convolution
  x = keras.layers.Conv2D(filters = 64,
                          kernel_size=1,
                          padding="same",
                          activation="relu",
                          kernel_initializer="glorot_uniform")(x)

  # zero-padding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # a 3x3 convolution; it will output 192 feature maps
  x = keras.layers.Conv2D(filters=192,
                          kernel_size=3,
                          strides=1,
                          padding="valid",
                          activation="relu",
                          kernel_initializer="glorot_uniform"
                          )(x)

  # zero-padding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # apply strided max pooling with a 3x3 window
  # the size of each feature map will be reduced by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)


  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### Auxiliary Classifier

# %%
def auxiliary(x, classes):
  '''
  Build the auxiliary classifier.

  x       : input to the auxiliary classifier
  classes : number of output classes
  '''

  # strided average pooling operation with a 5x5 window
  x = keras.layers.AveragePooling2D(pool_size=5, strides=3)(x)

  # a 1x1 convolution which will output 128 feature maps
  x = keras.layers.Conv2D(filters=128,
                          kernel_size=1,
                          padding="same",
                          activation="relu",
                          kernel_initializer="glorot_uniform"
                          )(x)

  # flatten the feature maps before passing them to the Dense layer
  x = keras.layers.Flatten()(x)

  # a fully connected layer with 1024 neurons
  x = keras.layers.Dense(units=1024,
                         activation="relu",
                         kernel_initializer="glorot_uniform")(x)

  # dropout layer for regularization
  x = keras.layers.Dropout(rate=0.7)(x)

  # softmax layer to output probabilities for each class
  output = keras.layers.Dense(units=classes,
                              activation="softmax",
                              kernel_initializer="glorot_uniform")(x)


  return output

# %% [markdown]
# ### Inception Block

# %%
def inception_block(input, filters_1x1, filters_3x3, filters_5x5, filter_pool):
  '''
  Build the inception block/module.

  input : input to the inception block/module
  filters_1x1 : nr. of filters for the 1x1 conv branch of the inception module
  filters_3x3 : nr. of filters for the 3x3 conv branch of the inception model
  filters_5x5 : nr. of filters for the 5x5 conv branch of the inception module
  filters_pool: nr. of filters for the max pooling branch of the inception module
  '''

  # create the 1x1 conv branch
  branch_1x1 = keras.layers.Conv2D(filters=filters_1x1[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(input)

  # create the 3x3 conv branch with the 1x1 bottleneck convolution that performs dimensionality reduction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(input)

  branch_3x3 = keras.layers.ZeroPadding2D(padding=1)(branch_3x3)
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[1],
                                   kernel_size=3,
                                   strides=1,
                                   padding="valid",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(branch_3x3)

  # create the 5x5 conv branch with the 1x1 bottleneck convolution that performs dimensionality reduction
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(input)

  branch_5x5 = keras.layers.ZeroPadding2D(padding=1)(branch_5x5)
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[1],
                                   kernel_size=3,
                                   strides=1,
                                   padding="valid",
                                   activation='relu',
                                   kernel_initializer='glorot_uniform')(branch_5x5)

  # create the max pooling branch with 1x1 linear projection for dimensionality expansion
  branch_pool = keras.layers.MaxPooling2D(pool_size=3,
                                          strides=1,
                                          padding="same")(input)

  branch_pool = keras.layers.Conv2D(filters=filter_pool[0],
                                    kernel_size=1,
                                    strides=1,
                                    padding='same',
                                    activation='relu',
                                    kernel_initializer='glorot_uniform')(branch_pool)


  # Concatenate the output feature maps of the branches
  x = keras.layers.Concatenate()([branch_1x1, branch_3x3, branch_5x5, branch_pool])

  return x

# %% [markdown]
# ### Inception Group

# %%
def group(x, blocks, pooling=True, classes=1000):
  '''
  Build an Inception group.

  x       : input to the inception group
  blocks  : list of tuples containing nr. of filters for each block in the group
  pooling : flag indicating whether to end the group with max pooling
  classes : nr. of classes for auxiliary classifier
  '''

  # list to save the auxiliary outputs
  aux = []

  # build the inception blocks
  for block in blocks:

    # adding the auxiliary classifier
    if block is None:
      # save the auxiliary output
      aux.append(auxiliary(x,classes))

    else:
       # create inception block
       x = inception_block(x,
                           block[0],
                           block[1],
                           block[2],
                           block[3])


  # if pooling is True
  if pooling:
    # zero-padding
    x = keras.layers.ZeroPadding2D(padding=(1,1))(x)

    # max pooling
    x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)


  return x, aux

# %% [markdown]
# Now, we can finally build the learner component of Inception v1:

# %%
def learner(x, classes):
  '''
  Build the learner component.

  x       : input to the learner
  classes : nr. of classes
  '''

  # a list to store outputs from the auxiliary classifiers
  aux = []

  # set the block specs for group 3
  blocks = [((64,),  (96,128),   (16, 32), (32,)),
            ((128,), (128, 192), (32, 96), (64,))]

  # build group 3
  x, o = group(x, blocks)
  aux += o

  # set block spec for group 4
  blocks = [((192,),  (96, 208), (16, 48), (64,)),
            None,
            ((160,), (112, 224), (24, 64), (64,)),
            ((128,), (128, 256), (24, 64), (64,)),
            ((112,), (144, 288), (32, 64), (64,)),
            None,
            ((256,), (160, 320), (32, 128), (128,))]

  # build group 4
  x, o = group(x, blocks, classes=classes)
  aux += o

  # set block specs for group 5
  blocks = [((256,), (160, 320), (32, 128), (128,)),
            ((384,), (192, 384), (48, 128), (128,))]
  # build group 5
  x, o = group(x, blocks, pooling=False)
  aux += o


  return x, aux

# %% [markdown]
# ## The task component

# %%
def task(x, classes, dropout=0.4):
  '''
  Build the task component.

  x       : input to the task component
  classes : nr. of output classes
  dropout : dropout rate
  '''

  # a 7x7 average pooling
  x = keras.layers.AveragePooling2D(pool_size=7)(x)

  # flatten the output from the avg pooling
  x = keras.layers.Flatten()(x)

  # dropout for regularization
  x = keras.layers.Dropout(rate=dropout)(x)

  # softmax layer
  outputs = keras.layers.Dense(units=classes,
                               activation="softmax",
                               kernel_initializer="glorot_uniform")(x)

  return outputs

# %% [markdown]
# ## Inception model v1

# %%
def build_model(shape=(224, 224, 3), dropout=0.4):

  # define inputs
  inputs = keras.layers.Input(shape=shape)

  # the stem component
  x = stem(inputs)

  # the learner component
  x, aux = learner(x, 1000)

  # the task component
  outputs = task(x, 1000, dropout)

  # build the model
  model = keras.Model(inputs=inputs,
                      outputs=[outputs] + aux,
                      name="inception_v1")

  return model

# %%
# create the inception model (v1)
inception_model_v1 = build_model()

# print a summary
inception_model_v1.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_11 (ZeroPadding  (None, 230, 230, 3)  0          ['input_5[0][0]']
#  2D)
#
#  conv2d_11 (Conv2D)             (None, 112, 112, 64  9472        ['zero_padding2d_11[0][0]']
#                                 )
#
#  zero_padding2d_12 (ZeroPadding  (None, 114, 114, 64  0          ['conv2d_11[0][0]']
#  2D)                            )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 64)  0           ['zero_padding2d_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   4160        ['max_pooling2d_4[0][0]']
#
#  zero_padding2d_13 (ZeroPadding  (None, 58, 58, 64)  0           ['conv2d_12[0][0]']
#  2D)
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 192)  110784      ['zero_padding2d_13[0][0]']
#
#  zero_padding2d_14 (ZeroPadding  (None, 58, 58, 192)  0          ['conv2d_13[0][0]']
#  2D)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 192)  0          ['zero_padding2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 96)   18528       ['max_pooling2d_5[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 16)   3088        ['max_pooling2d_5[0][0]']
#
#  zero_padding2d_15 (ZeroPadding  (None, 30, 30, 96)  0           ['conv2d_15[0][0]']
#  2D)
#
#  zero_padding2d_16 (ZeroPadding  (None, 30, 30, 16)  0           ['conv2d_17[0][0]']
#  2D)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 64)   12352       ['max_pooling2d_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 128)  110720      ['zero_padding2d_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 32)   4640        ['zero_padding2d_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 32)   6176        ['max_pooling2d_6[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d_14[0][0]',
#                                                                   'conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 32)   8224        ['concatenate[0][0]']
#
#  zero_padding2d_17 (ZeroPadding  (None, 30, 30, 128)  0          ['conv2d_21[0][0]']
#  2D)
#
#  zero_padding2d_18 (ZeroPadding  (None, 30, 30, 32)  0           ['conv2d_23[0][0]']
#  2D)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 28, 28, 256)  0          ['concatenate[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 192)  221376      ['zero_padding2d_17[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 96)   27744       ['zero_padding2d_18[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 64)   16448       ['max_pooling2d_7[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 480)  0           ['conv2d_20[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  zero_padding2d_19 (ZeroPadding  (None, 30, 30, 480)  0          ['concatenate_1[0][0]']
#  2D)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 480)  0          ['zero_padding2d_19[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 96)   46176       ['max_pooling2d_8[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 16)   7696        ['max_pooling2d_8[0][0]']
#
#  zero_padding2d_20 (ZeroPadding  (None, 16, 16, 96)  0           ['conv2d_27[0][0]']
#  2D)
#
#  zero_padding2d_21 (ZeroPadding  (None, 16, 16, 16)  0           ['conv2d_29[0][0]']
#  2D)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 480)  0          ['max_pooling2d_8[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 192)  92352       ['max_pooling2d_8[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 208)  179920      ['zero_padding2d_20[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 48)   6960        ['zero_padding2d_21[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 64)   30784       ['max_pooling2d_9[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_26[0][0]',
#                                                                   'conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_2[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_2[0][0]']
#
#  zero_padding2d_22 (ZeroPadding  (None, 16, 16, 112)  0          ['conv2d_34[0][0]']
#  2D)
#
#  zero_padding2d_23 (ZeroPadding  (None, 16, 16, 24)  0           ['conv2d_36[0][0]']
#  2D)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_2[0][0]']
#  )
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 160)  82080       ['concatenate_2[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 224)  226016      ['zero_padding2d_22[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 64)   13888       ['zero_padding2d_23[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_10[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_33[0][0]',
#                                                                   'conv2d_35[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_3[0][0]']
#
#  zero_padding2d_24 (ZeroPadding  (None, 16, 16, 128)  0          ['conv2d_40[0][0]']
#  2D)
#
#  zero_padding2d_25 (ZeroPadding  (None, 16, 16, 24)  0           ['conv2d_42[0][0]']
#  2D)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_3[0][0]']
#  )
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 256)  295168      ['zero_padding2d_24[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 64)   13888       ['zero_padding2d_25[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_11[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_39[0][0]',
#                                                                   'conv2d_41[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 144)  73872       ['concatenate_4[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 32)   16416       ['concatenate_4[0][0]']
#
#  zero_padding2d_26 (ZeroPadding  (None, 16, 16, 144)  0          ['conv2d_46[0][0]']
#  2D)
#
#  zero_padding2d_27 (ZeroPadding  (None, 16, 16, 32)  0           ['conv2d_48[0][0]']
#  2D)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_4[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_4[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 288)  373536      ['zero_padding2d_26[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 64)   18496       ['zero_padding2d_27[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_12[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 14, 14, 528)  0           ['conv2d_45[0][0]',
#                                                                   'conv2d_47[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 160)  84640       ['concatenate_5[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 32)   16928       ['concatenate_5[0][0]']
#
#  zero_padding2d_28 (ZeroPadding  (None, 16, 16, 160)  0          ['conv2d_53[0][0]']
#  2D)
#
#  zero_padding2d_29 (ZeroPadding  (None, 16, 16, 32)  0           ['conv2d_55[0][0]']
#  2D)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 14, 14, 528)  0          ['concatenate_5[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 256)  135424      ['concatenate_5[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 320)  461120      ['zero_padding2d_28[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 128)  36992       ['zero_padding2d_29[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 128)  67712       ['max_pooling2d_13[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 832)  0           ['conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_56[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  zero_padding2d_30 (ZeroPadding  (None, 16, 16, 832)  0          ['concatenate_6[0][0]']
#  2D)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 7, 7, 832)   0           ['zero_padding2d_30[0][0]']
#  )
#
#  conv2d_59 (Conv2D)             (None, 7, 7, 160)    133280      ['max_pooling2d_14[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 7, 7, 32)     26656       ['max_pooling2d_14[0][0]']
#
#  zero_padding2d_31 (ZeroPadding  (None, 9, 9, 160)   0           ['conv2d_59[0][0]']
#  2D)
#
#  zero_padding2d_32 (ZeroPadding  (None, 9, 9, 32)    0           ['conv2d_61[0][0]']
#  2D)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 7, 7, 832)   0           ['max_pooling2d_14[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 256)    213248      ['max_pooling2d_14[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 7, 7, 320)    461120      ['zero_padding2d_31[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 7, 7, 128)    36992       ['zero_padding2d_32[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_15[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 7, 7, 832)    0           ['conv2d_58[0][0]',
#                                                                   'conv2d_60[0][0]',
#                                                                   'conv2d_62[0][0]',
#                                                                   'conv2d_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 7, 7, 192)    159936      ['concatenate_7[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 7, 7, 48)     39984       ['concatenate_7[0][0]']
#
#  zero_padding2d_33 (ZeroPadding  (None, 9, 9, 192)   0           ['conv2d_65[0][0]']
#  2D)
#
#  zero_padding2d_34 (ZeroPadding  (None, 9, 9, 48)    0           ['conv2d_67[0][0]']
#  2D)
#
#  max_pooling2d_16 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_64 (Conv2D)             (None, 7, 7, 384)    319872      ['concatenate_7[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 7, 7, 384)    663936      ['zero_padding2d_33[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 7, 7, 128)    55424       ['zero_padding2d_34[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_16[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 512)   0           ['concatenate_2[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 528)   0           ['concatenate_5[0][0]']
#  oling2D)
#
#  concatenate_8 (Concatenate)    (None, 7, 7, 1024)   0           ['conv2d_64[0][0]',
#                                                                   'conv2d_66[0][0]',
#                                                                   'conv2d_68[0][0]',
#                                                                   'conv2d_69[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 4, 4, 128)    65664       ['average_pooling2d[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 4, 4, 128)    67712       ['average_pooling2d_1[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 1024)  0           ['concatenate_8[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['conv2d_32[0][0]']
#
#  flatten_1 (Flatten)            (None, 2048)         0           ['conv2d_51[0][0]']
#
#  flatten_2 (Flatten)            (None, 1024)         0           ['average_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 1024)         2098176     ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 1024)         2098176     ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['flatten_2[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 1000)         1025000     ['dropout_2[0][0]']
#
#  dense_1 (Dense)                (None, 1000)         1025000     ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 1000)         1025000     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 12,997,352
# Trainable params: 12,997,352
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Inception v2

# %% [markdown]
# ## The stem component

# %%
def stem(inputs):
  '''
  Build the stem component of Inception v1.
  It extracts the coarse-level features of the input.

  input: the input image
  '''

  # apply ZeroPadding so that the size of the input is preserved
  x = keras.layers.ZeroPadding2D(padding=3)(inputs)

  # apply a strided 7x7 convolution to extract features
  # it will generate 64 output feature maps
  x = keras.layers.Conv2D(filters=64,
                          kernel_size=7,
                          strides=2,
                          padding="valid",
                          use_bias=False,
                          kernel_initializer="glorot_uniform"
                          )(x)

  # a BatchNormalization layer followed by a ReLu activation layer
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # again, apply ZeroPadding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # apply strided max pooling with a 3x3 window
  # the size of each feature map will be reduced by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)

  # apply a 1x1 convolution
  x = keras.layers.Conv2D(filters = 64,
                          kernel_size=1,
                          padding="same",
                          use_bias = False,
                          kernel_initializer="glorot_uniform")(x)

  # a BatchNormalization layer followed by a ReLu activation layer
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # zero-padding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # a 3x3 convolution; it will output 192 feature maps
  x = keras.layers.Conv2D(filters=192,
                          kernel_size=3,
                          strides=1,
                          padding="valid",
                          use_bias=False,
                          kernel_initializer="glorot_uniform"
                          )(x)

  # a BatchNormalization layer followed by a ReLu activation layer
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # zero-padding
  x = keras.layers.ZeroPadding2D(padding=1)(x)

  # apply strided max pooling with a 3x3 window
  # the size of each feature map will be reduced by 75%
  x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)


  return x

# %% [markdown]
# ## The learner component

# %% [markdown]
# ### Auxiliary Classifier

# %%
def auxiliary(x, classes):
  '''
  Build the auxiliary classifier.

  x       : input to the auxiliary classifier
  classes : number of output classes
  '''

  # strided average pooling operation with a 5x5 window
  x = keras.layers.AveragePooling2D(pool_size=5, strides=3)(x)

  # a 1x1 convolution which will output 128 feature maps
  x = keras.layers.Conv2D(filters=128,
                          kernel_size=1,
                          padding="same",
                          use_bias=False,
                          kernel_initializer="glorot_uniform"
                          )(x)

  # a BatchNormalization layer followed by a ReLU action layer
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.ReLU()(x)

  # flatten the feature maps before passing them to the Dense layer
  x = keras.layers.Flatten()(x)

  # a fully connected layer with 1024 neurons
  x = keras.layers.Dense(units=1024,
                         activation="relu",
                         kernel_initializer="glorot_uniform")(x)

  # dropout layer for regularization
  x = keras.layers.Dropout(rate=0.7)(x)

  # softmax layer to output probabilities for each class
  output = keras.layers.Dense(units=classes,
                              activation="softmax",
                              kernel_initializer="glorot_uniform")(x)


  return output

# %% [markdown]
# ### Inception Block

# %%
def inception_block(input, filters_1x1, filters_3x3, filters_5x5, filter_pool):
  '''
  Build the inception block/module.

  input : input to the inception block/module
  filters_1x1 : nr. of filters for the 1x1 conv branch of the inception module
  filters_3x3 : nr. of filters for the 3x3 conv branch of the inception model
  filters_5x5 : nr. of filters for the 5x5 conv branch of the inception module
  filters_pool: nr. of filters for the max pooling branch of the inception module
  '''

  # create the 1x1 conv branch with a BatchNormalization followed by a ReLU activation
  branch_1x1 = keras.layers.Conv2D(filters=filters_1x1[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(input)

  branch_1x1 = keras.layers.BatchNormalization()(branch_1x1)
  branch_1x1 = keras.layers.ReLU()(branch_1x1)

  # create the 3x3 conv branch with the 1x1 bottleneck convolution that performs dimensionality reduction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(input)

  # a BatchNormalization layer followed by a ReLU action layer
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)

  # zero-padding
  branch_3x3 = keras.layers.ZeroPadding2D(padding=1)(branch_3x3)

  # a 3x3 conv layer for feature extraction
  branch_3x3 = keras.layers.Conv2D(filters=filters_3x3[1],
                                   kernel_size=3,
                                   strides=1,
                                   padding="valid",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(branch_3x3)

  # a BatchNormalization layer followed by a ReLU activation layer
  branch_3x3 = keras.layers.BatchNormalization()(branch_3x3)
  branch_3x3 = keras.layers.ReLU()(branch_3x3)


  # create the 5x5 conv branch with the 1x1 bottleneck convolution that performs dimensionality reduction
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[0],
                                   kernel_size=1,
                                   strides=1,
                                   padding="same",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(input)

  # a BatchNormalization layer followed by a ReLU activation layer
  branch_5x5 = keras.layers.BatchNormalization()(branch_5x5)
  branch_5x5 = keras.layers.ReLU()(branch_5x5)

  # zero-padding
  branch_5x5 = keras.layers.ZeroPadding2D(padding=1)(branch_5x5)

  # a 3x3 convolution layer
  branch_5x5 = keras.layers.Conv2D(filters=filters_5x5[1],
                                   kernel_size=3,
                                   strides=1,
                                   padding="valid",
                                   use_bias=False,
                                   kernel_initializer='glorot_uniform')(branch_5x5)

  # a BatchNormalization layer followed by a ReLU activation layer
  branch_5x5 = keras.layers.BatchNormalization()(branch_5x5)
  branch_5x5 = keras.layers.ReLU()(branch_5x5)


  # create the max pooling branch with 1x1 linear projection for dimensionality expansion
  branch_pool = keras.layers.MaxPooling2D(pool_size=3,
                                          strides=1,
                                          padding="same")(input)

  # a 1x1 convolution layer
  branch_pool = keras.layers.Conv2D(filters=filter_pool[0],
                                    kernel_size=1,
                                    strides=1,
                                    padding='same',
                                    use_bias=False,
                                    kernel_initializer='glorot_uniform')(branch_pool)
  # a BatchNormalization layer followed by a ReLU activation layer
  branch_pool = keras.layers.BatchNormalization()(branch_pool)
  branch_pool = keras.layers.ReLU()(branch_pool)

  # Concatenate the output feature maps of the branches
  x = keras.layers.Concatenate()([branch_1x1, branch_3x3, branch_5x5, branch_pool])

  return x

# %% [markdown]
# ### Inception Group

# %%
def group(x, blocks, pooling=True, classes=1000):
  '''
  Build an Inception group.

  x       : input to the inception group
  blocks  : list of tuples containing nr. of filters for each block in the group
  pooling : flag indicating whether to end the group with max pooling
  classes : nr. of classes for auxiliary classifier
  '''

  # list to save the auxiliary outputs
  aux = []

  # build the inception blocks
  for block in blocks:

    # adding the auxiliary classifier
    if block is None:
      # save the auxiliary output
      aux.append(auxiliary(x,classes))

    else:
       # create inception block
       x = inception_block(x,
                           block[0],
                           block[1],
                           block[2],
                           block[3])


  # if pooling is True
  if pooling:
    # zero-padding
    x = keras.layers.ZeroPadding2D(padding=(1,1))(x)

    # max pooling
    x = keras.layers.MaxPooling2D(pool_size=3, strides=2)(x)


  return x, aux

# %% [markdown]
# Finally, we can build the learner component as follows:

# %%
def learner(x, classes):
  """ Build the learner component.

      x        : input to the learner
      classes: number of output classes
  """

  # a list to keep track of the auxiliary classifiers
  aux = []

  # the block specs for group 3
  blocks = [((64,),  (96,128),   (16, 32), (32,)),
              ((128,), (128, 192), (32, 96), (64,))]
  # build group 3
  x, o = group(x, blocks)
  aux += o

  # the block specs for group 4
  blocks = [((192,),  (96, 208), (16, 48), (64,)),
            None,
            ((160,), (112, 224), (24, 64), (64,)),
            ((128,), (128, 256), (24, 64), (64,)),
            ((112,), (144, 288), (32, 64), (64,)),
            None,
            ((256,), (160, 320), (32, 128), (128,))]
  # build group 4
  x, o = group(x, blocks, classes=classes)
  aux += o

  # the block specs for group 5
  blocks = [((256,), (160, 320), (32, 128), (128,)),
            ((384,), (192, 384), (48, 128), (128,))]
  # build group 5
  x, o = group(x, blocks, pooling=False)
  aux += o


  return x, aux

# %% [markdown]
# ## The task component

# %%
def task(x, classes, dropout=0.4):
  '''
  Build the task component.

  x       : input to the task component
  classes : nr. of output classes
  dropout : dropout rate
  '''

  # a 7x7 average pooling
  x = keras.layers.AveragePooling2D(pool_size=7)(x)

  # flatten the output from the avg pooling
  x = keras.layers.Flatten()(x)

  # dropout for regularization
  x = keras.layers.Dropout(rate=dropout)(x)

  # softmax layer
  outputs = keras.layers.Dense(units=classes,
                               activation="softmax",
                               kernel_initializer="glorot_uniform")(x)

  return outputs

# %% [markdown]
# ## Inception model v2

# %%
def build_model(shape=(224, 224, 3), dropout=0.4):

  # define inputs
  inputs = keras.layers.Input(shape=shape)

  # the stem component
  x = stem(inputs)

  # the learner component
  x, aux = learner(x, 1000)

  # the task component
  outputs = task(x, 1000, dropout)

  # build the model
  model = keras.Model(inputs=inputs,
                      outputs=[outputs] + aux,
                      name="inception_v2")

  return model

# %%
# create the inception model (v1)
inception_model_v2 = build_model()

# print a summary
inception_model_v2.summary()
# Out:
# Model: "inception_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_24 (ZeroPadding  (None, 230, 230, 3)  0          ['input_2[0][0]']
#  2D)
#
#  conv2d_59 (Conv2D)             (None, 112, 112, 64  9408        ['zero_padding2d_24[0][0]']
#                                 )
#
#  batch_normalization_59 (BatchN  (None, 112, 112, 64  256        ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  re_lu_59 (ReLU)                (None, 112, 112, 64  0           ['batch_normalization_59[0][0]']
#                                 )
#
#  zero_padding2d_25 (ZeroPadding  (None, 114, 114, 64  0          ['re_lu_59[0][0]']
#  2D)                            )
#
#  max_pooling2d_13 (MaxPooling2D  (None, 56, 56, 64)  0           ['zero_padding2d_25[0][0]']
#  )
#
#  conv2d_60 (Conv2D)             (None, 56, 56, 64)   4096        ['max_pooling2d_13[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 56, 56, 64)  256         ['conv2d_60[0][0]']
#  ormalization)
#
#  re_lu_60 (ReLU)                (None, 56, 56, 64)   0           ['batch_normalization_60[0][0]']
#
#  zero_padding2d_26 (ZeroPadding  (None, 58, 58, 64)  0           ['re_lu_60[0][0]']
#  2D)
#
#  conv2d_61 (Conv2D)             (None, 56, 56, 192)  110592      ['zero_padding2d_26[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 56, 56, 192)  768        ['conv2d_61[0][0]']
#  ormalization)
#
#  re_lu_61 (ReLU)                (None, 56, 56, 192)  0           ['batch_normalization_61[0][0]']
#
#  zero_padding2d_27 (ZeroPadding  (None, 58, 58, 192)  0          ['re_lu_61[0][0]']
#  2D)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 28, 28, 192)  0          ['zero_padding2d_27[0][0]']
#  )
#
#  conv2d_63 (Conv2D)             (None, 28, 28, 96)   18432       ['max_pooling2d_14[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 28, 28, 16)   3072        ['max_pooling2d_14[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 28, 28, 96)  384         ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_65 (BatchN  (None, 28, 28, 16)  64          ['conv2d_65[0][0]']
#  ormalization)
#
#  re_lu_63 (ReLU)                (None, 28, 28, 96)   0           ['batch_normalization_63[0][0]']
#
#  re_lu_65 (ReLU)                (None, 28, 28, 16)   0           ['batch_normalization_65[0][0]']
#
#  zero_padding2d_28 (ZeroPadding  (None, 30, 30, 96)  0           ['re_lu_63[0][0]']
#  2D)
#
#  zero_padding2d_29 (ZeroPadding  (None, 30, 30, 16)  0           ['re_lu_65[0][0]']
#  2D)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 28, 28, 192)  0          ['max_pooling2d_14[0][0]']
#  )
#
#  conv2d_62 (Conv2D)             (None, 28, 28, 64)   12288       ['max_pooling2d_14[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 28, 28, 128)  110592      ['zero_padding2d_28[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 28, 28, 32)   4608        ['zero_padding2d_29[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 28, 28, 32)   6144        ['max_pooling2d_15[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 28, 28, 64)  256         ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (None, 28, 28, 128)  512        ['conv2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_66 (BatchN  (None, 28, 28, 32)  128         ['conv2d_66[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 28, 28, 32)  128         ['conv2d_67[0][0]']
#  ormalization)
#
#  re_lu_62 (ReLU)                (None, 28, 28, 64)   0           ['batch_normalization_62[0][0]']
#
#  re_lu_64 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_64[0][0]']
#
#  re_lu_66 (ReLU)                (None, 28, 28, 32)   0           ['batch_normalization_66[0][0]']
#
#  re_lu_67 (ReLU)                (None, 28, 28, 32)   0           ['batch_normalization_67[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 256)  0           ['re_lu_62[0][0]',
#                                                                   're_lu_64[0][0]',
#                                                                   're_lu_66[0][0]',
#                                                                   're_lu_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 28, 28, 128)  32768       ['concatenate_9[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 28, 28, 32)   8192        ['concatenate_9[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 28, 28, 128)  512        ['conv2d_69[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (None, 28, 28, 32)  128         ['conv2d_71[0][0]']
#  ormalization)
#
#  re_lu_69 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_69[0][0]']
#
#  re_lu_71 (ReLU)                (None, 28, 28, 32)   0           ['batch_normalization_71[0][0]']
#
#  zero_padding2d_30 (ZeroPadding  (None, 30, 30, 128)  0          ['re_lu_69[0][0]']
#  2D)
#
#  zero_padding2d_31 (ZeroPadding  (None, 30, 30, 32)  0           ['re_lu_71[0][0]']
#  2D)
#
#  max_pooling2d_16 (MaxPooling2D  (None, 28, 28, 256)  0          ['concatenate_9[0][0]']
#  )
#
#  conv2d_68 (Conv2D)             (None, 28, 28, 128)  32768       ['concatenate_9[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 28, 28, 192)  221184      ['zero_padding2d_30[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 28, 28, 96)   27648       ['zero_padding2d_31[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 28, 28, 64)   16384       ['max_pooling2d_16[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 28, 28, 128)  512        ['conv2d_68[0][0]']
#  ormalization)
#
#  batch_normalization_70 (BatchN  (None, 28, 28, 192)  768        ['conv2d_70[0][0]']
#  ormalization)
#
#  batch_normalization_72 (BatchN  (None, 28, 28, 96)  384         ['conv2d_72[0][0]']
#  ormalization)
#
#  batch_normalization_73 (BatchN  (None, 28, 28, 64)  256         ['conv2d_73[0][0]']
#  ormalization)
#
#  re_lu_68 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_68[0][0]']
#
#  re_lu_70 (ReLU)                (None, 28, 28, 192)  0           ['batch_normalization_70[0][0]']
#
#  re_lu_72 (ReLU)                (None, 28, 28, 96)   0           ['batch_normalization_72[0][0]']
#
#  re_lu_73 (ReLU)                (None, 28, 28, 64)   0           ['batch_normalization_73[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 480)  0           ['re_lu_68[0][0]',
#                                                                   're_lu_70[0][0]',
#                                                                   're_lu_72[0][0]',
#                                                                   're_lu_73[0][0]']
#
#  zero_padding2d_32 (ZeroPadding  (None, 30, 30, 480)  0          ['concatenate_10[0][0]']
#  2D)
#
#  max_pooling2d_17 (MaxPooling2D  (None, 14, 14, 480)  0          ['zero_padding2d_32[0][0]']
#  )
#
#  conv2d_75 (Conv2D)             (None, 14, 14, 96)   46080       ['max_pooling2d_17[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 14, 14, 16)   7680        ['max_pooling2d_17[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 14, 14, 96)  384         ['conv2d_75[0][0]']
#  ormalization)
#
#  batch_normalization_77 (BatchN  (None, 14, 14, 16)  64          ['conv2d_77[0][0]']
#  ormalization)
#
#  re_lu_75 (ReLU)                (None, 14, 14, 96)   0           ['batch_normalization_75[0][0]']
#
#  re_lu_77 (ReLU)                (None, 14, 14, 16)   0           ['batch_normalization_77[0][0]']
#
#  zero_padding2d_33 (ZeroPadding  (None, 16, 16, 96)  0           ['re_lu_75[0][0]']
#  2D)
#
#  zero_padding2d_34 (ZeroPadding  (None, 16, 16, 16)  0           ['re_lu_77[0][0]']
#  2D)
#
#  max_pooling2d_18 (MaxPooling2D  (None, 14, 14, 480)  0          ['max_pooling2d_17[0][0]']
#  )
#
#  conv2d_74 (Conv2D)             (None, 14, 14, 192)  92160       ['max_pooling2d_17[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 14, 14, 208)  179712      ['zero_padding2d_33[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 14, 14, 48)   6912        ['zero_padding2d_34[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 14, 14, 64)   30720       ['max_pooling2d_18[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 14, 14, 192)  768        ['conv2d_74[0][0]']
#  ormalization)
#
#  batch_normalization_76 (BatchN  (None, 14, 14, 208)  832        ['conv2d_76[0][0]']
#  ormalization)
#
#  batch_normalization_78 (BatchN  (None, 14, 14, 48)  192         ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 14, 14, 64)  256         ['conv2d_79[0][0]']
#  ormalization)
#
#  re_lu_74 (ReLU)                (None, 14, 14, 192)  0           ['batch_normalization_74[0][0]']
#
#  re_lu_76 (ReLU)                (None, 14, 14, 208)  0           ['batch_normalization_76[0][0]']
#
#  re_lu_78 (ReLU)                (None, 14, 14, 48)   0           ['batch_normalization_78[0][0]']
#
#  re_lu_79 (ReLU)                (None, 14, 14, 64)   0           ['batch_normalization_79[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 14, 14, 512)  0           ['re_lu_74[0][0]',
#                                                                   're_lu_76[0][0]',
#                                                                   're_lu_78[0][0]',
#                                                                   're_lu_79[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 14, 14, 112)  57344       ['concatenate_11[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 14, 14, 24)   12288       ['concatenate_11[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 14, 14, 112)  448        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_84 (BatchN  (None, 14, 14, 24)  96          ['conv2d_84[0][0]']
#  ormalization)
#
#  re_lu_82 (ReLU)                (None, 14, 14, 112)  0           ['batch_normalization_82[0][0]']
#
#  re_lu_84 (ReLU)                (None, 14, 14, 24)   0           ['batch_normalization_84[0][0]']
#
#  zero_padding2d_35 (ZeroPadding  (None, 16, 16, 112)  0          ['re_lu_82[0][0]']
#  2D)
#
#  zero_padding2d_36 (ZeroPadding  (None, 16, 16, 24)  0           ['re_lu_84[0][0]']
#  2D)
#
#  max_pooling2d_19 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_11[0][0]']
#  )
#
#  conv2d_81 (Conv2D)             (None, 14, 14, 160)  81920       ['concatenate_11[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 14, 14, 224)  225792      ['zero_padding2d_35[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 14, 14, 64)   13824       ['zero_padding2d_36[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 14, 14, 64)   32768       ['max_pooling2d_19[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 14, 14, 160)  640        ['conv2d_81[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 14, 14, 224)  896        ['conv2d_83[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (None, 14, 14, 64)  256         ['conv2d_85[0][0]']
#  ormalization)
#
#  batch_normalization_86 (BatchN  (None, 14, 14, 64)  256         ['conv2d_86[0][0]']
#  ormalization)
#
#  re_lu_81 (ReLU)                (None, 14, 14, 160)  0           ['batch_normalization_81[0][0]']
#
#  re_lu_83 (ReLU)                (None, 14, 14, 224)  0           ['batch_normalization_83[0][0]']
#
#  re_lu_85 (ReLU)                (None, 14, 14, 64)   0           ['batch_normalization_85[0][0]']
#
#  re_lu_86 (ReLU)                (None, 14, 14, 64)   0           ['batch_normalization_86[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 14, 14, 512)  0           ['re_lu_81[0][0]',
#                                                                   're_lu_83[0][0]',
#                                                                   're_lu_85[0][0]',
#                                                                   're_lu_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 128)  65536       ['concatenate_12[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 24)   12288       ['concatenate_12[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 14, 14, 128)  512        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 14, 14, 24)  96          ['conv2d_90[0][0]']
#  ormalization)
#
#  re_lu_88 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_88[0][0]']
#
#  re_lu_90 (ReLU)                (None, 14, 14, 24)   0           ['batch_normalization_90[0][0]']
#
#  zero_padding2d_37 (ZeroPadding  (None, 16, 16, 128)  0          ['re_lu_88[0][0]']
#  2D)
#
#  zero_padding2d_38 (ZeroPadding  (None, 16, 16, 24)  0           ['re_lu_90[0][0]']
#  2D)
#
#  max_pooling2d_20 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_12[0][0]']
#  )
#
#  conv2d_87 (Conv2D)             (None, 14, 14, 128)  65536       ['concatenate_12[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 256)  294912      ['zero_padding2d_37[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 14, 14, 64)   13824       ['zero_padding2d_38[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 14, 14, 64)   32768       ['max_pooling2d_20[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 14, 14, 128)  512        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_89 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_89[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 14, 14, 64)  256         ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 14, 14, 64)  256         ['conv2d_92[0][0]']
#  ormalization)
#
#  re_lu_87 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_87[0][0]']
#
#  re_lu_89 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_89[0][0]']
#
#  re_lu_91 (ReLU)                (None, 14, 14, 64)   0           ['batch_normalization_91[0][0]']
#
#  re_lu_92 (ReLU)                (None, 14, 14, 64)   0           ['batch_normalization_92[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 14, 14, 512)  0           ['re_lu_87[0][0]',
#                                                                   're_lu_89[0][0]',
#                                                                   're_lu_91[0][0]',
#                                                                   're_lu_92[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 14, 14, 144)  73728       ['concatenate_13[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 14, 14, 32)   16384       ['concatenate_13[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 14, 14, 144)  576        ['conv2d_94[0][0]']
#  ormalization)
#
#  batch_normalization_96 (BatchN  (None, 14, 14, 32)  128         ['conv2d_96[0][0]']
#  ormalization)
#
#  re_lu_94 (ReLU)                (None, 14, 14, 144)  0           ['batch_normalization_94[0][0]']
#
#  re_lu_96 (ReLU)                (None, 14, 14, 32)   0           ['batch_normalization_96[0][0]']
#
#  zero_padding2d_39 (ZeroPadding  (None, 16, 16, 144)  0          ['re_lu_94[0][0]']
#  2D)
#
#  zero_padding2d_40 (ZeroPadding  (None, 16, 16, 32)  0           ['re_lu_96[0][0]']
#  2D)
#
#  max_pooling2d_21 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_13[0][0]']
#  )
#
#  conv2d_93 (Conv2D)             (None, 14, 14, 112)  57344       ['concatenate_13[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 14, 14, 288)  373248      ['zero_padding2d_39[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 14, 14, 64)   18432       ['zero_padding2d_40[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 14, 14, 64)   32768       ['max_pooling2d_21[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 14, 14, 112)  448        ['conv2d_93[0][0]']
#  ormalization)
#
#  batch_normalization_95 (BatchN  (None, 14, 14, 288)  1152       ['conv2d_95[0][0]']
#  ormalization)
#
#  batch_normalization_97 (BatchN  (None, 14, 14, 64)  256         ['conv2d_97[0][0]']
#  ormalization)
#
#  batch_normalization_98 (BatchN  (None, 14, 14, 64)  256         ['conv2d_98[0][0]']
#  ormalization)
#
#  re_lu_93 (ReLU)                (None, 14, 14, 112)  0           ['batch_normalization_93[0][0]']
#
#  re_lu_95 (ReLU)                (None, 14, 14, 288)  0           ['batch_normalization_95[0][0]']
#
#  re_lu_97 (ReLU)                (None, 14, 14, 64)   0           ['batch_normalization_97[0][0]']
#
#  re_lu_98 (ReLU)                (None, 14, 14, 64)   0           ['batch_normalization_98[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 14, 14, 528)  0           ['re_lu_93[0][0]',
#                                                                   're_lu_95[0][0]',
#                                                                   're_lu_97[0][0]',
#                                                                   're_lu_98[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 14, 14, 160)  84480       ['concatenate_14[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 14, 14, 32)   16896       ['concatenate_14[0][0]']
#
#  batch_normalization_101 (Batch  (None, 14, 14, 160)  640        ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 14, 14, 32)  128         ['conv2d_103[0][0]']
#  Normalization)
#
#  re_lu_101 (ReLU)               (None, 14, 14, 160)  0           ['batch_normalization_101[0][0]']
#
#  re_lu_103 (ReLU)               (None, 14, 14, 32)   0           ['batch_normalization_103[0][0]']
#
#  zero_padding2d_41 (ZeroPadding  (None, 16, 16, 160)  0          ['re_lu_101[0][0]']
#  2D)
#
#  zero_padding2d_42 (ZeroPadding  (None, 16, 16, 32)  0           ['re_lu_103[0][0]']
#  2D)
#
#  max_pooling2d_22 (MaxPooling2D  (None, 14, 14, 528)  0          ['concatenate_14[0][0]']
#  )
#
#  conv2d_100 (Conv2D)            (None, 14, 14, 256)  135168      ['concatenate_14[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 14, 14, 320)  460800      ['zero_padding2d_41[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 14, 14, 128)  36864       ['zero_padding2d_42[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 14, 14, 128)  67584       ['max_pooling2d_22[0][0]']
#
#  batch_normalization_100 (Batch  (None, 14, 14, 256)  1024       ['conv2d_100[0][0]']
#  Normalization)
#
#  batch_normalization_102 (Batch  (None, 14, 14, 320)  1280       ['conv2d_102[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 14, 14, 128)  512        ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 14, 14, 128)  512        ['conv2d_105[0][0]']
#  Normalization)
#
#  re_lu_100 (ReLU)               (None, 14, 14, 256)  0           ['batch_normalization_100[0][0]']
#
#  re_lu_102 (ReLU)               (None, 14, 14, 320)  0           ['batch_normalization_102[0][0]']
#
#  re_lu_104 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_104[0][0]']
#
#  re_lu_105 (ReLU)               (None, 14, 14, 128)  0           ['batch_normalization_105[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 14, 14, 832)  0           ['re_lu_100[0][0]',
#                                                                   're_lu_102[0][0]',
#                                                                   're_lu_104[0][0]',
#                                                                   're_lu_105[0][0]']
#
#  zero_padding2d_43 (ZeroPadding  (None, 16, 16, 832)  0          ['concatenate_15[0][0]']
#  2D)
#
#  max_pooling2d_23 (MaxPooling2D  (None, 7, 7, 832)   0           ['zero_padding2d_43[0][0]']
#  )
#
#  conv2d_107 (Conv2D)            (None, 7, 7, 160)    133120      ['max_pooling2d_23[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 7, 32)     26624       ['max_pooling2d_23[0][0]']
#
#  batch_normalization_107 (Batch  (None, 7, 7, 160)   640         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_109 (Batch  (None, 7, 7, 32)    128         ['conv2d_109[0][0]']
#  Normalization)
#
#  re_lu_107 (ReLU)               (None, 7, 7, 160)    0           ['batch_normalization_107[0][0]']
#
#  re_lu_109 (ReLU)               (None, 7, 7, 32)     0           ['batch_normalization_109[0][0]']
#
#  zero_padding2d_44 (ZeroPadding  (None, 9, 9, 160)   0           ['re_lu_107[0][0]']
#  2D)
#
#  zero_padding2d_45 (ZeroPadding  (None, 9, 9, 32)    0           ['re_lu_109[0][0]']
#  2D)
#
#  max_pooling2d_24 (MaxPooling2D  (None, 7, 7, 832)   0           ['max_pooling2d_23[0][0]']
#  )
#
#  conv2d_106 (Conv2D)            (None, 7, 7, 256)    212992      ['max_pooling2d_23[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 7, 7, 320)    460800      ['zero_padding2d_44[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 7, 128)    36864       ['zero_padding2d_45[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 7, 7, 128)    106496      ['max_pooling2d_24[0][0]']
#
#  batch_normalization_106 (Batch  (None, 7, 7, 256)   1024        ['conv2d_106[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 7, 7, 320)   1280        ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 7, 7, 128)   512         ['conv2d_110[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 7, 7, 128)   512         ['conv2d_111[0][0]']
#  Normalization)
#
#  re_lu_106 (ReLU)               (None, 7, 7, 256)    0           ['batch_normalization_106[0][0]']
#
#  re_lu_108 (ReLU)               (None, 7, 7, 320)    0           ['batch_normalization_108[0][0]']
#
#  re_lu_110 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_110[0][0]']
#
#  re_lu_111 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_111[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 7, 7, 832)    0           ['re_lu_106[0][0]',
#                                                                   're_lu_108[0][0]',
#                                                                   're_lu_110[0][0]',
#                                                                   're_lu_111[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 7, 192)    159744      ['concatenate_16[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 7, 7, 48)     39936       ['concatenate_16[0][0]']
#
#  batch_normalization_113 (Batch  (None, 7, 7, 192)   768         ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 7, 7, 48)    192         ['conv2d_115[0][0]']
#  Normalization)
#
#  re_lu_113 (ReLU)               (None, 7, 7, 192)    0           ['batch_normalization_113[0][0]']
#
#  re_lu_115 (ReLU)               (None, 7, 7, 48)     0           ['batch_normalization_115[0][0]']
#
#  zero_padding2d_46 (ZeroPadding  (None, 9, 9, 192)   0           ['re_lu_113[0][0]']
#  2D)
#
#  zero_padding2d_47 (ZeroPadding  (None, 9, 9, 48)    0           ['re_lu_115[0][0]']
#  2D)
#
#  max_pooling2d_25 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_16[0][0]']
#  )
#
#  conv2d_112 (Conv2D)            (None, 7, 7, 384)    319488      ['concatenate_16[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 7, 7, 384)    663552      ['zero_padding2d_46[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 7, 7, 128)    55296       ['zero_padding2d_47[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 7, 7, 128)    106496      ['max_pooling2d_25[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 4, 4, 512)   0           ['concatenate_11[0][0]']
#  oling2D)
#
#  average_pooling2d_4 (AveragePo  (None, 4, 4, 528)   0           ['concatenate_14[0][0]']
#  oling2D)
#
#  batch_normalization_112 (Batch  (None, 7, 7, 384)   1536        ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 7, 7, 384)   1536        ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 7, 7, 128)   512         ['conv2d_116[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 7, 7, 128)   512         ['conv2d_117[0][0]']
#  Normalization)
#
#  conv2d_80 (Conv2D)             (None, 4, 4, 128)    65536       ['average_pooling2d_3[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 4, 4, 128)    67584       ['average_pooling2d_4[0][0]']
#
#  re_lu_112 (ReLU)               (None, 7, 7, 384)    0           ['batch_normalization_112[0][0]']
#
#  re_lu_114 (ReLU)               (None, 7, 7, 384)    0           ['batch_normalization_114[0][0]']
#
#  re_lu_116 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_116[0][0]']
#
#  re_lu_117 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_117[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 4, 4, 128)   512         ['conv2d_80[0][0]']
#  ormalization)
#
#  batch_normalization_99 (BatchN  (None, 4, 4, 128)   512         ['conv2d_99[0][0]']
#  ormalization)
#
#  concatenate_17 (Concatenate)   (None, 7, 7, 1024)   0           ['re_lu_112[0][0]',
#                                                                   're_lu_114[0][0]',
#                                                                   're_lu_116[0][0]',
#                                                                   're_lu_117[0][0]']
#
#  re_lu_80 (ReLU)                (None, 4, 4, 128)    0           ['batch_normalization_80[0][0]']
#
#  re_lu_99 (ReLU)                (None, 4, 4, 128)    0           ['batch_normalization_99[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 1, 1, 1024)  0           ['concatenate_17[0][0]']
#  oling2D)
#
#  flatten_3 (Flatten)            (None, 2048)         0           ['re_lu_80[0][0]']
#
#  flatten_4 (Flatten)            (None, 2048)         0           ['re_lu_99[0][0]']
#
#  flatten_5 (Flatten)            (None, 1024)         0           ['average_pooling2d_5[0][0]']
#
#  dense_5 (Dense)                (None, 1024)         2098176     ['flatten_3[0][0]']
#
#  dense_7 (Dense)                (None, 1024)         2098176     ['flatten_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 1024)         0           ['flatten_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 1024)         0           ['dense_5[0][0]']
#
#  dropout_4 (Dropout)            (None, 1024)         0           ['dense_7[0][0]']
#
#  dense_9 (Dense)                (None, 1000)         1025000     ['dropout_5[0][0]']
#
#  dense_6 (Dense)                (None, 1000)         1025000     ['dropout_3[0][0]']
#
#  dense_8 (Dense)                (None, 1000)         1025000     ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 13,019,960
# Trainable params: 13,004,888
# Non-trainable params: 15,072
# __________________________________________________________________________________________________
