# %% [markdown]
# <a href="https://colab.research.google.com/github/CelikAbdullah/deep-learning-notebooks/blob/main/Deep%20Reinforcement%20Learning%20(TF)/Policy%20Based/REINFORCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import tensorflow as tf
import numpy as np
import gym
import time
import tensorflow_probability as tfp
from itertools import count
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <

# %% [markdown]
# # Policy Network

# %% [markdown]
# This is the fully connected policy network, we will use in the REINFORCE algorithm:

# %%
class PolicyNetwork(tf.keras.Model):
  def __init__(self, input_dim, output_dim):
    super().__init__()
    self.input_dim = input_dim
    self.output_dim = output_dim
    self.model = self.get_model()

  def get_model(self):
    inputs = tf.keras.Input(shape=(None, self.input_dim))
    x = tf.keras.layers.Dense(units=128, activation="relu")(inputs)
    x = tf.keras.layers.Dense(units=64, activation="relu")(x)
    outputs = tf.keras.layers.Dense(units=self.output_dim)(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

  def _format(self, state):
    x = state
    if not isinstance(x, tf.Tensor):
      x = tf.convert_to_tensor(x)
    if tf.rank(x) == 1:
      x = tf.expand_dims(x, 0)

    return x

  def call(self, state):
    x = self._format(state)
    output = self.model(x)

    return output

  def full_pass(self, state):
    logits = self(state)
    # Create a Categorical distribution
    dist = tfp.distributions.Categorical(logits=logits)
    # sample an action from the Categorical distribution
    action = dist.sample()
    # compute the log probabilites of each action
    logpa = dist.log_prob(action)
    logpa = tf.expand_dims(logpa, axis=-1)

    return action.numpy().item(), logpa

  def select_action(self, state):
    # forward pass
    logits = self(state)
    # get a probability distribution
    dist = tfp.distributions.Categorical(logits=logits)
    # sample an action from the probability distribution
    action = dist.sample()

    return action.numpy().item()

  def select_greedy_action(self, state):
    # forward pass
    logits = self(state)
    # return index of action with the highest probability
    return np.argmax(logits)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# print summary
env = gym.make("CartPole-v1")
agent = PolicyNetwork(env.observation_space.shape[0],env.action_space.n)
agent.model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 4)]         0
#
#  dense (Dense)               (None, None, 128)         640
#
#  dense_1 (Dense)             (None, None, 64)          8256
#
#  dense_2 (Dense)             (None, None, 2)           130
#
# =================================================================
# Total params: 9,026
# Trainable params: 9,026
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # REINFORCE

# %% [markdown]
# The REINFORCE is the simplest policy-gradient algorithm. This algorithm tries to increase the log probability of all actions in a trajectory, proportional to the goodness of the full return (Monte-Carlo return). So, basically, it first collects a full trajectory, calculate the full discounted return and then use that score to weight the log probabilities of every action taken in that trajectory.
#
# The gradient we are trying to estimate is the following one:

# %% [markdown]
# $\nabla_{\theta} J(\theta) = \mathbb{E}_{\tau \sim \pi_\theta}\biggl[\sum_{t=0}^T G_t(\tau)\nabla_\theta log(\pi_\theta(A_t|S_t))\biggr]$
#
# whereas:
#
#
#
# *   $\tau \sim \pi_\theta$ means "sample a trajectory $\tau$"
# *   $\sum_{t=0}^T G_t(\tau)$ means "for each timestep t in the trajectory $\tau$, calculate the full return from that step"
# *   $log(\pi_\theta(A_t|S_t)$ is the log probability of action $A$ taken at time step t given the state $S$ at time step t
#
# As mentioned above, we use the full return $G_t$ as the score to weight the log probability of the action taken at time step t.

# %%
class REINFORCE():

  def __init__(self,
               env,
               model,
               optimizer,
               gamma,
               seed,
               max_episodes = 10000,
               max_minutes=10,
               goal=475,
               ):

    # set the attributes
    self.env = env
    self.model = model
    self.optimizer = optimizer
    self.gamma = gamma
    self.seed = seed
    self.max_episodes = max_episodes
    self.max_minutes = max_minutes
    self.goal = goal
    self.evaluation_scores = []
    self.mean_eval_scores = []


  def __interact(self, state):
    '''
    Perform the interaction with environment
    '''
    # pass the state through the policy network to
    # sample an action from the probability distribution and
    # also get the log probability of the selected action
    action, logpa = self.model.full_pass(state)
    # take the action in the environment
    next_state, reward, is_terminal, _ = self.env.step(action)
    # store the log probability of the action
    self.logpas.append(logpa)
    # store the experienced reward we get after taking the action
    self.rewards.append(reward)

    return next_state, is_terminal


  def __compute_loss(self):
    '''
    Compute the loss.
    '''

    # compute the number of rewards
    T = len(self.rewards)
    # compute the discounts for each reward
    discounts = np.logspace(0,
                            T,
                            num=T,
                            base=self.gamma,
                            endpoint=False)

    # calculate the full discounted return
    # compute the sum of the discounted returns for all time steps
    # this is the returns for every time step in the current episode
    # from the initial state at time step 0, to one before the terminal T-1
    returns = np.array([np.sum(discounts[:T-t] * self.rewards[t:]) for t in range(T)])

    # convert the discounts and returns to float tensors
    discounts = tf.convert_to_tensor(discounts, dtype="float32")
    discounts = tf.expand_dims(discounts, axis=1)
    returns = tf.convert_to_tensor(returns, dtype="float32")
    returns = tf.expand_dims(returns, axis=1)

    # concatenate the list of log probabilities
    self.logpas = tf.concat(self.logpas, axis=0)


    # now, compute the loss of the policy network
    # note that we discount the returns; this extra discount assumes
    # that we are trying to optimize the expect discounted return
    # from the initial state, so the returns later in an episode get
    # discounted
    # we also add a minus sign because PyTorch performs gradient descent by default
    # since we want to maximize the performance objective we take the negative mean of
    # the objective to flip it; as a result, the probability of "good" actions will be
    # increased and the probability of "bad" actions will be decreased
    # last but not least, we also account for discounted policy gradients, so we multiply
    # the returns by the discounts
    loss = -tf.reduce_mean(discounts * returns * self.logpas)

    return loss


  def __optimize(self, loss, tape):
    '''
    Optimize the model.
    '''
    # compute the gradients of the loss with respect to the trainable variables
    grads = tape.gradient(loss, self.model.trainable_variables)
    # update the weights
    self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))


  def __evaluate(self, episodes=1, greedy=True):
    ''' Evaluate the model. '''

    # keep track of the rewards
    rewards = []
    # for each episode (default: 1) do the following
    for _ in range(episodes):
      # get the initial state
      state = self.env.reset()
      # set is_terminal flag to False
      is_terminal = False
      # append a 0 to rewards list
      rewards.append(0)
      # for each timestep of the current episode, do the following
      for _ in count():
        if greedy:
          # select a greedy action according to the policy.
          action = self.model.select_greedy_action(state)
        else:
          # sample an action from the distribution
          action = self.model.select_action(state)

        # take the action in the environment
        state, reward, is_terminal, _ = self.env.step(action)
        # save the reward
        rewards[-1] += reward
        # finish when terminal state is reached
        if is_terminal:
          break

    # return the mean of the rewards to the caller
    return np.mean(rewards)

  def train(self):
    '''
    Train the agent.
    '''
    # get the starting time of the training phase
    training_start = time.time()
    # for each episode do the following
    for episode in range(1, self.max_episodes + 1):

      # get the initial state
      state = self.env.reset(seed=self.seed)
      # is_terminal flag to indicate whether an episode is finished
      is_terminal = False
      # list to hold the log probabilities of the actions
      self.logpas = []
      # list to hold the rewards
      self.rewards = []

      with tf.GradientTape() as tape:
        # we first collect a full trajectory
        for timestep in count():
          # interact with the environment
          state, is_terminal = self.__interact(state)
          # finish current episode if a terminal state is reached
          if is_terminal:
            break

        # compute the loss
        loss = self.__compute_loss()

      # update the weights
      self.__optimize(loss, tape)
      # compute the evaluation score
      evaluation_score = self.__evaluate()
      # store the evaluation score
      self.evaluation_scores.append(evaluation_score)
      # compute the mean evaluation score
      mean_100_eval_score = np.mean(self.evaluation_scores[-100:])
      # append mean evaluation score (will be used later for visualization)
      self.mean_eval_scores.append(mean_100_eval_score)
      print(f"Current mean evaluation score {mean_100_eval_score}") # printing for debugging purposes

      # calculate the elapsed wallclock time
      wallclock_elapsed = time.time() - training_start

      # flag indicating whether max minutes are reached or not
      reached_max_minutes = wallclock_elapsed >= self.max_minutes * 60
      # flag indicating whether max episodes are reached or not
      reached_max_episodes = episode >= self.max_episodes
      # flag indicating whether the mean reward goal is reached
      reached_goal_mean_reward = mean_100_eval_score >= self.goal

      # flag that decides whether is over or not
      training_is_over = reached_max_minutes or reached_max_episodes or reached_goal_mean_reward

      if training_is_over:
        if reached_max_minutes: print('Max minutes are reached')
        if reached_max_episodes: print('Max episodes are reached')
        if reached_goal_mean_reward: print('Goal mean reward is reached')
        break


    # compute final evaluation score
    final_evaluation_score = self.__evaluate(episodes=100)
    print(f"Final evaluation score: {final_evaluation_score}")

    self.env.close()
    del self.env

    return final_evaluation_score

# %% [markdown]
# # Train

# %%
# define the our discount factor
gamma = 1.00
# define max minutes
max_minutes = 20
# define nr. of max episodes
max_episodes = 10000
# define mean reward value
goal = 475
# define the learning rate
lr = 0.0005

current_best_agent = None
current_best_eval_score = float('-inf')
seeds = (12, 34, 56, 78, 90)

# %%
# we let five REINFORCE agents train, the one with the best evaluation score will be selected as the best one
# in each iteration, a different seed is used for creating the environment
for seed in seeds:
  print("Starting a new REINFORCE agent.")
  # create an instance of the environment
  env = gym.make("CartPole-v1")
  # obtain the number of variables used in each state and the number of actions
  state_space = env.observation_space.shape[0]
  action_space = env.action_space.n
  # build the online network
  policy_model = PolicyNetwork(state_space, action_space)
  # create an instance of the RMSprop optimizer
  optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

  # create the REINFORCE agent
  reinforce_agent = REINFORCE(env,
                              policy_model,
                              optimizer,
                              gamma,
                              seed,
                              max_episodes,
                              max_minutes,
                              goal
                              )

  # let the REINFORCE agent train
  final_evaluation_score = reinforce_agent.train()

  if final_evaluation_score > current_best_eval_score:
    current_best_eval_score = final_evaluation_score
    current_best_agent = reinforce_agent
# Out:
# Starting a new REINFORCE agent.
# Current mean evaluation score 25.0
# Current mean evaluation score 24.0
# Current mean evaluation score 23.666666666666668
# Current mean evaluation score 24.0
# Current mean evaluation score 24.8
# Current mean evaluation score 25.333333333333332
# Current mean evaluation score 26.714285714285715
# Current mean evaluation score 27.125
# Current mean evaluation score 27.444444444444443
# Current mean evaluation score 27.7
# Current mean evaluation score 27.90909090909091
# Current mean evaluation score 28.083333333333332
# Current mean evaluation score 28.23076923076923
# Current mean evaluation score 28.357142857142858
# Current mean evaluation score 28.466666666666665
# Current mean evaluation score 28.5625
# Current mean evaluation score 28.647058823529413
# Current mean evaluation score 28.11111111111111
# Current mean evaluation score 27.526315789473685
# Current mean evaluation score 26.85
# Current mean evaluation score 26.19047619047619
# Current mean evaluation score 25.545454545454547
# Current mean evaluation score 24.956521739130434
# Current mean evaluation score 24.416666666666668
# Current mean evaluation score 23.96
# Current mean evaluation score 23.53846153846154
# Current mean evaluation score 23.14814814814815
# Current mean evaluation score 22.821428571428573
# Current mean evaluation score 22.551724137931036
# Current mean evaluation score 22.433333333333334
# Current mean evaluation score 22.322580645161292
# Current mean evaluation score 22.28125
# Current mean evaluation score 22.272727272727273
# Current mean evaluation score 22.294117647058822
# Current mean evaluation score 22.314285714285713
# Current mean evaluation score 22.305555555555557
# Current mean evaluation score 22.2972972972973
# Current mean evaluation score 22.263157894736842
# Current mean evaluation score 22.23076923076923
# Current mean evaluation score 22.2
# Current mean evaluation score 22.170731707317074
# Current mean evaluation score 22.142857142857142
# Current mean evaluation score 22.11627906976744
# Current mean evaluation score 22.068181818181817
# Current mean evaluation score 21.955555555555556
# Current mean evaluation score 21.804347826086957
# Current mean evaluation score 21.659574468085108
# Current mean evaluation score 21.458333333333332
# Current mean evaluation score 21.244897959183675
# Current mean evaluation score 21.02
# Current mean evaluation score 20.80392156862745
# Current mean evaluation score 20.576923076923077
# Current mean evaluation score 20.358490566037737
# Current mean evaluation score 20.14814814814815
# Current mean evaluation score 19.945454545454545
# Current mean evaluation score 19.75
# Current mean evaluation score 19.56140350877193
# Current mean evaluation score 19.379310344827587
# Current mean evaluation score 19.203389830508474
# Current mean evaluation score 19.033333333333335
# Current mean evaluation score 18.868852459016395
# Current mean evaluation score 18.70967741935484
# Current mean evaluation score 18.555555555555557
# Current mean evaluation score 18.421875
# Current mean evaluation score 18.323076923076922
# Current mean evaluation score 18.272727272727273
# Current mean evaluation score 18.238805970149254
# Current mean evaluation score 18.264705882352942
# Current mean evaluation score 18.318840579710145
# Current mean evaluation score 18.485714285714284
# Current mean evaluation score 18.661971830985916
# Current mean evaluation score 18.84722222222222
# Current mean evaluation score 19.041095890410958
# Current mean evaluation score 19.243243243243242
# Current mean evaluation score 19.453333333333333
# Current mean evaluation score 19.657894736842106
# Current mean evaluation score 19.883116883116884
# Current mean evaluation score 20.128205128205128
# Current mean evaluation score 20.367088607594937
# Current mean evaluation score 20.6375
# Current mean evaluation score 20.901234567901234
# Current mean evaluation score 21.158536585365855
# Current mean evaluation score 21.457831325301203
# Current mean evaluation score 21.75
# Current mean evaluation score 22.03529411764706
# Current mean evaluation score 22.325581395348838
# Current mean evaluation score 22.666666666666668
# Current mean evaluation score 23.0
# Current mean evaluation score 23.325842696629213
# Current mean evaluation score 23.644444444444446
# Current mean evaluation score 23.956043956043956
# Current mean evaluation score 24.26086956521739
# Current mean evaluation score 24.688172043010752
# Current mean evaluation score 24.97872340425532
# Current mean evaluation score 25.263157894736842
# Current mean evaluation score 25.541666666666668
# Current mean evaluation score 25.814432989690722
# Current mean evaluation score 26.081632653061224
# Current mean evaluation score 26.343434343434343
# Current mean evaluation score 26.7
# Current mean evaluation score 27.07
# Current mean evaluation score 27.46
# Current mean evaluation score 27.85
# Current mean evaluation score 28.22
# Current mean evaluation score 28.56
# Current mean evaluation score 28.9
# Current mean evaluation score 29.17
# Current mean evaluation score 29.49
# Current mean evaluation score 29.83
# Current mean evaluation score 30.17
# Current mean evaluation score 30.51
# Current mean evaluation score 30.85
# Current mean evaluation score 31.19
# Current mean evaluation score 31.53
# Current mean evaluation score 31.87
# Current mean evaluation score 32.21
# Current mean evaluation score 32.55
# Current mean evaluation score 33.01
# Current mean evaluation score 33.49
# Current mean evaluation score 34.0
# Current mean evaluation score 35.28
# Current mean evaluation score 36.57
# Current mean evaluation score 37.86
# Current mean evaluation score 39.17
# Current mean evaluation score 40.47
# Current mean evaluation score 41.77
# Current mean evaluation score 43.07
# Current mean evaluation score 44.34
# Current mean evaluation score 44.84
# Current mean evaluation score 45.3
# Current mean evaluation score 45.76
# Current mean evaluation score 46.2
# Current mean evaluation score 46.63
# Current mean evaluation score 47.05
# Current mean evaluation score 47.47
# Current mean evaluation score 47.92
# Current mean evaluation score 48.37
# Current mean evaluation score 48.83
# Current mean evaluation score 49.29
# Current mean evaluation score 49.75
# Current mean evaluation score 50.21
# Current mean evaluation score 50.67
# Current mean evaluation score 51.13
# Current mean evaluation score 51.61
# Current mean evaluation score 52.12
# Current mean evaluation score 52.65
# Current mean evaluation score 53.18
# Current mean evaluation score 53.74
# Current mean evaluation score 54.31
# Current mean evaluation score 54.89
# Current mean evaluation score 55.47
# Current mean evaluation score 56.06
# Current mean evaluation score 56.65
# Current mean evaluation score 57.24
# Current mean evaluation score 57.83
# Current mean evaluation score 58.42
# Current mean evaluation score 59.01
# Current mean evaluation score 59.6
# Current mean evaluation score 60.19
# Current mean evaluation score 60.78
# Current mean evaluation score 61.25
# Current mean evaluation score 61.72
# Current mean evaluation score 62.19
# Current mean evaluation score 62.65
# Current mean evaluation score 63.09
# Current mean evaluation score 63.5
# Current mean evaluation score 63.9
# Current mean evaluation score 64.26
# Current mean evaluation score 64.6
# Current mean evaluation score 64.81
# Current mean evaluation score 65.01
# Current mean evaluation score 65.2
# Current mean evaluation score 65.38
# Current mean evaluation score 65.53
# Current mean evaluation score 65.67
# Current mean evaluation score 65.83
# Current mean evaluation score 65.97
# Current mean evaluation score 66.09
# Current mean evaluation score 66.21
# Current mean evaluation score 66.3
# Current mean evaluation score 66.39
# Current mean evaluation score 66.48
# Current mean evaluation score 66.58
# Current mean evaluation score 66.68
# Current mean evaluation score 66.78
# Current mean evaluation score 66.87
# Current mean evaluation score 66.91
# Current mean evaluation score 66.9
# Current mean evaluation score 66.89
# Current mean evaluation score 66.88
# Current mean evaluation score 66.87
# Current mean evaluation score 66.86
# Current mean evaluation score 66.73
# Current mean evaluation score 66.72
# Current mean evaluation score 66.76
# Current mean evaluation score 66.8
# Current mean evaluation score 66.85
# Current mean evaluation score 66.92
# Current mean evaluation score 66.99
# Current mean evaluation score 66.96
# Current mean evaluation score 66.93
# Current mean evaluation score 66.9
# Current mean evaluation score 66.87
# Current mean evaluation score 66.84
# Current mean evaluation score 66.81
# Current mean evaluation score 66.78
# Current mean evaluation score 66.75
# Current mean evaluation score 66.72
# Current mean evaluation score 66.69
# Current mean evaluation score 66.66
# Current mean evaluation score 66.73
# Current mean evaluation score 66.82
# Current mean evaluation score 66.91
# Current mean evaluation score 67.0
# Current mean evaluation score 67.11
# Current mean evaluation score 67.22
# Current mean evaluation score 67.33
# Current mean evaluation score 67.43
# Current mean evaluation score 67.53
# Current mean evaluation score 67.63
# Current mean evaluation score 66.97
# Current mean evaluation score 66.18
# Current mean evaluation score 65.39
# Current mean evaluation score 64.58
# Current mean evaluation score 63.77
# Current mean evaluation score 62.97
# Current mean evaluation score 62.17
# Current mean evaluation score 61.39
# Current mean evaluation score 61.37
# Current mean evaluation score 61.35
# Current mean evaluation score 61.34
# Current mean evaluation score 61.33
# Current mean evaluation score 61.32
# Current mean evaluation score 61.31
# Current mean evaluation score 61.3
# Current mean evaluation score 61.27
# Current mean evaluation score 61.24
# Current mean evaluation score 61.34
# Current mean evaluation score 61.44
# Current mean evaluation score 61.54
# Current mean evaluation score 61.64
# Current mean evaluation score 61.77
# Current mean evaluation score 61.9
# Current mean evaluation score 62.02
# Current mean evaluation score 62.14
# Current mean evaluation score 62.26
# Current mean evaluation score 65.21
# Current mean evaluation score 67.22
# Current mean evaluation score 69.25
# Current mean evaluation score 71.28
# Current mean evaluation score 73.31
# Current mean evaluation score 75.36
# Current mean evaluation score 77.41
# Current mean evaluation score 79.46
# Current mean evaluation score 81.51
# Current mean evaluation score 83.56
# Current mean evaluation score 85.62
# Current mean evaluation score 87.68
# Current mean evaluation score 87.9
# Current mean evaluation score 88.12
# Current mean evaluation score 88.46
# Current mean evaluation score 88.8
# Current mean evaluation score 89.14
# Current mean evaluation score 89.5
# Current mean evaluation score 89.86
# Current mean evaluation score 90.22
# Current mean evaluation score 90.62
# Current mean evaluation score 91.02
# Current mean evaluation score 91.42
# Current mean evaluation score 91.8
# Current mean evaluation score 92.15
# Current mean evaluation score 92.5
# Current mean evaluation score 92.85
# Current mean evaluation score 93.22
# Current mean evaluation score 93.62
# Current mean evaluation score 94.0
# Current mean evaluation score 94.46
# Current mean evaluation score 94.92
# Current mean evaluation score 95.38
# Current mean evaluation score 97.65
# Current mean evaluation score 99.48
# Current mean evaluation score 101.31
# Current mean evaluation score 102.91
# Current mean evaluation score 104.51
# Current mean evaluation score 106.11
# Current mean evaluation score 107.71
# Current mean evaluation score 109.31
# Current mean evaluation score 110.96
# Current mean evaluation score 112.61
# Current mean evaluation score 114.26
# Current mean evaluation score 115.91
# Current mean evaluation score 117.56
# Current mean evaluation score 119.21
# Current mean evaluation score 121.04
# Current mean evaluation score 122.82
# Current mean evaluation score 125.15
# Current mean evaluation score 127.44
# Current mean evaluation score 127.82
# Current mean evaluation score 128.2
# Current mean evaluation score 128.58
# Current mean evaluation score 128.96
# Current mean evaluation score 129.34
# Current mean evaluation score 131.64
# Current mean evaluation score 133.28
# Current mean evaluation score 134.92
# Current mean evaluation score 136.7
# Current mean evaluation score 138.48
# Current mean evaluation score 141.83
# Current mean evaluation score 146.22
# Current mean evaluation score 150.61
# Current mean evaluation score 154.9
# Current mean evaluation score 159.17
# Current mean evaluation score 163.44
# Current mean evaluation score 167.71
# Current mean evaluation score 171.91
# Current mean evaluation score 176.11
# Current mean evaluation score 180.36
# Current mean evaluation score 184.61
# Current mean evaluation score 188.86
# Current mean evaluation score 193.11
# Current mean evaluation score 197.36
# Current mean evaluation score 201.74
# Current mean evaluation score 206.12
# Current mean evaluation score 210.5
# Current mean evaluation score 214.88
# Current mean evaluation score 219.25
# Current mean evaluation score 223.62
# Current mean evaluation score 227.99
# Current mean evaluation score 232.36
# Current mean evaluation score 236.73
# Current mean evaluation score 241.09
# Current mean evaluation score 245.45
# Current mean evaluation score 249.81
# Current mean evaluation score 254.17
# Current mean evaluation score 258.53
# Current mean evaluation score 262.89
# Current mean evaluation score 267.25
# Current mean evaluation score 271.48
# Current mean evaluation score 275.71
# Current mean evaluation score 279.94
# Current mean evaluation score 284.17
# Current mean evaluation score 288.37
# Current mean evaluation score 292.57
# Current mean evaluation score 296.77
# Current mean evaluation score 300.97
# Current mean evaluation score 305.17
# Current mean evaluation score 306.54
# Current mean evaluation score 308.85
# Current mean evaluation score 311.14
# Current mean evaluation score 313.43
# Current mean evaluation score 315.72
# Current mean evaluation score 317.99
# Current mean evaluation score 320.26
# Current mean evaluation score 322.53
# Current mean evaluation score 324.8
# Current mean evaluation score 327.07
# Current mean evaluation score 329.33
# Current mean evaluation score 331.59
# Current mean evaluation score 335.69
# Current mean evaluation score 339.79
# Current mean evaluation score 343.89
# Current mean evaluation score 347.99
# Current mean evaluation score 352.09
# Current mean evaluation score 356.17
# Current mean evaluation score 360.25
# Current mean evaluation score 364.33
# Current mean evaluation score 368.37
# Current mean evaluation score 372.41
# Current mean evaluation score 376.45
# Current mean evaluation score 380.56
# Current mean evaluation score 384.7
# Current mean evaluation score 388.84
# Current mean evaluation score 392.98
# Current mean evaluation score 397.12
# Current mean evaluation score 401.23
# Current mean evaluation score 405.34
# Current mean evaluation score 409.37
# Current mean evaluation score 413.4
# Current mean evaluation score 417.43
# Current mean evaluation score 419.65
# Current mean evaluation score 422.31
# Current mean evaluation score 424.97
# Current mean evaluation score 427.81
# Current mean evaluation score 430.65
# Current mean evaluation score 433.49
# Current mean evaluation score 436.06
# Current mean evaluation score 438.61
# Current mean evaluation score 441.09
# Current mean evaluation score 443.93
# Current mean evaluation score 446.77
# Current mean evaluation score 449.61
# Current mean evaluation score 452.45
# Current mean evaluation score 455.29
# Current mean evaluation score 457.95
# Current mean evaluation score 460.61
# Current mean evaluation score 462.72
# Current mean evaluation score 464.86
# Current mean evaluation score 468.89
# Current mean evaluation score 472.92
# Current mean evaluation score 476.95
# Goal mean reward is reached
# Final evaluation score: 488.93
# Starting a new REINFORCE agent.
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 16.8
# Current mean evaluation score 31.545454545454547
# Current mean evaluation score 40.5
# Current mean evaluation score 49.0
# Current mean evaluation score 56.07142857142857
# Current mean evaluation score 62.666666666666664
# Current mean evaluation score 68.4375
# Current mean evaluation score 72.76470588235294
# Current mean evaluation score 76.33333333333333
# Current mean evaluation score 79.42105263157895
# Current mean evaluation score 82.2
# Current mean evaluation score 84.66666666666667
# Current mean evaluation score 86.9090909090909
# Current mean evaluation score 88.91304347826087
# Current mean evaluation score 90.75
# Current mean evaluation score 92.36
# Current mean evaluation score 93.8076923076923
# Current mean evaluation score 95.07407407407408
# Current mean evaluation score 96.03571428571429
# Current mean evaluation score 96.6896551724138
# Current mean evaluation score 97.16666666666667
# Current mean evaluation score 97.16129032258064
# Current mean evaluation score 97.15625
# Current mean evaluation score 97.03030303030303
# Current mean evaluation score 96.58823529411765
# Current mean evaluation score 96.05714285714286
# Current mean evaluation score 95.52777777777777
# Current mean evaluation score 94.75675675675676
# Current mean evaluation score 93.92105263157895
# Current mean evaluation score 93.12820512820512
# Current mean evaluation score 92.375
# Current mean evaluation score 91.7560975609756
# Current mean evaluation score 91.16666666666667
# Current mean evaluation score 90.6046511627907
# Current mean evaluation score 90.20454545454545
# Current mean evaluation score 89.82222222222222
# Current mean evaluation score 89.45652173913044
# Current mean evaluation score 89.19148936170212
# Current mean evaluation score 88.9375
# Current mean evaluation score 88.6938775510204
# Current mean evaluation score 88.46
# Current mean evaluation score 88.33333333333333
# Current mean evaluation score 88.21153846153847
# Current mean evaluation score 88.09433962264151
# Current mean evaluation score 87.92592592592592
# Current mean evaluation score 87.76363636363637
# Current mean evaluation score 87.60714285714286
# Current mean evaluation score 87.35087719298245
# Current mean evaluation score 87.10344827586206
# Current mean evaluation score 86.86440677966101
# Current mean evaluation score 86.63333333333334
# Current mean evaluation score 86.40983606557377
# Current mean evaluation score 86.19354838709677
# Current mean evaluation score 85.98412698412699
# Current mean evaluation score 85.75
# Current mean evaluation score 85.52307692307693
# Current mean evaluation score 85.3030303030303
# Current mean evaluation score 85.08955223880596
# Current mean evaluation score 84.88235294117646
# Current mean evaluation score 84.68115942028986
# Current mean evaluation score 84.48571428571428
# Current mean evaluation score 84.29577464788733
# Current mean evaluation score 84.11111111111111
# Current mean evaluation score 83.87671232876713
# Current mean evaluation score 83.64864864864865
# Current mean evaluation score 83.42666666666666
# Current mean evaluation score 83.21052631578948
# Current mean evaluation score 83.0
# Current mean evaluation score 82.7948717948718
# Current mean evaluation score 82.59493670886076
# Current mean evaluation score 82.4
# Current mean evaluation score 82.08641975308642
# Current mean evaluation score 81.78048780487805
# Current mean evaluation score 81.48192771084338
# Current mean evaluation score 81.19047619047619
# Current mean evaluation score 80.90588235294118
# Current mean evaluation score 80.59302325581395
# Current mean evaluation score 80.28735632183908
# Current mean evaluation score 79.98863636363636
# Current mean evaluation score 79.69662921348315
# Current mean evaluation score 79.41111111111111
# Current mean evaluation score 79.0989010989011
# Current mean evaluation score 78.79347826086956
# Current mean evaluation score 78.49462365591398
# Current mean evaluation score 78.20212765957447
# Current mean evaluation score 77.91578947368421
# Current mean evaluation score 77.63541666666667
# Current mean evaluation score 77.3917525773196
# Current mean evaluation score 77.15306122448979
# Current mean evaluation score 76.91919191919192
# Current mean evaluation score 76.69
# Current mean evaluation score 77.13
# Current mean evaluation score 77.57
# Current mean evaluation score 78.01
# Current mean evaluation score 78.45
# Current mean evaluation score 78.89
# Current mean evaluation score 79.33
# Current mean evaluation score 79.8
# Current mean evaluation score 80.32
# Current mean evaluation score 80.87
# Current mean evaluation score 80.74
# Current mean evaluation score 79.61
# Current mean evaluation score 78.89
# Current mean evaluation score 78.05
# Current mean evaluation score 77.24
# Current mean evaluation score 76.36
# Current mean evaluation score 75.48
# Current mean evaluation score 74.73
# Current mean evaluation score 74.03
# Current mean evaluation score 73.35
# Current mean evaluation score 72.67
# Current mean evaluation score 72.0
# Current mean evaluation score 71.33
# Current mean evaluation score 70.67
# Current mean evaluation score 69.99
# Current mean evaluation score 69.25
# Current mean evaluation score 68.52
# Current mean evaluation score 67.81
# Current mean evaluation score 67.16
# Current mean evaluation score 66.58
# Current mean evaluation score 66.14
# Current mean evaluation score 65.74
# Current mean evaluation score 65.34
# Current mean evaluation score 64.98
# Current mean evaluation score 64.73
# Current mean evaluation score 64.52
# Current mean evaluation score 64.32
# Current mean evaluation score 64.22
# Current mean evaluation score 64.16
# Current mean evaluation score 64.12
# Current mean evaluation score 64.08
# Current mean evaluation score 64.0
# Current mean evaluation score 64.04
# Current mean evaluation score 64.08
# Current mean evaluation score 64.06
# Current mean evaluation score 64.04
# Current mean evaluation score 64.02
# Current mean evaluation score 63.96
# Current mean evaluation score 63.9
# Current mean evaluation score 63.77
# Current mean evaluation score 63.64
# Current mean evaluation score 63.46
# Current mean evaluation score 63.27
# Current mean evaluation score 63.08
# Current mean evaluation score 62.93
# Current mean evaluation score 62.85
# Current mean evaluation score 62.77
# Current mean evaluation score 62.75
# Current mean evaluation score 62.73
# Current mean evaluation score 62.71
# Current mean evaluation score 62.69
# Current mean evaluation score 62.67
# Current mean evaluation score 62.65
# Current mean evaluation score 62.65
# Current mean evaluation score 62.67
# Current mean evaluation score 62.69
# Current mean evaluation score 62.74
# Current mean evaluation score 62.79
# Current mean evaluation score 62.84
# Current mean evaluation score 62.89
# Current mean evaluation score 62.94
# Current mean evaluation score 63.02
# Current mean evaluation score 63.1
# Current mean evaluation score 63.22
# Current mean evaluation score 63.34
# Current mean evaluation score 63.46
# Current mean evaluation score 63.58
# Current mean evaluation score 63.7
# Current mean evaluation score 63.82
# Current mean evaluation score 63.94
# Current mean evaluation score 64.09
# Current mean evaluation score 64.34
# Current mean evaluation score 64.63
# Current mean evaluation score 64.92
# Current mean evaluation score 65.21
# Current mean evaluation score 65.54
# Current mean evaluation score 65.9
# Current mean evaluation score 66.26
# Current mean evaluation score 66.62
# Current mean evaluation score 66.98
# Current mean evaluation score 67.47
# Current mean evaluation score 67.99
# Current mean evaluation score 68.53
# Current mean evaluation score 69.07
# Current mean evaluation score 69.49
# Current mean evaluation score 69.88
# Current mean evaluation score 70.27
# Current mean evaluation score 70.63
# Current mean evaluation score 70.99
# Current mean evaluation score 71.35
# Current mean evaluation score 71.71
# Current mean evaluation score 72.07
# Current mean evaluation score 72.43
# Current mean evaluation score 72.79
# Current mean evaluation score 73.15
# Current mean evaluation score 73.49
# Current mean evaluation score 73.72
# Current mean evaluation score 73.92
# Current mean evaluation score 74.07
# Current mean evaluation score 74.19
# Current mean evaluation score 74.25
# Current mean evaluation score 74.3
# Current mean evaluation score 74.34
# Current mean evaluation score 74.44
# Current mean evaluation score 74.54
# Current mean evaluation score 74.64
# Current mean evaluation score 74.74
# Current mean evaluation score 74.84
# Current mean evaluation score 74.94
# Current mean evaluation score 75.17
# Current mean evaluation score 75.4
# Current mean evaluation score 75.63
# Current mean evaluation score 75.92
# Current mean evaluation score 76.21
# Current mean evaluation score 76.52
# Current mean evaluation score 76.97
# Current mean evaluation score 77.46
# Current mean evaluation score 78.0
# Current mean evaluation score 78.58
# Current mean evaluation score 79.16
# Current mean evaluation score 79.64
# Current mean evaluation score 80.22
# Current mean evaluation score 80.8
# Current mean evaluation score 81.38
# Current mean evaluation score 82.03
# Current mean evaluation score 82.71
# Current mean evaluation score 83.39
# Current mean evaluation score 84.13
# Current mean evaluation score 84.81
# Current mean evaluation score 85.47
# Current mean evaluation score 86.19
# Current mean evaluation score 86.91
# Current mean evaluation score 87.55
# Current mean evaluation score 88.19
# Current mean evaluation score 88.83
# Current mean evaluation score 89.53
# Current mean evaluation score 90.25
# Current mean evaluation score 90.96
# Current mean evaluation score 91.71
# Current mean evaluation score 92.53
# Current mean evaluation score 93.37
# Current mean evaluation score 94.25
# Current mean evaluation score 95.16
# Current mean evaluation score 96.08
# Current mean evaluation score 97.02
# Current mean evaluation score 97.98
# Current mean evaluation score 98.95
# Current mean evaluation score 99.92
# Current mean evaluation score 100.89
# Current mean evaluation score 101.87
# Current mean evaluation score 102.85
# Current mean evaluation score 103.83
# Current mean evaluation score 104.81
# Current mean evaluation score 105.79
# Current mean evaluation score 106.85
# Current mean evaluation score 107.91
# Current mean evaluation score 108.99
# Current mean evaluation score 110.19
# Current mean evaluation score 111.44
# Current mean evaluation score 112.75
# Current mean evaluation score 114.42
# Current mean evaluation score 116.06
# Current mean evaluation score 117.43
# Current mean evaluation score 119.06
# Current mean evaluation score 120.6
# Current mean evaluation score 121.95
# Current mean evaluation score 123.89
# Current mean evaluation score 125.71
# Current mean evaluation score 127.39
# Current mean evaluation score 129.04
# Current mean evaluation score 130.67
# Current mean evaluation score 132.28
# Current mean evaluation score 133.85
# Current mean evaluation score 135.44
# Current mean evaluation score 137.11
# Current mean evaluation score 138.74
# Current mean evaluation score 140.36
# Current mean evaluation score 142.02
# Current mean evaluation score 143.7
# Current mean evaluation score 145.05
# Current mean evaluation score 146.26
# Current mean evaluation score 147.48
# Current mean evaluation score 148.47
# Current mean evaluation score 149.46
# Current mean evaluation score 150.57
# Current mean evaluation score 151.74
# Current mean evaluation score 153.2
# Current mean evaluation score 154.68
# Current mean evaluation score 156.27
# Current mean evaluation score 157.7
# Current mean evaluation score 159.36
# Current mean evaluation score 161.49
# Current mean evaluation score 163.77
# Current mean evaluation score 166.01
# Current mean evaluation score 168.29
# Current mean evaluation score 170.65
# Current mean evaluation score 173.06
# Current mean evaluation score 175.41
# Current mean evaluation score 177.75
# Current mean evaluation score 180.0
# Current mean evaluation score 182.39
# Current mean evaluation score 184.85
# Current mean evaluation score 187.35
# Current mean evaluation score 189.87
# Current mean evaluation score 192.56
# Current mean evaluation score 195.31
# Current mean evaluation score 198.3
# Current mean evaluation score 202.53
# Current mean evaluation score 206.76
# Current mean evaluation score 209.94
# Current mean evaluation score 213.25
# Current mean evaluation score 217.35
# Current mean evaluation score 220.85
# Current mean evaluation score 224.89
# Current mean evaluation score 228.73
# Current mean evaluation score 232.71
# Current mean evaluation score 236.65
# Current mean evaluation score 240.54
# Current mean evaluation score 244.22
# Current mean evaluation score 247.81
# Current mean evaluation score 251.29
# Current mean evaluation score 254.65
# Current mean evaluation score 258.04
# Current mean evaluation score 261.42
# Current mean evaluation score 264.53
# Current mean evaluation score 267.43
# Current mean evaluation score 270.2
# Current mean evaluation score 272.96
# Current mean evaluation score 275.86
# Current mean evaluation score 278.76
# Current mean evaluation score 281.71
# Current mean evaluation score 285.31
# Current mean evaluation score 288.96
# Current mean evaluation score 292.61
# Current mean evaluation score 296.26
# Current mean evaluation score 299.84
# Current mean evaluation score 303.39
# Current mean evaluation score 306.86
# Current mean evaluation score 310.17
# Current mean evaluation score 313.52
# Current mean evaluation score 316.71
# Current mean evaluation score 319.72
# Current mean evaluation score 322.65
# Current mean evaluation score 324.81
# Current mean evaluation score 326.8
# Current mean evaluation score 328.66
# Current mean evaluation score 330.49
# Current mean evaluation score 331.87
# Current mean evaluation score 333.27
# Current mean evaluation score 335.2
# Current mean evaluation score 337.31
# Current mean evaluation score 339.44
# Current mean evaluation score 341.72
# Current mean evaluation score 344.05
# Current mean evaluation score 345.8
# Current mean evaluation score 347.4
# Current mean evaluation score 348.77
# Current mean evaluation score 350.05
# Current mean evaluation score 351.19
# Current mean evaluation score 352.32
# Current mean evaluation score 353.08
# Current mean evaluation score 353.9
# Current mean evaluation score 354.96
# Current mean evaluation score 355.9
# Current mean evaluation score 357.03
# Current mean evaluation score 358.48
# Current mean evaluation score 359.47
# Current mean evaluation score 360.61
# Current mean evaluation score 362.06
# Current mean evaluation score 364.62
# Current mean evaluation score 367.17
# Current mean evaluation score 369.74
# Current mean evaluation score 372.31
# Current mean evaluation score 374.86
# Current mean evaluation score 377.33
# Current mean evaluation score 379.8
# Current mean evaluation score 382.28
# Current mean evaluation score 384.72
# Current mean evaluation score 386.75
# Current mean evaluation score 388.72
# Current mean evaluation score 391.48
# Current mean evaluation score 393.17
# Current mean evaluation score 395.04
# Current mean evaluation score 396.9
# Current mean evaluation score 398.79
# Current mean evaluation score 400.63
# Current mean evaluation score 402.33
# Current mean evaluation score 404.15
# Current mean evaluation score 406.08
# Current mean evaluation score 408.43
# Current mean evaluation score 410.52
# Current mean evaluation score 412.18
# Current mean evaluation score 414.0
# Current mean evaluation score 415.22
# Current mean evaluation score 416.22
# Current mean evaluation score 416.88
# Current mean evaluation score 417.23
# Current mean evaluation score 417.53
# Current mean evaluation score 417.74
# Current mean evaluation score 417.99
# Current mean evaluation score 418.1
# Current mean evaluation score 418.02
# Current mean evaluation score 417.85
# Current mean evaluation score 417.54
# Current mean evaluation score 416.88
# Current mean evaluation score 416.02
# Current mean evaluation score 414.8
# Current mean evaluation score 412.26
# Current mean evaluation score 409.69
# Current mean evaluation score 408.0
# Current mean evaluation score 406.15
# Current mean evaluation score 403.48
# Current mean evaluation score 401.38
# Current mean evaluation score 398.72
# Current mean evaluation score 396.26
# Current mean evaluation score 393.64
# Current mean evaluation score 391.07
# Current mean evaluation score 388.48
# Current mean evaluation score 386.05
# Current mean evaluation score 383.68
# Current mean evaluation score 381.4
# Current mean evaluation score 379.23
# Current mean evaluation score 377.0
# Current mean evaluation score 374.77
# Current mean evaluation score 372.74
# Current mean evaluation score 370.93
# Current mean evaluation score 369.19
# Current mean evaluation score 367.35
# Current mean evaluation score 365.08
# Current mean evaluation score 362.81
# Current mean evaluation score 360.42
# Current mean evaluation score 357.38
# Current mean evaluation score 354.15
# Current mean evaluation score 350.88
# Current mean evaluation score 347.61
# Current mean evaluation score 344.35
# Current mean evaluation score 341.1
# Current mean evaluation score 337.94
# Current mean evaluation score 334.9
# Current mean evaluation score 331.82
# Current mean evaluation score 328.88
# Current mean evaluation score 326.08
# Current mean evaluation score 323.34
# Current mean evaluation score 321.36
# Current mean evaluation score 319.52
# Current mean evaluation score 317.72
# Current mean evaluation score 315.89
# Current mean evaluation score 314.5
# Current mean evaluation score 313.09
# Current mean evaluation score 311.14
# Current mean evaluation score 308.9
# Current mean evaluation score 306.64
# Current mean evaluation score 304.23
# Current mean evaluation score 301.75
# Current mean evaluation score 299.77
# Current mean evaluation score 297.94
# Current mean evaluation score 296.41
# Current mean evaluation score 294.87
# Current mean evaluation score 293.42
# Current mean evaluation score 291.93
# Current mean evaluation score 290.46
# Current mean evaluation score 288.93
# Current mean evaluation score 287.63
# Current mean evaluation score 286.22
# Current mean evaluation score 284.72
# Current mean evaluation score 283.27
# Current mean evaluation score 281.74
# Current mean evaluation score 280.56
# Current mean evaluation score 279.27
# Current mean evaluation score 276.94
# Current mean evaluation score 274.68
# Current mean evaluation score 272.52
# Current mean evaluation score 270.39
# Current mean evaluation score 268.4
# Current mean evaluation score 266.44
# Current mean evaluation score 264.54
# Current mean evaluation score 262.65
# Current mean evaluation score 260.65
# Current mean evaluation score 259.03
# Current mean evaluation score 257.78
# Current mean evaluation score 255.73
# Current mean evaluation score 254.68
# Current mean evaluation score 253.59
# Current mean evaluation score 252.49
# Current mean evaluation score 251.34
# Current mean evaluation score 250.21
# Current mean evaluation score 248.89
# Current mean evaluation score 247.45
# Current mean evaluation score 245.86
# Current mean evaluation score 244.0
# Current mean evaluation score 242.27
# Current mean evaluation score 240.5
# Current mean evaluation score 238.45
# Current mean evaluation score 237.08
# Current mean evaluation score 235.91
# Current mean evaluation score 235.05
# Current mean evaluation score 234.56
# Current mean evaluation score 234.2
# Current mean evaluation score 233.99
# Current mean evaluation score 233.79
# Current mean evaluation score 233.74
# Current mean evaluation score 233.83
# Current mean evaluation score 234.09
# Current mean evaluation score 234.31
# Current mean evaluation score 234.74
# Current mean evaluation score 235.32
# Current mean evaluation score 236.14
# Current mean evaluation score 236.96
# Current mean evaluation score 237.83
# Current mean evaluation score 238.8
# Current mean evaluation score 239.79
# Current mean evaluation score 240.9
# Current mean evaluation score 241.98
# Current mean evaluation score 243.15
# Current mean evaluation score 244.46
# Current mean evaluation score 245.81
# Current mean evaluation score 247.22
# Current mean evaluation score 248.85
# Current mean evaluation score 250.69
# Current mean evaluation score 252.79
# Current mean evaluation score 255.26
# Current mean evaluation score 257.92
# Current mean evaluation score 260.61
# Current mean evaluation score 263.31
# Current mean evaluation score 266.01
# Current mean evaluation score 268.67
# Current mean evaluation score 271.39
# Current mean evaluation score 274.16
# Current mean evaluation score 277.28
# Current mean evaluation score 280.4
# Current mean evaluation score 283.53
# Current mean evaluation score 286.66
# Current mean evaluation score 289.89
# Current mean evaluation score 293.16
# Current mean evaluation score 296.43
# Current mean evaluation score 299.7
# Current mean evaluation score 302.97
# Current mean evaluation score 306.24
# Current mean evaluation score 309.51
# Current mean evaluation score 312.78
# Current mean evaluation score 316.05
# Current mean evaluation score 319.32
# Current mean evaluation score 322.59
# Current mean evaluation score 325.86
# Current mean evaluation score 329.13
# Current mean evaluation score 332.4
# Current mean evaluation score 335.72
# Current mean evaluation score 339.05
# Current mean evaluation score 342.38
# Current mean evaluation score 345.71
# Current mean evaluation score 349.15
# Current mean evaluation score 352.59
# Current mean evaluation score 356.03
# Current mean evaluation score 359.47
# Current mean evaluation score 362.91
# Current mean evaluation score 366.35
# Current mean evaluation score 369.67
# Current mean evaluation score 372.97
# Current mean evaluation score 376.27
# Current mean evaluation score 379.56
# Current mean evaluation score 382.84
# Current mean evaluation score 386.12
# Current mean evaluation score 389.2
# Current mean evaluation score 392.25
# Current mean evaluation score 395.29
# Current mean evaluation score 398.15
# Current mean evaluation score 400.96
# Current mean evaluation score 403.39
# Current mean evaluation score 405.76
# Current mean evaluation score 408.09
# Current mean evaluation score 410.35
# Current mean evaluation score 412.51
# Current mean evaluation score 414.64
# Current mean evaluation score 416.63
# Current mean evaluation score 418.59
# Current mean evaluation score 420.49
# Current mean evaluation score 422.38
# Current mean evaluation score 424.38
# Current mean evaluation score 426.39
# Current mean evaluation score 428.42
# Current mean evaluation score 430.47
# Current mean evaluation score 432.58
# Current mean evaluation score 434.76
# Current mean evaluation score 436.96
# Current mean evaluation score 439.18
# Current mean evaluation score 441.4
# Current mean evaluation score 443.66
# Current mean evaluation score 445.9
# Current mean evaluation score 448.07
# Current mean evaluation score 450.25
# Current mean evaluation score 452.33
# Current mean evaluation score 454.41
# Current mean evaluation score 456.46
# Current mean evaluation score 458.47
# Current mean evaluation score 460.46
# Current mean evaluation score 462.42
# Current mean evaluation score 464.38
# Current mean evaluation score 466.32
# Current mean evaluation score 468.21
# Current mean evaluation score 470.14
# Current mean evaluation score 471.98
# Current mean evaluation score 473.8
# Current mean evaluation score 475.5
# Goal mean reward is reached
# Final evaluation score: 500.0
# Starting a new REINFORCE agent.
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.0
# Current mean evaluation score 10.054054054054054
# Current mean evaluation score 10.210526315789474
# Current mean evaluation score 10.384615384615385
# Current mean evaluation score 10.75
# Current mean evaluation score 11.195121951219512
# Current mean evaluation score 11.666666666666666
# Current mean evaluation score 12.162790697674419
# Current mean evaluation score 12.659090909090908
# Current mean evaluation score 13.133333333333333
# Current mean evaluation score 13.608695652173912
# Current mean evaluation score 14.085106382978724
# Current mean evaluation score 14.541666666666666
# Current mean evaluation score 15.061224489795919
# Current mean evaluation score 15.74
# Current mean evaluation score 16.627450980392158
# Current mean evaluation score 17.48076923076923
# Current mean evaluation score 18.30188679245283
# Current mean evaluation score 19.09259259259259
# Current mean evaluation score 19.854545454545455
# Current mean evaluation score 21.875
# Current mean evaluation score 24.105263157894736
# Current mean evaluation score 26.448275862068964
# Current mean evaluation score 28.694915254237287
# Current mean evaluation score 30.916666666666668
# Current mean evaluation score 32.59016393442623
# Current mean evaluation score 34.774193548387096
# Current mean evaluation score 36.79365079365079
# Current mean evaluation score 38.75
# Current mean evaluation score 40.6
# Current mean evaluation score 40.92424242424242
# Current mean evaluation score 41.223880597014926
# Current mean evaluation score 41.51470588235294
# Current mean evaluation score 41.79710144927536
# Current mean evaluation score 42.07142857142857
# Current mean evaluation score 42.352112676056336
# Current mean evaluation score 42.625
# Current mean evaluation score 42.89041095890411
# Current mean evaluation score 43.148648648648646
# Current mean evaluation score 43.4
# Current mean evaluation score 43.53947368421053
# Current mean evaluation score 43.675324675324674
# Current mean evaluation score 43.80769230769231
# Current mean evaluation score 43.936708860759495
# Current mean evaluation score 44.0625
# Current mean evaluation score 44.18518518518518
# Current mean evaluation score 44.30487804878049
# Current mean evaluation score 44.42168674698795
# Current mean evaluation score 44.535714285714285
# Current mean evaluation score 44.64705882352941
# Current mean evaluation score 44.7093023255814
# Current mean evaluation score 44.770114942528735
# Current mean evaluation score 44.82954545454545
# Current mean evaluation score 44.8876404494382
# Current mean evaluation score 44.94444444444444
# Current mean evaluation score 45.0
# Current mean evaluation score 45.05434782608695
# Current mean evaluation score 45.10752688172043
# Current mean evaluation score 45.159574468085104
# Current mean evaluation score 45.21052631578947
# Current mean evaluation score 45.260416666666664
# Current mean evaluation score 45.30927835051546
# Current mean evaluation score 45.357142857142854
# Current mean evaluation score 45.4040404040404
# Current mean evaluation score 45.45
# Current mean evaluation score 45.9
# Current mean evaluation score 46.35
# Current mean evaluation score 46.8
# Current mean evaluation score 47.26
# Current mean evaluation score 47.72
# Current mean evaluation score 48.18
# Current mean evaluation score 48.64
# Current mean evaluation score 49.1
# Current mean evaluation score 49.56
# Current mean evaluation score 50.02
# Current mean evaluation score 50.48
# Current mean evaluation score 50.95
# Current mean evaluation score 51.42
# Current mean evaluation score 51.89
# Current mean evaluation score 52.36
# Current mean evaluation score 52.83
# Current mean evaluation score 53.3
# Current mean evaluation score 53.77
# Current mean evaluation score 54.24
# Current mean evaluation score 54.79
# Current mean evaluation score 55.34
# Current mean evaluation score 55.89
# Current mean evaluation score 56.44
# Current mean evaluation score 56.99
# Current mean evaluation score 57.54
# Current mean evaluation score 58.09
# Current mean evaluation score 58.64
# Current mean evaluation score 59.19
# Current mean evaluation score 59.74
# Current mean evaluation score 60.29
# Current mean evaluation score 60.76
# Current mean evaluation score 61.23
# Current mean evaluation score 61.7
# Current mean evaluation score 62.17
# Current mean evaluation score 62.64
# Current mean evaluation score 63.11
# Current mean evaluation score 63.56
# Current mean evaluation score 63.97
# Current mean evaluation score 64.37
# Current mean evaluation score 64.71
# Current mean evaluation score 65.01
# Current mean evaluation score 65.29
# Current mean evaluation score 65.55
# Current mean evaluation score 65.88
# Current mean evaluation score 66.21
# Current mean evaluation score 66.53
# Current mean evaluation score 66.84
# Current mean evaluation score 67.15
# Current mean evaluation score 67.42
# Current mean evaluation score 67.6
# Current mean evaluation score 67.66
# Current mean evaluation score 67.72
# Current mean evaluation score 67.78
# Current mean evaluation score 67.84
# Current mean evaluation score 67.9
# Current mean evaluation score 67.24
# Current mean evaluation score 66.42
# Current mean evaluation score 65.49
# Current mean evaluation score 64.57
# Current mean evaluation score 63.62
# Current mean evaluation score 62.96
# Current mean evaluation score 61.95
# Current mean evaluation score 61.0
# Current mean evaluation score 60.05
# Current mean evaluation score 59.13
# Current mean evaluation score 59.18
# Current mean evaluation score 59.24
# Current mean evaluation score 59.3
# Current mean evaluation score 59.36
# Current mean evaluation score 59.42
# Current mean evaluation score 59.47
# Current mean evaluation score 59.52
# Current mean evaluation score 59.59
# Current mean evaluation score 59.64
# Current mean evaluation score 59.71
# Current mean evaluation score 59.84
# Current mean evaluation score 59.97
# Current mean evaluation score 60.12
# Current mean evaluation score 60.27
# Current mean evaluation score 60.42
# Current mean evaluation score 60.57
# Current mean evaluation score 60.72
# Current mean evaluation score 60.87
# Current mean evaluation score 61.02
# Current mean evaluation score 61.17
# Current mean evaluation score 61.36
# Current mean evaluation score 62.6
# Current mean evaluation score 63.84
# Current mean evaluation score 65.08
# Current mean evaluation score 66.14
# Current mean evaluation score 67.4
# Current mean evaluation score 68.66
# Current mean evaluation score 69.92
# Current mean evaluation score 70.98
# Current mean evaluation score 72.09
# Current mean evaluation score 73.2
# Current mean evaluation score 74.34
# Current mean evaluation score 75.45
# Current mean evaluation score 76.54
# Current mean evaluation score 77.8
# Current mean evaluation score 79.01
# Current mean evaluation score 80.05
# Current mean evaluation score 81.1
# Current mean evaluation score 82.14
# Current mean evaluation score 83.19
# Current mean evaluation score 84.21
# Current mean evaluation score 85.41
# Current mean evaluation score 86.61
# Current mean evaluation score 87.81
# Current mean evaluation score 88.84
# Current mean evaluation score 89.9
# Current mean evaluation score 90.99
# Current mean evaluation score 92.55
# Current mean evaluation score 94.24
# Current mean evaluation score 95.94
# Current mean evaluation score 97.8
# Current mean evaluation score 99.77
# Current mean evaluation score 101.94
# Current mean evaluation score 104.21
# Current mean evaluation score 106.43
# Current mean evaluation score 108.86
# Current mean evaluation score 111.19
# Current mean evaluation score 113.65
# Current mean evaluation score 116.11
# Current mean evaluation score 118.3
# Current mean evaluation score 120.43
# Current mean evaluation score 122.38
# Current mean evaluation score 124.34
# Current mean evaluation score 125.97
# Current mean evaluation score 127.53
# Current mean evaluation score 129.09
# Current mean evaluation score 130.61
# ...
# Current mean evaluation score 132.7319587628866
# Current mean evaluation score 132.75510204081633
# Current mean evaluation score 132.77777777777777
# Current mean evaluation score 132.8
# Current mean evaluation score 134.05
# Current mean evaluation score 135.3
# Current mean evaluation score 136.55
# Current mean evaluation score 138.67
# Current mean evaluation score 140.72
# Current mean evaluation score 142.68
# Current mean evaluation score 144.35
# Current mean evaluation score 146.11
# Current mean evaluation score 147.55
# Current mean evaluation score 148.96
# Current mean evaluation score 149.56
# Current mean evaluation score 149.87
# Current mean evaluation score 147.79
# Current mean evaluation score 145.71
# Current mean evaluation score 144.64
# Current mean evaluation score 147.47
# Current mean evaluation score 150.7
# Current mean evaluation score 153.97
# Current mean evaluation score 156.81
# Current mean evaluation score 159.68
# Current mean evaluation score 161.73
# Current mean evaluation score 163.74
# Current mean evaluation score 166.56
# Current mean evaluation score 168.34
# Current mean evaluation score 169.97
# Current mean evaluation score 171.55
# Current mean evaluation score 172.98
# Current mean evaluation score 174.38
# Current mean evaluation score 175.53
# Current mean evaluation score 176.63
# Current mean evaluation score 173.38
# Current mean evaluation score 170.14
# Current mean evaluation score 166.79
# Current mean evaluation score 163.34
# Current mean evaluation score 159.85
# Current mean evaluation score 156.34
# Current mean evaluation score 152.93
# Current mean evaluation score 149.52
# Current mean evaluation score 147.64
# Current mean evaluation score 145.55
# Current mean evaluation score 142.5
# Current mean evaluation score 141.58
# Current mean evaluation score 142.65
# Current mean evaluation score 143.77
# Current mean evaluation score 144.94
# Current mean evaluation score 146.15
# Current mean evaluation score 147.38
# Current mean evaluation score 148.88
# Current mean evaluation score 150.38
# Current mean evaluation score 151.93
# Current mean evaluation score 153.5
# Current mean evaluation score 155.26
# Current mean evaluation score 157.68
# Current mean evaluation score 160.77
# Current mean evaluation score 164.03
# Current mean evaluation score 166.38
# Current mean evaluation score 169.63
# Current mean evaluation score 172.04
# Current mean evaluation score 174.45
# Current mean evaluation score 176.74
# Current mean evaluation score 179.01
# Current mean evaluation score 181.57
# Current mean evaluation score 182.63
# Current mean evaluation score 183.69
# Current mean evaluation score 184.75
# Current mean evaluation score 187.37
# Current mean evaluation score 189.99
# Current mean evaluation score 192.74
# Current mean evaluation score 195.33
# Current mean evaluation score 197.96
# Current mean evaluation score 200.59
# Current mean evaluation score 203.22
# Current mean evaluation score 205.85
# Current mean evaluation score 210.16
# Current mean evaluation score 214.76
# Current mean evaluation score 219.36
# Current mean evaluation score 223.92
# Current mean evaluation score 228.47
# Current mean evaluation score 232.95
# Current mean evaluation score 237.43
# Current mean evaluation score 239.7
# Current mean evaluation score 244.0
# Current mean evaluation score 248.29
# Current mean evaluation score 251.38
# Current mean evaluation score 255.11
# Current mean evaluation score 258.84
# Current mean evaluation score 261.31
# Current mean evaluation score 263.74
# Current mean evaluation score 265.99
# Current mean evaluation score 268.44
# Current mean evaluation score 270.71
# Current mean evaluation score 273.03
# Current mean evaluation score 276.68
# Current mean evaluation score 280.33
# Current mean evaluation score 283.98
# Current mean evaluation score 286.02
# Current mean evaluation score 288.01
# Current mean evaluation score 289.59
# Current mean evaluation score 291.35
# Current mean evaluation score 293.11
# Current mean evaluation score 294.13
# Current mean evaluation score 295.15
# Current mean evaluation score 295.97
# Current mean evaluation score 295.21
# Current mean evaluation score 294.18
# Current mean evaluation score 293.13
# Current mean evaluation score 292.06
# Current mean evaluation score 290.93
# Current mean evaluation score 289.7
# Current mean evaluation score 288.41
# Current mean evaluation score 287.07
# Current mean evaluation score 285.68
# Current mean evaluation score 284.34
# Current mean evaluation score 283.05
# Current mean evaluation score 281.84
# Current mean evaluation score 278.65
# Current mean evaluation score 276.64
# Current mean evaluation score 274.77
# Current mean evaluation score 273.45
# Current mean evaluation score 272.23
# Current mean evaluation score 271.98
# Current mean evaluation score 271.85
# Current mean evaluation score 270.87
# Current mean evaluation score 271.12
# Current mean evaluation score 271.67
# Current mean evaluation score 272.29
# Current mean evaluation score 272.95
# Current mean evaluation score 273.85
# Current mean evaluation score 274.83
# Current mean evaluation score 275.85
# Current mean evaluation score 277.15
# Current mean evaluation score 278.43
# Current mean evaluation score 280.22
# Current mean evaluation score 283.16
# Current mean evaluation score 286.65
# Current mean evaluation score 290.16
# Current mean evaluation score 293.69
# Current mean evaluation score 297.22
# Current mean evaluation score 300.75
# Current mean evaluation score 304.27
# Current mean evaluation score 307.64
# Current mean evaluation score 310.92
# Current mean evaluation score 314.17
# Current mean evaluation score 317.39
# Current mean evaluation score 320.56
# Current mean evaluation score 323.69
# Current mean evaluation score 326.8
# Current mean evaluation score 329.8
# Current mean evaluation score 332.8
# Current mean evaluation score 335.75
# Current mean evaluation score 338.68
# Current mean evaluation score 341.42
# Current mean evaluation score 343.5
# Current mean evaluation score 344.91
# Current mean evaluation score 345.76
# Current mean evaluation score 347.5
# Current mean evaluation score 348.14
# Current mean evaluation score 350.21
# Current mean evaluation score 352.28
# Current mean evaluation score 354.49
# Current mean evaluation score 356.7
# Current mean evaluation score 358.64
# Current mean evaluation score 362.14
# Current mean evaluation score 364.46
# Current mean evaluation score 367.76
# Current mean evaluation score 368.12
# Current mean evaluation score 369.19
# Current mean evaluation score 369.43
# Current mean evaluation score 368.99
# Current mean evaluation score 368.51
# Current mean evaluation score 367.88
# Current mean evaluation score 367.43
# Current mean evaluation score 366.73
# Current mean evaluation score 364.31
# Current mean evaluation score 361.35
# Current mean evaluation score 358.39
# Current mean evaluation score 355.41
# Current mean evaluation score 352.38
# Current mean evaluation score 349.28
# Current mean evaluation score 346.13
# Current mean evaluation score 344.92
# Current mean evaluation score 341.73
# Current mean evaluation score 338.53
# Current mean evaluation score 335.33
# Current mean evaluation score 332.22
# Current mean evaluation score 329.11
# Current mean evaluation score 327.26
# Current mean evaluation score 325.41
# Current mean evaluation score 323.76
# Current mean evaluation score 321.91
# Current mean evaluation score 320.24
# Current mean evaluation score 318.43
# Current mean evaluation score 315.23
# Current mean evaluation score 312.12
# Current mean evaluation score 309.01
# Current mean evaluation score 307.51
# Current mean evaluation score 306.06
# Current mean evaluation score 305.02
# Current mean evaluation score 303.8
# Current mean evaluation score 302.58
# Current mean evaluation score 302.1
# Current mean evaluation score 301.62
# Current mean evaluation score 301.34
# Current mean evaluation score 301.07
# Current mean evaluation score 301.07
# Current mean evaluation score 301.09
# Current mean evaluation score 301.13
# Current mean evaluation score 301.23
# Current mean evaluation score 301.43
# Current mean evaluation score 301.69
# Current mean evaluation score 302.0
# Current mean evaluation score 302.36
# Current mean evaluation score 302.67
# Current mean evaluation score 302.93
# Current mean evaluation score 303.17
# Current mean evaluation score 303.31
# Current mean evaluation score 303.41
# Current mean evaluation score 303.49
# Current mean evaluation score 303.55
# Current mean evaluation score 303.65
# Current mean evaluation score 303.68
# Current mean evaluation score 303.66
# Current mean evaluation score 303.66
# Current mean evaluation score 303.82
# Current mean evaluation score 304.2
# Current mean evaluation score 304.4
# Current mean evaluation score 304.61
# Current mean evaluation score 305.01
# Current mean evaluation score 305.51
# Current mean evaluation score 306.17
# Current mean evaluation score 306.47
# Current mean evaluation score 306.74
# Current mean evaluation score 306.02
# Current mean evaluation score 304.75
# Current mean evaluation score 302.53
# Current mean evaluation score 300.3
# Current mean evaluation score 298.35
# Current mean evaluation score 295.72
# Current mean evaluation score 293.09
# Current mean evaluation score 290.46
# Current mean evaluation score 287.71
# Current mean evaluation score 284.76
# Current mean evaluation score 281.81
# Current mean evaluation score 278.86
# Current mean evaluation score 275.91
# Current mean evaluation score 272.86
# Current mean evaluation score 269.81
# Current mean evaluation score 266.76
# Current mean evaluation score 263.71
# Current mean evaluation score 260.66
# Current mean evaluation score 257.61
# Current mean evaluation score 254.56
# Current mean evaluation score 251.51
# Current mean evaluation score 248.46
# Current mean evaluation score 245.8
# Current mean evaluation score 243.14
# Current mean evaluation score 240.68
# Current mean evaluation score 237.73
# Current mean evaluation score 234.78
# Current mean evaluation score 231.83
# Current mean evaluation score 228.88
# Current mean evaluation score 225.93
# Current mean evaluation score 222.98
# Current mean evaluation score 221.21
# Current mean evaluation score 218.46
# Current mean evaluation score 217.09
# Current mean evaluation score 215.01
# Current mean evaluation score 213.67
# Current mean evaluation score 213.17
# Current mean evaluation score 212.67
# Current mean evaluation score 212.32
# Current mean evaluation score 211.79
# Current mean evaluation score 211.42
# Current mean evaluation score 211.08
# Current mean evaluation score 210.97
# Current mean evaluation score 210.84
# Current mean evaluation score 210.69
# Current mean evaluation score 210.59
# Current mean evaluation score 210.56
# Current mean evaluation score 210.58
# Current mean evaluation score 210.73
# Current mean evaluation score 210.85
# Current mean evaluation score 211.01
# Current mean evaluation score 211.38
# Current mean evaluation score 211.84
# Current mean evaluation score 212.32
# Current mean evaluation score 212.8
# Current mean evaluation score 213.28
# Current mean evaluation score 213.76
# Current mean evaluation score 214.24
# Current mean evaluation score 214.72
# Current mean evaluation score 215.53
# Current mean evaluation score 216.72
# Current mean evaluation score 217.6
# Current mean evaluation score 220.71
# Current mean evaluation score 223.82
# Current mean evaluation score 226.93
# Current mean evaluation score 230.04
# Current mean evaluation score 233.15
# Current mean evaluation score 236.26
# Current mean evaluation score 239.37
# Current mean evaluation score 242.48
# Current mean evaluation score 245.59
# Current mean evaluation score 248.7
# Current mean evaluation score 251.81
# Current mean evaluation score 254.92
# Current mean evaluation score 258.03
# Current mean evaluation score 261.14
# Current mean evaluation score 264.25
# Current mean evaluation score 266.6
# Current mean evaluation score 268.53
# Current mean evaluation score 269.81
# Current mean evaluation score 270.7
# Current mean evaluation score 271.58
# Current mean evaluation score 272.48
# Current mean evaluation score 273.38
# Current mean evaluation score 274.28
# Current mean evaluation score 275.3
# Current mean evaluation score 276.32
# Current mean evaluation score 276.88
# Current mean evaluation score 277.44
# Current mean evaluation score 277.97
# Current mean evaluation score 278.48
# Current mean evaluation score 278.97
# Current mean evaluation score 278.73
# Current mean evaluation score 278.57
# Current mean evaluation score 278.39
# Current mean evaluation score 277.82
# Current mean evaluation score 277.64
# Current mean evaluation score 277.31
# Current mean evaluation score 277.06
# Current mean evaluation score 276.87
# Current mean evaluation score 277.28
# Current mean evaluation score 277.21
# Current mean evaluation score 278.1
# Current mean evaluation score 279.17
# Current mean evaluation score 279.23
# Current mean evaluation score 279.97
# Current mean evaluation score 281.52
# Current mean evaluation score 282.97
# Current mean evaluation score 285.72
# Current mean evaluation score 288.67
# Current mean evaluation score 291.62
# Current mean evaluation score 294.57
# Current mean evaluation score 297.52
# Current mean evaluation score 300.57
# Current mean evaluation score 303.62
# Current mean evaluation score 306.67
# Current mean evaluation score 309.72
# Current mean evaluation score 312.77
# Current mean evaluation score 315.82
# Current mean evaluation score 318.87
# Current mean evaluation score 321.92
# Current mean evaluation score 324.97
# Current mean evaluation score 328.02
# Current mean evaluation score 331.07
# Current mean evaluation score 334.12
# Current mean evaluation score 337.07
# Current mean evaluation score 340.02
# Current mean evaluation score 342.97
# Current mean evaluation score 345.92
# Current mean evaluation score 348.87
# Current mean evaluation score 351.82
# Current mean evaluation score 354.77
# Current mean evaluation score 357.72
# Current mean evaluation score 360.67
# Current mean evaluation score 363.62
# Current mean evaluation score 366.57
# Current mean evaluation score 369.52
# Current mean evaluation score 372.47
# Current mean evaluation score 375.42
# Current mean evaluation score 378.37
# Current mean evaluation score 381.41
# Current mean evaluation score 384.46
# Current mean evaluation score 387.53
# Current mean evaluation score 390.62
# Current mean evaluation score 393.75
# Current mean evaluation score 396.88
# Current mean evaluation score 400.01
# Current mean evaluation score 403.14
# Current mean evaluation score 406.25
# Current mean evaluation score 409.32
# Current mean evaluation score 412.36
# Current mean evaluation score 415.19
# Current mean evaluation score 417.84
# Current mean evaluation score 420.47
# Current mean evaluation score 423.1
# Current mean evaluation score 425.73
# Current mean evaluation score 428.36
# Current mean evaluation score 430.99
# Current mean evaluation score 433.62
# Current mean evaluation score 436.01
# Current mean evaluation score 438.02
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 440.25
# Current mean evaluation score 441.01
# Current mean evaluation score 442.19
# Current mean evaluation score 444.02
# Current mean evaluation score 446.24
# Current mean evaluation score 448.47
# Current mean evaluation score 450.62
# Current mean evaluation score 452.77
# Current mean evaluation score 454.92
# Current mean evaluation score 456.95
# Current mean evaluation score 458.98
# Current mean evaluation score 461.37
# Current mean evaluation score 463.76
# Current mean evaluation score 466.15
# Current mean evaluation score 468.54
# Current mean evaluation score 470.51
# Current mean evaluation score 472.81
# Current mean evaluation score 475.15
# Goal mean reward is reached
# Final evaluation score: 465.15

# %% [markdown]
# # Saved the model

# %%
current_best_agent.model.save_weights("/content/drive/MyDrive/Tensorflow/REINFORCE/REINFORCE.ckpt")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Visualization

# %% [markdown]
# Let's plot the mean of rewards our best agent has collected during the training process:

# %%
import matplotlib.pyplot as plt

plt.plot(reinforce_agent.mean_eval_scores)
plt.xlabel("Epochs")
plt.ylabel("Mean evaluation score")
plt.title("Training Process")
plt.show()

# %% [markdown]
# # Let our REINFORCE agent play CartPole

# %%
import os
import imageio
from PIL import Image as Im
import PIL.ImageDraw as ImageDraw
from IPython import display

# %%
def create_gif(env, episodes):
  # list to keep track of frames
  frames = []

  for episode in range(0, episodes):
    # get the initial state
    state = env.reset()

    # for each timestep, do the following
    for t in range(500):
      # select an action from the probability distribution
      action = reinforce_agent.model.select_greedy_action(state)

      # get the frame & store it
      frame = env.render(mode='rgb_array')

      # prepare the frame
      im = Im.fromarray(frame)
      drawer = ImageDraw.Draw(im)
      if np.mean(im) < 128:
        text_color = (255,255,255)
      else:
        text_color = (0,0,0)
        drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode}', fill=text_color)
        drawer.text((im.size[0]/20,im.size[1]/8), f'Timestep: {t+1}', fill=text_color)

      # store the frame
      frames.append(im)

      # take the action in the environment
      state, _, is_terminal, _ = env.step(action)

      # if we land at a terminal state, break
      if is_terminal:
        break

    # close the environment
    env.close()

    # create the gif
    imageio.mimwrite(os.path.join('/content/drive/MyDrive/Tensorflow/REINFORCE/Gif/', 'REINFORCE_agent.gif'), frames, duration=20)

# %%
episodes = 5
env = gym.make('CartPole-v1')
create_gif(env, episodes)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(

# %%
from IPython import display
display.Image(open('/content/drive/MyDrive/Tensorflow/REINFORCE/Gif/REINFORCE_agent.gif','rb').read())
